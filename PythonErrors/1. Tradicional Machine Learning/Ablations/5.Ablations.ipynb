# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.56.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.35.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.8.3)

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import re
import shutil
import string
from sklearn.metrics import classification_report
import tensorflow as tf
from keras.models import Model
from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras.optimizers import Adam
from keras.callbacks import EarlyStopping,ModelCheckpoint
from tensorflow.keras.layers import Dense, Input, Dropout, Bidirectional, LSTM, Embedding, BatchNormalization,  Reshape, Conv2D, MaxPool2D, concatenate, Flatten, Activation
import torch
import numpy as np
from transformers import BertTokenizer, BertModel,RobertaTokenizer, RobertaModel
import ast

# %%
# Verificar si la GPU está disponible
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
archivo_3 = '/content/drive/MyDrive/UDENAR/ProyectosGrado/Errol/Ginna/ResultsBERT/DataProgramsandDescriptions-CatRetroalimentacion5000.xlsx'
train_full = pd.read_excel(archivo_3)

# %% [markdown]
# # AST spliter D. Gries form

# %%
class WhileLoopFinder(ast.NodeVisitor):
    def __init__(self, source_code):
        self.source_code = source_code.splitlines()
        self.functions_with_while = []
        self.current_function = None

    def visit_FunctionDef(self, node):
        original_current_function = self.current_function
        self.current_function = {
            "function_name": node.name,
            "has_while_loop": False,
            "pre_while_code_lines": [],
            "while_loops": []
        }

        function_start_line = node.lineno - 1
        function_end_line = (node.end_lineno if hasattr(node, 'end_lineno') else len(self.source_code))
        function_lines = self.source_code[function_start_line:function_end_line]

        found_while = False
        for stmt in node.body:
            if isinstance(stmt, ast.While):
                self.current_function["has_while_loop"] = True
                found_while = True
                try:
                    while_condition = ast.unparse(stmt.test).strip()
                    print("OK condition")
                except AttributeError:
                    print("Error al obtener la condición del while")
                try:
                    while_body_code = ast.unparse(ast.Module(body=stmt.body, type_ignores=[])).strip()
                    print("Ok body")
                except AttributeError:
                    print("Error al obtener el código del cuerpo del while")

                self.current_function["while_loops"].append({
                    "condition": while_condition,
                    "body_code": while_body_code
                })
            elif not found_while:
                start_line = stmt.lineno - 1
                end_line = (stmt.end_lineno if hasattr(stmt, 'end_lineno') else stmt.lineno)
                self.current_function["pre_while_code_lines"].extend(self.source_code[start_line:end_line])
            self.generic_visit(stmt)

        if self.current_function["has_while_loop"]:
            last_while_end_line = None
            if self.current_function["while_loops"]:
                last_while_node = next((node for node in reversed(node.body) if isinstance(node, ast.While)), None)
                if last_while_node and hasattr(last_while_node, 'end_lineno'):
                    last_while_end_line = last_while_node.end_lineno
            post_while_code_lines = []
            if last_while_end_line:
                function_indent = len(self.source_code[node.lineno - 1]) - len(self.source_code[node.lineno - 1].lstrip())
                for line in self.source_code[last_while_end_line:function_end_line]:
                    if line.startswith(self.source_code[node.lineno - 1][:function_indent] + "    "):
                        post_while_code_lines.append(line[function_indent + 4:])
                    else:
                        post_while_code_lines.append(line[function_indent:])
            self.current_function["post_while_code_lines"] = "\n".join(post_while_code_lines).strip()
            self.current_function["pre_while_code_lines"] = "\n".join(self.current_function["pre_while_code_lines"]).strip()
            self.functions_with_while.append(self.current_function)

        self.current_function = original_current_function

# %%
def DGries_states(solution):
  try:
    # Crear el AST
    tree = ast.parse(solution)
    # Recorrer el AST con nuestro visitante
    finder = WhileLoopFinder(solution)
    finder.visit(tree)
    for func_info in finder.functions_with_while:
      initial_state=func_info["pre_while_code_lines"] if func_info["pre_while_code_lines"] else False
      end_state=""
      transformation_state=""
      for j, wl in enumerate(func_info["while_loops"]):
          end_state=wl["condition"]
          transformation_state=wl["body_code"]

      if not initial_state:
        initial_state=transformation_state
      return initial_state,transformation_state,end_state
  except Exception as error:
    return "Exception:"+str(error),"Exception:"+str(error),"Exception:"+str(error)

# %% [markdown]
# # Encoder Description and Code

# %%
class EncodeTextSource:
  def __init__(self):
    self.is_loadtokenizers=False



  def tokenize_and_generate_embeddings_descriptions(self,description):
    if not self.is_loadtokenizers:
      raise ValueError("tokenizers dont load")
    # Tokenize input description and move tokens to GPU
    tokens = self.beart_tokenizer.encode_plus(description, return_tensors="pt", truncation=True)
    tokens = {key: value.to(device) for key, value in tokens.items()}
    # Generate embeddings
    with torch.no_grad():
        outputs = self.beart_model(**tokens)
    # Extract embeddings for all tokens
    desc_embeddings = outputs.last_hidden_state.cpu().numpy()
    return desc_embeddings

  def tokenize_and_generate_embeddings_codes(self,code):
    if not self.is_loadtokenizers:
      raise ValueError("tokenizers dont load")
    # Tokenize input code and move tokens to GPU
    tokens = self.beart_tokenizer.encode_plus(code, return_tensors="pt", truncation=True)
    tokens = {key: value.to(device) for key, value in tokens.items()}
    # Generate embeddings
    with torch.no_grad():
        outputs = self.codebeart_model(**tokens)
    # Extract embeddings for all tokens
    code_embeddings = outputs.last_hidden_state.cpu().numpy()

    return code_embeddings

  def load_beart_tokenizer(self):
    # Verificar si la GPU está disponible
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Cargar el tokenizer y el modelo en la GPU si está disponible
    model_name = "bert-base-uncased"
    self.beart_model = BertModel.from_pretrained(model_name)
    self.beart_tokenizer = BertTokenizer.from_pretrained(model_name)
    self.beart_model.to(device)

  def load_codebert_tokenizer(self):
    # Verificar si la GPU está disponible
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Cargar el tokenizer y el modelo en la GPU si está disponible
    self.codebeart_tokenizer = RobertaTokenizer.from_pretrained("microsoft/codebert-base")
    self.codebeart_model = RobertaModel.from_pretrained("microsoft/codebert-base")
    self.codebeart_model.to(device)

  def start_tokenizer(self):
    self.load_beart_tokenizer()
    self.load_codebert_tokenizer()
    self.is_loadtokenizers=True

# %% [markdown]
# # All characteristics

# %%
def categoricallabelAll(w):
  if w=="['Correct']":
    return 0
  if w=="['Initial state']":
    return 1
  if w=="['Final state']":
    return 2
  if w=="['State transformation']":
    return 3
  if w=="['Initial state', 'Final state']":
    return 4
  if w=="['Initial state', 'State transformation']":
    return 5
  if w=="['Final state', 'State transformation']":
    return 6
  if w=="['Initial state', 'Final state', 'State transformation']":
    return 7
  return 8

category=np.array([
    'Correct',
    'Initial state',
    'Final state',
    'State transformation',
    'Initial state, Final state',
    'Initial state, State transformation',
    'Final state, State transformation',
    'Initial state, Final state, State transformation'

])

# %% [markdown]
# # Load Dataset

# %%
train_full.head()
# Out:
#    No.                                           Problema  \
# 0    1  Write a Python function that returns the facto...
# 1    2  Write a Python function that returns the sum o...
# 2    3  Write a Python function that prints the number...
# 3    4  Write a Python function to print the numbers f...
# 4    5  Write a Python function to check if a number i...
#
#                                             Solución  \
# 0  def factorial(n):\n    result = 1\n    i = 1\n...
# 1  def sum_1_to_100():\n    total = 0\n    i = 1\...
# 2  def print_and_store():\n    numbers = []\n    ...
# 3  def print_and_store_reverse():\n    numbers = ...
# 4  def is_prime(num):\n    if num <= 1:\n        ...
#
#                  Estado incial Estado final  \
# 0            result = 1, i = 1       i <= n
# 1    total = 0, i = 1, n = 100       i <= n
# 2  numbers = [], i = 0, n = 10       i <= n
# 3  numbers = [], i = 10, n = 1       i >= n
# 4              i = 2, i = = 0:  i <= num//2
#
#                      Transformación de estado Etiqueta 1   Etiqueta 2  \
# 0                         result *= i, i += 1    Correct  ['Correct']
# 1                          total += i, i += 1    Correct  ['Correct']
# 2         print(i), numbers.append(i), i += 1    Correct  ['Correct']
# 3         print(i), numbers.append(i), i -= 1    Correct  ['Correct']
# 4  if num % i == 0:,     return False, i += 1    Correct  ['Correct']
#
#   Realimentación
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
train_full.drop(["No.","Realimentación","Estado incial","Estado final","Transformación de estado"],axis=1,inplace=True)
train_full
# Out:
#                                                Problema  \
# 0     Write a Python function that returns the facto...
# 1     Write a Python function that returns the sum o...
# 2     Write a Python function that prints the number...
# 3     Write a Python function to print the numbers f...
# 4     Write a Python function to check if a number i...
# ...                                                 ...
# 4995  Write a Python function that returns the sum o...
# 4996  Write a Python function that returns the facto...
# 4997  Write a Python function that prints the number...
# 4998  Write a Python function to print the numbers f...
# 4999  Write a Python function that finds the smalles...
#
#                                                Solución Etiqueta 1  \
# 0     def factorial(n):\n    result = 1\n    i = 1\n...    Correct
# 1     def sum_1_to_100():\n    total = 0\n    i = 1\...    Correct
# 2     def print_and_store():\n    numbers = []\n    ...    Correct
# 3     def print_and_store_reverse():\n    numbers = ...    Correct
# 4     def is_prime(num):\n    if num <= 1:\n        ...    Correct
# ...                                                 ...        ...
# 4995  def sum_of_first_five_numbers():\n    number =...  Incorrect
# 4996  def factorial(n):\n    result = 0\n    i = 0\n...  Incorrect
# 4997  def print_and_store_numbers():\n    numbers = ...  Incorrect
# 4998  def print_and_store_numbers():\n    numbers = ...  Incorrect
# 4999  def find_smallest(numbers):\n    smallest = nu...  Incorrect
#
#                             Etiqueta 2
# 0                          ['Correct']
# 1                          ['Correct']
# 2                          ['Correct']
# 3                          ['Correct']
# 4                          ['Correct']
# ...                                ...
# 4995  ['Initial state', 'Final state']
# 4996  ['Initial state', 'Final state']
# 4997  ['Initial state', 'Final state']
# 4998  ['Initial state', 'Final state']
# 4999  ['Initial state', 'Final state']
#
# [5000 rows x 4 columns]

# %%
train_full[["Estado incial","Transformación de estado","Estado final"]]=train_full['Solución'].apply(DGries_states).apply(pd.Series)
# Out:
# Streaming output truncated to the last 5000 lines.
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body

# %%
y=train_full['Etiqueta 2'].apply(categoricallabelAll)
np.unique(y)
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
train_full.dropna(inplace=True)

# %%
np.unique(train_full['Etiqueta 2'])
# Out:
# array(["['Correct']", "['Final state', 'State transformation']",
#        "['Final state']",
#        "['Initial state', 'Final state', 'State transformation']",
#        "['Initial state', 'Final state']",
#        "['Initial state', 'State transformation']", "['Initial state']",
#        "['State transformation']"], dtype=object)

# %%
train_full
# Out:
#                                                Problema  \
# 0     Write a Python function that returns the facto...
# 1     Write a Python function that returns the sum o...
# 2     Write a Python function that prints the number...
# 3     Write a Python function to print the numbers f...
# 4     Write a Python function to check if a number i...
# ...                                                 ...
# 4995  Write a Python function that returns the sum o...
# 4996  Write a Python function that returns the facto...
# 4997  Write a Python function that prints the number...
# 4998  Write a Python function to print the numbers f...
# 4999  Write a Python function that finds the smalles...
#
#                                                Solución Etiqueta 1  \
# 0     def factorial(n):\n    result = 1\n    i = 1\n...    Correct
# 1     def sum_1_to_100():\n    total = 0\n    i = 1\...    Correct
# 2     def print_and_store():\n    numbers = []\n    ...    Correct
# 3     def print_and_store_reverse():\n    numbers = ...    Correct
# 4     def is_prime(num):\n    if num <= 1:\n        ...    Correct
# ...                                                 ...        ...
# 4995  def sum_of_first_five_numbers():\n    number =...  Incorrect
# 4996  def factorial(n):\n    result = 0\n    i = 0\n...  Incorrect
# 4997  def print_and_store_numbers():\n    numbers = ...  Incorrect
# 4998  def print_and_store_numbers():\n    numbers = ...  Incorrect
# 4999  def find_smallest(numbers):\n    smallest = nu...  Incorrect
#
#                             Etiqueta 2  \
# 0                          ['Correct']
# 1                          ['Correct']
# 2                          ['Correct']
# 3                          ['Correct']
# 4                          ['Correct']
# ...                                ...
# 4995  ['Initial state', 'Final state']
# 4996  ['Initial state', 'Final state']
# 4997  ['Initial state', 'Final state']
# 4998  ['Initial state', 'Final state']
# 4999  ['Initial state', 'Final state']
#
#                                       Estado incial  \
# 0                             result = 1\n    i = 1
# 1                 total = 0\n    i = 1\n    n = 100
# 2               numbers = []\n    i = 0\n    n = 10
# 3               numbers = []\n    i = 10\n    n = 1
# 4     if num <= 1:\n        return False\n    i = 2
# ...                                             ...
# 4995   number = 1\n    total_sum = 0\n    count = 1
# 4996                          result = 0\n    i = 0
# 4997                        numbers = []\n    n = 1
# 4998                        numbers = []\n    n = 9
# 4999               smallest = numbers[0]\n    i = 1
#
#                                Transformación de estado      Estado final
# 0                                   result *= i\ni += 1            i <= n
# 1                                    total += i\ni += 1            i <= n
# 2                   print(i)\nnumbers.append(i)\ni += 1            i <= n
# 3                   print(i)\nnumbers.append(i)\ni -= 1            i >= n
# 4            if num % i == 0:\n    return False\ni += 1     i <= num // 2
# ...                                                 ...               ...
# 4995  total_sum = total_sum + number\ncount = count - 1         count < 5
# 4996                                result *= i\ni += 1             i < n
# 4997                print(n)\nnumbers.append(n)\nn += 1           n <= 11
# 4998                print(n)\nnumbers.append(n)\nn -= 1            n >= 0
# 4999  if numbers[i] < smallest:\n    smallest = numb...  i > len(numbers)
#
# [4919 rows x 7 columns]

# %%
encoder=EncodeTextSource()
encoder.start_tokenizer()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/498 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]

# %%
# %%time
problem=train_full['Problema'].apply(encoder.tokenize_and_generate_embeddings_descriptions).to_numpy()
code=train_full['Solución'].apply(encoder.tokenize_and_generate_embeddings_codes).to_numpy()
startstate = train_full['Estado incial'].apply(encoder.tokenize_and_generate_embeddings_codes).to_numpy()
finalstate = train_full['Estado final'].apply(encoder.tokenize_and_generate_embeddings_codes).to_numpy()
transstate = train_full['Transformación de estado'].apply(encoder.tokenize_and_generate_embeddings_codes).to_numpy()
# Out:
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# CPU times: user 3min 11s, sys: 2.53 s, total: 3min 13s
# Wall time: 3min 11s

# %%
problem.shape,code.shape,startstate.shape,finalstate.shape,transstate.shape
# Out:
# ((4919,), (4919,), (4919,), (4919,), (4919,))

# %%
print(startstate.shape)
print(startstate[1262].shape)
# Out:
# (4919,)
# (1, 11, 768)

# %%
Xp=np.array([sentence[0].mean(axis=0) for sentence in problem])
Xcode=np.array([sentence[0].mean(axis=0) for sentence in code])
Xs=np.array([sentence[0].mean(axis=0) for sentence in startstate])
Xf=np.array([sentence[0].mean(axis=0) for sentence in finalstate])
Xt=np.array([sentence[0].mean(axis=0) for sentence in transstate])
Xp.shape,Xs.shape,Xf.shape,Xt.shape
# Out:
# ((4919, 768), (4919, 768), (4919, 768), (4919, 768))

# %%
y=train_full['Etiqueta 2'].apply(categoricallabelAll)
y=y.to_numpy()
np.unique(y)
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
from sklearn.model_selection import train_test_split

Xp_train,Xp_test,Xcode_train,Xcode_test,Xs_train,Xs_test,Xt_train,Xt_test,Xf_train,Xf_test,y_train,y_test=train_test_split(Xp,Xcode,Xs,Xt,Xf,y,test_size=0.2,random_state=2023, stratify=y)

# %%
Xp_train.shape,Xp_test.shape,Xcode_train.shape, Xcode_test.shape, Xs_train.shape,Xs_test.shape,Xt_train.shape,Xt_test.shape,Xf_train.shape,Xf_test.shape,y_train.shape,y_test.shape
# Out:
# ((3935, 768),
#  (984, 768),
#  (3935, 768),
#  (984, 768),
#  (3935, 768),
#  (984, 768),
#  (3935, 768),
#  (984, 768),
#  (3935, 768),
#  (984, 768),
#  (3935,),
#  (984,))

# %%
#random search
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import matthews_corrcoef
#XGBoost
from xgboost import XGBClassifier
#pipeline
from sklearn.pipeline import Pipeline
from sklearn.neural_network import MLPClassifier

# %%
from sklearn.metrics import matthews_corrcoef, precision_recall_curve, auc
from sklearn.preprocessing import label_binarize
import numpy as np

def calculate_mcc_multiclass(y_true, y_pred_probs):
    y_pred_labels = np.argmax(y_pred_probs, axis=1)
    # Convertir etiquetas verdaderas one-hot a etiquetas enteras si es necesario
    #y_true_labels = np.argmax(y_true, axis=1) if y_true.ndim > 1 else y_true
    return matthews_corrcoef(y_true, y_pred_labels)

def calculate_auc_pr_multiclass(y_true, y_pred_probs, average='macro'):
    n_classes = y_pred_probs.shape[1]
    #y_true_labels = np.argmax(y_true, axis=1) if y_true.ndim > 1 else y_true
    y_true_bin = label_binarize(y_true, classes=range(n_classes))

    auc_pr_list = []
    for i in range(n_classes):
        precision, recall, _ = precision_recall_curve(y_true_bin[:, i], y_pred_probs[:, i])
        auc_pr_list.append(auc(recall, precision))

    if average == 'macro':
        return np.mean(auc_pr_list)
    elif average == 'weighted':
        class_counts = y_true_bin.sum(axis=0)
        return np.average(auc_pr_list, weights=class_counts)
    else:
        return auc_pr_list

# %% [markdown]
# # KNN

# %%
from tensorflow.keras.losses import sparse_categorical_crossentropy
from sklearn.ensemble import VotingClassifier,StackingClassifier
from sklearn.linear_model import LogisticRegression

# %%
accuracies_train=[]
accuracies_predict=[]
loss_predict=[]
times_train=[]
times_predict=[]
mccs_predict=[]
aucpr_predict=[]
ml_names=[]
abl_names=[]

# %%
import joblib

# %%
path="/content/drive/MyDrive/UDENAR/ProyectosGrado/Errol/Ginna/1. Tradicional Machine Learning/"

# %%
from time import time
knn=KNeighborsClassifier(n_neighbors=15,p=1,weights='distance')
svm_pipe=Pipeline([
    ('scaler',StandardScaler()),
    ('classifier',SVC(kernel='rbf',gamma=3.359818286283781e-05,C=69.51927961775606,probability=True))
])
mlp_pipe=Pipeline([
    ('scaler',StandardScaler()),
    ('classifier',MLPClassifier(hidden_layer_sizes=(100,100,100),learning_rate='adaptive'))
])

rf=RandomForestClassifier(n_estimators=80,max_depth=15)

vt=VotingClassifier(estimators=[('mlp',mlp_pipe),('rf',rf)],voting='soft')
st=StackingClassifier(estimators=[('mlp',mlp_pipe),('rf',rf)],final_estimator=LogisticRegression())

models=[knn,svm_pipe,mlp_pipe,rf,vt,st]
models_names=["KNN","SVM","MLP","Random Forest","Voting","Stacking"]
ablations_names=["problemall","problem_gries","code_gries","gries","problem_code","code"]

for model,name in zip(models,models_names):
  print(name)
  # Define the full datasets outside the inner loop
  X_train_full = np.concatenate((Xp_train,Xcode_train,Xs_train,Xt_train,Xf_train),axis=1)
  X_test_full = np.concatenate((Xp_test,Xcode_test,Xs_test,Xt_test,Xf_test),axis=1)

  for ablations_name in ablations_names:
    ml_names.append(name)
    abl_names.append(ablations_name)
    print(ablations_name)

    if ablations_name=="problemall":
      X_train = X_train_full
      X_test = X_test_full
    elif ablations_name=="problem_gries":
      X_train=np.concatenate((Xp_train,Xs_train,Xt_train,Xf_train),axis=1)
      X_test=np.concatenate((Xp_test,Xs_test,Xt_test,Xf_test),axis=1) # Corrected X_test construction
    elif ablations_name=="code_gries":
      X_train=np.concatenate((Xcode_train,Xs_train,Xt_train,Xf_train),axis=1)
      X_test=np.concatenate((Xcode_test,Xs_test,Xt_test,Xf_test),axis=1) # Corrected X_test construction
    elif ablations_name=="gries":
      X_train=np.concatenate((Xs_train,Xt_train,Xf_train),axis=1)
      X_test=np.concatenate((Xs_test,Xt_test,Xf_test),axis=1) # Corrected X_test construction
    elif ablations_name=="problem_code":
      X_train=np.concatenate((Xp_train,Xcode_train),axis=1)
      X_test=np.concatenate((Xp_test,Xcode_test),axis=1) # Corrected X_test construction
    elif ablations_name=="code":
      X_train=Xcode_train # Corrected X_train construction
      X_test=Xcode_test # Corrected X_test construction

    time1=time()
    model.fit(X_train,y_train)
    time2=time()
    joblib.dump(model,path+"bert_"+name+"_"+ablations_name+".joblib")
    times_train.append(time2-time1)
    time1=time()
    y_pred=model.predict(X_test)
    time2=time()
    times_predict.append(time2-time1)

    accuracie_train=model.score(X_train,y_train)
    accuracies_train.append(accuracie_train)
    accuracie_test=model.score(X_test,y_test)
    accuracies_predict.append(accuracie_test)
    #sparse_categorical_crossentropy
    y_pred_proba = model.predict_proba(X_test)
    loss=np.mean(sparse_categorical_crossentropy(y_test,y_pred_proba))
    loss_predict.append(loss)
    mcc = matthews_corrcoef(y_test, y_pred)
    mccs_predict.append(mcc)
    auc_pr = calculate_auc_pr_multiclass(y_test, model.predict_proba(X_test))
    aucpr_predict.append(auc_pr)
    print(classification_report(y_test,y_pred))
    print("Accuracy train",accuracie_train)
    print("Accuracy predict",accuracie_test)
    print("Loss",loss)
    print("MCC",mcc)
    print("AUC",auc_pr)
    print("==================================")
# Out:
# KNN
# problemall
#               precision    recall  f1-score   support
#
#            0       0.88      0.79      0.83       292
#            1       0.90      0.93      0.92       198
#            2       0.93      0.96      0.95       197
#            3       0.83      0.92      0.88       197
#            4       1.00      0.96      0.98        26
#            5       0.85      0.68      0.76        25
#            6       1.00      0.86      0.92        28
#            7       0.91      1.00      0.95        21
#
#     accuracy                           0.89       984
#    macro avg       0.91      0.89      0.90       984
# weighted avg       0.89      0.89      0.89       984
#
# Accuracy train 0.9949174078780177
# Accuracy predict 0.8882113821138211
# Loss 0.4710433878580898
# MCC 0.8592937221327646
# AUC 0.9643853939364616
# ==================================
# problem_gries
#               precision    recall  f1-score   support
#
#            0       0.88      0.80      0.84       292
#            1       0.91      0.93      0.92       198
#            2       0.94      0.96      0.95       197
#            3       0.80      0.89      0.84       197
#            4       1.00      0.96      0.98        26
#            5       0.85      0.68      0.76        25
#            6       1.00      0.86      0.92        28
#            7       0.91      1.00      0.95        21
#
#     accuracy                           0.88       984
#    macro avg       0.91      0.89      0.90       984
# weighted avg       0.89      0.88      0.88       984
#
# Accuracy train 0.9913595933926302
# Accuracy predict 0.8841463414634146
# Loss 0.4567268221994221
# MCC 0.8540717022334808
# AUC 0.9631946843773611
# ==================================
# code_gries
#               precision    recall  f1-score   support
#
#            0       0.88      0.79      0.83       292
#            1       0.91      0.93      0.92       198
#            2       0.93      0.96      0.95       197
#            3       0.81      0.91      0.86       197
#            4       1.00      0.96      0.98        26
#            5       0.94      0.68      0.79        25
#            6       1.00      0.86      0.92        28
#            7       0.95      1.00      0.98        21
#
#     accuracy                           0.89       984
#    macro avg       0.93      0.89      0.90       984
# weighted avg       0.89      0.89      0.89       984
#
# Accuracy train 0.9946632782719187
# Accuracy predict 0.8871951219512195
# Loss 0.4656625430891589
# MCC 0.8579456644055461
# AUC 0.9647794093051322
# ==================================
# gries
#               precision    recall  f1-score   support
#
#            0       0.86      0.81      0.84       292
#            1       0.91      0.93      0.92       198
#            2       0.93      0.96      0.95       197
#            3       0.80      0.88      0.84       197
#            4       1.00      0.96      0.98        26
#            5       1.00      0.68      0.81        25
#            6       1.00      0.86      0.92        28
#            7       0.95      1.00      0.98        21
#
#     accuracy                           0.89       984
#    macro avg       0.93      0.89      0.90       984
# weighted avg       0.89      0.89      0.88       984
#
# Accuracy train 0.9903430749682338
# Accuracy predict 0.8851626016260162
# Loss 0.45662678001037993
# MCC 0.8548547134715503
# AUC 0.9634017641509092
# ==================================
# problem_code
#               precision    recall  f1-score   support
#
#            0       0.89      0.73      0.80       292
#            1       0.84      0.93      0.88       198
#            2       0.85      0.95      0.90       197
#            3       0.86      0.90      0.88       197
#            4       1.00      0.96      0.98        26
#            5       0.74      0.68      0.71        25
#            6       1.00      0.86      0.92        28
#            7       0.81      1.00      0.89        21
#
#     accuracy                           0.86       984
#    macro avg       0.87      0.88      0.87       984
# weighted avg       0.87      0.86      0.86       984
#
# Accuracy train 0.9949174078780177
# Accuracy predict 0.8628048780487805
# Loss 0.545388060547345
# MCC 0.8294517817507316
# AUC 0.9601376954093287
# ==================================
# code
#               precision    recall  f1-score   support
#
#            0       0.91      0.77      0.83       292
#            1       0.86      0.94      0.90       198
#            2       0.87      0.95      0.91       197
#            3       0.87      0.90      0.89       197
#            4       0.96      0.96      0.96        26
#            5       0.74      0.68      0.71        25
#            6       1.00      0.86      0.92        28
#            7       0.81      1.00      0.89        21
#
#     accuracy                           0.88       984
#    macro avg       0.88      0.88      0.88       984
# weighted avg       0.88      0.88      0.88       984
#
# Accuracy train 0.9946632782719187
# Accuracy predict 0.8780487804878049
# Loss 0.531353436688384
# MCC 0.8476952914399912
# AUC 0.9617545200801286
# ==================================
# SVM
# problemall
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83       292
#            1       0.89      0.89      0.89       198
#            2       0.92      0.91      0.91       197
#            3       0.79      0.83      0.81       197
#            4       0.96      0.96      0.96        26
#            5       1.00      0.52      0.68        25
#            6       0.86      0.68      0.76        28
#            7       1.00      1.00      1.00        21
#
#     accuracy                           0.86       984
#    macro avg       0.90      0.83      0.86       984
# weighted avg       0.86      0.86      0.86       984
#
# Accuracy train 0.9537484116899618
# Accuracy predict 0.8567073170731707
# Loss 0.43965143129982154
# MCC 0.8175924242048055
# AUC 0.9305192370665201
# ==================================
# problem_gries
#               precision    recall  f1-score   support
#
#            0       0.78      0.82      0.80       292
#            1       0.87      0.89      0.88       198
#            2       0.89      0.87      0.88       197
#            3       0.74      0.77      0.75       197
#            4       0.88      0.85      0.86        26
#            5       1.00      0.48      0.65        25
#            6       0.86      0.64      0.73        28
#            7       1.00      1.00      1.00        21
#
#     accuracy                           0.82       984
#    macro avg       0.88      0.79      0.82       984
# weighted avg       0.83      0.82      0.82       984
#
# Accuracy train 0.921982210927573
# Accuracy predict 0.8221544715447154
# Loss 0.5312096030741608
# MCC 0.7733184915218106
# AUC 0.8974870859813612
# ==================================
# code_gries
#               precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83       292
#            1       0.90      0.89      0.89       198
#            2       0.94      0.91      0.92       197
#            3       0.78      0.82      0.80       197
#            4       0.96      0.96      0.96        26
#            5       1.00      0.52      0.68        25
#            6       0.86      0.68      0.76        28
#            7       1.00      1.00      1.00        21
#
#     accuracy                           0.86       984
#    macro avg       0.91      0.83      0.86       984
# weighted avg       0.86      0.86      0.86       984
#
# Accuracy train 0.9468869123252859
# Accuracy predict 0.8556910569105691
# Loss 0.46078346725549546
# MCC 0.8162433845030332
# AUC 0.9221493469634492
# ==================================
# gries
#               precision    recall  f1-score   support
#
#            0       0.75      0.82      0.78       292
#            1       0.86      0.88      0.87       198
#            2       0.90      0.85      0.88       197
#            3       0.73      0.74      0.73       197
#            4       0.88      0.85      0.86        26
#            5       1.00      0.48      0.65        25
#            6       0.85      0.61      0.71        28
#            7       1.00      1.00      1.00        21
#
#     accuracy                           0.81       984
#    macro avg       0.87      0.78      0.81       984
# weighted avg       0.82      0.81      0.81       984
#
# Accuracy train 0.9161372299872935
# Accuracy predict 0.8109756097560976
# Loss 0.564203233023765
# MCC 0.7589046466604181
# AUC 0.8826535844678702
# ==================================
# problem_code
#               precision    recall  f1-score   support
#
#            0       0.61      0.78      0.69       292
#            1       0.61      0.67      0.64       198
#            2       0.62      0.57      0.60       197
#            3       0.68      0.55      0.61       197
#            4       0.86      0.46      0.60        26
#            5       1.00      0.20      0.33        25
#            6       0.71      0.36      0.48        28
#            7       0.86      0.90      0.88        21
#
#     accuracy                           0.64       984
#    macro avg       0.75      0.56      0.60       984
# weighted avg       0.65      0.64      0.63       984
#
# Accuracy train 0.7336721728081321
# Accuracy predict 0.6382113821138211
# Loss 0.9981947097234307
# MCC 0.5352831431361661
# AUC 0.6912796274126793
# ==================================
# code
#               precision    recall  f1-score   support
#
#            0       0.56      0.76      0.64       292
#            1       0.58      0.61      0.59       198
#            2       0.63      0.56      0.59       197
#            3       0.68      0.52      0.59       197
#            4       1.00      0.27      0.42        26
#            5       1.00      0.04      0.08        25
#            6       0.69      0.32      0.44        28
#            7       0.69      0.86      0.77        21
#
#     accuracy                           0.60       984
#    macro avg       0.73      0.49      0.52       984
# weighted avg       0.63      0.60      0.59       984
#
# Accuracy train 0.6800508259212198
# Accuracy predict 0.6016260162601627
# Loss 1.0631527522290571
# MCC 0.48718370244908127
# AUC 0.6576224677091653
# ==================================
# MLP
# problemall
#               precision    recall  f1-score   support
#
#            0       0.91      0.86      0.89       292
#            1       0.93      0.94      0.94       198
#            2       0.93      0.95      0.94       197
#            3       0.82      0.90      0.86       197
#            4       1.00      1.00      1.00        26
#            5       1.00      0.68      0.81        25
#            6       0.96      0.82      0.88        28
#            7       1.00      1.00      1.00        21
#
#     accuracy                           0.90       984
#    macro avg       0.94      0.89      0.91       984
# weighted avg       0.91      0.90      0.90       984
#
# Accuracy train 0.9819567979669631
# Accuracy predict 0.9044715447154471
# Loss 0.498916
# MCC 0.8792334944827563
# AUC 0.94754019391621
# ==================================
# problem_gries
#               precision    recall  f1-score   support
#
#            0       0.91      0.78      0.84       292
#            1       0.91      0.94      0.93       198
#            2       0.90      0.91      0.90       197
#            3       0.79      0.89      0.84       197
#            4       0.93      0.96      0.94        26
#            5       0.63      0.68      0.65        25
#            6       0.93      0.93      0.93        28
#            7       0.88      1.00      0.93        21
#
#     accuracy                           0.87       984
#    macro avg       0.86      0.89      0.87       984
# weighted avg       0.88      0.87      0.87       984
#
# Accuracy train 0.9700127064803049
# Accuracy predict 0.8739837398373984
# Loss 0.50489634
# MCC 0.8425573142547458
# AUC 0.9352923411210038
# ==================================
# code_gries
#               precision    recall  f1-score   support
#
#            0       0.89      0.87      0.88       292
#            1       0.92      0.93      0.93       198
#            2       0.96      0.94      0.95       197
#            3       0.86      0.91      0.88       197
#            4       0.93      0.96      0.94        26
#            5       1.00      0.68      0.81        25
#            6       0.93      0.93      0.93        28
#            7       1.00      1.00      1.00        21
#
#     accuracy                           0.91       984
#    macro avg       0.94      0.90      0.92       984
# weighted avg       0.91      0.91      0.91       984
#
# Accuracy train 0.9860228716645489
# Accuracy predict 0.9085365853658537
# Loss 0.4395722
# MCC 0.8840494071140569
# AUC 0.9526864167964021
# ==================================
# gries
#               precision    recall  f1-score   support
#
#            0       0.86      0.85      0.86       292
#            1       0.92      0.89      0.91       198
#            2       0.90      0.97      0.93       197
#            3       0.88      0.89      0.88       197
#            4       0.96      0.96      0.96        26
#            5       0.81      0.68      0.74        25
#            6       1.00      0.86      0.92        28
#            7       1.00      1.00      1.00        21
#
#     accuracy                           0.89       984
#    macro avg       0.92      0.89      0.90       984
# weighted avg       0.89      0.89      0.89       984
#
# Accuracy train 0.9781448538754764
# Accuracy predict 0.8932926829268293
# Loss 0.43939742
# MCC 0.8647090886019388
# AUC 0.9382359040485155
# ==================================
# problem_code
#               precision    recall  f1-score   support
#
#            0       0.92      0.86      0.89       292
#            1       0.89      0.95      0.92       198
#            2       0.93      0.95      0.94       197
#            3       0.87      0.90      0.89       197
#            4       1.00      0.96      0.98        26
#            5       0.95      0.80      0.87        25
#            6       1.00      0.93      0.96        28
#            7       0.91      1.00      0.95        21
#
#     accuracy                           0.91       984
#    macro avg       0.93      0.92      0.93       984
# weighted avg       0.91      0.91      0.91       984
#
# Accuracy train 0.9811944091486658
# Accuracy predict 0.9105691056910569
# Loss 0.4726932
# MCC 0.8871527122292117
# AUC 0.9576737704380625
# ==================================
# code
#               precision    recall  f1-score   support
#
#            0       0.91      0.85      0.88       292
#            1       0.93      0.95      0.94       198
#            2       0.91      0.95      0.93       197
#            3       0.86      0.91      0.89       197
#            4       1.00      0.96      0.98        26
#            5       1.00      0.76      0.86        25
#            6       1.00      0.96      0.98        28
#            7       0.91      1.00      0.95        21
#
#     accuracy                           0.91       984
#    macro avg       0.94      0.92      0.93       984
# weighted avg       0.91      0.91      0.91       984
#
# Accuracy train 0.9855146124523507
# Accuracy predict 0.9105691056910569
# Loss 0.4754137
# MCC 0.88703688047556
# AUC 0.9558988891647446
# ==================================
# Random Forest
# problemall
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90       292
#            1       0.95      0.93      0.94       198
#            2       0.95      0.96      0.96       197
#            3       0.88      0.93      0.91       197
#            4       1.00      0.96      0.98        26
#            5       1.00      0.68      0.81        25
#            6       1.00      0.93      0.96        28
#            7       1.00      1.00      1.00        21
#
#     accuracy                           0.93       984
#    macro avg       0.96      0.91      0.93       984
# weighted avg       0.93      0.93      0.93       984
#
# Accuracy train 0.9949174078780177
# Accuracy predict 0.9258130081300813
# Loss 0.3920813441362838
# MCC 0.9058553409575932
# AUC 0.9680443359588172
# ==================================
# problem_gries
#               precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88       292
#            1       0.96      0.93      0.95       198
#            2       0.97      0.96      0.97       197
#            3       0.86      0.90      0.88       197
#            4       0.96      0.96      0.96        26
#            5       1.00      0.64      0.78        25
#            6       1.00      0.93      0.96        28
#            7       1.00      1.00      1.00        21
#
#     accuracy                           0.92       984
#    macro avg       0.95      0.90      0.92       984
# weighted avg       0.92      0.92      0.92       984
#
# Accuracy train 0.9900889453621347
# Accuracy predict 0.915650406504065
# Loss 0.3906358735318845
# MCC 0.8928345635954719
# AUC 0.9627861447897406
# ==================================
# code_gries
#               precision    recall  f1-score   support
#
#            0       0.90      0.89      0.90       292
#            1       0.95      0.94      0.95       198
#            2       0.95      0.96      0.95       197
#            3       0.87      0.93      0.90       197
#            4       1.00      0.96      0.98        26
#            5       1.00      0.64      0.78        25
#            6       1.00      0.86      0.92        28
#            7       1.00      1.00      1.00        21
#
#     accuracy                           0.92       984
#    macro avg       0.96      0.90      0.92       984
# weighted avg       0.92      0.92      0.92       984
#
# Accuracy train 0.9944091486658195
# Accuracy predict 0.9227642276422764
# Loss 0.3943385430276608
# MCC 0.9020109937327669
# AUC 0.9603265332069753
# ==================================
# gries
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89       292
#            1       0.96      0.93      0.95       198
#            2       0.96      0.97      0.97       197
#            3       0.85      0.91      0.88       197
#            4       1.00      0.96      0.98        26
#            5       1.00      0.72      0.84        25
#            6       1.00      0.86      0.92        28
#            7       1.00      1.00      1.00        21
#
#     accuracy                           0.92       984
#    macro avg       0.96      0.91      0.93       984
# weighted avg       0.92      0.92      0.92       984
#
# Accuracy train 0.9898348157560356
# Accuracy predict 0.9186991869918699
# Loss 0.3962486597565182
# MCC 0.8968620058490756
# AUC 0.9618726742286066
# ==================================
# problem_code
#               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89       292
#            1       0.93      0.93      0.93       198
#            2       0.94      0.95      0.95       197
#            3       0.89      0.90      0.90       197
#            4       1.00      0.96      0.98        26
#            5       1.00      0.64      0.78        25
#            6       1.00      0.86      0.92        28
#            7       1.00      1.00      1.00        21
#
#     accuracy                           0.91       984
#    macro avg       0.95      0.89      0.92       984
# weighted avg       0.92      0.91      0.91       984
#
# Accuracy train 0.9944091486658195
# Accuracy predict 0.9136178861788617
# Loss 0.5292221959429088
# MCC 0.8901289497913717
# AUC 0.9538842409821515
# ==================================
# code
#               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89       292
#            1       0.94      0.93      0.94       198
#            2       0.95      0.95      0.95       197
#            3       0.90      0.92      0.91       197
#            4       1.00      0.96      0.98        26
#            5       0.94      0.68      0.79        25
#            6       1.00      0.86      0.92        28
#            7       1.00      1.00      1.00        21
#
#     accuracy                           0.92       984
#    macro avg       0.95      0.90      0.92       984
# weighted avg       0.92      0.92      0.92       984
#
# Accuracy train 0.9946632782719187
# Accuracy predict 0.9197154471544715
# Loss 0.5131228473667472
# MCC 0.8979363905931423
# AUC 0.9468787983197804
# ==================================
# Voting
# problemall
#               precision    recall  f1-score   support
#
#            0       0.91      0.86      0.89       292
#            1       0.90      0.94      0.92       198
#            2       0.97      0.94      0.96       197
#            3       0.85      0.92      0.89       197
#            4       0.96      1.00      0.98        26
#            5       0.94      0.60      0.73        25
#            6       0.88      1.00      0.93        28
#            7       0.95      1.00      0.98        21
#
#     accuracy                           0.91       984
#    macro avg       0.92      0.91      0.91       984
# weighted avg       0.91      0.91      0.91       984
#
# Accuracy train 0.98856416772554
# Accuracy predict 0.9105691056910569
# Loss 0.31898138870077186
# MCC 0.8872025764040226
# AUC 0.963375970639601
# ==================================
# problem_gries
#               precision    recall  f1-score   support
#
#            0       0.90      0.88      0.89       292
#            1       0.93      0.94      0.94       198
#            2       0.95      0.96      0.96       197
#            3       0.84      0.88      0.86       197
#            4       0.96      0.96      0.96        26
#            5       1.00      0.76      0.86        25
#            6       1.00      0.86      0.92        28
#            7       1.00      1.00      1.00        21
#
#     accuracy                           0.91       984
#    macro avg       0.95      0.91      0.92       984
# weighted avg       0.91      0.91      0.91       984
#
# Accuracy train 0.9875476493011436
# Accuracy predict 0.9126016260162602
# Loss 0.29970606596072397
# MCC 0.8891487765621202
# AUC 0.9706108614305262
# ==================================
# code_gries
#               precision    recall  f1-score   support
#
#            0       0.92      0.84      0.87       292
#            1       0.91      0.94      0.93       198
#            2       0.95      0.96      0.95       197
#            3       0.83      0.92      0.88       197
#            4       0.96      1.00      0.98        26
#            5       0.81      0.68      0.74        25
#            6       0.96      0.82      0.88        28
#            7       1.00      1.00      1.00        21
#
#     accuracy                           0.90       984
#    macro avg       0.92      0.90      0.90       984
# weighted avg       0.91      0.90      0.90       984
#
# Accuracy train 0.98856416772554
# Accuracy predict 0.9044715447154471
# Loss 0.3103456551330322
# MCC 0.8798003840075121
# AUC 0.9623276762809162
# ==================================
# gries
#               precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87       292
#            1       0.92      0.91      0.92       198
#            2       0.93      0.96      0.94       197
#            3       0.84      0.91      0.88       197
#            4       0.96      0.96      0.96        26
#            5       0.94      0.68      0.79        25
#            6       0.96      0.86      0.91        28
#            7       1.00      1.00      1.00        21
#
#     accuracy                           0.90       984
#    macro avg       0.93      0.89      0.91       984
# weighted avg       0.90      0.90      0.90       984
#
# Accuracy train 0.9852604828462516
# Accuracy predict 0.899390243902439
# Loss 0.32827691367982753
# MCC 0.8725322558468523
# AUC 0.9537647184397912
# ==================================
# problem_code
#               precision    recall  f1-score   support
#
#            0       0.92      0.84      0.88       292
#            1       0.89      0.95      0.92       198
#            2       0.96      0.95      0.95       197
#            3       0.84      0.90      0.87       197
#            4       1.00      0.96      0.98        26
#            5       0.80      0.64      0.71        25
#            6       0.90      1.00      0.95        28
#            7       0.88      1.00      0.93        21
#
#     accuracy                           0.90       984
#    macro avg       0.90      0.91      0.90       984
# weighted avg       0.90      0.90      0.90       984
#
# Accuracy train 0.9827191867852605
# Accuracy predict 0.9034552845528455
# Loss 0.3844435295586052
# MCC 0.8786847857555048
# AUC 0.952796471299699
# ==================================
# code
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91       292
#            1       0.92      0.92      0.92       198
#            2       0.94      0.95      0.95       197
#            3       0.89      0.91      0.90       197
#            4       1.00      1.00      1.00        26
#            5       1.00      0.76      0.86        25
#            6       1.00      0.93      0.96        28
#            7       0.91      1.00      0.95        21
#
#     accuracy                           0.92       984
#    macro avg       0.95      0.92      0.93       984
# weighted avg       0.92      0.92      0.92       984
#
# Accuracy train 0.993138500635324
# Accuracy predict 0.9217479674796748
# Loss 0.3525879230271454
# MCC 0.9006871953786567
# AUC 0.9646747690272461
# ==================================
# Stacking
# problemall
#               precision    recall  f1-score   support
#
#            0       0.90      0.91      0.91       292
#            1       0.94      0.94      0.94       198
#            2       0.97      0.96      0.97       197
#            3       0.89      0.92      0.91       197
#            4       0.96      0.96      0.96        26
#            5       1.00      0.76      0.86        25
#            6       0.93      0.93      0.93        28
#            7       1.00      1.00      1.00        21
#
#     accuracy                           0.93       984
#    macro avg       0.95      0.92      0.94       984
# weighted avg       0.93      0.93      0.93       984
#
# Accuracy train 0.9939008894536213
# Accuracy predict 0.9298780487804879
# Loss 0.24285636251965367
# MCC 0.9110128904271698
# AUC 0.9752745978515438
# ==================================
# problem_gries
#               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90       292
#            1       0.95      0.94      0.95       198
#            2       0.95      0.96      0.96       197
#            3       0.90      0.89      0.90       197
#            4       0.96      0.96      0.96        26
#            5       1.00      0.68      0.81        25
#            6       1.00      0.86      0.92        28
#            7       1.00      1.00      1.00        21
#
#     accuracy                           0.92       984
#    macro avg       0.96      0.90      0.92       984
# weighted avg       0.92      0.92      0.92       984
#
# Accuracy train 0.990851334180432
# Accuracy predict 0.9227642276422764
# Loss 0.25992323551458213
# MCC 0.9018035158196853
# AUC 0.9665581085632353
# ==================================
# code_gries
#               precision    recall  f1-score   support
#
#            0       0.89      0.92      0.91       292
#            1       0.98      0.94      0.96       198
#            2       0.97      0.96      0.97       197
#            3       0.91      0.94      0.93       197
#            4       0.96      0.96      0.96        26
#            5       1.00      0.76      0.86        25
#            6       0.96      0.86      0.91        28
#            7       1.00      1.00      1.00        21
#
#     accuracy                           0.93       984
#    macro avg       0.96      0.92      0.94       984
# weighted avg       0.94      0.93      0.93       984
#
# Accuracy train 0.9946632782719187
# Accuracy predict 0.9349593495934959
# Loss 0.22887248874498217
# MCC 0.9174340052668329
# AUC 0.9728078211903756
# ==================================
# gries
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.90       292
#            1       0.95      0.94      0.95       198
#            2       0.97      0.96      0.97       197
#            3       0.88      0.89      0.88       197
#            4       0.96      0.96      0.96        26
#            5       1.00      0.68      0.81        25
#            6       1.00      0.86      0.92        28
#            7       1.00      1.00      1.00        21
#
#     accuracy                           0.92       984
#    macro avg       0.95      0.90      0.92       984
# weighted avg       0.92      0.92      0.92       984
#
# Accuracy train 0.9895806861499364
# Accuracy predict 0.9207317073170732
# Loss 0.2662855218735312
# MCC 0.8992151687905311
# AUC 0.9636863120562595
# ==================================
# problem_code
#               precision    recall  f1-score   support
#
#            0       0.89      0.90      0.89       292
#            1       0.95      0.95      0.95       198
#            2       0.95      0.95      0.95       197
#            3       0.89      0.91      0.90       197
#            4       1.00      0.96      0.98        26
#            5       0.85      0.68      0.76        25
#            6       0.96      0.89      0.93        28
#            7       1.00      1.00      1.00        21
#
#     accuracy                           0.92       984
#    macro avg       0.94      0.91      0.92       984
# weighted avg       0.92      0.92      0.92       984
#
# Accuracy train 0.9939008894536213
# Accuracy predict 0.9197154471544715
# Loss 0.2599264072234906
# MCC 0.8980238741972234
# AUC 0.9685450076390525
# ==================================
# code
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90       292
#            1       0.93      0.95      0.94       198
#            2       0.94      0.95      0.94       197
#            3       0.93      0.91      0.92       197
#            4       1.00      0.96      0.98        26
#            5       0.85      0.68      0.76        25
#            6       0.96      0.82      0.88        28
#            7       0.91      1.00      0.95        21
#
#     accuracy                           0.92       984
#    macro avg       0.93      0.90      0.91       984
# weighted avg       0.92      0.92      0.92       984
#
# Accuracy train 0.9936467598475223
# Accuracy predict 0.9207317073170732
# Loss 0.2693399649966624
# MCC 0.8993659190271279
# AUC 0.9646435182178459
# ==================================

# %%
import pandas as pd
df=pd.DataFrame({
    "Model":ml_names,
    "Ablation":abl_names,
    "Accuracy_train":accuracies_train,
    "Accuracy_predict":accuracies_predict,
    "Loss":loss_predict,
    "Time_train":times_train,
    "Time_predict":times_predict,
    "MCC":mccs_predict,
    "AUC":aucpr_predict
})

# %%
df
# Out:
#             Model       Ablation  Accuracy_train  Accuracy_predict      Loss  \
# 0             KNN     problemall        0.994917          0.888211  0.471043
# 1             KNN  problem_gries        0.991360          0.884146  0.456727
# 2             KNN     code_gries        0.994663          0.887195  0.465663
# 3             KNN          gries        0.990343          0.885163  0.456627
# 4             KNN   problem_code        0.994917          0.862805  0.545388
# 5             KNN           code        0.994663          0.878049  0.531353
# 6             SVM     problemall        0.953748          0.856707  0.439651
# 7             SVM  problem_gries        0.921982          0.822154  0.531210
# 8             SVM     code_gries        0.946887          0.855691  0.460783
# 9             SVM          gries        0.916137          0.810976  0.564203
# 10            SVM   problem_code        0.733672          0.638211  0.998195
# 11            SVM           code        0.680051          0.601626  1.063153
# 12            MLP     problemall        0.981957          0.904472  0.498916
# 13            MLP  problem_gries        0.970013          0.873984  0.504896
# 14            MLP     code_gries        0.986023          0.908537  0.439572
# 15            MLP          gries        0.978145          0.893293  0.439397
# 16            MLP   problem_code        0.981194          0.910569  0.472693
# 17            MLP           code        0.985515          0.910569  0.475414
# 18  Random Forest     problemall        0.994917          0.925813  0.392081
# 19  Random Forest  problem_gries        0.990089          0.915650  0.390636
# 20  Random Forest     code_gries        0.994409          0.922764  0.394339
# 21  Random Forest          gries        0.989835          0.918699  0.396249
# 22  Random Forest   problem_code        0.994409          0.913618  0.529222
# 23  Random Forest           code        0.994663          0.919715  0.513123
# 24         Voting     problemall        0.988564          0.910569  0.318981
# 25         Voting  problem_gries        0.987548          0.912602  0.299706
# 26         Voting     code_gries        0.988564          0.904472  0.310346
# 27         Voting          gries        0.985260          0.899390  0.328277
# 28         Voting   problem_code        0.982719          0.903455  0.384444
# 29         Voting           code        0.993139          0.921748  0.352588
# 30       Stacking     problemall        0.993901          0.929878  0.242856
# 31       Stacking  problem_gries        0.990851          0.922764  0.259923
# 32       Stacking     code_gries        0.994663          0.934959  0.228872
# 33       Stacking          gries        0.989581          0.920732  0.266286
# 34       Stacking   problem_code        0.993901          0.919715  0.259926
# 35       Stacking           code        0.993647          0.920732  0.269340
#
#     Time_train  Time_predict       MCC       AUC
# 0     0.006294      5.021235  0.859294  0.964385
# 1     0.004772      4.153062  0.854072  0.963195
# 2     0.004995      4.012487  0.857946  0.964779
# 3     0.004272      3.218750  0.854855  0.963402
# 4     0.002694      2.160353  0.829452  0.960138
# 5     0.001737      1.013701  0.847695  0.961755
# 6   114.758061      9.557438  0.817592  0.930519
# 7    89.962410      7.709242  0.773318  0.897487
# 8    87.243823      7.621240  0.816243  0.922149
# 9    64.067498      6.150654  0.758905  0.882654
# 10   51.812204      4.750131  0.535283  0.691280
# 11   29.071411      1.899608  0.487184  0.657622
# 12   14.148384      0.029185  0.879233  0.947540
# 13   10.645545      0.022486  0.842557  0.935292
# 14    5.717908      0.024088  0.884049  0.952686
# 15    7.950279      0.018067  0.864709  0.938236
# 16    5.536767      0.012391  0.887153  0.957674
# 17    8.152192      0.007282  0.887037  0.955899
# 18   11.144301      0.026112  0.905855  0.968044
# 19    8.528312      0.026156  0.892835  0.962786
# 20   10.994308      0.024965  0.902011  0.960327
# 21    8.284392      0.025230  0.896862  0.961873
# 22    7.735371      0.022700  0.890129  0.953884
# 23    7.749093      0.022334  0.897936  0.946879
# 24   19.437049      0.058012  0.887203  0.963376
# 25   17.025072      0.050781  0.889149  0.970611
# 26   19.225100      0.047502  0.879800  0.962328
# 27   18.842900      0.043015  0.872532  0.953765
# 28   14.757090      0.037579  0.878685  0.952796
# 29   14.341825      0.046744  0.900687  0.964675
# 30  111.664133      0.061898  0.911013  0.975275
# 31  101.937216      0.050726  0.901804  0.966558
# 32  106.722290      0.054293  0.917434  0.972808
# 33   84.038455      0.043098  0.899215  0.963686
# 34   74.999288      0.038684  0.898024  0.968545
# 35   64.719212      0.033675  0.899366  0.964644

# %%
path="/content/drive/MyDrive/UDENAR/ProyectosGrado/Errol/Ginna/1. Tradicional Machine Learning/"

# %%
df.to_csv(path+"tradicionalML_ablationsResults.csv",index=False)

# %%
df=pd.read_csv(path+"tradicionalML_ablationsResults.csv")
df
# Out:
#             Model       Ablation  Accuracy_train  Accuracy_predict      Loss  \
# 0             KNN     problemall        0.994917          0.888211  0.471043
# 1             KNN  problem_gries        0.991360          0.884146  0.456727
# 2             KNN     code_gries        0.994663          0.887195  0.465663
# 3             KNN          gries        0.990343          0.885163  0.456627
# 4             KNN   problem_code        0.994917          0.862805  0.545388
# 5             KNN           code        0.994663          0.878049  0.531353
# 6             SVM     problemall        0.953748          0.856707  0.439651
# 7             SVM  problem_gries        0.921982          0.822154  0.531210
# 8             SVM     code_gries        0.946887          0.855691  0.460783
# 9             SVM          gries        0.916137          0.810976  0.564203
# 10            SVM   problem_code        0.733672          0.638211  0.998195
# 11            SVM           code        0.680051          0.601626  1.063153
# 12            MLP     problemall        0.981957          0.904472  0.498916
# 13            MLP  problem_gries        0.970013          0.873984  0.504896
# 14            MLP     code_gries        0.986023          0.908537  0.439572
# 15            MLP          gries        0.978145          0.893293  0.439397
# 16            MLP   problem_code        0.981194          0.910569  0.472693
# 17            MLP           code        0.985515          0.910569  0.475414
# 18  Random Forest     problemall        0.994917          0.925813  0.392081
# 19  Random Forest  problem_gries        0.990089          0.915650  0.390636
# 20  Random Forest     code_gries        0.994409          0.922764  0.394339
# 21  Random Forest          gries        0.989835          0.918699  0.396249
# 22  Random Forest   problem_code        0.994409          0.913618  0.529222
# 23  Random Forest           code        0.994663          0.919715  0.513123
# 24         Voting     problemall        0.988564          0.910569  0.318981
# 25         Voting  problem_gries        0.987548          0.912602  0.299706
# 26         Voting     code_gries        0.988564          0.904472  0.310346
# 27         Voting          gries        0.985260          0.899390  0.328277
# 28         Voting   problem_code        0.982719          0.903455  0.384444
# 29         Voting           code        0.993139          0.921748  0.352588
# 30       Stacking     problemall        0.993901          0.929878  0.242856
# 31       Stacking  problem_gries        0.990851          0.922764  0.259923
# 32       Stacking     code_gries        0.994663          0.934959  0.228872
# 33       Stacking          gries        0.989581          0.920732  0.266286
# 34       Stacking   problem_code        0.993901          0.919715  0.259926
# 35       Stacking           code        0.993647          0.920732  0.269340
#
#     Time_train  Time_predict       MCC       AUC
# 0     0.006294      5.021235  0.859294  0.964385
# 1     0.004772      4.153062  0.854072  0.963195
# 2     0.004995      4.012487  0.857946  0.964779
# 3     0.004272      3.218750  0.854855  0.963402
# 4     0.002694      2.160353  0.829452  0.960138
# 5     0.001737      1.013701  0.847695  0.961755
# 6   114.758061      9.557438  0.817592  0.930519
# 7    89.962410      7.709242  0.773318  0.897487
# 8    87.243823      7.621240  0.816243  0.922149
# 9    64.067498      6.150654  0.758905  0.882654
# 10   51.812204      4.750131  0.535283  0.691280
# 11   29.071411      1.899608  0.487184  0.657622
# 12   14.148384      0.029185  0.879233  0.947540
# 13   10.645545      0.022486  0.842557  0.935292
# 14    5.717908      0.024088  0.884049  0.952686
# 15    7.950279      0.018067  0.864709  0.938236
# 16    5.536767      0.012391  0.887153  0.957674
# 17    8.152192      0.007282  0.887037  0.955899
# 18   11.144301      0.026112  0.905855  0.968044
# 19    8.528312      0.026156  0.892835  0.962786
# 20   10.994308      0.024965  0.902011  0.960327
# 21    8.284392      0.025230  0.896862  0.961873
# 22    7.735371      0.022700  0.890129  0.953884
# 23    7.749093      0.022334  0.897936  0.946879
# 24   19.437049      0.058012  0.887203  0.963376
# 25   17.025072      0.050781  0.889149  0.970611
# 26   19.225100      0.047502  0.879800  0.962328
# 27   18.842900      0.043015  0.872532  0.953765
# 28   14.757090      0.037579  0.878685  0.952796
# 29   14.341825      0.046744  0.900687  0.964675
# 30  111.664133      0.061898  0.911013  0.975275
# 31  101.937216      0.050726  0.901804  0.966558
# 32  106.722290      0.054293  0.917434  0.972808
# 33   84.038455      0.043098  0.899215  0.963686
# 34   74.999288      0.038684  0.898024  0.968545
# 35   64.719212      0.033675  0.899366  0.964644

# %% [markdown]
# # Externd Data

# %%
extern_file = '/content/drive/MyDrive/UDENAR/ProyectosGrado/Errol/Ginna/Tuning/BestModels/Copia de ExternData.csv'
train_full = pd.read_csv(extern_file)
train_full
# Out:
#                                   Problem Description  \
# 0             Count how many even numbers are up to n
# 1                             Sum numbers from 1 to n
# 2          Prompt user for numbers until 0 is entered
# 3             Find first multiple of 7 greater than n
# 4                            Calculate factorial of n
# 5                Count digits in a positive integer n
# 6                        Sum all even numbers up to n
# 7                     Find a prime number using break
# 8                  Print cubes of numbers from 1 to n
# 9                   Prompt for password until correct
# 10  Print numbers from 1 to n, but condition exclu...
# 11  Divide a number by 2 repeatedly until it's les...
# 12                                Sum all digits of n
# 13    Count how many times 5 can be subtracted from n
# 14                   Calculate power using while loop
# 15                         Check if number is perfect
# 16                          Convert decimal to binary
# 17        Print items in list until negative is found
# 18                       Count multiples of 3 up to n
# 19                          Print odd numbers up to n
# 20                    Sum the first n natural numbers
# 21                            Sum odd numbers up to n
# 22                               Count primes up to n
# 23   Read and sum numbers until a negative is entered
# 24                            Find LCM of two numbers
# 25             Print Fibonacci sequence up to n terms
# 26                       Count multiples of 5 up to n
# 27     Find GCD of two numbers using Euclid algorithm
# 28  Prompt user for positive numbers until 5 are e...
# 29                 Sum multiples of 4 between 1 and n
# 30  Print the factorial of n, but n is not initial...
# 31  Reverse a list but forget to initialize the in...
# 32  Print numbers from a to b, missing both variab...
# 33  Sum even numbers in a list, with an off-by-one...
# 34  Count numbers divisible by 3, fails to initial...
#
#                                           Python Code  \
# 0   def count_evens_buggy(n):\n    i = 0\n    coun...
# 1   def sum_to_n_buggy(n):\n    total = 0\n    i =...
# 2   def input_until_zero_buggy():\n    num = int(i...
# 3   def first_multiple_7_buggy(n):\n    i = n + 1\...
# 4   def factorial_buggy(n):\n    result = 1\n    w...
# 5   def count_digits_buggy(n):\n    count = 0\n   ...
# 6   def sum_evens_buggy(n):\n    total = 0\n    i ...
# 7   def find_prime_buggy():\n    num = 2\n    whil...
# 8   def print_cubes_buggy(n):\n    while i <= n:\n...
# 9   def prompt_password_buggy():\n    password = i...
# 10  def print_numbers_buggy(n):\n    i = 1\n    wh...
# 11  def divide_repeatedly_buggy(n):\n    while n >...
# 12  def sum_digits_buggy(n):\n    total = 0\n    w...
# 13  def count_subtract_5_buggy(n):\n    count = 0\...
# 14  def power_buggy(base, exp):\n    result = 1\n ...
# 15  def is_perfect_buggy(n):\n    sum_div = 0\n   ...
# 16  def decimal_to_binary_buggy(n):\n    res = ''\...
# 17  def print_until_negative_buggy(lst):\n    i = ...
# 18  def count_mult_3_buggy(n):\n    i = 1\n    cou...
# 19  def print_odds_buggy(n):\n    i = 1\n    while...
# 20  def sum_n_buggy(n):\n    i = 1\n    total = 0\...
# 21  def sum_odds_buggy(n):\n    total = 0\n    i =...
# 22  def count_primes_buggy(n):\n    count = 0\n   ...
# 23  def sum_until_negative_buggy():\n    total = 0...
# 24  def lcm_buggy(a, b):\n    num = max(a, b)\n   ...
# 25  def fibonacci_buggy(n):\n    a, b = 0, 1\n    ...
# 26  def count_mult_5_buggy(n):\n    i = 1\n    cou...
# 27  def gcd_buggy(a, b):\n    while a != b:\n     ...
# 28  def count_positives_buggy():\n    count = 0\n ...
# 29  def sum_mult_4_buggy(n):\n    i = 1\n    while...
# 30  def buggy_factorial():\n    while n > 0:\n    ...
# 31  def buggy_reverse(lst):\n    # missing i = len...
# 32  def buggy_print_range(b):\n    # missing a = 1...
# 33  def buggy_sum_evens(lst):\n    i = 0\n    sum_...
# 34  def buggy_count_mult_3(n):\n    while i < n:  ...
#
#                                                Source  \
# 0   Inspired by CodeChef Learn Python (While Loop)...
# 1   Based on typical mistakes in Codeforces common...
# 2   Common error from GeeksforGeeks Python while l...
# 3     Typical error in CodeNet beginner loop problems
# 4             Inspired by classic factorial exercises
# 5   Inspired by digit counting problems in Codefor...
# 6   CodeChef/Codeforces summing problems, conditio...
# 7   Inspired by break/continue loop errors from Py...
# 8   Common initialization error, based on CodeNet ...
# 9   Typical validation loop error from Python begi...
# 10  Common inclusive/exclusive error in loops (Cod...
# 11  Inspired by CodeNet loop problems involving di...
# 12  Classic digit-processing error, Python/Codeforces
# 13  Common mistake in decrement loops (CodeNet/Cod...
# 14  Power calculation errors in Codeforces/Python ...
# 15        Perfect number mistakes, classic math loops
# 16  Typical binary conversion loop, Codeforces/Cod...
# 17  Inspired by control-flow misplacement from Pyt...
# 18  Loops with missed accumulation, typical in beg...
# 19         Increment logic error, Codeforces/CodeChef
# 20  Classic off-by-one loop error, inspired by bas...
# 21   Odd number sum, increment bug, beginner mistakes
# 22  Classic loop and condition error in prime coun...
# 23  Missing input update bug, shown in tutorials (...
# 24  LCM calculation, common loop bug (CodeNet/Code...
# 25  Sequence and assignment bug, inspired by class...
# 26  Missing i update, common beginner error, CodeC...
# 27  Euclid's algorithm off-by-one/condition bug, C...
# 28  Input accumulation/counting error, basic progr...
# 29  Sum variable scope bug, inspired by sum/accumu...
# 30  Initialization errors are a classic mistake (C...
# 31  Initialization and condition errors, common in...
# 32  Initialization and update errors frequently se...
# 33  Condition and update errors, drawn from typica...
# 34  Simultaneous initialization, condition, and bo...
#
#                                     Description Error  Error Label
# 0            missing increment leads to infinite loop            2
# 1                        i is incorrectly incremented            2
# 2                 number is never updated in the loop            2
# 3                                   i not incremented            2
# 4                               decrement by 2, not 1            2
# 5                       n not updated inside the loop            2
# 6                            loop condition incorrect            1
# 7                          break outside the if block            2
# 8                                   i not initialized            0
# 9                        password requested only once            2
# 10                               condition excludes n            1
# 11                integer division and missing update            2
# 12                                missing update of n            2
# 13                                   n is not updated            2
# 14                             missing increment of i            2
# 15              sum calculation and missing increment            2
# 16                      n not updated inside the loop            2
# 17                         break outside the if block            2
# 18                                count never updated            2
# 19                       i is incremented incorrectly            2
# 20                          loop condition excludes n            1
# 21                              i increment incorrect            2
# 22                          loop condition excludes n            1
# 23               does not read new number inside loop            2
# 24                     missing increment of candidate            2
# 25                           assignments out of order            2
# 26                                      i not updated            2
# 27                  condition may cause infinite loop            1
# 28                          counter never incremented            2
# 29              sum variable is reset inside the loop            2
# 30         n is not initialized before the while loop            0
# 31  missing initialization and undefined variable ...            3
# 32  missing initialization and wrong update in loo...            4
# 33   wrong condition and no accumulation in loop body            5
# 34  multiple errors in initialization, condition a...            6

# %%
train_full['Python Code']=train_full['Python Code'].apply(lambda x: x.replace("\\n","\n"))

# %%
train_full[["Estado incial","Transformación de estado","Estado final"]]=train_full['Python Code'].apply(DGries_states).apply(pd.Series)
# Out:
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body

# %%
train_full
# Out:
#                                   Problem Description  \
# 0             Count how many even numbers are up to n
# 1                             Sum numbers from 1 to n
# 2          Prompt user for numbers until 0 is entered
# 3             Find first multiple of 7 greater than n
# 4                            Calculate factorial of n
# 5                Count digits in a positive integer n
# 6                        Sum all even numbers up to n
# 7                     Find a prime number using break
# 8                  Print cubes of numbers from 1 to n
# 9                   Prompt for password until correct
# 10  Print numbers from 1 to n, but condition exclu...
# 11  Divide a number by 2 repeatedly until it's les...
# 12                                Sum all digits of n
# 13    Count how many times 5 can be subtracted from n
# 14                   Calculate power using while loop
# 15                         Check if number is perfect
# 16                          Convert decimal to binary
# 17        Print items in list until negative is found
# 18                       Count multiples of 3 up to n
# 19                          Print odd numbers up to n
# 20                    Sum the first n natural numbers
# 21                            Sum odd numbers up to n
# 22                               Count primes up to n
# 23   Read and sum numbers until a negative is entered
# 24                            Find LCM of two numbers
# 25             Print Fibonacci sequence up to n terms
# 26                       Count multiples of 5 up to n
# 27     Find GCD of two numbers using Euclid algorithm
# 28  Prompt user for positive numbers until 5 are e...
# 29                 Sum multiples of 4 between 1 and n
# 30  Print the factorial of n, but n is not initial...
# 31  Reverse a list but forget to initialize the in...
# 32  Print numbers from a to b, missing both variab...
# 33  Sum even numbers in a list, with an off-by-one...
# 34  Count numbers divisible by 3, fails to initial...
#
#                                           Python Code  \
# 0   def count_evens_buggy(n):\n    i = 0\n    coun...
# 1   def sum_to_n_buggy(n):\n    total = 0\n    i =...
# 2   def input_until_zero_buggy():\n    num = int(i...
# 3   def first_multiple_7_buggy(n):\n    i = n + 1\...
# 4   def factorial_buggy(n):\n    result = 1\n    w...
# 5   def count_digits_buggy(n):\n    count = 0\n   ...
# 6   def sum_evens_buggy(n):\n    total = 0\n    i ...
# 7   def find_prime_buggy():\n    num = 2\n    whil...
# 8   def print_cubes_buggy(n):\n    while i <= n:\n...
# 9   def prompt_password_buggy():\n    password = i...
# 10  def print_numbers_buggy(n):\n    i = 1\n    wh...
# 11  def divide_repeatedly_buggy(n):\n    while n >...
# 12  def sum_digits_buggy(n):\n    total = 0\n    w...
# 13  def count_subtract_5_buggy(n):\n    count = 0\...
# 14  def power_buggy(base, exp):\n    result = 1\n ...
# 15  def is_perfect_buggy(n):\n    sum_div = 0\n   ...
# 16  def decimal_to_binary_buggy(n):\n    res = ''\...
# 17  def print_until_negative_buggy(lst):\n    i = ...
# 18  def count_mult_3_buggy(n):\n    i = 1\n    cou...
# 19  def print_odds_buggy(n):\n    i = 1\n    while...
# 20  def sum_n_buggy(n):\n    i = 1\n    total = 0\...
# 21  def sum_odds_buggy(n):\n    total = 0\n    i =...
# 22  def count_primes_buggy(n):\n    count = 0\n   ...
# 23  def sum_until_negative_buggy():\n    total = 0...
# 24  def lcm_buggy(a, b):\n    num = max(a, b)\n   ...
# 25  def fibonacci_buggy(n):\n    a, b = 0, 1\n    ...
# 26  def count_mult_5_buggy(n):\n    i = 1\n    cou...
# 27  def gcd_buggy(a, b):\n    while a != b:\n     ...
# 28  def count_positives_buggy():\n    count = 0\n ...
# 29  def sum_mult_4_buggy(n):\n    i = 1\n    while...
# 30  def buggy_factorial():\n    while n > 0:\n    ...
# 31  def buggy_reverse(lst):\n    # missing i = len...
# 32  def buggy_print_range(b):\n    # missing a = 1...
# 33  def buggy_sum_evens(lst):\n    i = 0\n    sum_...
# 34  def buggy_count_mult_3(n):\n    while i < n:  ...
#
#                                                Source  \
# 0   Inspired by CodeChef Learn Python (While Loop)...
# 1   Based on typical mistakes in Codeforces common...
# 2   Common error from GeeksforGeeks Python while l...
# 3     Typical error in CodeNet beginner loop problems
# 4             Inspired by classic factorial exercises
# 5   Inspired by digit counting problems in Codefor...
# 6   CodeChef/Codeforces summing problems, conditio...
# 7   Inspired by break/continue loop errors from Py...
# 8   Common initialization error, based on CodeNet ...
# 9   Typical validation loop error from Python begi...
# 10  Common inclusive/exclusive error in loops (Cod...
# 11  Inspired by CodeNet loop problems involving di...
# 12  Classic digit-processing error, Python/Codeforces
# 13  Common mistake in decrement loops (CodeNet/Cod...
# 14  Power calculation errors in Codeforces/Python ...
# 15        Perfect number mistakes, classic math loops
# 16  Typical binary conversion loop, Codeforces/Cod...
# 17  Inspired by control-flow misplacement from Pyt...
# 18  Loops with missed accumulation, typical in beg...
# 19         Increment logic error, Codeforces/CodeChef
# 20  Classic off-by-one loop error, inspired by bas...
# 21   Odd number sum, increment bug, beginner mistakes
# 22  Classic loop and condition error in prime coun...
# 23  Missing input update bug, shown in tutorials (...
# 24  LCM calculation, common loop bug (CodeNet/Code...
# 25  Sequence and assignment bug, inspired by class...
# 26  Missing i update, common beginner error, CodeC...
# 27  Euclid's algorithm off-by-one/condition bug, C...
# 28  Input accumulation/counting error, basic progr...
# 29  Sum variable scope bug, inspired by sum/accumu...
# 30  Initialization errors are a classic mistake (C...
# 31  Initialization and condition errors, common in...
# 32  Initialization and update errors frequently se...
# 33  Condition and update errors, drawn from typica...
# 34  Simultaneous initialization, condition, and bo...
#
#                                     Description Error  Error Label  \
# 0            missing increment leads to infinite loop            2
# 1                        i is incorrectly incremented            2
# 2                 number is never updated in the loop            2
# 3                                   i not incremented            2
# 4                               decrement by 2, not 1            2
# 5                       n not updated inside the loop            2
# 6                            loop condition incorrect            1
# 7                          break outside the if block            2
# 8                                   i not initialized            0
# 9                        password requested only once            2
# 10                               condition excludes n            1
# 11                integer division and missing update            2
# 12                                missing update of n            2
# 13                                   n is not updated            2
# 14                             missing increment of i            2
# 15              sum calculation and missing increment            2
# 16                      n not updated inside the loop            2
# 17                         break outside the if block            2
# 18                                count never updated            2
# 19                       i is incremented incorrectly            2
# 20                          loop condition excludes n            1
# 21                              i increment incorrect            2
# 22                          loop condition excludes n            1
# 23               does not read new number inside loop            2
# 24                     missing increment of candidate            2
# 25                           assignments out of order            2
# 26                                      i not updated            2
# 27                  condition may cause infinite loop            1
# 28                          counter never incremented            2
# 29              sum variable is reset inside the loop            2
# 30         n is not initialized before the while loop            0
# 31  missing initialization and undefined variable ...            3
# 32  missing initialization and wrong update in loo...            4
# 33   wrong condition and no accumulation in loop body            5
# 34  multiple errors in initialization, condition a...            6
#
#                                         Estado incial  \
# 0                                i = 0\n    count = 0
# 1                                total = 0\n    i = 1
# 2      num = int(input('Enter number (0 to exit): '))
# 3                                           i = n + 1
# 4                                          result = 1
# 5                                           count = 0
# 6                                total = 0\n    i = 2
# 7                                             num = 2
# 8                               print(i ** 3)\ni += 1
# 9                password = input('Enter password: ')
# 10                                              i = 1
# 11                               print(n)\nn = n // 2
# 12                                          total = 0
# 13                                          count = 0
# 14                              result = 1\n    i = 0
# 15                       sum_div = 0\n    divisor = 1
# 16                                           res = ''
# 17                                              i = 0
# 18                               i = 1\n    count = 0
# 19                                              i = 1
# 20                               i = 1\n    total = 0
# 21                               total = 0\n    i = 1
# 22                               count = 0\n    i = 2
# 23  total = 0\n    num = int(input('Enter number (...
# 24                                    num = max(a, b)
# 25                             a, b = 0, 1\n    i = 0
# 26                               i = 1\n    count = 0
# 27           if a > b:\n    a -= b\nelse:\n    b -= a
# 28                                          count = 0
# 29                                              i = 1
# 30                                   print(n)\nn -= 1
# 31                              print(lst[j])\nj -= 1
# 32                            a = 1\nprint(a)\na += 1
# 33                           i = 0\n    sum_evens = 0
# 34        count = 0\nif i % 3 == 0:\n    pass\ni += 1
#
#                              Transformación de estado          Estado final
# 0                      if i % 2 == 0:\n    count += 1                i <= n
# 1                               total += i\ni = i + 0                i <= n
# 2                               print('Number:', num)              num != 0
# 3                                                pass            i % 7 != 0
# 4                                 result *= n\nn -= 2                 n > 1
# 5                                  n % 10\ncount += 1                 n > 0
# 6                                  total += i\ni += 2                 i < n
# 7   is_prime = True\ndivisor = 2\nwhile divisor < ...                  True
# 8                               print(i ** 3)\ni += 1                i <= n
# 9                                  print('Incorrect')  password != 'secret'
# 10                                   print(i)\ni += 1                 i < n
# 11                               print(n)\nn = n // 2                n >= 1
# 12                                    total += n % 10                 n > 0
# 13                                         count += 1                n >= 5
# 14                                     result *= base               i < exp
# 15        if n % divisor == 0:\n    sum_div = divisor           divisor < n
# 16                             res = str(n % 2) + res                 n > 0
# 17  print(lst[i])\nbreak\nif lst[i] < 0:\n    brea...          i < len(lst)
# 18                   if i % 3 == 0:\n    pass\ni += 1                i <= n
# 19                           print(i)\ni += 2\ni += 1                i <= n
# 20                                 total += i\ni += 1                 i < n
# 21      if i % 2 != 0:\n    total += i\ni = i + 1 - 1                i <= n
# 22            if is_prime(i):\n    count += 1\ni += 1                 i < n
# 23                                       total += num              num >= 0
# 24  if num % a == 0 and num % b == 0:\n    return num                  True
# 25                 print(a)\nb = a + b\na = b\ni += 1                 i < n
# 26                     if i % 5 == 0:\n    count += 1                i <= n
# 27           if a > b:\n    a -= b\nelse:\n    b -= a                a != b
# 28  num = int(input('Enter positive number: '))\ni...             count < 5
# 29      sum = 0\nif i % 4 == 0:\n    sum += i\ni += 1                i <= n
# 30                                   print(n)\nn -= 1                 n > 0
# 31                              print(lst[j])\nj -= 1                j >= 0
# 32                            a = 1\nprint(a)\na += 1                a <= b
# 33              if lst[i] % 2 == 0:\n    pass\ni += 1         i <= len(lst)
# 34        count = 0\nif i % 3 == 0:\n    pass\ni += 1                 i < n

# %%
train_full['Python Code']=train_full['Python Code'].apply(lambda x: x.replace("\\n","\n"))

# %%
train_full[["Estado incial","Transformación de estado","Estado final"]]=train_full['Python Code'].apply(DGries_states).apply(pd.Series)
# Out:
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body

# %%
# %%time
problem=train_full['Problem Description'].apply(encoder.tokenize_and_generate_embeddings_descriptions).to_numpy()
code=train_full['Python Code'].apply(encoder.tokenize_and_generate_embeddings_codes).to_numpy()
startstate = train_full['Estado incial'].apply(encoder.tokenize_and_generate_embeddings_codes).to_numpy()
finalstate = train_full['Estado final'].apply(encoder.tokenize_and_generate_embeddings_codes).to_numpy()
transstate = train_full['Transformación de estado'].apply(encoder.tokenize_and_generate_embeddings_codes).to_numpy()
# Out:
# CPU times: user 1.33 s, sys: 998 µs, total: 1.33 s
# Wall time: 1.33 s

# %%
problem.shape,code.shape,startstate.shape,finalstate.shape,transstate.shape
# Out:
# ((35,), (35,), (35,), (35,), (35,))

# %%
print(startstate.shape)
print(startstate[0].shape)
# Out:
# (35,)
# (1, 8, 768)

# %%
Xp=np.array([sentence[0].mean(axis=0) for sentence in problem])
Xcode=np.array([sentence[0].mean(axis=0) for sentence in code])
Xs=np.array([sentence[0].mean(axis=0) for sentence in startstate])
Xf=np.array([sentence[0].mean(axis=0) for sentence in finalstate])
Xt=np.array([sentence[0].mean(axis=0) for sentence in transstate])
Xp.shape,Xs.shape,Xf.shape,Xt.shape
# Out:
# ((35, 768), (35, 768), (35, 768), (35, 768))

# %%
y=train_full['Error Label']+1
y=y.to_numpy()
np.unique(y)
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %%
accuracies_predict=[]
loss_predict=[]
times_predict=[]
mccs_predict=[]
aucpr_predict=[]
ml_names=[]
abl_names=[]

ml_names=[]
abl_names=[]

# %%
from time import time


models_names=["KNN","SVM","MLP","Random Forest","Voting","Stacking"]
ablations_names=["problemall","problem_gries","code_gries","gries","problem_code","code"]

for name in models_names:
  print(name)
  for ablations_name in ablations_names:
    ml_names.append(name)
    abl_names.append(ablations_name)
    print(ablations_name)
    model=joblib.load(path+"bert_"+name+"_"+ablations_name+".joblib")
    print(model)
    if ablations_name=="problemall":
      Xe= np.concatenate((Xp,Xcode,Xs,Xt,Xf),axis=1)
    elif ablations_name=="problem_gries":
      Xe=np.concatenate((Xp,Xs,Xt,Xf),axis=1)
    elif ablations_name=="code_gries":
      Xe=np.concatenate((Xcode,Xs,Xt,Xf),axis=1)
    elif ablations_name=="gries":
      Xe=np.concatenate((Xs,Xt,Xf),axis=1)
    elif ablations_name=="problem_code":
      Xe=np.concatenate((Xp,Xcode),axis=1)
    elif ablations_name=="code":
      Xe=Xcode

    time1=time()
    y_pred=model.predict(Xe)
    time2=time()
    times_predict.append(time2-time1)

    accuracie_test=model.score(Xe,y)
    accuracies_predict.append(accuracie_test)
    #sparse_categorical_crossentropy
    y_pred_proba = model.predict_proba(Xe)
    loss=np.mean(sparse_categorical_crossentropy(y,y_pred_proba))
    loss_predict.append(loss)
    mcc = matthews_corrcoef(y, y_pred)
    mccs_predict.append(mcc)
    auc_pr = calculate_auc_pr_multiclass(y, y_pred_proba)
    aucpr_predict.append(auc_pr)
    print(classification_report(y,y_pred))
    print("Accuracy predict",accuracie_test)
    print("Loss",loss)
    print("MCC",mcc)
    print("AUC",auc_pr)
    print("==================================")
# Out:
# KNN
# problemall
# KNeighborsClassifier(n_neighbors=15, p=1, weights='distance')
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.00      0.00      0.00         2
#            2       0.29      0.40      0.33         5
#            3       0.80      0.17      0.28        24
#            4       0.00      0.00      0.00         1
#            5       0.00      0.00      0.00         1
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         1
#
#     accuracy                           0.17        35
#    macro avg       0.14      0.07      0.08        35
# weighted avg       0.59      0.17      0.24        35
#
# Accuracy predict 0.17142857142857143
# Loss 5.2174699063563725
# MCC 0.04369362635038459
# AUC 0.24557146282334574
# ==================================
# problem_gries
# KNeighborsClassifier(n_neighbors=15, p=1, weights='distance')
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.00      0.00      0.00         2
#            2       0.29      0.40      0.33         5
#            3       0.75      0.25      0.38        24
#            4       0.00      0.00      0.00         1
#            5       0.00      0.00      0.00         1
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         1
#
#     accuracy                           0.23        35
#    macro avg       0.13      0.08      0.09        35
# weighted avg       0.56      0.23      0.30        35
#
# Accuracy predict 0.22857142857142856
# Loss 5.626884038717947
# MCC 0.04589778118178919
# AUC 0.20969740958894
# ==================================
# code_gries
# KNeighborsClassifier(n_neighbors=15, p=1, weights='distance')
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.00      0.00      0.00         2
#            2       0.33      0.40      0.36         5
#            3       0.75      0.25      0.38        24
#            4       0.00      0.00      0.00         1
#            5       0.00      0.00      0.00         1
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         1
#
#     accuracy                           0.23        35
#    macro avg       0.14      0.08      0.09        35
# weighted avg       0.56      0.23      0.31        35
#
# Accuracy predict 0.22857142857142856
# Loss 5.5711203372461995
# MCC 0.05262210490598266
# AUC 0.2326700927995606
# ==================================
# gries
# KNeighborsClassifier(n_neighbors=15, p=1, weights='distance')
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.00      0.00      0.00         2
#            2       0.29      0.40      0.33         5
#            3       0.75      0.25      0.38        24
#            4       0.00      0.00      0.00         1
#            5       0.00      0.00      0.00         1
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         1
#
#     accuracy                           0.23        35
#    macro avg       0.13      0.08      0.09        35
# weighted avg       0.56      0.23      0.30        35
#
# Accuracy predict 0.22857142857142856
# Loss 6.3961712818295435
# MCC 0.04318365674378351
# AUC 0.25070162257699063
# ==================================
# problem_code
# KNeighborsClassifier(n_neighbors=15, p=1, weights='distance')
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.14      0.50      0.22         2
#            2       0.00      0.00      0.00         5
#            3       0.75      0.12      0.21        24
#            4       0.00      0.00      0.00         1
#            5       0.00      0.00      0.00         1
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         1
#
#     accuracy                           0.11        35
#    macro avg       0.11      0.08      0.05        35
# weighted avg       0.52      0.11      0.16        35
#
# Accuracy predict 0.11428571428571428
# Loss 5.76202370406291
# MCC 0.0
# AUC 0.24987959597356152
# ==================================
# code
# KNeighborsClassifier(n_neighbors=15, p=1, weights='distance')
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.12      0.50      0.20         2
#            2       0.20      0.20      0.20         5
#            3       1.00      0.17      0.29        24
#            4       0.00      0.00      0.00         1
#            5       0.00      0.00      0.00         1
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         1
#
#     accuracy                           0.17        35
#    macro avg       0.17      0.11      0.09        35
# weighted avg       0.72      0.17      0.24        35
#
# Accuracy predict 0.17142857142857143
# Loss 5.750046525891723
# MCC 0.10424997756151035
# AUC 0.25159121797101003
# ==================================
# SVM
# problemall
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('classifier',
#                  SVC(C=69.51927961775606, gamma=3.359818286283781e-05,
#                      probability=True))])
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.00      0.00      0.00         2
#            2       0.00      0.00      0.00         5
#            3       0.86      0.50      0.63        24
#            4       0.00      0.00      0.00         1
#            5       0.00      0.00      0.00         1
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         1
#
#     accuracy                           0.34        35
#    macro avg       0.11      0.06      0.08        35
# weighted avg       0.59      0.34      0.43        35
#
# Accuracy predict 0.34285714285714286
# Loss 2.2637252589265233
# MCC 0.07715563299951622
# AUC 0.20374041653056504
# ==================================
# problem_gries
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('classifier',
#                  SVC(C=69.51927961775606, gamma=3.359818286283781e-05,
#                      probability=True))])
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.00      0.00      0.00         2
#            2       0.50      0.40      0.44         5
#            3       0.92      0.50      0.65        24
#            4       0.00      0.00      0.00         1
#            5       0.00      0.00      0.00         1
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         1
#
#     accuracy                           0.40        35
#    macro avg       0.18      0.11      0.14        35
# weighted avg       0.70      0.40      0.51        35
#
# Accuracy predict 0.4
# Loss 1.994631331143937
# MCC 0.18472455604657795
# AUC 0.20943531548786973
# ==================================
# code_gries
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('classifier',
#                  SVC(C=69.51927961775606, gamma=3.359818286283781e-05,
#                      probability=True))])
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.00      0.00      0.00         2
#            2       0.33      0.20      0.25         5
#            3       0.86      0.25      0.39        24
#            4       0.00      0.00      0.00         1
#            5       0.00      0.00      0.00         1
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         1
#
#     accuracy                           0.20        35
#    macro avg       0.15      0.06      0.08        35
# weighted avg       0.64      0.20      0.30        35
#
# Accuracy predict 0.2
# Loss 2.702662881672582
# MCC 0.05996621038308492
# AUC 0.22577081472017885
# ==================================
# gries
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('classifier',
#                  SVC(C=69.51927961775606, gamma=3.359818286283781e-05,
#                      probability=True))])
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.00      0.00      0.00         2
#            2       0.33      0.20      0.25         5
#            3       0.75      0.25      0.38        24
#            4       0.00      0.00      0.00         1
#            5       0.00      0.00      0.00         1
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         1
#
#     accuracy                           0.20        35
#    macro avg       0.14      0.06      0.08        35
# weighted avg       0.56      0.20      0.29        35
#
# Accuracy predict 0.2
# Loss 2.1414168366752815
# MCC 0.01721264068348484
# AUC 0.2491919963218042
# ==================================
# problem_code
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('classifier',
#                  SVC(C=69.51927961775606, gamma=3.359818286283781e-05,
#                      probability=True))])
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.00      0.00      0.00         2
#            2       0.17      0.20      0.18         5
#            3       0.71      0.42      0.53        24
#            4       0.00      0.00      0.00         1
#            5       0.00      0.00      0.00         1
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         1
#
#     accuracy                           0.31        35
#    macro avg       0.11      0.08      0.09        35
# weighted avg       0.51      0.31      0.39        35
#
# Accuracy predict 0.3142857142857143
# Loss 1.9164845049905783
# MCC 0.006656285041272799
# AUC 0.2034818313639452
# ==================================
# code
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('classifier',
#                  SVC(C=69.51927961775606, gamma=3.359818286283781e-05,
#                      probability=True))])
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.00      0.00      0.00         2
#            2       0.00      0.00      0.00         5
#            3       0.67      0.08      0.15        24
#            4       0.00      0.00      0.00         1
#            5       0.00      0.00      0.00         1
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         1
#
#     accuracy                           0.06        35
#    macro avg       0.08      0.01      0.02        35
# ...
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# StackingClassifier(estimators=[('mlp',
#                                 Pipeline(steps=[('scaler', StandardScaler()),
#                                                 ('classifier',
#                                                  MLPClassifier(hidden_layer_sizes=(100,
#                                                                                    100,
#                                                                                    100),
#                                                                learning_rate='adaptive'))])),
#                                ('rf',
#                                 RandomForestClassifier(max_depth=15,
#                                                        n_estimators=80))],
#                    final_estimator=LogisticRegression())
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.00      0.00      0.00         2
#            2       0.50      0.40      0.44         5
#            3       0.67      0.08      0.15        24
#            4       0.00      0.00      0.00         1
#            5       0.00      0.00      0.00         1
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         1
#
#     accuracy                           0.11        35
#    macro avg       0.15      0.06      0.07        35
# weighted avg       0.53      0.11      0.17        35
#
# Accuracy predict 0.11428571428571428
# Loss 2.0302254039525085
# MCC 0.06666675479780404
# AUC 0.3613536021944104
# ==================================
# gries
# StackingClassifier(estimators=[('mlp',
#                                 Pipeline(steps=[('scaler', StandardScaler()),
#                                                 ('classifier',
#                                                  MLPClassifier(hidden_layer_sizes=(100,
#                                                                                    100,
#                                                                                    100),
#                                                                learning_rate='adaptive'))])),
#                                ('rf',
#                                 RandomForestClassifier(max_depth=15,
#                                                        n_estimators=80))],
#                    final_estimator=LogisticRegression())
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.00      0.00      0.00         2
#            2       0.25      0.20      0.22         5
#            3       1.00      0.17      0.29        24
#            4       0.00      0.00      0.00         1
#            5       0.00      0.00      0.00         1
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         1
#
#     accuracy                           0.14        35
#    macro avg       0.16      0.05      0.06        35
# weighted avg       0.72      0.14      0.23        35
#
# Accuracy predict 0.14285714285714285
# Loss 2.280764638232706
# MCC 0.06544557556038524
# AUC 0.23096227750243045
# ==================================
# problem_code
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# StackingClassifier(estimators=[('mlp',
#                                 Pipeline(steps=[('scaler', StandardScaler()),
#                                                 ('classifier',
#                                                  MLPClassifier(hidden_layer_sizes=(100,
#                                                                                    100,
#                                                                                    100),
#                                                                learning_rate='adaptive'))])),
#                                ('rf',
#                                 RandomForestClassifier(max_depth=15,
#                                                        n_estimators=80))],
#                    final_estimator=LogisticRegression())
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.00      0.00      0.00         2
#            2       1.00      0.20      0.33         5
#            3       0.75      0.12      0.21        24
#            4       0.00      0.00      0.00         1
#            5       0.00      0.00      0.00         1
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         1
#
#     accuracy                           0.11        35
#    macro avg       0.22      0.04      0.07        35
# weighted avg       0.66      0.11      0.19        35
#
# Accuracy predict 0.11428571428571428
# Loss 2.170100908109103
# MCC 0.037176862970206864
# AUC 0.20248991167334174
# ==================================
# code
# StackingClassifier(estimators=[('mlp',
#                                 Pipeline(steps=[('scaler', StandardScaler()),
#                                                 ('classifier',
#                                                  MLPClassifier(hidden_layer_sizes=(100,
#                                                                                    100,
#                                                                                    100),
#                                                                learning_rate='adaptive'))])),
#                                ('rf',
#                                 RandomForestClassifier(max_depth=15,
#                                                        n_estimators=80))],
#                    final_estimator=LogisticRegression())
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.00      0.00      0.00         2
#            2       0.00      0.00      0.00         5
#            3       0.75      0.25      0.38        24
#            4       0.00      0.00      0.00         1
#            5       0.00      0.00      0.00         1
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         1
#
#     accuracy                           0.17        35
#    macro avg       0.09      0.03      0.05        35
# weighted avg       0.51      0.17      0.26        35
#
# Accuracy predict 0.17142857142857143
# Loss 2.383257793007317
# MCC 0.02261739002365266
# AUC 0.21029324211571698
# ==================================
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import pandas as pd
dfe=pd.DataFrame({
    "Model":ml_names,
    "Ablation":abl_names,
    "Accuracy_predict":accuracies_predict,
    "Loss":loss_predict,
    "Time_predict":times_predict,
    "MCC":mccs_predict,
    "AUC":aucpr_predict
})

# %%
dfe
# Out:
#             Model       Ablation  Accuracy_predict      Loss  Time_predict  \
# 0             KNN     problemall          0.171429  5.217470      0.185108
# 1             KNN  problem_gries          0.228571  5.626884      0.152587
# 2             KNN     code_gries          0.228571  5.571120      0.151235
# 3             KNN          gries          0.228571  6.396171      0.110185
# 4             KNN   problem_code          0.114286  5.762024      0.073312
# 5             KNN           code          0.171429  5.750047      0.041795
# 6             SVM     problemall          0.342857  2.263725      0.352507
# 7             SVM  problem_gries          0.400000  1.994631      0.301746
# 8             SVM     code_gries          0.200000  2.702663      0.296874
# 9             SVM          gries          0.200000  2.141417      0.215809
# 10            SVM   problem_code          0.314286  1.916485      0.165939
# 11            SVM           code          0.057143  2.314983      0.076446
# 12            MLP     problemall          0.428571  3.854427      0.001948
# 13            MLP  problem_gries          0.342857  5.018728      0.001732
# 14            MLP     code_gries          0.342857  5.344286      0.001576
# 15            MLP          gries          0.257143  5.672770      0.001671
# 16            MLP   problem_code          0.257143  7.743815      0.001240
# 17            MLP           code          0.200000  8.410345      0.001064
# 18  Random Forest     problemall          0.085714  1.918748      0.006303
# 19  Random Forest  problem_gries          0.142857  1.830325      0.006226
# 20  Random Forest     code_gries          0.114286  1.912681      0.006171
# 21  Random Forest          gries          0.114286  1.908604      0.006096
# 22  Random Forest   problem_code          0.000000  2.125262      0.005784
# 23  Random Forest           code          0.085714  2.071942      0.006654
# 24         Voting     problemall          0.428571  1.624303      0.008883
# 25         Voting  problem_gries          0.314286  1.928486      0.008846
# 26         Voting     code_gries          0.314286  1.900183      0.010825
# 27         Voting          gries          0.342857  2.011435      0.007941
# 28         Voting   problem_code          0.228571  2.086357      0.007912
# 29         Voting           code          0.200000  2.204126      0.007589
# 30       Stacking     problemall          0.200000  2.259556      0.008935
# 31       Stacking  problem_gries          0.200000  2.384104      0.008847
# 32       Stacking     code_gries          0.114286  2.030225      0.008527
# 33       Stacking          gries          0.142857  2.280765      0.009055
# 34       Stacking   problem_code          0.114286  2.170101      0.007989
# 35       Stacking           code          0.171429  2.383258      0.008148
#
#          MCC       AUC
# 0   0.043694  0.245571
# 1   0.045898  0.209697
# 2   0.052622  0.232670
# 3   0.043184  0.250702
# 4   0.000000  0.249880
# 5   0.104250  0.251591
# 6   0.077156  0.203740
# 7   0.184725  0.209435
# 8   0.059966  0.225771
# 9   0.017213  0.249192
# 10  0.006656  0.203482
# 11 -0.044604  0.196398
# 12  0.116512  0.378562
# 13  0.035788  0.214552
# 14  0.210364  0.237127
# 15  0.090870  0.256701
# 16  0.051640  0.201966
# 17  0.115659  0.242304
# 18  0.098710  0.236110
# 19  0.138777  0.275047
# 20  0.092113  0.224629
# 21  0.041519  0.248258
# 22 -0.090496  0.236715
# 23  0.016071  0.177366
# 24  0.090716  0.253172
# 25  0.126194  0.262156
# 26  0.081474  0.249386
# 27  0.144887  0.275737
# 28  0.020258  0.211930
# 29  0.079624  0.205272
# 30  0.040606  0.233469
# 31  0.079244  0.234623
# 32  0.066667  0.361354
# 33  0.065446  0.230962
# 34  0.037177  0.202490
# 35  0.022617  0.210293

# %%
dfe.to_csv(path+"bert_externData_ablationsResults.csv",index=False)

# %%
dfe=pd.read_csv(path+"bert_externData_ablationsResults.csv")
dfe
# Out:
#             Model       Ablation  Accuracy_predict      Loss  Time_predict  \
# 0             KNN     problemall          0.171429  5.217470      0.185108
# 1             KNN  problem_gries          0.228571  5.626884      0.152587
# 2             KNN     code_gries          0.228571  5.571120      0.151235
# 3             KNN          gries          0.228571  6.396171      0.110185
# 4             KNN   problem_code          0.114286  5.762024      0.073312
# 5             KNN           code          0.171429  5.750047      0.041795
# 6             SVM     problemall          0.342857  2.263725      0.352507
# 7             SVM  problem_gries          0.400000  1.994631      0.301746
# 8             SVM     code_gries          0.200000  2.702663      0.296874
# 9             SVM          gries          0.200000  2.141417      0.215809
# 10            SVM   problem_code          0.314286  1.916485      0.165939
# 11            SVM           code          0.057143  2.314983      0.076446
# 12            MLP     problemall          0.428571  3.854427      0.001948
# 13            MLP  problem_gries          0.342857  5.018728      0.001732
# 14            MLP     code_gries          0.342857  5.344286      0.001576
# 15            MLP          gries          0.257143  5.672770      0.001671
# 16            MLP   problem_code          0.257143  7.743815      0.001240
# 17            MLP           code          0.200000  8.410345      0.001064
# 18  Random Forest     problemall          0.085714  1.918748      0.006303
# 19  Random Forest  problem_gries          0.142857  1.830325      0.006226
# 20  Random Forest     code_gries          0.114286  1.912681      0.006171
# 21  Random Forest          gries          0.114286  1.908604      0.006096
# 22  Random Forest   problem_code          0.000000  2.125262      0.005784
# 23  Random Forest           code          0.085714  2.071942      0.006654
# 24         Voting     problemall          0.428571  1.624303      0.008883
# 25         Voting  problem_gries          0.314286  1.928486      0.008846
# 26         Voting     code_gries          0.314286  1.900183      0.010825
# 27         Voting          gries          0.342857  2.011435      0.007941
# 28         Voting   problem_code          0.228571  2.086357      0.007912
# 29         Voting           code          0.200000  2.204126      0.007589
# 30       Stacking     problemall          0.200000  2.259556      0.008935
# 31       Stacking  problem_gries          0.200000  2.384104      0.008847
# 32       Stacking     code_gries          0.114286  2.030225      0.008527
# 33       Stacking          gries          0.142857  2.280765      0.009055
# 34       Stacking   problem_code          0.114286  2.170101      0.007989
# 35       Stacking           code          0.171429  2.383258      0.008148
#
#          MCC       AUC
# 0   0.043694  0.245571
# 1   0.045898  0.209697
# 2   0.052622  0.232670
# 3   0.043184  0.250702
# 4   0.000000  0.249880
# 5   0.104250  0.251591
# 6   0.077156  0.203740
# 7   0.184725  0.209435
# 8   0.059966  0.225771
# 9   0.017213  0.249192
# 10  0.006656  0.203482
# 11 -0.044604  0.196398
# 12  0.116512  0.378562
# 13  0.035788  0.214552
# 14  0.210364  0.237127
# 15  0.090870  0.256701
# 16  0.051640  0.201966
# 17  0.115659  0.242304
# 18  0.098710  0.236110
# 19  0.138777  0.275047
# 20  0.092113  0.224629
# 21  0.041519  0.248258
# 22 -0.090496  0.236715
# 23  0.016071  0.177366
# 24  0.090716  0.253172
# 25  0.126194  0.262156
# 26  0.081474  0.249386
# 27  0.144887  0.275737
# 28  0.020258  0.211930
# 29  0.079624  0.205272
# 30  0.040606  0.233469
# 31  0.079244  0.234623
# 32  0.066667  0.361354
# 33  0.065446  0.230962
# 34  0.037177  0.202490
# 35  0.022617  0.210293

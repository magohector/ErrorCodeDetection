# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.56.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.35.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.8.3)

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import re
import shutil
import string
from sklearn.metrics import classification_report
import tensorflow as tf
from keras.models import Model
from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras.optimizers import Adam
from keras.callbacks import EarlyStopping,ModelCheckpoint
from tensorflow.keras.layers import Dense, Input, Dropout, Bidirectional, LSTM, Embedding, BatchNormalization,  Reshape, Conv2D, MaxPool2D, concatenate, Flatten, Activation
import torch
import numpy as np
from transformers import BertTokenizer, BertModel,RobertaTokenizer, RobertaModel
import ast

# %%
# Verificar si la GPU está disponible
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
archivo_3 = '/content/drive/MyDrive/UDENAR/ProyectosGrado/Errol/Ginna/Tuning/BestModels/finallDataset.csv'
train_full = pd.read_csv(archivo_3)

# %%
train_full
# Out:
#                                                Problema  \
# 0     Write a Python function that returns the facto...
# 1     Write a Python function that returns the sum o...
# 2     Write a Python function that prints the number...
# 3     Write a Python function to print the numbers f...
# 4     Write a Python function to check if a number i...
# ...                                                 ...
# 4130      calculate how many numbers are divisible by 3
# 4131      calculate how many numbers are divisible by 3
# 4132      calculate how many numbers are divisible by 3
# 4133      calculate how many numbers are divisible by 3
# 4134      calculate how many numbers are divisible by 3
#
#                                                Solución  y
# 0     def factorial(n):\n    result = 0\n    i = 1\n...  0
# 1     def sum_1_to_100():\n    total = 0\n    i = 1\...  0
# 2     def print_and_store():\n    numbers = []\n    ...  0
# 3     def print_and_store_reverse():\n    numbers = ...  0
# 4     def is_prime(num):\n    i = 2\n    while i < n...  0
# ...                                                 ... ..
# 4130  def buggy_count_mult_3(n):\n    i = 0\n    cou...  6
# 4131  def buggy_count_mult_3(n):\n    i = 0\n    cou...  6
# 4132  def buggy_count_mult_3(n):\n    count = 0\n   ...  6
# 4133  def buggy_count_mult_3(n):\n    count = 0\n   ...  6
# 4134  def buggy_count_mult_3(n):\n    count = 0\n   ...  6
#
# [4135 rows x 3 columns]

# %% [markdown]
# # AST spliter D. Gries form

# %%
class WhileLoopFinder(ast.NodeVisitor):
    def __init__(self, source_code):
        self.source_code = source_code.splitlines()
        self.functions_with_while = []
        self.current_function = None

    def visit_FunctionDef(self, node):
        original_current_function = self.current_function
        self.current_function = {
            "function_name": node.name,
            "has_while_loop": False,
            "pre_while_code_lines": [],
            "while_loops": []
        }

        function_start_line = node.lineno - 1
        function_end_line = (node.end_lineno if hasattr(node, 'end_lineno') else len(self.source_code))
        function_lines = self.source_code[function_start_line:function_end_line]

        found_while = False
        for stmt in node.body:
            if isinstance(stmt, ast.While):
                self.current_function["has_while_loop"] = True
                found_while = True
                try:
                    while_condition = ast.unparse(stmt.test).strip()
                    print("OK condition")
                except AttributeError:
                    print("Error al obtener la condición del while")
                try:
                    while_body_code = ast.unparse(ast.Module(body=stmt.body, type_ignores=[])).strip()
                    print("Ok body")
                except AttributeError:
                    print("Error al obtener el código del cuerpo del while")

                self.current_function["while_loops"].append({
                    "condition": while_condition,
                    "body_code": while_body_code
                })
            elif not found_while:
                start_line = stmt.lineno - 1
                end_line = (stmt.end_lineno if hasattr(stmt, 'end_lineno') else stmt.lineno)
                self.current_function["pre_while_code_lines"].extend(self.source_code[start_line:end_line])
            self.generic_visit(stmt)

        if self.current_function["has_while_loop"]:
            last_while_end_line = None
            if self.current_function["while_loops"]:
                last_while_node = next((node for node in reversed(node.body) if isinstance(node, ast.While)), None)
                if last_while_node and hasattr(last_while_node, 'end_lineno'):
                    last_while_end_line = last_while_node.end_lineno
            post_while_code_lines = []
            if last_while_end_line:
                function_indent = len(self.source_code[node.lineno - 1]) - len(self.source_code[node.lineno - 1].lstrip())
                for line in self.source_code[last_while_end_line:function_end_line]:
                    if line.startswith(self.source_code[node.lineno - 1][:function_indent] + "    "):
                        post_while_code_lines.append(line[function_indent + 4:])
                    else:
                        post_while_code_lines.append(line[function_indent:])
            self.current_function["post_while_code_lines"] = "\n".join(post_while_code_lines).strip()
            self.current_function["pre_while_code_lines"] = "\n".join(self.current_function["pre_while_code_lines"]).strip()
            self.functions_with_while.append(self.current_function)

        self.current_function = original_current_function

# %%
def DGries_states(solution):
  try:
    # Crear el AST
    tree = ast.parse(solution)
    # Recorrer el AST con nuestro visitante
    finder = WhileLoopFinder(solution)
    finder.visit(tree)
    for func_info in finder.functions_with_while:
      initial_state=func_info["pre_while_code_lines"] if func_info["pre_while_code_lines"] else False
      end_state=""
      transformation_state=""
      for j, wl in enumerate(func_info["while_loops"]):
          end_state=wl["condition"]
          transformation_state=wl["body_code"]

      if not initial_state:
        initial_state=transformation_state
      return initial_state,transformation_state,end_state
  except Exception as error:
    return "Exception:"+str(error),"Exception:"+str(error),"Exception:"+str(error)

# %% [markdown]
# # Encoder Description and Code

# %%
class EncodeTextSource:
  def __init__(self):
    self.is_loadtokenizers=False



  def tokenize_and_generate_embeddings_descriptions(self,description):
    if not self.is_loadtokenizers:
      raise ValueError("tokenizers dont load")
    # Tokenize input description and move tokens to GPU
    tokens = self.beart_tokenizer.encode_plus(description, return_tensors="pt", truncation=True)
    tokens = {key: value.to(device) for key, value in tokens.items()}
    # Generate embeddings
    with torch.no_grad():
        outputs = self.beart_model(**tokens)
    # Extract embeddings for all tokens
    desc_embeddings = outputs.last_hidden_state.cpu().numpy()
    return desc_embeddings

  def tokenize_and_generate_embeddings_codes(self,code):
    if not self.is_loadtokenizers:
      raise ValueError("tokenizers dont load")
    # Tokenize input code and move tokens to GPU
    tokens = self.beart_tokenizer.encode_plus(code, return_tensors="pt", truncation=True)
    tokens = {key: value.to(device) for key, value in tokens.items()}
    # Generate embeddings
    with torch.no_grad():
        outputs = self.codebeart_model(**tokens)
    # Extract embeddings for all tokens
    code_embeddings = outputs.last_hidden_state.cpu().numpy()

    return code_embeddings

  def load_beart_tokenizer(self):
    # Verificar si la GPU está disponible
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Cargar el tokenizer y el modelo en la GPU si está disponible
    model_name = "bert-base-uncased"
    self.beart_model = BertModel.from_pretrained(model_name)
    self.beart_tokenizer = BertTokenizer.from_pretrained(model_name)
    self.beart_model.to(device)

  def load_codebert_tokenizer(self):
    # Verificar si la GPU está disponible
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Cargar el tokenizer y el modelo en la GPU si está disponible
    self.codebeart_tokenizer = RobertaTokenizer.from_pretrained("microsoft/codebert-base")
    self.codebeart_model = RobertaModel.from_pretrained("microsoft/codebert-base")
    self.codebeart_model.to(device)

  def start_tokenizer(self):
    self.load_beart_tokenizer()
    self.load_codebert_tokenizer()
    self.is_loadtokenizers=True

# %% [markdown]
# # All characteristics

# %%
train_full.head()
# Out:
#                                             Problema  \
# 0  Write a Python function that returns the facto...
# 1  Write a Python function that returns the sum o...
# 2  Write a Python function that prints the number...
# 3  Write a Python function to print the numbers f...
# 4  Write a Python function to check if a number i...
#
#                                             Solución  y
# 0  def factorial(n):\n    result = 0\n    i = 1\n...  0
# 1  def sum_1_to_100():\n    total = 0\n    i = 1\...  0
# 2  def print_and_store():\n    numbers = []\n    ...  0
# 3  def print_and_store_reverse():\n    numbers = ...  0
# 4  def is_prime(num):\n    i = 2\n    while i < n...  0

# %%
train_full[["Estado incial","Transformación de estado","Estado final"]]=train_full['Solución'].apply(DGries_states).apply(pd.Series)
# Out:
# Streaming output truncated to the last 5000 lines.
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body

# %%
train_full.dropna(inplace=True)

# %%
train_full
# Out:
#                                                Problema  \
# 0     Write a Python function that returns the facto...
# 1     Write a Python function that returns the sum o...
# 2     Write a Python function that prints the number...
# 3     Write a Python function to print the numbers f...
# 4     Write a Python function to check if a number i...
# ...                                                 ...
# 4130      calculate how many numbers are divisible by 3
# 4131      calculate how many numbers are divisible by 3
# 4132      calculate how many numbers are divisible by 3
# 4133      calculate how many numbers are divisible by 3
# 4134      calculate how many numbers are divisible by 3
#
#                                                Solución  y  \
# 0     def factorial(n):\n    result = 0\n    i = 1\n...  0
# 1     def sum_1_to_100():\n    total = 0\n    i = 1\...  0
# 2     def print_and_store():\n    numbers = []\n    ...  0
# 3     def print_and_store_reverse():\n    numbers = ...  0
# 4     def is_prime(num):\n    i = 2\n    while i < n...  0
# ...                                                 ... ..
# 4130  def buggy_count_mult_3(n):\n    i = 0\n    cou...  6
# 4131  def buggy_count_mult_3(n):\n    i = 0\n    cou...  6
# 4132  def buggy_count_mult_3(n):\n    count = 0\n   ...  6
# 4133  def buggy_count_mult_3(n):\n    count = 0\n   ...  6
# 4134  def buggy_count_mult_3(n):\n    count = 0\n   ...  6
#
#                 Estado incial  \
# 0       result = 0\n    i = 1
# 1        total = 0\n    i = 1
# 2     numbers = []\n    i = 0
# 3     numbers = []\n    i = 0
# 4                       i = 2
# ...                       ...
# 4130     i = 0\n    count = 0
# 4131     i = 0\n    count = 0
# 4132     count = 0\n    i = 0
# 4133     count = 0\n    i = 0
# 4134     count = 0\n    i = 0
#
#                                Transformación de estado Estado final
# 0                                   result += i\ni += 1       i <= n
# 1                                    total += i\ni += 2      i < 100
# 2                      print(i)\nnumbers[i] = i\ni += 1       i < 10
# 3              print(10 - i)\nnumbers.append(i)\ni += 1       i < 10
# 4            if num % i == 0:\n    return False\ni += 1      i < num
# ...                                                 ...          ...
# 4130   if i % 3 == 0:\n    count = count + 1\ni = i + 1        i < n
# 4131             if i % 3 == 0:\n    count += 1\ni += 1   not i >= n
# 4132              if not i % 3:\n    count += 1\ni += 1        n > i
# 4133  if i % 3 == 0 and True:\n    count = count + 1...       i != n
# 4134                   count += int(i % 3 == 0)\ni += 1        i < n
#
# [4094 rows x 6 columns]

# %%
encoder=EncodeTextSource()
encoder.start_tokenizer()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/498 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]

# %%
# %%time
problem=train_full['Problema'].apply(encoder.tokenize_and_generate_embeddings_descriptions).to_numpy()
code=train_full['Solución'].apply(encoder.tokenize_and_generate_embeddings_codes).to_numpy()
startstate = train_full['Estado incial'].apply(encoder.tokenize_and_generate_embeddings_codes).to_numpy()
finalstate = train_full['Estado final'].apply(encoder.tokenize_and_generate_embeddings_codes).to_numpy()
transstate = train_full['Transformación de estado'].apply(encoder.tokenize_and_generate_embeddings_codes).to_numpy()
# Out:
# CPU times: user 3min 2s, sys: 1.41 s, total: 3min 3s
# Wall time: 3min 27s

# %%
problem.shape,code.shape,startstate.shape,finalstate.shape,transstate.shape
# Out:
# ((4094,), (4094,), (4094,), (4094,), (4094,))

# %%
print(startstate.shape)
print(startstate[1262].shape)
# Out:
# (4094,)
# (1, 9, 768)

# %%
Xp=np.array([sentence[0].mean(axis=0) for sentence in problem])
Xcode=np.array([sentence[0].mean(axis=0) for sentence in code])
Xs=np.array([sentence[0].mean(axis=0) for sentence in startstate])
Xf=np.array([sentence[0].mean(axis=0) for sentence in finalstate])
Xt=np.array([sentence[0].mean(axis=0) for sentence in transstate])
Xp.shape,Xs.shape,Xf.shape,Xt.shape
# Out:
# ((4094, 768), (4094, 768), (4094, 768), (4094, 768))

# %%
y=train_full['y']
y=y.to_numpy()
np.unique(y)
# Out:
# array([0, 1, 2, 3, 4, 5, 6])

# %%
from sklearn.model_selection import train_test_split

Xp_train,Xp_test,Xcode_train,Xcode_test,Xs_train,Xs_test,Xt_train,Xt_test,Xf_train,Xf_test,y_train,y_test=train_test_split(Xp,Xcode,Xs,Xt,Xf,y,test_size=0.2,random_state=2023, stratify=y)

# %%
Xp_train.shape,Xp_test.shape,Xcode_train.shape, Xcode_test.shape, Xs_train.shape,Xs_test.shape,Xt_train.shape,Xt_test.shape,Xf_train.shape,Xf_test.shape,y_train.shape,y_test.shape
# Out:
# ((3275, 768),
#  (819, 768),
#  (3275, 768),
#  (819, 768),
#  (3275, 768),
#  (819, 768),
#  (3275, 768),
#  (819, 768),
#  (3275, 768),
#  (819, 768),
#  (3275,),
#  (819,))

# %% [markdown]
# # Keras model

# %%
from tensorflow.keras import backend as K
import gc
def ANNTC(input,base,pow_initial,num_max_blocks):

  drop_out=0.5
  print("base",base,"pow",pow_initial,"num_max_blocks",num_max_blocks)
  n=num_max_blocks//2
  neurons=int(base**(pow_initial+n+1))
  # Encoder
  x=None
  print("Encoder",n)
  try:
    for i in range(n):
      x=Dense(neurons)(input)
      x=BatchNormalization()(x)
      x=Activation('relu')(x)
      x=Dropout(drop_out)(x)
      input=x
      drop_out=0.2
      print("Block ",i,neurons)
      neurons=int(neurons/base)



    #BottleNeck
    x=Dense(neurons)(x)
    x=BatchNormalization()(x)
    x=Activation('relu')(x)
    x=Dropout(0.2)(x)
    print("BottleNeck",neurons)

    # Decoder
    print("Decoder",n)
    for i in range(n):
      neurons=int(neurons*base)
      print("Block ",i,neurons)
      x=Dense(neurons)(x)
      x=BatchNormalization()(x)
      x=Activation('relu')(x)
      x=Dropout(drop_out)(x)
      if i==n-1:
        drop_out=0.5
      drop_out=0.2
  except Exception as err:

    K.clear_session()
    gc.collect()
    del x
    print(f"Unexpected {err=}, {type(err)=}")
    raise

  return x

def neural_network_all(problem,code,start_input,trass_input,final_input,base=10,pow_initial=4,num_max_blocks=3):
  mlp_p=ANNTC(problem,base,pow_initial,num_max_blocks)
  mlp_code=ANNTC(code,base,pow_initial,num_max_blocks)
  mlp_s=ANNTC(start_input,base,pow_initial,num_max_blocks)
  mlp_t=ANNTC(trass_input,base,pow_initial,num_max_blocks)
  mlp_f=ANNTC(final_input,base,pow_initial,num_max_blocks)
  ## Concatenate All models
  combined = concatenate([mlp_p,mlp_code ,mlp_s, mlp_t,mlp_f])
  ## output layer
  output=Dense(8)(combined)
  output=BatchNormalization()(output)
  output=Activation('softmax')(output)
  ## Model
  model = Model(inputs=[problem_input,code,start_input, trass_input,final_input], outputs=output)
  return model

def neural_network_code_gries(code_input,start_input,trass_input,final_input,base=10,pow_initial=4,num_max_blocks=3):
  mlp_code=ANNTC(code_input,base,pow_initial,num_max_blocks)
  mlp_s=ANNTC(start_input,base,pow_initial,num_max_blocks)
  mlp_t=ANNTC(trass_input,base,pow_initial,num_max_blocks)
  mlp_f=ANNTC(final_input,base,pow_initial,num_max_blocks)
  ## Concatenate All models
  combined = concatenate([mlp_code, mlp_s, mlp_t,mlp_f])
  ## output layer
  output=Dense(8)(combined)
  output=BatchNormalization()(output)
  output=Activation('softmax')(output)
  ## Model
  model = Model(inputs=[code_input, start_input, trass_input,final_input], outputs=output)
  return model


def neural_network(problem,start_input,trass_input,final_input,base=10,pow_initial=4,num_max_blocks=3):
  mlp_p=ANNTC(problem,base,pow_initial,num_max_blocks)
  mlp_s=ANNTC(start_input,base,pow_initial,num_max_blocks)
  mlp_t=ANNTC(trass_input,base,pow_initial,num_max_blocks)
  mlp_f=ANNTC(final_input,base,pow_initial,num_max_blocks)
  ## Concatenate All models
  combined = concatenate([mlp_p, mlp_s, mlp_t,mlp_f])
  ## output layer
  output=Dense(8)(combined)
  output=BatchNormalization()(output)
  output=Activation('softmax')(output)
  ## Model
  model = Model(inputs=[problem_input, start_input, trass_input,final_input], outputs=output)
  return model

def neural_network_wproblem(start_input,trass_input,final_input,base=10,pow_initial=4,num_max_blocks=3):
  mlp_s=ANNTC(start_input,base,pow_initial,num_max_blocks)
  mlp_t=ANNTC(trass_input,base,pow_initial,num_max_blocks)
  mlp_f=ANNTC(final_input,base,pow_initial,num_max_blocks)
  ## Concatenate All models
  combined = concatenate([mlp_s, mlp_t,mlp_f])
  ## output layer
  output=Dense(8)(combined)
  output=BatchNormalization()(output)
  output=Activation('softmax')(output)
  ## Model
  model = Model(inputs=[start_input, trass_input,final_input], outputs=output)
  return model

def neural_network_problem_code(problem,code_input,base=10,pow_initial=4,num_max_blocks=3):
  mlp_p=ANNTC(problem,base,pow_initial,num_max_blocks)
  mlp_code=ANNTC(code_input,base,pow_initial,num_max_blocks)
  ## Concatenate All models
  combined = concatenate([mlp_p, mlp_code])
  ## output layer
  output=Dense(8)(combined)
  output=BatchNormalization()(output)
  output=Activation('softmax')(output)
  ## Model
  model = Model(inputs=[problem, code_input], outputs=output)
  return model

def neural_network_code(code_input,base=10,pow_initial=4,num_max_blocks=3):

  mlp_code=ANNTC(code_input,base,pow_initial,num_max_blocks)
  ## output layer
  output=Dense(8)(mlp_code)
  output=BatchNormalization()(output)
  output=Activation('softmax')(output)
  ## Model
  model = Model(inputs=[code_input], outputs=output)
  return model

# %%
import numpy as np
np.linspace(5,70,14)
# Out:
# array([ 5., 10., 15., 20., 25., 30., 35., 40., 45., 50., 55., 60., 65.,
#        70.])

# %%
models=[]
models_names=["problemall","problem_gries","code_gries","gries","problem_code","code"]

problem_input=Input((768,))
code_input=Input((768,))
start_input=Input((768,))
trass_input=Input((768,))
final_input=Input((768,))

print("problem all")
models.append(neural_network_all(problem_input,code_input,start_input,trass_input,final_input,base=8,pow_initial=1, num_max_blocks=3))
print("problem gries")
models.append(neural_network(problem_input,start_input,trass_input,final_input,base=8,pow_initial=1, num_max_blocks=3))
print("problem code gries")
models.append(neural_network_code_gries(code_input,start_input,trass_input,final_input,base=8,pow_initial=1, num_max_blocks=3))
print("gries")
models.append(neural_network_wproblem(start_input,trass_input,final_input,base=8,pow_initial=1, num_max_blocks=3))
print("problem code")
models.append(neural_network_problem_code(problem_input,code_input,base=8,pow_initial=1, num_max_blocks=3))
print("code")
models.append(neural_network_code(code_input,base=8,pow_initial=1, num_max_blocks=3))
# Out:
# problem all
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# problem gries
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# problem code gries
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# gries
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# problem code
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# code
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
from time import time
#tensorflow random state
tf.random.set_seed(2023)

times=[]
max_accuracies=[]
max_val_accuracies=[]
max_val_losses=[]
max_losses=[]
learning_rates=[]
Model_Xtrain=[Xp_train,Xcode_train,Xs_train,Xt_train,Xf_train]

for i,my_model in enumerate(models):
  print(models_names[i])

  problem_input=Input((768,))
  start_input=Input((768,))
  trass_input=Input((768,))
  final_input=Input((768,))

  patience=60

  my_model.compile(loss='sparse_categorical_crossentropy',
                optimizer=Adam(),
                metrics=['accuracy'])

  es = EarlyStopping(monitor='val_loss', mode='min', patience=patience)

  mc = ModelCheckpoint('/content/drive/MyDrive/UDENAR/ProyectosGrado/Errol/Ginna/Tuning/BestModels/ablationsBERT_finall_{0}.keras'.format(models_names[i]), monitor='val_loss', mode='min', save_best_only=True)
  reduce_lr = ReduceLROnPlateau(
      monitor='val_loss',
      factor=0.1,
      patience=patience//2,
      min_lr=1e-9,
      verbose=1
  )
  if(i==1):
    Model_Xtrain=[Xp_train,Xs_train,Xt_train,Xf_train]
  if(i==2):
    Model_Xtrain=[Xcode_train,Xs_train,Xt_train,Xf_train]
  if(i==3):
    Model_Xtrain=[Xs_train,Xt_train,Xf_train]
  if(i==4):
    Model_Xtrain=[Xp_train,Xcode_train]
  if(i==5):
    Model_Xtrain=[Xcode_train]

  time1=time()
  history=my_model.fit(Model_Xtrain,y_train,batch_size=100,epochs=1000,
            validation_split=0.2,callbacks=[es, mc,reduce_lr])
  time2=time()

  df_histories=pd.DataFrame(history.history)
  df_histories.to_csv('/content/drive/MyDrive/UDENAR/ProyectosGrado/Errol/Ginna/Tuning/BestModels/ablations_best_finallBERT_{0}.csv'.format(models_names[i]))

  times.append(time2-time1)

  max_accuracies.append(max(history.history['accuracy']))
  max_val_accuracies.append(max(history.history['val_accuracy']))
  max_val_losses.append(max(history.history['val_loss']))
  max_losses.append(max(history.history['loss']))
  learning_rates.append(min(history.history['learning_rate']))

  print(f"{patience}")
  print("times=",time2-time1)
  print("max_val_accuracy",max(history.history['val_accuracy']))
  print("max_accuracy",max(history.history['accuracy']))


  print("max_val_loss",max(history.history['val_loss']))
  print("max_loss",max(history.history['loss']))
  print("learning_rate",min(history.history['learning_rate']))
# Out:
# problemall
# Epoch 1/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 36s 574ms/step - accuracy: 0.2504 - loss: 2.0945 - val_accuracy: 0.2733 - val_loss: 1.9519 - learning_rate: 0.0010
# Epoch 2/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5735 - loss: 1.4412 - val_accuracy: 0.2244 - val_loss: 1.9956 - learning_rate: 0.0010
# Epoch 3/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6924 - loss: 1.2521 - val_accuracy: 0.2855 - val_loss: 1.9854 - learning_rate: 0.0010
# Epoch 4/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.7370 - loss: 1.1234 - val_accuracy: 0.3435 - val_loss: 1.9129 - learning_rate: 0.0010
# Epoch 5/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.7928 - loss: 1.0189 - val_accuracy: 0.4412 - val_loss: 1.7818 - learning_rate: 0.0010
# Epoch 6/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.8186 - loss: 0.9541 - val_accuracy: 0.5649 - val_loss: 1.6928 - learning_rate: 0.0010
# Epoch 7/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.8410 - loss: 0.8897 - val_accuracy: 0.6855 - val_loss: 1.5775 - learning_rate: 0.0010
# Epoch 8/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8458 - loss: 0.8434 - val_accuracy: 0.6962 - val_loss: 1.5263 - learning_rate: 0.0010
# Epoch 9/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.8808 - loss: 0.7741 - val_accuracy: 0.6809 - val_loss: 1.4283 - learning_rate: 0.0010
# Epoch 10/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8800 - loss: 0.7384 - val_accuracy: 0.7863 - val_loss: 1.2714 - learning_rate: 0.0010
# Epoch 11/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8958 - loss: 0.7012 - val_accuracy: 0.8015 - val_loss: 1.1248 - learning_rate: 0.0010
# Epoch 12/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9140 - loss: 0.6508 - val_accuracy: 0.7450 - val_loss: 1.0598 - learning_rate: 0.0010
# Epoch 13/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9114 - loss: 0.6316 - val_accuracy: 0.7603 - val_loss: 1.0734 - learning_rate: 0.0010
# Epoch 14/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9136 - loss: 0.6067 - val_accuracy: 0.8550 - val_loss: 0.8825 - learning_rate: 0.0010
# Epoch 15/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9264 - loss: 0.5720 - val_accuracy: 0.8534 - val_loss: 0.8617 - learning_rate: 0.0010
# Epoch 16/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9263 - loss: 0.5422 - val_accuracy: 0.8458 - val_loss: 0.7737 - learning_rate: 0.0010
# Epoch 17/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9426 - loss: 0.5093 - val_accuracy: 0.8443 - val_loss: 0.8012 - learning_rate: 0.0010
# Epoch 18/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9391 - loss: 0.4829 - val_accuracy: 0.8534 - val_loss: 0.7672 - learning_rate: 0.0010
# Epoch 19/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9510 - loss: 0.4647 - val_accuracy: 0.8687 - val_loss: 0.7334 - learning_rate: 0.0010
# Epoch 20/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9549 - loss: 0.4375 - val_accuracy: 0.8550 - val_loss: 0.7522 - learning_rate: 0.0010
# Epoch 21/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9510 - loss: 0.4298 - val_accuracy: 0.7985 - val_loss: 0.8186 - learning_rate: 0.0010
# Epoch 22/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9519 - loss: 0.4054 - val_accuracy: 0.8443 - val_loss: 0.6711 - learning_rate: 0.0010
# Epoch 23/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9491 - loss: 0.3984 - val_accuracy: 0.8931 - val_loss: 0.6633 - learning_rate: 0.0010
# Epoch 24/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9661 - loss: 0.3764 - val_accuracy: 0.9023 - val_loss: 0.5961 - learning_rate: 0.0010
# Epoch 25/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9688 - loss: 0.3510 - val_accuracy: 0.9221 - val_loss: 0.5439 - learning_rate: 0.0010
# Epoch 26/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9648 - loss: 0.3455 - val_accuracy: 0.8840 - val_loss: 0.6213 - learning_rate: 0.0010
# Epoch 27/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9643 - loss: 0.3281 - val_accuracy: 0.8931 - val_loss: 0.5323 - learning_rate: 0.0010
# Epoch 28/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9675 - loss: 0.3141 - val_accuracy: 0.8977 - val_loss: 0.5363 - learning_rate: 0.0010
# Epoch 29/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9732 - loss: 0.3052 - val_accuracy: 0.8947 - val_loss: 0.5263 - learning_rate: 0.0010
# Epoch 30/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9748 - loss: 0.2904 - val_accuracy: 0.9191 - val_loss: 0.4423 - learning_rate: 0.0010
# Epoch 31/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9761 - loss: 0.2799 - val_accuracy: 0.9008 - val_loss: 0.4386 - learning_rate: 0.0010
# Epoch 32/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9777 - loss: 0.2670 - val_accuracy: 0.9252 - val_loss: 0.4155 - learning_rate: 0.0010
# Epoch 33/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9728 - loss: 0.2730 - val_accuracy: 0.9267 - val_loss: 0.3959 - learning_rate: 0.0010
# Epoch 34/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9810 - loss: 0.2540 - val_accuracy: 0.9130 - val_loss: 0.4259 - learning_rate: 0.0010
# Epoch 35/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9818 - loss: 0.2459 - val_accuracy: 0.9282 - val_loss: 0.3907 - learning_rate: 0.0010
# Epoch 36/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9752 - loss: 0.2436 - val_accuracy: 0.9313 - val_loss: 0.3691 - learning_rate: 0.0010
# Epoch 37/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9817 - loss: 0.2313 - val_accuracy: 0.9008 - val_loss: 0.4220 - learning_rate: 0.0010
# Epoch 38/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9812 - loss: 0.2200 - val_accuracy: 0.9237 - val_loss: 0.3817 - learning_rate: 0.0010
# Epoch 39/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9868 - loss: 0.2073 - val_accuracy: 0.9023 - val_loss: 0.4308 - learning_rate: 0.0010
# Epoch 40/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9812 - loss: 0.2127 - val_accuracy: 0.9176 - val_loss: 0.3683 - learning_rate: 0.0010
# Epoch 41/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9842 - loss: 0.2057 - val_accuracy: 0.9176 - val_loss: 0.4053 - learning_rate: 0.0010
# Epoch 42/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9863 - loss: 0.1885 - val_accuracy: 0.9130 - val_loss: 0.3866 - learning_rate: 0.0010
# Epoch 43/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9900 - loss: 0.1845 - val_accuracy: 0.8840 - val_loss: 0.4711 - learning_rate: 0.0010
# Epoch 44/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9870 - loss: 0.1885 - val_accuracy: 0.9176 - val_loss: 0.3964 - learning_rate: 0.0010
# Epoch 45/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9890 - loss: 0.1745 - val_accuracy: 0.8519 - val_loss: 0.6029 - learning_rate: 0.0010
# Epoch 46/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9896 - loss: 0.1702 - val_accuracy: 0.9099 - val_loss: 0.4239 - learning_rate: 0.0010
# Epoch 47/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9825 - loss: 0.1732 - val_accuracy: 0.9221 - val_loss: 0.3862 - learning_rate: 0.0010
# Epoch 48/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9887 - loss: 0.1639 - val_accuracy: 0.8916 - val_loss: 0.4407 - learning_rate: 0.0010
# Epoch 49/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9923 - loss: 0.1538 - val_accuracy: 0.8977 - val_loss: 0.4081 - learning_rate: 0.0010
# Epoch 50/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9880 - loss: 0.1542 - val_accuracy: 0.9359 - val_loss: 0.3480 - learning_rate: 0.0010
# Epoch 51/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9888 - loss: 0.1517 - val_accuracy: 0.9160 - val_loss: 0.3316 - learning_rate: 0.0010
# Epoch 52/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9902 - loss: 0.1454 - val_accuracy: 0.9374 - val_loss: 0.3229 - learning_rate: 0.0010
# Epoch 53/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9906 - loss: 0.1397 - val_accuracy: 0.8702 - val_loss: 0.4514 - learning_rate: 0.0010
# Epoch 54/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9952 - loss: 0.1332 - val_accuracy: 0.9221 - val_loss: 0.2965 - learning_rate: 0.0010
# Epoch 55/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9893 - loss: 0.1318 - val_accuracy: 0.9267 - val_loss: 0.2880 - learning_rate: 0.0010
# Epoch 56/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9888 - loss: 0.1331 - val_accuracy: 0.9115 - val_loss: 0.3485 - learning_rate: 0.0010
# Epoch 57/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9903 - loss: 0.1278 - val_accuracy: 0.9282 - val_loss: 0.2851 - learning_rate: 0.0010
# Epoch 58/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9914 - loss: 0.1193 - val_accuracy: 0.9435 - val_loss: 0.2364 - learning_rate: 0.0010
# Epoch 59/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9933 - loss: 0.1189 - val_accuracy: 0.9405 - val_loss: 0.2387 - learning_rate: 0.0010
# Epoch 60/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9928 - loss: 0.1147 - val_accuracy: 0.9267 - val_loss: 0.3091 - learning_rate: 0.0010
# Epoch 61/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9899 - loss: 0.1178 - val_accuracy: 0.9359 - val_loss: 0.3029 - learning_rate: 0.0010
# Epoch 62/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9919 - loss: 0.1111 - val_accuracy: 0.9069 - val_loss: 0.3422 - learning_rate: 0.0010
# Epoch 63/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9951 - loss: 0.1064 - val_accuracy: 0.9435 - val_loss: 0.2603 - learning_rate: 0.0010
# Epoch 64/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.1035 - val_accuracy: 0.9237 - val_loss: 0.2642 - learning_rate: 0.0010
# Epoch 65/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9917 - loss: 0.1101 - val_accuracy: 0.9481 - val_loss: 0.2274 - learning_rate: 0.0010
# Epoch 66/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9904 - loss: 0.1074 - val_accuracy: 0.9435 - val_loss: 0.2545 - learning_rate: 0.0010
# Epoch 67/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9944 - loss: 0.1005 - val_accuracy: 0.9313 - val_loss: 0.2924 - learning_rate: 0.0010
# Epoch 68/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9943 - loss: 0.1010 - val_accuracy: 0.9405 - val_loss: 0.2822 - learning_rate: 0.0010
# Epoch 69/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9941 - loss: 0.0938 - val_accuracy: 0.9221 - val_loss: 0.2930 - learning_rate: 0.0010
# Epoch 70/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9930 - loss: 0.0932 - val_accuracy: 0.9328 - val_loss: 0.2655 - learning_rate: 0.0010
# Epoch 71/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9956 - loss: 0.0942 - val_accuracy: 0.9542 - val_loss: 0.2143 - learning_rate: 0.0010
# Epoch 72/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9936 - loss: 0.0919 - val_accuracy: 0.9405 - val_loss: 0.2349 - learning_rate: 0.0010
# Epoch 73/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9876 - loss: 0.0974 - val_accuracy: 0.9206 - val_loss: 0.3136 - learning_rate: 0.0010
# Epoch 74/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9946 - loss: 0.0898 - val_accuracy: 0.9389 - val_loss: 0.2488 - learning_rate: 0.0010
# Epoch 75/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9962 - loss: 0.0835 - val_accuracy: 0.9389 - val_loss: 0.2367 - learning_rate: 0.0010
# Epoch 76/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9949 - loss: 0.0795 - val_accuracy: 0.9008 - val_loss: 0.3701 - learning_rate: 0.0010
# Epoch 77/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9960 - loss: 0.0795 - val_accuracy: 0.9191 - val_loss: 0.3039 - learning_rate: 0.0010
# Epoch 78/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9934 - loss: 0.0777 - val_accuracy: 0.9420 - val_loss: 0.2451 - learning_rate: 0.0010
# Epoch 79/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9970 - loss: 0.0763 - val_accuracy: 0.9374 - val_loss: 0.2579 - learning_rate: 0.0010
# Epoch 80/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9961 - loss: 0.0722 - val_accuracy: 0.9237 - val_loss: 0.2593 - learning_rate: 0.0010
# Epoch 81/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9938 - loss: 0.0765 - val_accuracy: 0.9481 - val_loss: 0.2205 - learning_rate: 0.0010
# Epoch 82/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9972 - loss: 0.0694 - val_accuracy: 0.9481 - val_loss: 0.2229 - learning_rate: 0.0010
# Epoch 83/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9960 - loss: 0.0708 - val_accuracy: 0.9542 - val_loss: 0.1923 - learning_rate: 0.0010
# Epoch 84/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9987 - loss: 0.0674 - val_accuracy: 0.9298 - val_loss: 0.2588 - learning_rate: 0.0010
# Epoch 85/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9956 - loss: 0.0687 - val_accuracy: 0.9374 - val_loss: 0.2435 - learning_rate: 0.0010
# Epoch 86/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9959 - loss: 0.0671 - val_accuracy: 0.8763 - val_loss: 0.3827 - learning_rate: 0.0010
# Epoch 87/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9974 - loss: 0.0665 - val_accuracy: 0.9420 - val_loss: 0.2447 - learning_rate: 0.0010
# Epoch 88/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9982 - loss: 0.0590 - val_accuracy: 0.9420 - val_loss: 0.2170 - learning_rate: 0.0010
# Epoch 89/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9957 - loss: 0.0624 - val_accuracy: 0.9344 - val_loss: 0.2232 - learning_rate: 0.0010
# Epoch 90/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9957 - loss: 0.0620 - val_accuracy: 0.9496 - val_loss: 0.2149 - learning_rate: 0.0010
# Epoch 91/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9964 - loss: 0.0617 - val_accuracy: 0.9466 - val_loss: 0.2244 - learning_rate: 0.0010
# Epoch 92/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9956 - loss: 0.0608 - val_accuracy: 0.9450 - val_loss: 0.2394 - learning_rate: 0.0010
# Epoch 93/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9949 - loss: 0.0642 - val_accuracy: 0.9466 - val_loss: 0.2393 - learning_rate: 0.0010
# Epoch 94/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9959 - loss: 0.0602 - val_accuracy: 0.9282 - val_loss: 0.2572 - learning_rate: 0.0010
# Epoch 95/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.
1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9996 - loss: 0.0281 - val_accuracy: 0.9542 - val_loss: 0.1595 - learning_rate: 1.0000e-05
# Epoch 164/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9993 - loss: 0.0275 - val_accuracy: 0.9542 - val_loss: 0.1594 - learning_rate: 1.0000e-05
# Epoch 165/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9995 - loss: 0.0271 - val_accuracy: 0.9542 - val_loss: 0.1591 - learning_rate: 1.0000e-05
# Epoch 166/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9996 - loss: 0.0287 - val_accuracy: 0.9542 - val_loss: 0.1589 - learning_rate: 1.0000e-05
# Epoch 167/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 0.0267 - val_accuracy: 0.9542 - val_loss: 0.1585 - learning_rate: 1.0000e-05
# Epoch 168/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9991 - loss: 0.0281 - val_accuracy: 0.9542 - val_loss: 0.1585 - learning_rate: 1.0000e-05
# Epoch 169/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9993 - loss: 0.0307 - val_accuracy: 0.9542 - val_loss: 0.1584 - learning_rate: 1.0000e-05
# Epoch 170/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9996 - loss: 0.0293 - val_accuracy: 0.9542 - val_loss: 0.1585 - learning_rate: 1.0000e-05
# Epoch 171/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9999 - loss: 0.0281 - val_accuracy: 0.9542 - val_loss: 0.1583 - learning_rate: 1.0000e-05
# Epoch 172/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9993 - loss: 0.0293 - val_accuracy: 0.9542 - val_loss: 0.1586 - learning_rate: 1.0000e-05
# Epoch 173/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9982 - loss: 0.0292 - val_accuracy: 0.9542 - val_loss: 0.1584 - learning_rate: 1.0000e-05
# Epoch 174/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0285 - val_accuracy: 0.9542 - val_loss: 0.1582 - learning_rate: 1.0000e-05
# Epoch 175/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9991 - loss: 0.0283 - val_accuracy: 0.9542 - val_loss: 0.1584 - learning_rate: 1.0000e-05
# Epoch 176/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9992 - loss: 0.0298 - val_accuracy: 0.9542 - val_loss: 0.1584 - learning_rate: 1.0000e-05
# Epoch 177/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9996 - loss: 0.0279 - val_accuracy: 0.9542 - val_loss: 0.1582 - learning_rate: 1.0000e-05
# Epoch 178/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 1.0000 - loss: 0.0276 - val_accuracy: 0.9542 - val_loss: 0.1583 - learning_rate: 1.0000e-05
# Epoch 179/1000
# 22/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9985 - loss: 0.0299
# Epoch 179: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9985 - loss: 0.0298 - val_accuracy: 0.9542 - val_loss: 0.1583 - learning_rate: 1.0000e-05
# 60
# times= 120.52593517303467
# max_val_accuracy 0.9618320465087891
# max_accuracy 1.0
# max_val_loss 1.9955724477767944
# max_loss 1.8657675981521606
# learning_rate 1.0000000656873453e-05
# problem_gries
# Epoch 1/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 29s 451ms/step - accuracy: 0.2518 - loss: 2.0989 - val_accuracy: 0.2763 - val_loss: 1.9608 - learning_rate: 0.0010
# Epoch 2/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5086 - loss: 1.5012 - val_accuracy: 0.2290 - val_loss: 2.0093 - learning_rate: 0.0010
# Epoch 3/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6585 - loss: 1.2911 - val_accuracy: 0.4137 - val_loss: 1.9354 - learning_rate: 0.0010
# Epoch 4/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7259 - loss: 1.1632 - val_accuracy: 0.3008 - val_loss: 1.8747 - learning_rate: 0.0010
# Epoch 5/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7788 - loss: 1.0465 - val_accuracy: 0.3450 - val_loss: 1.7954 - learning_rate: 0.0010
# Epoch 6/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7899 - loss: 0.9866 - val_accuracy: 0.5206 - val_loss: 1.6212 - learning_rate: 0.0010
# Epoch 7/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8232 - loss: 0.9126 - val_accuracy: 0.7252 - val_loss: 1.4539 - learning_rate: 0.0010
# Epoch 8/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8407 - loss: 0.8568 - val_accuracy: 0.6107 - val_loss: 1.4432 - learning_rate: 0.0010
# Epoch 9/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.
1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9701 - loss: 0.2681 - val_accuracy: 0.9191 - val_loss: 0.4294 - learning_rate: 0.0010
# Epoch 36/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9727 - loss: 0.2580 - val_accuracy: 0.8855 - val_loss: 0.4982 - learning_rate: 0.0010
# Epoch 37/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9733 - loss: 0.2575 - val_accuracy: 0.8260 - val_loss: 0.5905 - learning_rate: 0.0010
# Epoch 38/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9727 - loss: 0.2461 - val_accuracy: 0.9023 - val_loss: 0.4511 - learning_rate: 0.0010
# Epoch 39/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9771 - loss: 0.2314 - val_accuracy: 0.7695 - val_loss: 0.6837 - learning_rate: 0.0010
# Epoch 40/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9799 - loss: 0.2293 - val_accuracy: 0.8916 - val_loss: 0.4509 - learning_rate: 0.0010
# Epoch 41/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9718 - loss: 0.2306 - val_accuracy: 0.9084 - val_loss: 0.4496 - learning_rate: 0.0010
# Epoch 42/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9798 - loss: 0.2197 - val_accuracy: 0.8947 - val_loss: 0.4355 - learning_rate: 0.0010
# Epoch 43/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9780 - loss: 0.2083 - val_accuracy: 0.9160 - val_loss: 0.3627 - learning_rate: 0.0010
# Epoch 44/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9766 - loss: 0.2124 - val_accuracy: 0.8840 - val_loss: 0.4463 - learning_rate: 0.0010
# Epoch 45/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9767 - loss: 0.2011 - val_accuracy: 0.8992 - val_loss: 0.4122 - learning_rate: 0.0010
# Epoch 46/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9789 - loss: 0.1876 - val_accuracy: 0.8855 - val_loss: 0.4267 - learning_rate: 0.0010
# Epoch 47/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9768 - loss: 0.1915 - val_accuracy: 0.9099 - val_loss: 0.4073 - learning_rate: 0.0010
# Epoch 48/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9813 - loss: 0.1791 - val_accuracy: 0.9191 - val_loss: 0.3416 - learning_rate: 0.0010
# Epoch 49/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9792 - loss: 0.1789 - val_accuracy: 0.9237 - val_loss: 0.3310 - learning_rate: 0.0010
# Epoch 50/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9885 - loss: 0.1657 - val_accuracy: 0.9298 - val_loss: 0.3360 - learning_rate: 0.0010
# Epoch 51/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9836 - loss: 0.1703 - val_accuracy: 0.9267 - val_loss: 0.3097 - learning_rate: 0.0010
# Epoch 52/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9838 - loss: 0.1714 - val_accuracy: 0.9221 - val_loss: 0.3232 - learning_rate: 0.0010
# Epoch 53/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9791 - loss: 0.1657 - val_accuracy: 0.9130 - val_loss: 0.4105 - learning_rate: 0.0010
# Epoch 54/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9839 - loss: 0.1594 - val_accuracy: 0.9435 - val_loss: 0.2882 - learning_rate: 0.0010
# Epoch 55/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9778 - loss: 0.1635 - val_accuracy: 0.9237 - val_loss: 0.3231 - learning_rate: 0.0010
# Epoch 56/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9826 - loss: 0.1566 - val_accuracy: 0.9344 - val_loss: 0.3106 - learning_rate: 0.0010
# Epoch 57/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9820 - loss: 0.1561 - val_accuracy: 0.9267 - val_loss: 0.3325 - learning_rate: 0.0010
# Epoch 58/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9857 - loss: 0.1470 - val_accuracy: 0.8901 - val_loss: 0.3867 - learning_rate: 0.0010
# Epoch 59/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9862 - loss: 0.1360 - val_accuracy: 0.9389 - val_loss: 0.2671 - learning_rate: 0.0010
# Epoch 60/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9824 - loss: 0.1350 - val_accuracy: 0.9160 - val_loss: 0.3226 - learning_rate: 0.0010
# Epoch 61/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9842 - loss: 0.1339 - val_accuracy: 0.9359 - val_loss: 0.3166 - learning_rate: 0.0010
# Epoch 62/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9873 - loss: 0.1337 - val_accuracy: 0.9160 - val_loss: 0.3386 - learning_rate: 0.0010
# Epoch 63/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9830 - loss: 0.1335 - val_accuracy: 0.9176 - val_loss: 0.3089 - learning_rate: 0.0010
# Epoch 64/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9885 - loss: 0.1233 - val_accuracy: 0.9359 - val_loss: 0.2636 - learning_rate: 0.0010
# Epoch 65/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9890 - loss: 0.1220 - val_accuracy: 0.9282 - val_loss: 0.3597 - learning_rate: 0.0010
# Epoch 66/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9867 - loss: 0.1183 - val_accuracy: 0.8992 - val_loss: 0.3660 - learning_rate: 0.0010
# Epoch 67/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9877 - loss: 0.1207 - val_accuracy: 0.8702 - val_loss: 0.4358 - learning_rate: 0.0010
# Epoch 68/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9886 - loss: 0.1134 - val_accuracy: 0.9313 - val_loss: 0.3181 - learning_rate: 0.0010
# Epoch 69/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9903 - loss: 0.1140 - val_accuracy: 0.9191 - val_loss: 0.3158 - learning_rate: 0.0010
# Epoch 70/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9871 - loss: 0.1147 - val_accuracy: 0.8580 - val_loss: 0.4468 - learning_rate: 0.0010
# Epoch 71/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9923 - loss: 0.1055 - val_accuracy: 0.9237 - val_loss: 0.3014 - learning_rate: 0.0010
# Epoch 72/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9896 - loss: 0.1093 - val_accuracy: 0.6916 - val_loss: 0.7205 - learning_rate: 0.0010
# Epoch 73/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9867 - loss: 0.1065 - val_accuracy: 0.9206 - val_loss: 0.3081 - learning_rate: 0.0010
# Epoch 74/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9896 - loss: 0.1013 - val_accuracy: 0.9344 - val_loss: 0.2587 - learning_rate: 0.0010
# Epoch 75/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9890 - loss: 0.0984 - val_accuracy: 0.9313 - val_loss: 0.2629 - learning_rate: 0.0010
# Epoch 76/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9941 - loss: 0.0904 - val_accuracy: 0.9405 - val_loss: 0.2439 - learning_rate: 0.0010
# Epoch 77/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9942 - loss: 0.0945 - val_accuracy: 0.9298 - val_loss: 0.2759 - learning_rate: 0.0010
# Epoch 78/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9951 - loss: 0.0873 - val_accuracy: 0.9405 - val_loss: 0.2338 - learning_rate: 0.0010
# Epoch 79/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9892 - loss: 0.0955 - val_accuracy: 0.9298 - val_loss: 0.2880 - learning_rate: 0.0010
# Epoch 80/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9895 - loss: 0.0956 - val_accuracy: 0.9160 - val_loss: 0.3104 - learning_rate: 0.0010
# Epoch 81/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9923 - loss: 0.0944 - val_accuracy: 0.9130 - val_loss: 0.3154 - learning_rate: 0.0010
# Epoch 82/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9955 - loss: 0.0867 - val_accuracy: 0.9359 - val_loss: 0.2655 - learning_rate: 0.0010
# Epoch 83/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9914 - loss: 0.0871 - val_accuracy: 0.9344 - val_loss: 0.2410 - learning_rate: 0.0010
# Epoch 84/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9929 - loss: 0.0848 - val_accuracy: 0.9298 - val_loss: 0.2663 - learning_rate: 0.0010
# Epoch 85/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9894 - loss: 0.0873 - val_accuracy: 0.9191 - val_loss: 0.2993 - learning_rate: 0.0010
# Epoch 86/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9931 - loss: 0.0840 - val_accuracy: 0.8565 - val_loss: 0.4303 - learning_rate: 0.0010
# Epoch 87/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9913 - loss: 0.0839 - val_accuracy: 0.9481 - val_loss: 0.2260 - learning_rate: 0.0010
# Epoch 88/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.
- learning_rate: 1.0000e-04
# Epoch 188/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9963 - loss: 0.0381 - val_accuracy: 0.9435 - val_loss: 0.2507 - learning_rate: 1.0000e-04
# Epoch 189/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9961 - loss: 0.0381 - val_accuracy: 0.9466 - val_loss: 0.2501 - learning_rate: 1.0000e-04
# Epoch 190/1000
# 15/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9971 - loss: 0.0342
# Epoch 190: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9966 - loss: 0.0357 - val_accuracy: 0.9466 - val_loss: 0.2481 - learning_rate: 1.0000e-04
# Epoch 191/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9938 - loss: 0.0407 - val_accuracy: 0.9481 - val_loss: 0.2476 - learning_rate: 1.0000e-05
# Epoch 192/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9949 - loss: 0.0407 - val_accuracy: 0.9481 - val_loss: 0.2475 - learning_rate: 1.0000e-05
# Epoch 193/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9943 - loss: 0.0417 - val_accuracy: 0.9481 - val_loss: 0.2469 - learning_rate: 1.0000e-05
# Epoch 194/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9934 - loss: 0.0424 - val_accuracy: 0.9466 - val_loss: 0.2470 - learning_rate: 1.0000e-05
# Epoch 195/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9931 - loss: 0.0411 - val_accuracy: 0.9466 - val_loss: 0.2465 - learning_rate: 1.0000e-05
# Epoch 196/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9940 - loss: 0.0384 - val_accuracy: 0.9466 - val_loss: 0.2461 - learning_rate: 1.0000e-05
# Epoch 197/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9929 - loss: 0.0483 - val_accuracy: 0.9450 - val_loss: 0.2465 - learning_rate: 1.0000e-05
# Epoch 198/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9946 - loss: 0.0423 - val_accuracy: 0.9450 - val_loss: 0.2462 - learning_rate: 1.0000e-05
# Epoch 199/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9953 - loss: 0.0399 - val_accuracy: 0.9466 - val_loss: 0.2463 - learning_rate: 1.0000e-05
# Epoch 200/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9939 - loss: 0.0402 - val_accuracy: 0.9450 - val_loss: 0.2459 - learning_rate: 1.0000e-05
# Epoch 201/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9967 - loss: 0.0362 - val_accuracy: 0.9466 - val_loss: 0.2460 - learning_rate: 1.0000e-05
# Epoch 202/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9955 - loss: 0.0389 - val_accuracy: 0.9466 - val_loss: 0.2467 - learning_rate: 1.0000e-05
# Epoch 203/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9964 - loss: 0.0355 - val_accuracy: 0.9466 - val_loss: 0.2469 - learning_rate: 1.0000e-05
# Epoch 204/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9964 - loss: 0.0385 - val_accuracy: 0.9466 - val_loss: 0.2466 - learning_rate: 1.0000e-05
# Epoch 205/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9946 - loss: 0.0391 - val_accuracy: 0.9481 - val_loss: 0.2467 - learning_rate: 1.0000e-05
# Epoch 206/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9959 - loss: 0.0379 - val_accuracy: 0.9481 - val_loss: 0.2468 - learning_rate: 1.0000e-05
# Epoch 207/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9933 - loss: 0.0434 - val_accuracy: 0.9481 - val_loss: 0.2471 - learning_rate: 1.0000e-05
# Epoch 208/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9947 - loss: 0.0373 - val_accuracy: 0.9481 - val_loss: 0.2470 - learning_rate: 1.0000e-05
# Epoch 209/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9945 - loss: 0.0387 - val_accuracy: 0.9481 - val_loss: 0.2467 - learning_rate: 1.0000e-05
# Epoch 210/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9927 - loss: 0.0426 - val_accuracy: 0.9481 - val_loss: 0.2462 - learning_rate: 1.0000e-05
# Epoch 211/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9940 - loss: 0.0391 - val_accuracy: 0.9481 - val_loss: 0.2463 - learning_rate: 1.0000e-05
# Epoch 212/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9949 - loss: 0.0407 - val_accuracy: 0.9481 - val_loss: 0.2464 - learning_rate: 1.0000e-05
# Epoch 213/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9929 - loss: 0.0406 - val_accuracy: 0.9511 - val_loss: 0.2471 - learning_rate: 1.0000e-05
# Epoch 214/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9954 - loss: 0.0383 - val_accuracy: 0.9511 - val_loss: 0.2472 - learning_rate: 1.0000e-05
# Epoch 215/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9949 - loss: 0.0405 - val_accuracy: 0.9511 - val_loss: 0.2472 - learning_rate: 1.0000e-05
# Epoch 216/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9947 - loss: 0.0417 - val_accuracy: 0.9511 - val_loss: 0.2468 - learning_rate: 1.0000e-05
# Epoch 217/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9936 - loss: 0.0397 - val_accuracy: 0.9511 - val_loss: 0.2465 - learning_rate: 1.0000e-05
# Epoch 218/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9932 - loss: 0.0436 - val_accuracy: 0.9496 - val_loss: 0.2471 - learning_rate: 1.0000e-05
# Epoch 219/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9934 - loss: 0.0406 - val_accuracy: 0.9496 - val_loss: 0.2463 - learning_rate: 1.0000e-05
# Epoch 220/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9936 - loss: 0.0419
# Epoch 220: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9936 - loss: 0.0419 - val_accuracy: 0.9511 - val_loss: 0.2466 - learning_rate: 1.0000e-05
# 60
# times= 67.1112847328186
# max_val_accuracy 0.9541984796524048
# max_accuracy 0.9958015084266663
# max_val_loss 2.0621981620788574
# max_loss 2.096686363220215
# learning_rate 1.0000000656873453e-05

# %%
df_histories=pd.DataFrame({"times":times,"max_accuracies":max_accuracies,"max_val_accuracies":max_val_accuracies,"max_val_losses":max_val_losses,"max_losses":max_losses,"learning_rates":learning_rates})
df_histories.to_csv('/content/drive/MyDrive/UDENAR/ProyectosGrado/Errol/Ginna/Tuning/BestModels/ablations_finallBERT.csv')

# %%
df_histories
# Out:
#         times  max_accuracies  max_val_accuracies  max_val_losses  max_losses  \
# 0  169.172873        1.000000            0.942238        2.029496    2.024967
# 1  117.749322        1.000000            0.944043        1.936619    2.035028
# 2  119.699390        1.000000            0.945848        2.111512    1.978953
# 3  109.264185        0.999548            0.942238        2.041958    2.024786
# 4  104.880635        0.998644            0.938628        1.994298    2.186902
# 5   72.745415        0.995029            0.933213        2.424156    2.173478
#
#    learning_rates
# 0        0.000010
# 1        0.000001
# 2        0.000010
# 3        0.000100
# 4        0.000010
# 5        0.000010

# %%
from sklearn.metrics import matthews_corrcoef, precision_recall_curve, auc
from sklearn.preprocessing import label_binarize
import numpy as np

def calculate_mcc_multiclass(y_true, y_pred_probs):
    y_pred_labels = np.argmax(y_pred_probs, axis=1)
    # Convertir etiquetas verdaderas one-hot a etiquetas enteras si es necesario
    #y_true_labels = np.argmax(y_true, axis=1) if y_true.ndim > 1 else y_true
    return matthews_corrcoef(y_true, y_pred_labels)

def calculate_auc_pr_multiclass(y_true, y_pred_probs, average='macro'):
    n_classes = y_pred_probs.shape[1]
    #y_true_labels = np.argmax(y_true, axis=1) if y_true.ndim > 1 else y_true
    y_true_bin = label_binarize(y_true, classes=range(n_classes))

    auc_pr_list = []
    for i in range(n_classes):
        precision, recall, _ = precision_recall_curve(y_true_bin[:, i], y_pred_probs[:, i])
        auc_pr_list.append(auc(recall, precision))

    if average == 'macro':
        return np.mean(auc_pr_list)
    elif average == 'weighted':
        class_counts = y_true_bin.sum(axis=0)
        return np.average(auc_pr_list, weights=class_counts)
    else:
        return auc_pr_list

# %%
from tensorflow import keras
accuracies_predict=[]
loss_predict=[]
times_predict=[]
mccs_predict=[]
aucpr_predict=[]

Model_Xtest=[Xp_test,Xcode_test,Xs_test,Xt_test,Xf_test]
for i,my_model in enumerate(models):
  model=keras.models.load_model('/content/drive/MyDrive/UDENAR/ProyectosGrado/Errol/Ginna/Tuning/BestModels/ablations_finallBERT_{0}.keras'.format(models_names[i]))
  if(i==1):
    Model_Xtest=[Xp_test,Xs_test,Xt_test,Xf_test]
  if(i==2):
    Model_Xtest=[Xcode_test,Xs_test,Xt_test,Xf_test]
  if(i==3):
    Model_Xtest=[Xs_test,Xt_test,Xf_test]
  if(i==4):
    Model_Xtest=[Xp_test,Xcode_test]
  if(i==5):
    Model_Xtest=[Xcode_test]


  evaluate=model.evaluate(Model_Xtest,y_test)

  t1=time()
  y_pred=model.predict(Model_Xtest)
  t2=time()
  mcc=calculate_mcc_multiclass(y_test, y_pred)
  auc_pr=calculate_auc_pr_multiclass(y_test, y_pred)

  times_predict.append(t2-t1)
  accuracies_predict.append(evaluate[1])
  loss_predict.append(evaluate[0])
  mccs_predict.append(mcc)
  aucpr_predict.append(auc_pr)


  accuracy=evaluate[1]
  loss=evaluate[0]

  print("accuracy",accuracy)
  print("loss",loss)
  print("mcc",mcc)
  print("auc_pr",auc_pr)
  print("time predict",t2-t1)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 8s 97ms/step - accuracy: 0.9376 - loss: 0.2033
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 6s 198ms/step
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# accuracy 0.9277456402778625
# loss 0.2542642652988434
# mcc 0.9035662146378574
# auc_pr 0.9024990106710449
# time predict 6.4809629917144775
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 8s 110ms/step - accuracy: 0.9196 - loss: 0.2344
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# accuracy 0.9190751314163208
# loss 0.2697467803955078
# mcc 0.892148008061973
# auc_pr 0.8956686147023067
# time predict 5.492192029953003
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.9481 - loss: 0.2031
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# accuracy 0.9364162087440491
# loss 0.2574061453342438
# mcc 0.9151569481498553
# auc_pr 0.8966888667097355
# time predict 10.468127012252808
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9068 - loss: 0.2880
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step
# accuracy 0.9205202460289001
# loss 0.30491843819618225
# mcc 0.8940483314621949
# auc_pr 0.890266498439552
# time predict 1.2852563858032227
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9106 - loss: 0.3818
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# accuracy 0.9046242833137512
# loss 0.44650229811668396
# mcc 0.8730445535922701
# auc_pr 0.8849389287594958
# time predict 1.0103280544281006
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9121 - loss: 0.3473
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# accuracy 0.9031791687011719
# loss 0.4084739089012146
# mcc 0.8712175907051605
# auc_pr 0.885152795272113
# time predict 1.028111457824707
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(

# %%
df_histories['accuracies_predict']=accuracies_predict
df_histories['loss_predict']=loss_predict
df_histories['times_predict']=times_predict
df_histories['mccs']=mccs_predict
df_histories['aucpr']=aucpr_predict
df_histories.to_csv('/content/drive/MyDrive/UDENAR/ProyectosGrado/Errol/Ginna/Tuning/BestModels/early_best_finall_predictBERT.csv')

# %%
df_histories['model']=models_names

# %%
df_histories
# Out:
#         times  max_accuracies  max_val_accuracies  max_val_losses  max_losses  \
# 0  169.172873        1.000000            0.942238        2.029496    2.024967
# 1  117.749322        1.000000            0.944043        1.936619    2.035028
# 2  119.699390        1.000000            0.945848        2.111512    1.978953
# 3  109.264185        0.999548            0.942238        2.041958    2.024786
# 4  104.880635        0.998644            0.938628        1.994298    2.186902
# 5   72.745415        0.995029            0.933213        2.424156    2.173478
#
#    learning_rates  accuracies_predict  loss_predict  times_predict      mccs  \
# 0        0.000010            0.927746      0.254264       6.480963  0.903566
# 1        0.000001            0.919075      0.269747       5.492192  0.892148
# 2        0.000010            0.936416      0.257406      10.468127  0.915157
# 3        0.000100            0.920520      0.304918       1.285256  0.894048
# 4        0.000010            0.904624      0.446502       1.010328  0.873045
# 5        0.000010            0.903179      0.408474       1.028111  0.871218
#
#       aucpr          model
# 0  0.902499     problemall
# 1  0.895669  problem_gries
# 2  0.896689     code_gries
# 3  0.890266          gries
# 4  0.884939   problem_code
# 5  0.885153           code

# %%
df_histories[(df_histories['aucpr']>0.89)]
# Out:
#         times  max_accuracies  max_val_accuracies  max_val_losses  max_losses  \
# 0  169.172873        1.000000            0.942238        2.029496    2.024967
# 1  117.749322        1.000000            0.944043        1.936619    2.035028
# 2  119.699390        1.000000            0.945848        2.111512    1.978953
# 3  109.264185        0.999548            0.942238        2.041958    2.024786
#
#    learning_rates  accuracies_predict  loss_predict  times_predict      mccs  \
# 0        0.000010            0.927746      0.254264       6.480963  0.903566
# 1        0.000001            0.919075      0.269747       5.492192  0.892148
# 2        0.000010            0.936416      0.257406      10.468127  0.915157
# 3        0.000100            0.920520      0.304918       1.285256  0.894048
#
#       aucpr          model
# 0  0.902499     problemall
# 1  0.895669  problem_gries
# 2  0.896689     code_gries
# 3  0.890266          gries

# %%
df_histories[(df_histories['aucpr']>0.89)&(df_histories['max_accuracies']-df_histories['max_val_accuracies']<0.06)]
# Out:
#         times  max_accuracies  max_val_accuracies  max_val_losses  max_losses  \
# 0  169.172873        1.000000            0.942238        2.029496    2.024967
# 1  117.749322        1.000000            0.944043        1.936619    2.035028
# 2  119.699390        1.000000            0.945848        2.111512    1.978953
# 3  109.264185        0.999548            0.942238        2.041958    2.024786
#
#    learning_rates  accuracies_predict  loss_predict  times_predict      mccs  \
# 0        0.000010            0.927746      0.254264       6.480963  0.903566
# 1        0.000001            0.919075      0.269747       5.492192  0.892148
# 2        0.000010            0.936416      0.257406      10.468127  0.915157
# 3        0.000100            0.920520      0.304918       1.285256  0.894048
#
#       aucpr          model
# 0  0.902499     problemall
# 1  0.895669  problem_gries
# 2  0.896689     code_gries
# 3  0.890266          gries

# %% [markdown]
# Early stoping 40 the best, add code + gries

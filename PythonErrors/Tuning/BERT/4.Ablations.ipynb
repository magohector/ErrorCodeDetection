# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.56.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.35.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.8.3)

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import re
import shutil
import string
from sklearn.metrics import classification_report
import tensorflow as tf
from keras.models import Model
from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras.optimizers import Adam
from keras.callbacks import EarlyStopping,ModelCheckpoint
from tensorflow.keras.layers import Dense, Input, Dropout, Bidirectional, LSTM, Embedding, BatchNormalization,  Reshape, Conv2D, MaxPool2D, concatenate, Flatten, Activation
import torch
import numpy as np
from transformers import BertTokenizer, BertModel,RobertaTokenizer, RobertaModel
import ast

# %%
# Verificar si la GPU está disponible
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
archivo_3 = '/content/drive/MyDrive/UDENAR/ProyectosGrado/Errol/Ginna/ResultsBERT/DataProgramsandDescriptions-CatRetroalimentacion5000.xlsx'
train_full = pd.read_excel(archivo_3)

# %% [markdown]
# # AST spliter D. Gries form

# %%
class WhileLoopFinder(ast.NodeVisitor):
    def __init__(self, source_code):
        self.source_code = source_code.splitlines()
        self.functions_with_while = []
        self.current_function = None

    def visit_FunctionDef(self, node):
        original_current_function = self.current_function
        self.current_function = {
            "function_name": node.name,
            "has_while_loop": False,
            "pre_while_code_lines": [],
            "while_loops": []
        }

        function_start_line = node.lineno - 1
        function_end_line = (node.end_lineno if hasattr(node, 'end_lineno') else len(self.source_code))
        function_lines = self.source_code[function_start_line:function_end_line]

        found_while = False
        for stmt in node.body:
            if isinstance(stmt, ast.While):
                self.current_function["has_while_loop"] = True
                found_while = True
                try:
                    while_condition = ast.unparse(stmt.test).strip()
                    print("OK condition")
                except AttributeError:
                    print("Error al obtener la condición del while")
                try:
                    while_body_code = ast.unparse(ast.Module(body=stmt.body, type_ignores=[])).strip()
                    print("Ok body")
                except AttributeError:
                    print("Error al obtener el código del cuerpo del while")

                self.current_function["while_loops"].append({
                    "condition": while_condition,
                    "body_code": while_body_code
                })
            elif not found_while:
                start_line = stmt.lineno - 1
                end_line = (stmt.end_lineno if hasattr(stmt, 'end_lineno') else stmt.lineno)
                self.current_function["pre_while_code_lines"].extend(self.source_code[start_line:end_line])
            self.generic_visit(stmt)

        if self.current_function["has_while_loop"]:
            last_while_end_line = None
            if self.current_function["while_loops"]:
                last_while_node = next((node for node in reversed(node.body) if isinstance(node, ast.While)), None)
                if last_while_node and hasattr(last_while_node, 'end_lineno'):
                    last_while_end_line = last_while_node.end_lineno
            post_while_code_lines = []
            if last_while_end_line:
                function_indent = len(self.source_code[node.lineno - 1]) - len(self.source_code[node.lineno - 1].lstrip())
                for line in self.source_code[last_while_end_line:function_end_line]:
                    if line.startswith(self.source_code[node.lineno - 1][:function_indent] + "    "):
                        post_while_code_lines.append(line[function_indent + 4:])
                    else:
                        post_while_code_lines.append(line[function_indent:])
            self.current_function["post_while_code_lines"] = "\n".join(post_while_code_lines).strip()
            self.current_function["pre_while_code_lines"] = "\n".join(self.current_function["pre_while_code_lines"]).strip()
            self.functions_with_while.append(self.current_function)

        self.current_function = original_current_function

# %%
def DGries_states(solution):
  try:
    # Crear el AST
    tree = ast.parse(solution)
    # Recorrer el AST con nuestro visitante
    finder = WhileLoopFinder(solution)
    finder.visit(tree)
    for func_info in finder.functions_with_while:
      initial_state=func_info["pre_while_code_lines"] if func_info["pre_while_code_lines"] else False
      end_state=""
      transformation_state=""
      for j, wl in enumerate(func_info["while_loops"]):
          end_state=wl["condition"]
          transformation_state=wl["body_code"]

      if not initial_state:
        initial_state=transformation_state
      return initial_state,transformation_state,end_state
  except Exception as error:
    return "Exception:"+str(error),"Exception:"+str(error),"Exception:"+str(error)

# %% [markdown]
# # Encoder Description and Code

# %%
class EncodeTextSource:
  def __init__(self):
    self.is_loadtokenizers=False



  def tokenize_and_generate_embeddings_descriptions(self,description):
    if not self.is_loadtokenizers:
      raise ValueError("tokenizers dont load")
    # Tokenize input description and move tokens to GPU
    tokens = self.beart_tokenizer.encode_plus(description, return_tensors="pt", truncation=True)
    tokens = {key: value.to(device) for key, value in tokens.items()}
    # Generate embeddings
    with torch.no_grad():
        outputs = self.beart_model(**tokens)
    # Extract embeddings for all tokens
    desc_embeddings = outputs.last_hidden_state.cpu().numpy()
    return desc_embeddings

  def tokenize_and_generate_embeddings_codes(self,code):
    if not self.is_loadtokenizers:
      raise ValueError("tokenizers dont load")
    # Tokenize input code and move tokens to GPU
    tokens = self.beart_tokenizer.encode_plus(code, return_tensors="pt", truncation=True)
    tokens = {key: value.to(device) for key, value in tokens.items()}
    # Generate embeddings
    with torch.no_grad():
        outputs = self.codebeart_model(**tokens)
    # Extract embeddings for all tokens
    code_embeddings = outputs.last_hidden_state.cpu().numpy()

    return code_embeddings

  def load_beart_tokenizer(self):
    # Verificar si la GPU está disponible
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Cargar el tokenizer y el modelo en la GPU si está disponible
    model_name = "bert-base-uncased"
    self.beart_model = BertModel.from_pretrained(model_name)
    self.beart_tokenizer = BertTokenizer.from_pretrained(model_name)
    self.beart_model.to(device)

  def load_codebert_tokenizer(self):
    # Verificar si la GPU está disponible
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Cargar el tokenizer y el modelo en la GPU si está disponible
    self.codebeart_tokenizer = RobertaTokenizer.from_pretrained("microsoft/codebert-base")
    self.codebeart_model = RobertaModel.from_pretrained("microsoft/codebert-base")
    self.codebeart_model.to(device)

  def start_tokenizer(self):
    self.load_beart_tokenizer()
    self.load_codebert_tokenizer()
    self.is_loadtokenizers=True

# %% [markdown]
# # All characteristics

# %%
def categoricallabelAll(w):

  if w=="['Initial state']":
    return 0
  if w=="['Final state']":
    return 1
  if w=="['State transformation']":
    return 2
  if w=="['Initial state', 'Final state']":
    return 3
  if w=="['Initial state', 'State transformation']":
    return 4
  if w=="['Final state', 'State transformation']":
    return 5
  if w=="['Initial state', 'Final state', 'State transformation']":
    return 6
  return 7

category=np.array([
    'Initial state',
    'Final state',
    'State transformation',
    'Initial state, Final state',
    'Initial state, State transformation',
    'Final state, State transformation',
    'Initial state, Final state, State transformation'

])

# %% [markdown]
# # Load Dataset

# %%
train_full.head()

# %%
train_full.drop(["No.","Realimentación","Estado incial","Estado final","Transformación de estado"],axis=1,inplace=True)
train_full

# %%
train_full[["Estado incial","Transformación de estado","Estado final"]]=train_full['Solución'].apply(DGries_states).apply(pd.Series)
# Out:
# Streaming output truncated to the last 5000 lines.
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body

# %%
train_full = train_full[train_full['Etiqueta 1']!='Correct'].copy()

# %%
y=train_full['Etiqueta 2'].apply(categoricallabelAll)
np.unique(y)
# Out:
# array([0, 1, 2, 3, 4, 5, 6])

# %%
train_full.dropna(inplace=True)

# %%
np.unique(train_full['Etiqueta 2'])
# Out:
# array(["['Final state', 'State transformation']", "['Final state']",
#        "['Initial state', 'Final state', 'State transformation']",
#        "['Initial state', 'Final state']",
#        "['Initial state', 'State transformation']", "['Initial state']",
#        "['State transformation']"], dtype=object)

# %%
encoder=EncodeTextSource()
encoder.start_tokenizer()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/498 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]

# %%
# %%time
problem=train_full['Problema'].apply(encoder.tokenize_and_generate_embeddings_descriptions).to_numpy()
code=train_full['Solución'].apply(encoder.tokenize_and_generate_embeddings_codes).to_numpy()
startstate = train_full['Estado incial'].apply(encoder.tokenize_and_generate_embeddings_codes).to_numpy()
finalstate = train_full['Estado final'].apply(encoder.tokenize_and_generate_embeddings_codes).to_numpy()
transstate = train_full['Transformación de estado'].apply(encoder.tokenize_and_generate_embeddings_codes).to_numpy()
# Out:
# CPU times: user 2min 30s, sys: 2.69 s, total: 2min 33s
# Wall time: 2min 40s

# %%
problem.shape,code.shape,startstate.shape,finalstate.shape,transstate.shape
# Out:
# ((3459,), (3459,), (3459,), (3459,), (3459,))

# %%
print(startstate.shape)
print(startstate[1262].shape)
# Out:
# (3459,)
# (1, 9, 768)

# %%
Xp=np.array([sentence[0].mean(axis=0) for sentence in problem])
Xcode=np.array([sentence[0].mean(axis=0) for sentence in code])
Xs=np.array([sentence[0].mean(axis=0) for sentence in startstate])
Xf=np.array([sentence[0].mean(axis=0) for sentence in finalstate])
Xt=np.array([sentence[0].mean(axis=0) for sentence in transstate])
Xp.shape,Xs.shape,Xf.shape,Xt.shape
# Out:
# ((3459, 768), (3459, 768), (3459, 768), (3459, 768))

# %%
y=train_full['Etiqueta 2'].apply(categoricallabelAll)
y=y.to_numpy()
np.unique(y)
# Out:
# array([0, 1, 2, 3, 4, 5, 6])

# %%
from sklearn.model_selection import train_test_split

Xp_train,Xp_test,Xcode_train,Xcode_test,Xs_train,Xs_test,Xt_train,Xt_test,Xf_train,Xf_test,y_train,y_test=train_test_split(Xp,Xcode,Xs,Xt,Xf,y,test_size=0.2,random_state=2023, stratify=y)

# %%
Xp_train.shape,Xp_test.shape,Xcode_train.shape, Xcode_test.shape, Xs_train.shape,Xs_test.shape,Xt_train.shape,Xt_test.shape,Xf_train.shape,Xf_test.shape,y_train.shape,y_test.shape
# Out:
# ((2767, 768),
#  (692, 768),
#  (2767, 768),
#  (692, 768),
#  (2767, 768),
#  (692, 768),
#  (2767, 768),
#  (692, 768),
#  (2767, 768),
#  (692, 768),
#  (2767,),
#  (692,))

# %% [markdown]
# # Keras model

# %%
from tensorflow.keras import backend as K
import gc
def ANNTC(input,base,pow_initial,num_max_blocks):

  drop_out=0.5
  print("base",base,"pow",pow_initial,"num_max_blocks",num_max_blocks)
  n=num_max_blocks//2
  neurons=int(base**(pow_initial+n+1))
  # Encoder
  x=None
  print("Encoder",n)
  try:
    for i in range(n):
      x=Dense(neurons)(input)
      x=BatchNormalization()(x)
      x=Activation('relu')(x)
      x=Dropout(drop_out)(x)
      input=x
      drop_out=0.2
      print("Block ",i,neurons)
      neurons=int(neurons/base)



    #BottleNeck
    x=Dense(neurons)(x)
    x=BatchNormalization()(x)
    x=Activation('relu')(x)
    x=Dropout(0.2)(x)
    print("BottleNeck",neurons)

    # Decoder
    print("Decoder",n)
    for i in range(n):
      neurons=int(neurons*base)
      print("Block ",i,neurons)
      x=Dense(neurons)(x)
      x=BatchNormalization()(x)
      x=Activation('relu')(x)
      x=Dropout(drop_out)(x)
      if i==n-1:
        drop_out=0.5
      drop_out=0.2
  except Exception as err:

    K.clear_session()
    gc.collect()
    del x
    print(f"Unexpected {err=}, {type(err)=}")
    raise

  return x

def neural_network_all(problem,code,start_input,trass_input,final_input,base=10,pow_initial=4,num_max_blocks=3):
  mlp_p=ANNTC(problem,base,pow_initial,num_max_blocks)
  mlp_code=ANNTC(code,base,pow_initial,num_max_blocks)
  mlp_s=ANNTC(start_input,base,pow_initial,num_max_blocks)
  mlp_t=ANNTC(trass_input,base,pow_initial,num_max_blocks)
  mlp_f=ANNTC(final_input,base,pow_initial,num_max_blocks)
  ## Concatenate All models
  combined = concatenate([mlp_p,mlp_code ,mlp_s, mlp_t,mlp_f])
  ## output layer
  output=Dense(8)(combined)
  output=BatchNormalization()(output)
  output=Activation('softmax')(output)
  ## Model
  model = Model(inputs=[problem_input,code,start_input, trass_input,final_input], outputs=output)
  return model

def neural_network_code_gries(code_input,start_input,trass_input,final_input,base=10,pow_initial=4,num_max_blocks=3):
  mlp_code=ANNTC(code_input,base,pow_initial,num_max_blocks)
  mlp_s=ANNTC(start_input,base,pow_initial,num_max_blocks)
  mlp_t=ANNTC(trass_input,base,pow_initial,num_max_blocks)
  mlp_f=ANNTC(final_input,base,pow_initial,num_max_blocks)
  ## Concatenate All models
  combined = concatenate([mlp_code, mlp_s, mlp_t,mlp_f])
  ## output layer
  output=Dense(8)(combined)
  output=BatchNormalization()(output)
  output=Activation('softmax')(output)
  ## Model
  model = Model(inputs=[code_input, start_input, trass_input,final_input], outputs=output)
  return model


def neural_network(problem,start_input,trass_input,final_input,base=10,pow_initial=4,num_max_blocks=3):
  mlp_p=ANNTC(problem,base,pow_initial,num_max_blocks)
  mlp_s=ANNTC(start_input,base,pow_initial,num_max_blocks)
  mlp_t=ANNTC(trass_input,base,pow_initial,num_max_blocks)
  mlp_f=ANNTC(final_input,base,pow_initial,num_max_blocks)
  ## Concatenate All models
  combined = concatenate([mlp_p, mlp_s, mlp_t,mlp_f])
  ## output layer
  output=Dense(8)(combined)
  output=BatchNormalization()(output)
  output=Activation('softmax')(output)
  ## Model
  model = Model(inputs=[problem_input, start_input, trass_input,final_input], outputs=output)
  return model

def neural_network_wproblem(start_input,trass_input,final_input,base=10,pow_initial=4,num_max_blocks=3):
  mlp_s=ANNTC(start_input,base,pow_initial,num_max_blocks)
  mlp_t=ANNTC(trass_input,base,pow_initial,num_max_blocks)
  mlp_f=ANNTC(final_input,base,pow_initial,num_max_blocks)
  ## Concatenate All models
  combined = concatenate([mlp_s, mlp_t,mlp_f])
  ## output layer
  output=Dense(8)(combined)
  output=BatchNormalization()(output)
  output=Activation('softmax')(output)
  ## Model
  model = Model(inputs=[start_input, trass_input,final_input], outputs=output)
  return model

def neural_network_problem_code(problem,code_input,base=10,pow_initial=4,num_max_blocks=3):
  mlp_p=ANNTC(problem,base,pow_initial,num_max_blocks)
  mlp_code=ANNTC(code_input,base,pow_initial,num_max_blocks)
  ## Concatenate All models
  combined = concatenate([mlp_p, mlp_code])
  ## output layer
  output=Dense(8)(combined)
  output=BatchNormalization()(output)
  output=Activation('softmax')(output)
  ## Model
  model = Model(inputs=[problem, code_input], outputs=output)
  return model

def neural_network_code(code_input,base=10,pow_initial=4,num_max_blocks=3):

  mlp_code=ANNTC(code_input,base,pow_initial,num_max_blocks)
  ## output layer
  output=Dense(8)(mlp_code)
  output=BatchNormalization()(output)
  output=Activation('softmax')(output)
  ## Model
  model = Model(inputs=[code_input], outputs=output)
  return model

# %%
import numpy as np
np.linspace(5,70,14)
# Out:
# array([ 5., 10., 15., 20., 25., 30., 35., 40., 45., 50., 55., 60., 65.,
#        70.])

# %%
models=[]
models_names=["problemall","problem_gries","code_gries","gries","problem_code","code"]

problem_input=Input((768,))
code_input=Input((768,))
start_input=Input((768,))
trass_input=Input((768,))
final_input=Input((768,))

print("problem all")
models.append(neural_network_all(problem_input,code_input,start_input,trass_input,final_input,base=8,pow_initial=1, num_max_blocks=3))
print("problem gries")
models.append(neural_network(problem_input,start_input,trass_input,final_input,base=8,pow_initial=1, num_max_blocks=3))
print("problem code gries")
models.append(neural_network_code_gries(code_input,start_input,trass_input,final_input,base=8,pow_initial=1, num_max_blocks=3))
print("gries")
models.append(neural_network_wproblem(start_input,trass_input,final_input,base=8,pow_initial=1, num_max_blocks=3))
print("problem code")
models.append(neural_network_problem_code(problem_input,code_input,base=8,pow_initial=1, num_max_blocks=3))
print("code")
models.append(neural_network_code(code_input,base=8,pow_initial=1, num_max_blocks=3))
# Out:
# problem all
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# problem gries
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# problem code gries
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# gries
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# problem code
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# code
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
from time import time
#tensorflow random state
tf.random.set_seed(2023)

times=[]
max_accuracies=[]
max_val_accuracies=[]
max_val_losses=[]
max_losses=[]
learning_rates=[]
Model_Xtrain=[Xp_train,Xcode_train,Xs_train,Xt_train,Xf_train]

for i,my_model in enumerate(models):
  print(models_names[i])

  problem_input=Input((768,))
  start_input=Input((768,))
  trass_input=Input((768,))
  final_input=Input((768,))

  patience=60

  my_model.compile(loss='sparse_categorical_crossentropy',
                optimizer=Adam(),
                metrics=['accuracy'])

  es = EarlyStopping(monitor='val_loss', mode='min', patience=patience)

  mc = ModelCheckpoint('/content/drive/MyDrive/UDENAR/ProyectosGrado/Errol/Ginna/ResultsBERT/ablations_finall_{0}.keras'.format(models_names[i]), monitor='val_loss', mode='min', save_best_only=True)
  reduce_lr = ReduceLROnPlateau(
      monitor='val_loss',
      factor=0.1,
      patience=patience//2,
      min_lr=1e-9,
      verbose=1
  )
  if(i==1):
    Model_Xtrain=[Xp_train,Xs_train,Xt_train,Xf_train]
  if(i==2):
    Model_Xtrain=[Xcode_train,Xs_train,Xt_train,Xf_train]
  if(i==3):
    Model_Xtrain=[Xs_train,Xt_train,Xf_train]
  if(i==4):
    Model_Xtrain=[Xp_train,Xcode_train]
  if(i==5):
    Model_Xtrain=[Xcode_train]

  time1=time()
  history=my_model.fit(Model_Xtrain,y_train,batch_size=100,epochs=1000,
            validation_split=0.2,callbacks=[es, mc,reduce_lr])
  time2=time()

  df_histories=pd.DataFrame(history.history)
  df_histories.to_csv('/content/drive/MyDrive/UDENAR/ProyectosGrado/Errol/Ginna/ResultsBERT/ablations_best_finall_{0}.csv'.format(models_names[i]))

  times.append(time2-time1)

  max_accuracies.append(max(history.history['accuracy']))
  max_val_accuracies.append(max(history.history['val_accuracy']))
  max_val_losses.append(max(history.history['val_loss']))
  max_losses.append(max(history.history['loss']))
  learning_rates.append(min(history.history['learning_rate']))

  print(f"{patience}")
  print("times=",time2-time1)
  print("max_val_accuracy",max(history.history['val_accuracy']))
  print("max_accuracy",max(history.history['accuracy']))


  print("max_val_loss",max(history.history['val_loss']))
  print("max_loss",max(history.history['loss']))
  print("learning_rate",min(history.history['learning_rate']))
# Out:
# problemall
# Epoch 1/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 758ms/step - accuracy: 0.2311 - loss: 2.2233 - val_accuracy: 0.0758 - val_loss: 2.0295 - learning_rate: 0.0010
# Epoch 2/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5162 - loss: 1.5683 - val_accuracy: 0.4025 - val_loss: 1.9462 - learning_rate: 0.0010
# Epoch 3/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.6453 - loss: 1.3236 - val_accuracy: 0.4657 - val_loss: 1.8299 - learning_rate: 0.0010
# Epoch 4/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.7090 - loss: 1.2044 - val_accuracy: 0.4206 - val_loss: 1.7386 - learning_rate: 0.0010
# Epoch 5/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.7371 - loss: 1.0976 - val_accuracy: 0.5018 - val_loss: 1.6317 - learning_rate: 0.0010
# Epoch 6/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.7822 - loss: 1.0244 - val_accuracy: 0.5253 - val_loss: 1.5600 - learning_rate: 0.0010
# Epoch 7/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8104 - loss: 0.9468 - val_accuracy: 0.4621 - val_loss: 1.5090 - learning_rate: 0.0010
# Epoch 8/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8328 - loss: 0.9105 - val_accuracy: 0.5307 - val_loss: 1.4656 - learning_rate: 0.0010
# Epoch 9/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8451 - loss: 0.8592 - val_accuracy: 0.6119 - val_loss: 1.3897 - learning_rate: 0.0010
# Epoch 10/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8605 - loss: 0.8065 - val_accuracy: 0.6408 - val_loss: 1.2986 - learning_rate: 0.0010
# Epoch 11/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8733 - loss: 0.7673 - val_accuracy: 0.6209 - val_loss: 1.2946 - learning_rate: 0.0010
# Epoch 12/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8791 - loss: 0.7206 - val_accuracy: 0.7762 - val_loss: 1.0892 - learning_rate: 0.0010
# Epoch 13/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8993 - loss: 0.6825 - val_accuracy: 0.7978 - val_loss: 1.0590 - learning_rate: 0.0010
# Epoch 14/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9131 - loss: 0.6489 - val_accuracy: 0.7563 - val_loss: 1.0289 - learning_rate: 0.0010
# Epoch 15/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9020 - loss: 0.6274 - val_accuracy: 0.7924 - val_loss: 1.0185 - learning_rate: 0.0010
# Epoch 16/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9179 - loss: 0.5964 - val_accuracy: 0.7419 - val_loss: 1.0606 - learning_rate: 0.0010
# Epoch 17/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9220 - loss: 0.5675 - val_accuracy: 0.6227 - val_loss: 1.2270 - learning_rate: 0.0010
# Epoch 18/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9292 - loss: 0.5443 - val_accuracy: 0.7365 - val_loss: 1.0398 - learning_rate: 0.0010
# Epoch 19/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9273 - loss: 0.5242 - val_accuracy: 0.8105 - val_loss: 0.9260 - learning_rate: 0.0010
# Epoch 20/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9418 - loss: 0.4964 - val_accuracy: 0.8051 - val_loss: 0.9451 - learning_rate: 0.0010
# Epoch 21/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9427 - loss: 0.4831 - val_accuracy: 0.8339 - val_loss: 0.7708 - learning_rate: 0.0010
# Epoch 22/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9480 - loss: 0.4631 - val_accuracy: 0.8628 - val_loss: 0.6862 - learning_rate: 0.0010
# Epoch 23/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9540 - loss: 0.4511 - val_accuracy: 0.8664 - val_loss: 0.7074 - learning_rate: 0.0010
# Epoch 24/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9535 - loss: 0.4259 - val_accuracy: 0.8700 - val_loss: 0.7650 - learning_rate: 0.0010
# Epoch 25/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9583 - loss: 0.4095 - val_accuracy: 0.8881 - val_loss: 0.6700 - learning_rate: 0.0010
# Epoch 26/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9460 - loss: 0.4055 - val_accuracy: 0.8827 - val_loss: 0.6151 - learning_rate: 0.0010
# Epoch 27/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9560 - loss: 0.3812 - val_accuracy: 0.8953 - val_loss: 0.6354 - learning_rate: 0.0010
# Epoch 28/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9626 - loss: 0.3720 - val_accuracy: 0.8755 - val_loss: 0.6645 - learning_rate: 0.0010
# Epoch 29/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9582 - loss: 0.3589 - val_accuracy: 0.8700 - val_loss: 0.6134 - learning_rate: 0.0010
# Epoch 30/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.
# Epoch 64/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9855 - loss: 0.1419 - val_accuracy: 0.9097 - val_loss: 0.3984 - learning_rate: 0.0010
# Epoch 65/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9923 - loss: 0.1354 - val_accuracy: 0.9134 - val_loss: 0.3901 - learning_rate: 0.0010
# Epoch 66/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9872 - loss: 0.1351 - val_accuracy: 0.9007 - val_loss: 0.4153 - learning_rate: 0.0010
# Epoch 67/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9879 - loss: 0.1356 - val_accuracy: 0.8881 - val_loss: 0.4443 - learning_rate: 0.0010
# Epoch 68/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9910 - loss: 0.1277 - val_accuracy: 0.9170 - val_loss: 0.3872 - learning_rate: 0.0010
# Epoch 69/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9899 - loss: 0.1190 - val_accuracy: 0.9061 - val_loss: 0.4005 - learning_rate: 0.0010
# Epoch 70/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9860 - loss: 0.1249 - val_accuracy: 0.9350 - val_loss: 0.3315 - learning_rate: 0.0010
# Epoch 71/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9927 - loss: 0.1160 - val_accuracy: 0.8736 - val_loss: 0.4456 - learning_rate: 0.0010
# Epoch 72/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9944 - loss: 0.1077 - val_accuracy: 0.9043 - val_loss: 0.3586 - learning_rate: 0.0010
# Epoch 73/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9879 - loss: 0.1162 - val_accuracy: 0.8953 - val_loss: 0.4390 - learning_rate: 0.0010
# Epoch 74/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9945 - loss: 0.1068 - val_accuracy: 0.9152 - val_loss: 0.3863 - learning_rate: 0.0010
# Epoch 75/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9925 - loss: 0.1033 - val_accuracy: 0.9242 - val_loss: 0.3425 - learning_rate: 0.0010
# Epoch 76/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9938 - loss: 0.1041 - val_accuracy: 0.9025 - val_loss: 0.3885 - learning_rate: 0.0010
# Epoch 77/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9927 - loss: 0.1010 - val_accuracy: 0.9116 - val_loss: 0.3569 - learning_rate: 0.0010
# Epoch 78/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9903 - loss: 0.1009 - val_accuracy: 0.9224 - val_loss: 0.3112 - learning_rate: 0.0010
# Epoch 79/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9898 - loss: 0.1003 - val_accuracy: 0.9152 - val_loss: 0.3579 - learning_rate: 0.0010
# Epoch 80/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9933 - loss: 0.0972 - val_accuracy: 0.8574 - val_loss: 0.4657 - learning_rate: 0.0010
# Epoch 81/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9919 - loss: 0.1022 - val_accuracy: 0.8520 - val_loss: 0.5040 - learning_rate: 0.0010
# Epoch 82/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9891 - loss: 0.1011 - val_accuracy: 0.9152 - val_loss: 0.3641 - learning_rate: 0.0010
# Epoch 83/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9941 - loss: 0.0922 - val_accuracy: 0.9007 - val_loss: 0.3979 - learning_rate: 0.0010
# Epoch 84/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9903 - loss: 0.0948 - val_accuracy: 0.9206 - val_loss: 0.3405 - learning_rate: 0.0010
# Epoch 85/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9942 - loss: 0.0844 - val_accuracy: 0.9116 - val_loss: 0.3613 - learning_rate: 0.0010
# Epoch 86/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9918 - loss: 0.0914 - val_accuracy: 0.9188 - val_loss: 0.3315 - learning_rate: 0.0010
# Epoch 87/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9934 - loss: 0.0859 - val_accuracy: 0.9242 - val_loss: 0.3069 - learning_rate: 0.0010
# Epoch 88/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9951 - loss: 0.0822 - val_accuracy: 0.8809 - val_loss: 0.4454 - learning_rate: 0.0010
# Epoch 89/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9925 - loss: 0.0856 - val_accuracy: 0.8773 - val_loss: 0.4867 - learning_rate: 0.0010
# Epoch 90/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9921 - loss: 0.0846 - val_accuracy: 0.9260 - val_loss: 0.3127 - learning_rate: 0.0010
# Epoch 91/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9888 - loss: 0.0851 - val_accuracy: 0.9224 - val_loss: 0.3175 - learning_rate: 0.0010
# Epoch 92/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9922 - loss: 0.0804 - val_accuracy: 0.9260 - val_loss: 0.3114 - learning_rate: 0.0010
# Epoch 93/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9946 - loss: 0.0763 - val_accuracy: 0.8917 - val_loss: 0.3846 - learning_rate: 0.0010
# Epoch 94/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9922 - loss: 0.0781 - val_accuracy: 0.9224 - val_loss: 0.3299 - learning_rate: 0.0010
# Epoch 95/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9956 - loss: 0.0759 - val_accuracy: 0.9134 - val_loss: 0.3587 - learning_rate: 0.0010
# Epoch 96/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9952 - loss: 0.0729 - val_accuracy: 0.9043 - val_loss: 0.4163 - learning_rate: 0.0010
# Epoch 97/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9969 - loss: 0.0705 - val_accuracy: 0.9116 - val_loss: 0.3292 - learning_rate: 0.0010
# Epoch 98/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9935 - loss: 0.0734 - val_accuracy: 0.8989 - val_loss: 0.3472 - learning_rate: 0.0010
# Epoch 99/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0745 - val_accuracy: 0.9025 - val_loss: 0.3470 - learning_rate: 0.0010
# Epoch 100/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9932 - loss: 0.0709 - val_accuracy: 0.9170 - val_loss: 0.3184 - learning_rate: 0.0010
# Epoch 101/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9893 - loss: 0.0752 - val_accuracy: 0.9224 - val_loss: 0.3150 - learning_rate: 0.0010
# Epoch 102/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9956 - loss: 0.0654 - val_accuracy: 0.9079 - val_loss: 0.3459 - learning_rate: 0.0010
# Epoch 103/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9958 - loss: 0.0640 - val_accuracy: 0.9043 - val_loss: 0.3731 - learning_rate: 0.0010
# Epoch 104/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9937 - loss: 0.0671 - val_accuracy: 0.9296 - val_loss: 0.3182 - learning_rate: 0.0010
# Epoch 105/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9937 - loss: 0.0641 - val_accuracy: 0.8755 - val_loss: 0.3958 - learning_rate: 0.0010
# Epoch 106/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9924 - loss: 0.0671 - val_accuracy: 0.9134 - val_loss: 0.3208 - learning_rate: 0.0010
# Epoch 107/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9964 - loss: 0.0627 - val_accuracy: 0.9097 - val_loss: 0.3573 - learning_rate: 0.0010
# Epoch 108/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9946 - loss: 0.0634 - val_accuracy: 0.8736 - val_loss: 0.4531 - learning_rate: 0.0010
# Epoch 109/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9948 - loss: 0.0586 - val_accuracy: 0.9242 - val_loss: 0.3225 - learning_rate: 0.0010
# Epoch 110/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9947 - loss: 0.0584 - val_accuracy: 0.8971 - val_loss: 0.3815 - learning_rate: 0.0010
# Epoch 111/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9934 - loss: 0.0610 - val_accuracy: 0.8953 - val_loss: 0.4102 - learning_rate: 0.0010
# Epoch 112/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9964 - loss: 0.0583 - val_accuracy: 0.9278 - val_loss: 0.3151 - learning_rate: 0.0010
# Epoch 113/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9952 - loss: 0.0580 - val_accuracy: 0.9170 - val_loss: 0.3365 - learning_rate: 0.0010
# Epoch 114/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9927 - loss: 0.0584 - val_accuracy: 0.9242 - val_loss: 0.3311 - learning_rate: 0.0010
# Epoch 115/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9967 - loss: 0.0512 - val_accuracy: 0.9188 - val_loss: 0.3294 - learning_rate: 0.0010
# Epoch 116/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9947 - loss: 0.0554 - val_accuracy: 0.9278 - val_loss: 0.3159 - learning_rate: 0.0010
# Epoch 117/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9977 - loss: 0.0508 - val_accuracy: 0.9332 - val_loss: 0.2881 - learning_rate: 0.0010
# Epoch 118/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9962 - loss: 0.0518 - val_accuracy: 0.9350 - val_loss: 0.2920 - learning_rate: 0.0010
# Epoch 119/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9977 - loss: 0.0490 - val_accuracy: 0.9206 - val_loss: 0.3305 - learning_rate: 0.0010
# Epoch 120/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9957 - loss: 0.0497 - val_accuracy: 0.9079 - val_loss: 0.3635 - learning_rate: 0.0010
# Epoch 121/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9969 - loss: 0.0489 - val_accuracy: 0.9134 - val_loss: 0.3391 - learning_rate: 0.0010
# Epoch 122/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9970 - loss: 0.0472 - val_accuracy: 0.9116 - val_loss: 0.3486 - learning_rate: 0.0010
# Epoch 123/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9956 - loss: 0.0476 - val_accuracy: 0.9152 - val_loss: 0.3444 - learning_rate: 0.0010
# Epoch 124/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.
# Epoch 226/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0159 - val_accuracy: 0.9368 - val_loss: 0.2632 - learning_rate: 1.0000e-04
# Epoch 227/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9976 - loss: 0.0185 - val_accuracy: 0.9368 - val_loss: 0.2637 - learning_rate: 1.0000e-04
# Epoch 228/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9994 - loss: 0.0175 - val_accuracy: 0.9368 - val_loss: 0.2660 - learning_rate: 1.0000e-04
# Epoch 229/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0154 - val_accuracy: 0.9386 - val_loss: 0.2641 - learning_rate: 1.0000e-04
# Epoch 230/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9996 - loss: 0.0166 - val_accuracy: 0.9368 - val_loss: 0.2665 - learning_rate: 1.0000e-04
# Epoch 231/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9995 - loss: 0.0154 - val_accuracy: 0.9368 - val_loss: 0.2645 - learning_rate: 1.0000e-04
# Epoch 232/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0155 - val_accuracy: 0.9368 - val_loss: 0.2632 - learning_rate: 1.0000e-04
# Epoch 233/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9998 - loss: 0.0166 - val_accuracy: 0.9386 - val_loss: 0.2629 - learning_rate: 1.0000e-04
# Epoch 234/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9974 - loss: 0.0170 - val_accuracy: 0.9368 - val_loss: 0.2629 - learning_rate: 1.0000e-04
# Epoch 235/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9997 - loss: 0.0164 - val_accuracy: 0.9386 - val_loss: 0.2625 - learning_rate: 1.0000e-04
# Epoch 236/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9995 - loss: 0.0166 - val_accuracy: 0.9368 - val_loss: 0.2630 - learning_rate: 1.0000e-04
# Epoch 237/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9990 - loss: 0.0165 - val_accuracy: 0.9368 - val_loss: 0.2617 - learning_rate: 1.0000e-04
# Epoch 238/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9996 - loss: 0.0153 - val_accuracy: 0.9386 - val_loss: 0.2586 - learning_rate: 1.0000e-04
# Epoch 239/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9997 - loss: 0.0148 - val_accuracy: 0.9368 - val_loss: 0.2590 - learning_rate: 1.0000e-04
# Epoch 240/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0151 - val_accuracy: 0.9386 - val_loss: 0.2607 - learning_rate: 1.0000e-04
# Epoch 241/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9993 - loss: 0.0151 - val_accuracy: 0.9386 - val_loss: 0.2587 - learning_rate: 1.0000e-04
# Epoch 242/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0151 - val_accuracy: 0.9386 - val_loss: 0.2612 - learning_rate: 1.0000e-04
# Epoch 243/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9995 - loss: 0.0143 - val_accuracy: 0.9386 - val_loss: 0.2627 - learning_rate: 1.0000e-04
# Epoch 244/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0145 - val_accuracy: 0.9386 - val_loss: 0.2640 - learning_rate: 1.0000e-04
# Epoch 245/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9998 - loss: 0.0144 - val_accuracy: 0.9386 - val_loss: 0.2657 - learning_rate: 1.0000e-04
# Epoch 246/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0149 - val_accuracy: 0.9386 - val_loss: 0.2654 - learning_rate: 1.0000e-04
# Epoch 247/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9996 - loss: 0.0145 - val_accuracy: 0.9386 - val_loss: 0.2634 - learning_rate: 1.0000e-04
# Epoch 248/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0148 - val_accuracy: 0.9386 - val_loss: 0.2623 - learning_rate: 1.0000e-04
# Epoch 249/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9996 - loss: 0.0149 - val_accuracy: 0.9368 - val_loss: 0.2645 - learning_rate: 1.0000e-04
# Epoch 250/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9999 - loss: 0.0155 - val_accuracy: 0.9350 - val_loss: 0.2684 - learning_rate: 1.0000e-04
# Epoch 251/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0137 - val_accuracy: 0.9368 - val_loss: 0.2687 - learning_rate: 1.0000e-04
# Epoch 252/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0134 - val_accuracy: 0.9386 - val_loss: 0.2673 - learning_rate: 1.0000e-04
# Epoch 253/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9996 - loss: 0.0155 - val_accuracy: 0.9404 - val_loss: 0.2668 - learning_rate: 1.0000e-04
# Epoch 254/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9999 - loss: 0.0138 - val_accuracy: 0.9368 - val_loss: 0.2693 - learning_rate: 1.0000e-04
# Epoch 255/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9995 - loss: 0.0149 - val_accuracy: 0.9368 - val_loss: 0.2693 - learning_rate: 1.0000e-04
# Epoch 256/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9997 - loss: 0.0153 - val_accuracy: 0.9368 - val_loss: 0.2672 - learning_rate: 1.0000e-04
# Epoch 257/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9999 - loss: 0.0138 - val_accuracy: 0.9368 - val_loss: 0.2655 - learning_rate: 1.0000e-04
# Epoch 258/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9996 - loss: 0.0158 - val_accuracy: 0.9386 - val_loss: 0.2596 - learning_rate: 1.0000e-04
# Epoch 259/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9993 - loss: 0.0141 - val_accuracy: 0.9386 - val_loss: 0.2593 - learning_rate: 1.0000e-04
# Epoch 260/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 0.0131 - val_accuracy: 0.9404 - val_loss: 0.2605 - learning_rate: 1.0000e-04
# Epoch 261/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0131 - val_accuracy: 0.9404 - val_loss: 0.2626 - learning_rate: 1.0000e-04
# Epoch 262/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9998 - loss: 0.0136 - val_accuracy: 0.9404 - val_loss: 0.2631 - learning_rate: 1.0000e-04
# Epoch 263/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0138 - val_accuracy: 0.9404 - val_loss: 0.2635 - learning_rate: 1.0000e-04
# Epoch 264/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0139 - val_accuracy: 0.9386 - val_loss: 0.2645 - learning_rate: 1.0000e-04
# Epoch 265/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0131 - val_accuracy: 0.9404 - val_loss: 0.2645 - learning_rate: 1.0000e-04
# Epoch 266/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0136 - val_accuracy: 0.9404 - val_loss: 0.2639 - learning_rate: 1.0000e-04
# Epoch 267/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9997 - loss: 0.0134 - val_accuracy: 0.9404 - val_loss: 0.2608 - learning_rate: 1.0000e-04
# Epoch 268/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 0.0132 - val_accuracy: 0.9386 - val_loss: 0.2580 - learning_rate: 1.0000e-04
# Epoch 269/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9994 - loss: 0.0142 - val_accuracy: 0.9368 - val_loss: 0.2567 - learning_rate: 1.0000e-04
# Epoch 270/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9997 - loss: 0.0128 - val_accuracy: 0.9386 - val_loss: 0.2581 - learning_rate: 1.0000e-04
# Epoch 271/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9997 - loss: 0.0144 - val_accuracy: 0.9422 - val_loss: 0.2589 - learning_rate: 1.0000e-04
# Epoch 272/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0131 - val_accuracy: 0.9386 - val_loss: 0.2587 - learning_rate: 1.0000e-04
# Epoch 273/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9996 - loss: 0.0141 - val_accuracy: 0.9386 - val_loss: 0.2583 - learning_rate: 1.0000e-04
# Epoch 274/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0126 - val_accuracy: 0.9386 - val_loss: 0.2608 - learning_rate: 1.0000e-04
# Epoch 275/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9997 - loss: 0.0136 - val_accuracy: 0.9386 - val_loss: 0.2579 - learning_rate: 1.0000e-04
# Epoch 276/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0137 - val_accuracy: 0.9386 - val_loss: 0.2591 - learning_rate: 1.0000e-04
# Epoch 277/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0126 - val_accuracy: 0.9404 - val_loss: 0.2593 - learning_rate: 1.0000e-04
# Epoch 278/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0128 - val_accuracy: 0.9404 - val_loss: 0.2597 - learning_rate: 1.0000e-04
# Epoch 279/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0140 - val_accuracy: 0.9386 - val_loss: 0.2614 - learning_rate: 1.0000e-04
# Epoch 280/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9990 - loss: 0.0137 - val_accuracy: 0.9386 - val_loss: 0.2609 - learning_rate: 1.0000e-04
# Epoch 281/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9999 - loss: 0.0132 - val_accuracy: 0.9350 - val_loss: 0.2588 - learning_rate: 1.0000e-04
# Epoch 282/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9997 - loss: 0.0119 - val_accuracy: 0.9386 - val_loss: 0.2593 - learning_rate: 1.0000e-04
# Epoch 283/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0125 - val_accuracy: 0.9386 - val_loss: 0.2590 - learning_rate: 1.0000e-04
# Epoch 284/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0124 - val_accuracy: 0.9386 - val_loss: 0.2614 - learning_rate: 1.0000e-04
# Epoch 285/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9984 - loss: 0.0138 - val_accuracy: 0.9386 - val_loss: 0.2606 - learning_rate: 1.0000e-04
# Epoch 286/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9999 - loss: 0.0131 - val_accuracy: 0.9386 - val_loss: 0.2601 - learning_rate: 1.0000e-04
# Epoch 287/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9996 - loss: 0.0130 - val_accuracy: 0.9350 - val_loss: 0.2600 - learning_rate: 1.0000e-04
# Epoch 288/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9996 - loss: 0.0127 - val_accuracy: 0.9332 - val_loss: 0.2646 - learning_rate: 1.0000e-04
# Epoch 289/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 0.0123 - val_accuracy: 0.9332 - val_loss: 0.2663 - learning_rate: 1.0000e-04
# Epoch 290/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0126 - val_accuracy: 0.9332 - val_loss: 0.2660 - learning_rate: 1.0000e-04
# Epoch 291/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9997 - loss: 0.0133 - val_accuracy: 0.9350 - val_loss: 0.2616 - learning_rate: 1.0000e-04
# Epoch 292/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9999 - loss: 0.0136 - val_accuracy: 0.9350 - val_loss: 0.2609 - learning_rate: 1.0000e-04
# Epoch 293/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9995 - loss: 0.0121 - val_accuracy: 0.9368 - val_loss: 0.2625 - learning_rate: 1.0000e-04
# Epoch 294/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9998 - loss: 0.0123 - val_accuracy: 0.9350 - val_loss: 0.2616 - learning_rate: 1.0000e-04
# Epoch 295/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0128 - val_accuracy: 0.9350 - val_loss: 0.2633 - learning_rate: 1.0000e-04
# Epoch 296/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0127 - val_accuracy: 0.9350 - val_loss: 0.2650 - learning_rate: 1.0000e-04
# Epoch 297/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0119 - val_accuracy: 0.9368 - val_loss: 0.2644 - learning_rate: 1.0000e-04
# Epoch 298/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0123 - val_accuracy: 0.9386 - val_loss: 0.2639 - learning_rate: 1.0000e-04
# Epoch 299/1000
# 19/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9998 - loss: 0.0116
# Epoch 299: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9998 - loss: 0.0117 - val_accuracy: 0.9368 - val_loss: 0.2674 - learning_rate: 1.0000e-04
# Epoch 300/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0127 - val_accuracy: 0.9350 - val_loss: 0.2672 - learning_rate: 1.0000e-05
# Epoch 301/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9995 - loss: 0.0122 - val_accuracy: 0.9350 - val_loss: 0.2667 - learning_rate: 1.0000e-05
# Epoch 302/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0110 - val_accuracy: 0.9386 - val_loss: 0.2660 - learning_rate: 1.0000e-05
# Epoch 303/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9996 - loss: 0.0118 - val_accuracy: 0.9386 - val_loss: 0.2659 - learning_rate: 1.0000e-05
# Epoch 304/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0116 - val_accuracy: 0.9386 - val_loss: 0.2652 - learning_rate: 1.0000e-05
# Epoch 305/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0113 - val_accuracy: 0.9386 - val_loss: 0.2649 - learning_rate: 1.0000e-05
# ...
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9839 - loss: 0.0794 - val_accuracy: 0.9260 - val_loss: 0.2949 - learning_rate: 1.0000e-04
# Epoch 146/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9823 - loss: 0.0801 - val_accuracy: 0.9206 - val_loss: 0.2923 - learning_rate: 1.0000e-04
# Epoch 147/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9898 - loss: 0.0711 - val_accuracy: 0.9260 - val_loss: 0.2903 - learning_rate: 1.0000e-04
# Epoch 148/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9872 - loss: 0.0737 - val_accuracy: 0.9260 - val_loss: 0.2909 - learning_rate: 1.0000e-04
# Epoch 149/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9873 - loss: 0.0787 - val_accuracy: 0.9260 - val_loss: 0.2871 - learning_rate: 1.0000e-04
# Epoch 150/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9860 - loss: 0.0771 - val_accuracy: 0.9260 - val_loss: 0.2835 - learning_rate: 1.0000e-04
# Epoch 151/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9902 - loss: 0.0700 - val_accuracy: 0.9260 - val_loss: 0.2879 - learning_rate: 1.0000e-04
# Epoch 152/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9829 - loss: 0.0781 - val_accuracy: 0.9260 - val_loss: 0.2929 - learning_rate: 1.0000e-04
# Epoch 153/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9886 - loss: 0.0739 - val_accuracy: 0.9260 - val_loss: 0.2925 - learning_rate: 1.0000e-04
# Epoch 154/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9851 - loss: 0.0773 - val_accuracy: 0.9260 - val_loss: 0.2854 - learning_rate: 1.0000e-04
# Epoch 155/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9877 - loss: 0.0694 - val_accuracy: 0.9224 - val_loss: 0.2867 - learning_rate: 1.0000e-04
# Epoch 156/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9857 - loss: 0.0733 - val_accuracy: 0.9242 - val_loss: 0.2896 - learning_rate: 1.0000e-04
# Epoch 157/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9868 - loss: 0.0810 - val_accuracy: 0.9260 - val_loss: 0.2841 - learning_rate: 1.0000e-04
# Epoch 158/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9872 - loss: 0.0771 - val_accuracy: 0.9260 - val_loss: 0.2896 - learning_rate: 1.0000e-04
# Epoch 159/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9881 - loss: 0.0693 - val_accuracy: 0.9260 - val_loss: 0.2931 - learning_rate: 1.0000e-04
# Epoch 160/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9849 - loss: 0.0777 - val_accuracy: 0.9260 - val_loss: 0.2835 - learning_rate: 1.0000e-04
# Epoch 161/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9874 - loss: 0.0732 - val_accuracy: 0.9224 - val_loss: 0.2829 - learning_rate: 1.0000e-04
# Epoch 162/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9850 - loss: 0.0779 - val_accuracy: 0.9224 - val_loss: 0.2856 - learning_rate: 1.0000e-04
# Epoch 163/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9922 - loss: 0.0634 - val_accuracy: 0.9224 - val_loss: 0.2814 - learning_rate: 1.0000e-04
# Epoch 164/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9885 - loss: 0.0703 - val_accuracy: 0.9224 - val_loss: 0.2834 - learning_rate: 1.0000e-04
# Epoch 165/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9896 - loss: 0.0638 - val_accuracy: 0.9242 - val_loss: 0.2833 - learning_rate: 1.0000e-04
# Epoch 166/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9909 - loss: 0.0634 - val_accuracy: 0.9224 - val_loss: 0.2865 - learning_rate: 1.0000e-04
# Epoch 167/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9884 - loss: 0.0711 - val_accuracy: 0.9242 - val_loss: 0.2915 - learning_rate: 1.0000e-04
# Epoch 168/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9898 - loss: 0.0689 - val_accuracy: 0.9278 - val_loss: 0.2945 - learning_rate: 1.0000e-04
# Epoch 169/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9902 - loss: 0.0663 - val_accuracy: 0.9278 - val_loss: 0.2888 - learning_rate: 1.0000e-04
# Epoch 170/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9895 - loss: 0.0675 - val_accuracy: 0.9224 - val_loss: 0.2932 - learning_rate: 1.0000e-04
# Epoch 171/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9866 - loss: 0.0678 - val_accuracy: 0.9260 - val_loss: 0.2870 - learning_rate: 1.0000e-04
# Epoch 172/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9879 - loss: 0.0711 - val_accuracy: 0.9278 - val_loss: 0.2880 - learning_rate: 1.0000e-04
# Epoch 173/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9866 - loss: 0.0723 - val_accuracy: 0.9278 - val_loss: 0.2851 - learning_rate: 1.0000e-04
# Epoch 174/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9876 - loss: 0.0656 - val_accuracy: 0.9260 - val_loss: 0.2843 - learning_rate: 1.0000e-04
# Epoch 175/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9917 - loss: 0.0628 - val_accuracy: 0.9206 - val_loss: 0.2877 - learning_rate: 1.0000e-04
# Epoch 176/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9822 - loss: 0.0760 - val_accuracy: 0.9278 - val_loss: 0.2895 - learning_rate: 1.0000e-04
# Epoch 177/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9916 - loss: 0.0621 - val_accuracy: 0.9278 - val_loss: 0.2869 - learning_rate: 1.0000e-04
# Epoch 178/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9890 - loss: 0.0660 - val_accuracy: 0.9278 - val_loss: 0.2932 - learning_rate: 1.0000e-04
# Epoch 179/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9894 - loss: 0.0654 - val_accuracy: 0.9260 - val_loss: 0.2919 - learning_rate: 1.0000e-04
# Epoch 180/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9864 - loss: 0.0722 - val_accuracy: 0.9260 - val_loss: 0.2863 - learning_rate: 1.0000e-04
# Epoch 181/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9880 - loss: 0.0662 - val_accuracy: 0.9278 - val_loss: 0.2849 - learning_rate: 1.0000e-04
# Epoch 182/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9948 - loss: 0.0611 - val_accuracy: 0.9332 - val_loss: 0.2787 - learning_rate: 1.0000e-04
# Epoch 183/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9916 - loss: 0.0654 - val_accuracy: 0.9296 - val_loss: 0.2797 - learning_rate: 1.0000e-04
# Epoch 184/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9881 - loss: 0.0633 - val_accuracy: 0.9314 - val_loss: 0.2807 - learning_rate: 1.0000e-04
# Epoch 185/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9907 - loss: 0.0605 - val_accuracy: 0.9296 - val_loss: 0.2829 - learning_rate: 1.0000e-04
# Epoch 186/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9897 - loss: 0.0587 - val_accuracy: 0.9260 - val_loss: 0.2890 - learning_rate: 1.0000e-04
# Epoch 187/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9907 - loss: 0.0683 - val_accuracy: 0.9242 - val_loss: 0.2917 - learning_rate: 1.0000e-04
# Epoch 188/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9913 - loss: 0.0597 - val_accuracy: 0.9278 - val_loss: 0.2979 - learning_rate: 1.0000e-04
# Epoch 189/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9892 - loss: 0.0665 - val_accuracy: 0.9242 - val_loss: 0.3032 - learning_rate: 1.0000e-04
# Epoch 190/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9919 - loss: 0.0627 - val_accuracy: 0.9278 - val_loss: 0.3041 - learning_rate: 1.0000e-04
# Epoch 191/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9918 - loss: 0.0637 - val_accuracy: 0.9296 - val_loss: 0.3006 - learning_rate: 1.0000e-04
# Epoch 192/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9933 - loss: 0.0582 - val_accuracy: 0.9278 - val_loss: 0.2930 - learning_rate: 1.0000e-04
# Epoch 193/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9924 - loss: 0.0563 - val_accuracy: 0.9278 - val_loss: 0.2879 - learning_rate: 1.0000e-04
# Epoch 194/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9915 - loss: 0.0617 - val_accuracy: 0.9278 - val_loss: 0.2877 - learning_rate: 1.0000e-04
# Epoch 195/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9890 - loss: 0.0641 - val_accuracy: 0.9278 - val_loss: 0.2933 - learning_rate: 1.0000e-04
# Epoch 196/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9942 - loss: 0.0576 - val_accuracy: 0.9296 - val_loss: 0.2942 - learning_rate: 1.0000e-04
# Epoch 197/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9897 - loss: 0.0592 - val_accuracy: 0.9260 - val_loss: 0.2846 - learning_rate: 1.0000e-04
# Epoch 198/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9880 - loss: 0.0624 - val_accuracy: 0.9260 - val_loss: 0.2881 - learning_rate: 1.0000e-04
# Epoch 199/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9889 - loss: 0.0627 - val_accuracy: 0.9206 - val_loss: 0.2910 - learning_rate: 1.0000e-04
# Epoch 200/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9901 - loss: 0.0605 - val_accuracy: 0.9278 - val_loss: 0.2957 - learning_rate: 1.0000e-04
# Epoch 201/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9923 - loss: 0.0586 - val_accuracy: 0.9296 - val_loss: 0.2920 - learning_rate: 1.0000e-04
# Epoch 202/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9881 - loss: 0.0580 - val_accuracy: 0.9296 - val_loss: 0.2966 - learning_rate: 1.0000e-04
# Epoch 203/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9927 - loss: 0.0581 - val_accuracy: 0.9278 - val_loss: 0.3023 - learning_rate: 1.0000e-04
# Epoch 204/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9915 - loss: 0.0564 - val_accuracy: 0.9314 - val_loss: 0.3038 - learning_rate: 1.0000e-04
# Epoch 205/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9923 - loss: 0.0559 - val_accuracy: 0.9296 - val_loss: 0.2992 - learning_rate: 1.0000e-04
# Epoch 206/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9862 - loss: 0.0673 - val_accuracy: 0.9314 - val_loss: 0.2895 - learning_rate: 1.0000e-04
# Epoch 207/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9919 - loss: 0.0564 - val_accuracy: 0.9260 - val_loss: 0.2852 - learning_rate: 1.0000e-04
# Epoch 208/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9916 - loss: 0.0616 - val_accuracy: 0.9260 - val_loss: 0.2881 - learning_rate: 1.0000e-04
# Epoch 209/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9871 - loss: 0.0643 - val_accuracy: 0.9314 - val_loss: 0.2861 - learning_rate: 1.0000e-04
# Epoch 210/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9957 - loss: 0.0536 - val_accuracy: 0.9314 - val_loss: 0.2861 - learning_rate: 1.0000e-04
# Epoch 211/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9898 - loss: 0.0546 - val_accuracy: 0.9296 - val_loss: 0.2845 - learning_rate: 1.0000e-04
# Epoch 212/1000
# 14/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9842 - loss: 0.0626
# Epoch 212: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9864 - loss: 0.0602 - val_accuracy: 0.9296 - val_loss: 0.2863 - learning_rate: 1.0000e-04
# Epoch 213/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9904 - loss: 0.0574 - val_accuracy: 0.9296 - val_loss: 0.2860 - learning_rate: 1.0000e-05
# Epoch 214/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9875 - loss: 0.0621 - val_accuracy: 0.9296 - val_loss: 0.2861 - learning_rate: 1.0000e-05
# Epoch 215/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9927 - loss: 0.0553 - val_accuracy: 0.9314 - val_loss: 0.2863 - learning_rate: 1.0000e-05
# Epoch 216/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9878 - loss: 0.0597 - val_accuracy: 0.9314 - val_loss: 0.2867 - learning_rate: 1.0000e-05
# Epoch 217/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9916 - loss: 0.0596 - val_accuracy: 0.9332 - val_loss: 0.2861 - learning_rate: 1.0000e-05
# Epoch 218/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9890 - loss: 0.0594 - val_accuracy: 0.9332 - val_loss: 0.2855 - learning_rate: 1.0000e-05
# Epoch 219/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9871 - loss: 0.0650 - val_accuracy: 0.9332 - val_loss: 0.2853 - learning_rate: 1.0000e-05
# Epoch 220/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9965 - loss: 0.0518 - val_accuracy: 0.9332 - val_loss: 0.2857 - learning_rate: 1.0000e-05
# Epoch 221/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9924 - loss: 0.0583 - val_accuracy: 0.9332 - val_loss: 0.2859 - learning_rate: 1.0000e-05
# Epoch 222/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9929 - loss: 0.0523 - val_accuracy: 0.9332 - val_loss: 0.2866 - learning_rate: 1.0000e-05
# Epoch 223/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9928 - loss: 0.0544 - val_accuracy: 0.9314 - val_loss: 0.2865 - learning_rate: 1.0000e-05
# Epoch 224/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9952 - loss: 0.0516 - val_accuracy: 0.9314 - val_loss: 0.2861 - learning_rate: 1.0000e-05
# Epoch 225/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9905 - loss: 0.0585 - val_accuracy: 0.9314 - val_loss: 0.2851 - learning_rate: 1.0000e-05
# Epoch 226/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9916 - loss: 0.0542 - val_accuracy: 0.9332 - val_loss: 0.2857 - learning_rate: 1.0000e-05
# Epoch 227/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9926 - loss: 0.0535 - val_accuracy: 0.9296 - val_loss: 0.2870 - learning_rate: 1.0000e-05
# Epoch 228/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9945 - loss: 0.0505 - val_accuracy: 0.9296 - val_loss: 0.2856 - learning_rate: 1.0000e-05
# Epoch 229/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9881 - loss: 0.0574 - val_accuracy: 0.9296 - val_loss: 0.2853 - learning_rate: 1.0000e-05
# Epoch 230/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9940 - loss: 0.0557 - val_accuracy: 0.9296 - val_loss: 0.2853 - learning_rate: 1.0000e-05
# Epoch 231/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9915 - loss: 0.0534 - val_accuracy: 0.9314 - val_loss: 0.2866 - learning_rate: 1.0000e-05
# Epoch 232/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9942 - loss: 0.0546 - val_accuracy: 0.9314 - val_loss: 0.2867 - learning_rate: 1.0000e-05
# Epoch 233/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9872 - loss: 0.0648 - val_accuracy: 0.9314 - val_loss: 0.2870 - learning_rate: 1.0000e-05
# Epoch 234/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9946 - loss: 0.0521 - val_accuracy: 0.9314 - val_loss: 0.2867 - learning_rate: 1.0000e-05
# Epoch 235/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9896 - loss: 0.0648 - val_accuracy: 0.9314 - val_loss: 0.2870 - learning_rate: 1.0000e-05
# Epoch 236/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9936 - loss: 0.0501 - val_accuracy: 0.9314 - val_loss: 0.2859 - learning_rate: 1.0000e-05
# Epoch 237/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9912 - loss: 0.0533 - val_accuracy: 0.9296 - val_loss: 0.2858 - learning_rate: 1.0000e-05
# Epoch 238/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9909 - loss: 0.0515 - val_accuracy: 0.9314 - val_loss: 0.2854 - learning_rate: 1.0000e-05
# Epoch 239/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9904 - loss: 0.0561 - val_accuracy: 0.9314 - val_loss: 0.2852 - learning_rate: 1.0000e-05
# Epoch 240/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9891 - loss: 0.0588 - val_accuracy: 0.9296 - val_loss: 0.2855 - learning_rate: 1.0000e-05
# Epoch 241/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9913 - loss: 0.0534 - val_accuracy: 0.9296 - val_loss: 0.2857 - learning_rate: 1.0000e-05
# Epoch 242/1000
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9881 - loss: 0.0607
# Epoch 242: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9884 - loss: 0.0604 - val_accuracy: 0.9296 - val_loss: 0.2853 - learning_rate: 1.0000e-05
# 60
# times= 72.74541544914246
# max_val_accuracy 0.9332129955291748
# max_accuracy 0.9950293898582458
# max_val_loss 2.4241557121276855
# max_loss 2.173478126525879
# learning_rate 1.0000000656873453e-05

# %%
df_histories=pd.DataFrame({"times":times,"max_accuracies":max_accuracies,"max_val_accuracies":max_val_accuracies,"max_val_losses":max_val_losses,"max_losses":max_losses,"learning_rates":learning_rates})
df_histories.to_csv('/content/drive/MyDrive/UDENAR/ProyectosGrado/Errol/Ginna/ResultsBERT/ablations_finall.csv')

# %%
df_histories
# Out:
#         times  max_accuracies  max_val_accuracies  max_val_losses  max_losses  \
# 0  169.172873        1.000000            0.942238        2.029496    2.024967
# 1  117.749322        1.000000            0.944043        1.936619    2.035028
# 2  119.699390        1.000000            0.945848        2.111512    1.978953
# 3  109.264185        0.999548            0.942238        2.041958    2.024786
# 4  104.880635        0.998644            0.938628        1.994298    2.186902
# 5   72.745415        0.995029            0.933213        2.424156    2.173478
#
#    learning_rates
# 0        0.000010
# 1        0.000001
# 2        0.000010
# 3        0.000100
# 4        0.000010
# 5        0.000010

# %%
from sklearn.metrics import matthews_corrcoef, precision_recall_curve, auc
from sklearn.preprocessing import label_binarize
import numpy as np

def calculate_mcc_multiclass(y_true, y_pred_probs):
    y_pred_labels = np.argmax(y_pred_probs, axis=1)
    # Convertir etiquetas verdaderas one-hot a etiquetas enteras si es necesario
    #y_true_labels = np.argmax(y_true, axis=1) if y_true.ndim > 1 else y_true
    return matthews_corrcoef(y_true, y_pred_labels)

def calculate_auc_pr_multiclass(y_true, y_pred_probs, average='macro'):
    n_classes = y_pred_probs.shape[1]
    #y_true_labels = np.argmax(y_true, axis=1) if y_true.ndim > 1 else y_true
    y_true_bin = label_binarize(y_true, classes=range(n_classes))

    auc_pr_list = []
    for i in range(n_classes):
        precision, recall, _ = precision_recall_curve(y_true_bin[:, i], y_pred_probs[:, i])
        auc_pr_list.append(auc(recall, precision))

    if average == 'macro':
        return np.mean(auc_pr_list)
    elif average == 'weighted':
        class_counts = y_true_bin.sum(axis=0)
        return np.average(auc_pr_list, weights=class_counts)
    else:
        return auc_pr_list

# %%
from tensorflow import keras
accuracies_predict=[]
loss_predict=[]
times_predict=[]
mccs_predict=[]
aucpr_predict=[]

Model_Xtest=[Xp_test,Xcode_test,Xs_test,Xt_test,Xf_test]
for i,my_model in enumerate(models):
  model=keras.models.load_model('/content/drive/MyDrive/UDENAR/ProyectosGrado/Errol/Ginna/ResultsBERT/ablations_finall_{0}.keras'.format(models_names[i]))
  if(i==1):
    Model_Xtest=[Xp_test,Xs_test,Xt_test,Xf_test]
  if(i==2):
    Model_Xtest=[Xcode_test,Xs_test,Xt_test,Xf_test]
  if(i==3):
    Model_Xtest=[Xs_test,Xt_test,Xf_test]
  if(i==4):
    Model_Xtest=[Xp_test,Xcode_test]
  if(i==5):
    Model_Xtest=[Xcode_test]


  evaluate=model.evaluate(Model_Xtest,y_test)

  t1=time()
  y_pred=model.predict(Model_Xtest)
  t2=time()
  mcc=calculate_mcc_multiclass(y_test, y_pred)
  auc_pr=calculate_auc_pr_multiclass(y_test, y_pred)

  times_predict.append(t2-t1)
  accuracies_predict.append(evaluate[1])
  loss_predict.append(evaluate[0])
  mccs_predict.append(mcc)
  aucpr_predict.append(auc_pr)


  accuracy=evaluate[1]
  loss=evaluate[0]

  print("accuracy",accuracy)
  print("loss",loss)
  print("mcc",mcc)
  print("auc_pr",auc_pr)
  print("time predict",t2-t1)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 8s 97ms/step - accuracy: 0.9376 - loss: 0.2033
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 6s 198ms/step
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# accuracy 0.9277456402778625
# loss 0.2542642652988434
# mcc 0.9035662146378574
# auc_pr 0.9024990106710449
# time predict 6.4809629917144775
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 8s 110ms/step - accuracy: 0.9196 - loss: 0.2344
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# accuracy 0.9190751314163208
# loss 0.2697467803955078
# mcc 0.892148008061973
# auc_pr 0.8956686147023067
# time predict 5.492192029953003
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.9481 - loss: 0.2031
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# accuracy 0.9364162087440491
# loss 0.2574061453342438
# mcc 0.9151569481498553
# auc_pr 0.8966888667097355
# time predict 10.468127012252808
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9068 - loss: 0.2880
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step
# accuracy 0.9205202460289001
# loss 0.30491843819618225
# mcc 0.8940483314621949
# auc_pr 0.890266498439552
# time predict 1.2852563858032227
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9106 - loss: 0.3818
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# accuracy 0.9046242833137512
# loss 0.44650229811668396
# mcc 0.8730445535922701
# auc_pr 0.8849389287594958
# time predict 1.0103280544281006
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9121 - loss: 0.3473
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# accuracy 0.9031791687011719
# loss 0.4084739089012146
# mcc 0.8712175907051605
# auc_pr 0.885152795272113
# time predict 1.028111457824707
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(

# %%
df_histories['accuracies_predict']=accuracies_predict
df_histories['loss_predict']=loss_predict
df_histories['times_predict']=times_predict
df_histories['mccs']=mccs_predict
df_histories['aucpr']=aucpr_predict
df_histories.to_csv('/content/drive/MyDrive/UDENAR/ProyectosGrado/Errol/Ginna/ResultsBERT/early_best_finall_predict.csv')

# %%
df_histories['model']=models_names

# %%
df_histories
# Out:
#         times  max_accuracies  max_val_accuracies  max_val_losses  max_losses  \
# 0  169.172873        1.000000            0.942238        2.029496    2.024967
# 1  117.749322        1.000000            0.944043        1.936619    2.035028
# 2  119.699390        1.000000            0.945848        2.111512    1.978953
# 3  109.264185        0.999548            0.942238        2.041958    2.024786
# 4  104.880635        0.998644            0.938628        1.994298    2.186902
# 5   72.745415        0.995029            0.933213        2.424156    2.173478
#
#    learning_rates  accuracies_predict  loss_predict  times_predict      mccs  \
# 0        0.000010            0.927746      0.254264       6.480963  0.903566
# 1        0.000001            0.919075      0.269747       5.492192  0.892148
# 2        0.000010            0.936416      0.257406      10.468127  0.915157
# 3        0.000100            0.920520      0.304918       1.285256  0.894048
# 4        0.000010            0.904624      0.446502       1.010328  0.873045
# 5        0.000010            0.903179      0.408474       1.028111  0.871218
#
#       aucpr          model
# 0  0.902499     problemall
# 1  0.895669  problem_gries
# 2  0.896689     code_gries
# 3  0.890266          gries
# 4  0.884939   problem_code
# 5  0.885153           code

# %%
df_histories[(df_histories['aucpr']>0.89)]
# Out:
#         times  max_accuracies  max_val_accuracies  max_val_losses  max_losses  \
# 0  169.172873        1.000000            0.942238        2.029496    2.024967
# 1  117.749322        1.000000            0.944043        1.936619    2.035028
# 2  119.699390        1.000000            0.945848        2.111512    1.978953
# 3  109.264185        0.999548            0.942238        2.041958    2.024786
#
#    learning_rates  accuracies_predict  loss_predict  times_predict      mccs  \
# 0        0.000010            0.927746      0.254264       6.480963  0.903566
# 1        0.000001            0.919075      0.269747       5.492192  0.892148
# 2        0.000010            0.936416      0.257406      10.468127  0.915157
# 3        0.000100            0.920520      0.304918       1.285256  0.894048
#
#       aucpr          model
# 0  0.902499     problemall
# 1  0.895669  problem_gries
# 2  0.896689     code_gries
# 3  0.890266          gries

# %%
df_histories[(df_histories['aucpr']>0.89)&(df_histories['max_accuracies']-df_histories['max_val_accuracies']<0.06)]
# Out:
#         times  max_accuracies  max_val_accuracies  max_val_losses  max_losses  \
# 0  169.172873        1.000000            0.942238        2.029496    2.024967
# 1  117.749322        1.000000            0.944043        1.936619    2.035028
# 2  119.699390        1.000000            0.945848        2.111512    1.978953
# 3  109.264185        0.999548            0.942238        2.041958    2.024786
#
#    learning_rates  accuracies_predict  loss_predict  times_predict      mccs  \
# 0        0.000010            0.927746      0.254264       6.480963  0.903566
# 1        0.000001            0.919075      0.269747       5.492192  0.892148
# 2        0.000010            0.936416      0.257406      10.468127  0.915157
# 3        0.000100            0.920520      0.304918       1.285256  0.894048
#
#       aucpr          model
# 0  0.902499     problemall
# 1  0.895669  problem_gries
# 2  0.896689     code_gries
# 3  0.890266          gries

# %% [markdown]
# Early stoping 40 the best, add code + gries

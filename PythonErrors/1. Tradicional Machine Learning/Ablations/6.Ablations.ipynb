# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.56.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.35.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.8.3)

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import re
import shutil
import string
from sklearn.metrics import classification_report
import tensorflow as tf
from keras.models import Model
from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras.optimizers import Adam
from keras.callbacks import EarlyStopping,ModelCheckpoint
from tensorflow.keras.layers import Dense, Input, Dropout, Bidirectional, LSTM, Embedding, BatchNormalization,  Reshape, Conv2D, MaxPool2D, concatenate, Flatten, Activation
import torch
import numpy as np
from transformers import BertTokenizer, BertModel,RobertaTokenizer, RobertaModel
import ast

# %%
# Verificar si la GPU está disponible
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
archivo_3 = '/content/drive/MyDrive/UDENAR/ProyectosGrado/Errol/Ginna/Tuning/BestModels/finallDataset.csv'
train_full = pd.read_csv(archivo_3)

# %% [markdown]
# # AST spliter D. Gries form

# %%
class WhileLoopFinder(ast.NodeVisitor):
    def __init__(self, source_code):
        self.source_code = source_code.splitlines()
        self.functions_with_while = []
        self.current_function = None

    def visit_FunctionDef(self, node):
        original_current_function = self.current_function
        self.current_function = {
            "function_name": node.name,
            "has_while_loop": False,
            "pre_while_code_lines": [],
            "while_loops": []
        }

        function_start_line = node.lineno - 1
        function_end_line = (node.end_lineno if hasattr(node, 'end_lineno') else len(self.source_code))
        function_lines = self.source_code[function_start_line:function_end_line]

        found_while = False
        for stmt in node.body:
            if isinstance(stmt, ast.While):
                self.current_function["has_while_loop"] = True
                found_while = True
                try:
                    while_condition = ast.unparse(stmt.test).strip()
                    print("OK condition")
                except AttributeError:
                    print("Error al obtener la condición del while")
                try:
                    while_body_code = ast.unparse(ast.Module(body=stmt.body, type_ignores=[])).strip()
                    print("Ok body")
                except AttributeError:
                    print("Error al obtener el código del cuerpo del while")

                self.current_function["while_loops"].append({
                    "condition": while_condition,
                    "body_code": while_body_code
                })
            elif not found_while:
                start_line = stmt.lineno - 1
                end_line = (stmt.end_lineno if hasattr(stmt, 'end_lineno') else stmt.lineno)
                self.current_function["pre_while_code_lines"].extend(self.source_code[start_line:end_line])
            self.generic_visit(stmt)

        if self.current_function["has_while_loop"]:
            last_while_end_line = None
            if self.current_function["while_loops"]:
                last_while_node = next((node for node in reversed(node.body) if isinstance(node, ast.While)), None)
                if last_while_node and hasattr(last_while_node, 'end_lineno'):
                    last_while_end_line = last_while_node.end_lineno
            post_while_code_lines = []
            if last_while_end_line:
                function_indent = len(self.source_code[node.lineno - 1]) - len(self.source_code[node.lineno - 1].lstrip())
                for line in self.source_code[last_while_end_line:function_end_line]:
                    if line.startswith(self.source_code[node.lineno - 1][:function_indent] + "    "):
                        post_while_code_lines.append(line[function_indent + 4:])
                    else:
                        post_while_code_lines.append(line[function_indent:])
            self.current_function["post_while_code_lines"] = "\n".join(post_while_code_lines).strip()
            self.current_function["pre_while_code_lines"] = "\n".join(self.current_function["pre_while_code_lines"]).strip()
            self.functions_with_while.append(self.current_function)

        self.current_function = original_current_function

# %%
def DGries_states(solution):
  try:
    # Crear el AST
    tree = ast.parse(solution)
    # Recorrer el AST con nuestro visitante
    finder = WhileLoopFinder(solution)
    finder.visit(tree)
    for func_info in finder.functions_with_while:
      initial_state=func_info["pre_while_code_lines"] if func_info["pre_while_code_lines"] else False
      end_state=""
      transformation_state=""
      for j, wl in enumerate(func_info["while_loops"]):
          end_state=wl["condition"]
          transformation_state=wl["body_code"]

      if not initial_state:
        initial_state=transformation_state
      return initial_state,transformation_state,end_state
  except Exception as error:
    return "Exception:"+str(error),"Exception:"+str(error),"Exception:"+str(error)

# %% [markdown]
# # Encoder Description and Code

# %%
class EncodeTextSource:
  def __init__(self):
    self.is_loadtokenizers=False



  def tokenize_and_generate_embeddings_descriptions(self,description):
    if not self.is_loadtokenizers:
      raise ValueError("tokenizers dont load")
    # Tokenize input description and move tokens to GPU
    tokens = self.beart_tokenizer.encode_plus(description, return_tensors="pt", truncation=True)
    tokens = {key: value.to(device) for key, value in tokens.items()}
    # Generate embeddings
    with torch.no_grad():
        outputs = self.beart_model(**tokens)
    # Extract embeddings for all tokens
    desc_embeddings = outputs.last_hidden_state.cpu().numpy()
    return desc_embeddings

  def tokenize_and_generate_embeddings_codes(self,code):
    if not self.is_loadtokenizers:
      raise ValueError("tokenizers dont load")
    # Tokenize input code and move tokens to GPU
    tokens = self.beart_tokenizer.encode_plus(code, return_tensors="pt", truncation=True)
    tokens = {key: value.to(device) for key, value in tokens.items()}
    # Generate embeddings
    with torch.no_grad():
        outputs = self.codebeart_model(**tokens)
    # Extract embeddings for all tokens
    code_embeddings = outputs.last_hidden_state.cpu().numpy()

    return code_embeddings

  def load_beart_tokenizer(self):
    # Verificar si la GPU está disponible
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Cargar el tokenizer y el modelo en la GPU si está disponible
    model_name = "bert-base-uncased"
    self.beart_model = BertModel.from_pretrained(model_name)
    self.beart_tokenizer = BertTokenizer.from_pretrained(model_name)
    self.beart_model.to(device)

  def load_codebert_tokenizer(self):
    # Verificar si la GPU está disponible
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Cargar el tokenizer y el modelo en la GPU si está disponible
    self.codebeart_tokenizer = RobertaTokenizer.from_pretrained("microsoft/codebert-base")
    self.codebeart_model = RobertaModel.from_pretrained("microsoft/codebert-base")
    self.codebeart_model.to(device)

  def start_tokenizer(self):
    self.load_beart_tokenizer()
    self.load_codebert_tokenizer()
    self.is_loadtokenizers=True

# %% [markdown]
# # All characteristics

# %%
def categoricallabelAll(w):
  if w=="['Correct']":
    return 0
  if w=="['Initial state']":
    return 1
  if w=="['Final state']":
    return 2
  if w=="['State transformation']":
    return 3
  if w=="['Initial state', 'Final state']":
    return 4
  if w=="['Initial state', 'State transformation']":
    return 5
  if w=="['Final state', 'State transformation']":
    return 6
  if w=="['Initial state', 'Final state', 'State transformation']":
    return 7
  return 8

category=np.array([
    'Correct',
    'Initial state',
    'Final state',
    'State transformation',
    'Initial state, Final state',
    'Initial state, State transformation',
    'Final state, State transformation',
    'Initial state, Final state, State transformation'

])

# %% [markdown]
# # Load Dataset

# %%
train_full.head()
# Out:
#                                             Problema  \
# 0  Write a Python function that returns the facto...
# 1  Write a Python function that returns the sum o...
# 2  Write a Python function that prints the number...
# 3  Write a Python function to print the numbers f...
# 4  Write a Python function to check if a number i...
#
#                                             Solución  y
# 0  def factorial(n):\n    result = 0\n    i = 1\n...  0
# 1  def sum_1_to_100():\n    total = 0\n    i = 1\...  0
# 2  def print_and_store():\n    numbers = []\n    ...  0
# 3  def print_and_store_reverse():\n    numbers = ...  0
# 4  def is_prime(num):\n    i = 2\n    while i < n...  0

# %%
train_full[["Estado incial","Transformación de estado","Estado final"]]=train_full['Solución'].apply(DGries_states).apply(pd.Series)
# Out:
# Streaming output truncated to the last 5000 lines.
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body

# %%
train_full
# Out:
#                                                Problema  \
# 0     Write a Python function that returns the facto...
# 1     Write a Python function that returns the sum o...
# 2     Write a Python function that prints the number...
# 3     Write a Python function to print the numbers f...
# 4     Write a Python function to check if a number i...
# ...                                                 ...
# 4130      calculate how many numbers are divisible by 3
# 4131      calculate how many numbers are divisible by 3
# 4132      calculate how many numbers are divisible by 3
# 4133      calculate how many numbers are divisible by 3
# 4134      calculate how many numbers are divisible by 3
#
#                                                Solución  y  \
# 0     def factorial(n):\n    result = 0\n    i = 1\n...  0
# 1     def sum_1_to_100():\n    total = 0\n    i = 1\...  0
# 2     def print_and_store():\n    numbers = []\n    ...  0
# 3     def print_and_store_reverse():\n    numbers = ...  0
# 4     def is_prime(num):\n    i = 2\n    while i < n...  0
# ...                                                 ... ..
# 4130  def buggy_count_mult_3(n):\n    i = 0\n    cou...  6
# 4131  def buggy_count_mult_3(n):\n    i = 0\n    cou...  6
# 4132  def buggy_count_mult_3(n):\n    count = 0\n   ...  6
# 4133  def buggy_count_mult_3(n):\n    count = 0\n   ...  6
# 4134  def buggy_count_mult_3(n):\n    count = 0\n   ...  6
#
#                 Estado incial  \
# 0       result = 0\n    i = 1
# 1        total = 0\n    i = 1
# 2     numbers = []\n    i = 0
# 3     numbers = []\n    i = 0
# 4                       i = 2
# ...                       ...
# 4130     i = 0\n    count = 0
# 4131     i = 0\n    count = 0
# 4132     count = 0\n    i = 0
# 4133     count = 0\n    i = 0
# 4134     count = 0\n    i = 0
#
#                                Transformación de estado Estado final
# 0                                   result += i\ni += 1       i <= n
# 1                                    total += i\ni += 2      i < 100
# 2                      print(i)\nnumbers[i] = i\ni += 1       i < 10
# 3              print(10 - i)\nnumbers.append(i)\ni += 1       i < 10
# 4            if num % i == 0:\n    return False\ni += 1      i < num
# ...                                                 ...          ...
# 4130   if i % 3 == 0:\n    count = count + 1\ni = i + 1        i < n
# 4131             if i % 3 == 0:\n    count += 1\ni += 1   not i >= n
# 4132              if not i % 3:\n    count += 1\ni += 1        n > i
# 4133  if i % 3 == 0 and True:\n    count = count + 1...       i != n
# 4134                   count += int(i % 3 == 0)\ni += 1        i < n
#
# [4135 rows x 6 columns]

# %%
y=train_full['y'].to_numpy()
np.unique(y)
# Out:
# array([0, 1, 2, 3, 4, 5, 6])

# %%
train_full.dropna(inplace=True)

# %%
train_full
# Out:
#                                                Problema  \
# 0     Write a Python function that returns the facto...
# 1     Write a Python function that returns the sum o...
# 2     Write a Python function that prints the number...
# 3     Write a Python function to print the numbers f...
# 4     Write a Python function to check if a number i...
# ...                                                 ...
# 4130      calculate how many numbers are divisible by 3
# 4131      calculate how many numbers are divisible by 3
# 4132      calculate how many numbers are divisible by 3
# 4133      calculate how many numbers are divisible by 3
# 4134      calculate how many numbers are divisible by 3
#
#                                                Solución  y  \
# 0     def factorial(n):\n    result = 0\n    i = 1\n...  0
# 1     def sum_1_to_100():\n    total = 0\n    i = 1\...  0
# 2     def print_and_store():\n    numbers = []\n    ...  0
# 3     def print_and_store_reverse():\n    numbers = ...  0
# 4     def is_prime(num):\n    i = 2\n    while i < n...  0
# ...                                                 ... ..
# 4130  def buggy_count_mult_3(n):\n    i = 0\n    cou...  6
# 4131  def buggy_count_mult_3(n):\n    i = 0\n    cou...  6
# 4132  def buggy_count_mult_3(n):\n    count = 0\n   ...  6
# 4133  def buggy_count_mult_3(n):\n    count = 0\n   ...  6
# 4134  def buggy_count_mult_3(n):\n    count = 0\n   ...  6
#
#                 Estado incial  \
# 0       result = 0\n    i = 1
# 1        total = 0\n    i = 1
# 2     numbers = []\n    i = 0
# 3     numbers = []\n    i = 0
# 4                       i = 2
# ...                       ...
# 4130     i = 0\n    count = 0
# 4131     i = 0\n    count = 0
# 4132     count = 0\n    i = 0
# 4133     count = 0\n    i = 0
# 4134     count = 0\n    i = 0
#
#                                Transformación de estado Estado final
# 0                                   result += i\ni += 1       i <= n
# 1                                    total += i\ni += 2      i < 100
# 2                      print(i)\nnumbers[i] = i\ni += 1       i < 10
# 3              print(10 - i)\nnumbers.append(i)\ni += 1       i < 10
# 4            if num % i == 0:\n    return False\ni += 1      i < num
# ...                                                 ...          ...
# 4130   if i % 3 == 0:\n    count = count + 1\ni = i + 1        i < n
# 4131             if i % 3 == 0:\n    count += 1\ni += 1   not i >= n
# 4132              if not i % 3:\n    count += 1\ni += 1        n > i
# 4133  if i % 3 == 0 and True:\n    count = count + 1...       i != n
# 4134                   count += int(i % 3 == 0)\ni += 1        i < n
#
# [4094 rows x 6 columns]

# %%
encoder=EncodeTextSource()
encoder.start_tokenizer()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/498 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]

# %%
# %%time
problem=train_full['Problema'].apply(encoder.tokenize_and_generate_embeddings_descriptions).to_numpy()
code=train_full['Solución'].apply(encoder.tokenize_and_generate_embeddings_codes).to_numpy()
startstate = train_full['Estado incial'].apply(encoder.tokenize_and_generate_embeddings_codes).to_numpy()
finalstate = train_full['Estado final'].apply(encoder.tokenize_and_generate_embeddings_codes).to_numpy()
transstate = train_full['Transformación de estado'].apply(encoder.tokenize_and_generate_embeddings_codes).to_numpy()
# Out:
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# CPU times: user 2min 44s, sys: 2.66 s, total: 2min 47s
# Wall time: 2min 44s

# %%
problem.shape,code.shape,startstate.shape,finalstate.shape,transstate.shape
# Out:
# ((4094,), (4094,), (4094,), (4094,), (4094,))

# %%
print(startstate.shape)
print(startstate[1262].shape)
# Out:
# (4094,)
# (1, 9, 768)

# %%
Xp=np.array([sentence[0].mean(axis=0) for sentence in problem])
Xcode=np.array([sentence[0].mean(axis=0) for sentence in code])
Xs=np.array([sentence[0].mean(axis=0) for sentence in startstate])
Xf=np.array([sentence[0].mean(axis=0) for sentence in finalstate])
Xt=np.array([sentence[0].mean(axis=0) for sentence in transstate])
Xp.shape,Xs.shape,Xf.shape,Xt.shape
# Out:
# ((4094, 768), (4094, 768), (4094, 768), (4094, 768))

# %%
y=train_full['y'].to_numpy()
np.unique(y)
# Out:
# array([0, 1, 2, 3, 4, 5, 6])

# %%
y.shape
# Out:
# (4094,)

# %%
from sklearn.model_selection import train_test_split

Xp_train,Xp_test,Xcode_train,Xcode_test,Xs_train,Xs_test,Xt_train,Xt_test,Xf_train,Xf_test,y_train,y_test=train_test_split(Xp,Xcode,Xs,Xt,Xf,y,test_size=0.2,random_state=2023, stratify=y)

# %%
Xp_train.shape,Xp_test.shape,Xcode_train.shape, Xcode_test.shape, Xs_train.shape,Xs_test.shape,Xt_train.shape,Xt_test.shape,Xf_train.shape,Xf_test.shape,y_train.shape,y_test.shape
# Out:
# ((3275, 768),
#  (819, 768),
#  (3275, 768),
#  (819, 768),
#  (3275, 768),
#  (819, 768),
#  (3275, 768),
#  (819, 768),
#  (3275, 768),
#  (819, 768),
#  (3275,),
#  (819,))

# %%
#random search
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import matthews_corrcoef
#XGBoost
from xgboost import XGBClassifier
#pipeline
from sklearn.pipeline import Pipeline
from sklearn.neural_network import MLPClassifier

# %%
from sklearn.metrics import matthews_corrcoef, precision_recall_curve, auc
from sklearn.preprocessing import label_binarize
import numpy as np

def calculate_mcc_multiclass(y_true, y_pred_probs):
    y_pred_labels = np.argmax(y_pred_probs, axis=1)
    # Convertir etiquetas verdaderas one-hot a etiquetas enteras si es necesario
    #y_true_labels = np.argmax(y_true, axis=1) if y_true.ndim > 1 else y_true
    return matthews_corrcoef(y_true, y_pred_labels)

def calculate_auc_pr_multiclass(y_true, y_pred_probs, average='macro'):
    n_classes = y_pred_probs.shape[1]
    #y_true_labels = np.argmax(y_true, axis=1) if y_true.ndim > 1 else y_true
    y_true_bin = label_binarize(y_true, classes=range(n_classes))

    auc_pr_list = []
    for i in range(n_classes):
        precision, recall, _ = precision_recall_curve(y_true_bin[:, i], y_pred_probs[:, i])
        auc_pr_list.append(auc(recall, precision))

    if average == 'macro':
        return np.mean(auc_pr_list)
    elif average == 'weighted':
        class_counts = y_true_bin.sum(axis=0)
        return np.average(auc_pr_list, weights=class_counts)
    else:
        return auc_pr_list

# %% [markdown]
# # KNN

# %%
from tensorflow.keras.losses import sparse_categorical_crossentropy
from sklearn.ensemble import VotingClassifier,StackingClassifier
from sklearn.linear_model import LogisticRegression

# %%
accuracies_train=[]
accuracies_predict=[]
loss_predict=[]
times_train=[]
times_predict=[]
mccs_predict=[]
aucpr_predict=[]
ml_names=[]
abl_names=[]

# %%
import joblib

# %%
path="/content/drive/MyDrive/UDENAR/ProyectosGrado/Errol/Ginna/1. Tradicional Machine Learning/BestResult6/"

# %%
from time import time
knn=KNeighborsClassifier(n_neighbors=15,p=1,weights='distance')
svm_pipe=Pipeline([
    ('scaler',StandardScaler()),
    ('classifier',SVC(kernel='rbf',gamma=3.359818286283781e-05,C=69.51927961775606,probability=True))
])
mlp_pipe=Pipeline([
    ('scaler',StandardScaler()),
    ('classifier',MLPClassifier(hidden_layer_sizes=(100,100,100),learning_rate='adaptive'))
])

rf=RandomForestClassifier(n_estimators=80,max_depth=15)

vt=VotingClassifier(estimators=[('mlp',mlp_pipe),('rf',rf)],voting='soft')
st=StackingClassifier(estimators=[('mlp',mlp_pipe),('rf',rf)],final_estimator=LogisticRegression())

models=[knn,svm_pipe,mlp_pipe,rf,vt,st]
models_names=["KNN","SVM","MLP","Random Forest","Voting","Stacking"]
ablations_names=["problemall","problem_gries","code_gries","gries","problem_code","code"]

for model,name in zip(models,models_names):
  print(name)
  # Define the full datasets outside the inner loop
  X_train_full = np.concatenate((Xp_train,Xcode_train,Xs_train,Xt_train,Xf_train),axis=1)
  X_test_full = np.concatenate((Xp_test,Xcode_test,Xs_test,Xt_test,Xf_test),axis=1)

  for ablations_name in ablations_names:
    ml_names.append(name)
    abl_names.append(ablations_name)
    print(ablations_name)

    if ablations_name=="problemall":
      X_train = X_train_full
      X_test = X_test_full
    elif ablations_name=="problem_gries":
      X_train=np.concatenate((Xp_train,Xs_train,Xt_train,Xf_train),axis=1)
      X_test=np.concatenate((Xp_test,Xs_test,Xt_test,Xf_test),axis=1) # Corrected X_test construction
    elif ablations_name=="code_gries":
      X_train=np.concatenate((Xcode_train,Xs_train,Xt_train,Xf_train),axis=1)
      X_test=np.concatenate((Xcode_test,Xs_test,Xt_test,Xf_test),axis=1) # Corrected X_test construction
    elif ablations_name=="gries":
      X_train=np.concatenate((Xs_train,Xt_train,Xf_train),axis=1)
      X_test=np.concatenate((Xs_test,Xt_test,Xf_test),axis=1) # Corrected X_test construction
    elif ablations_name=="problem_code":
      X_train=np.concatenate((Xp_train,Xcode_train),axis=1)
      X_test=np.concatenate((Xp_test,Xcode_test),axis=1) # Corrected X_test construction
    elif ablations_name=="code":
      X_train=Xcode_train # Corrected X_train construction
      X_test=Xcode_test # Corrected X_test construction

    time1=time()
    model.fit(X_train,y_train)
    time2=time()
    joblib.dump(model,path+"bert_"+name+"_"+ablations_name+".joblib")
    times_train.append(time2-time1)
    time1=time()
    y_pred=model.predict(X_test)
    time2=time()
    times_predict.append(time2-time1)

    accuracie_train=model.score(X_train,y_train)
    accuracies_train.append(accuracie_train)
    accuracie_test=model.score(X_test,y_test)
    accuracies_predict.append(accuracie_test)
    #sparse_categorical_crossentropy
    y_pred_proba = model.predict_proba(X_test)
    loss=np.mean(sparse_categorical_crossentropy(y_test,y_pred_proba))
    loss_predict.append(loss)
    mcc = matthews_corrcoef(y_test, y_pred)
    mccs_predict.append(mcc)
    auc_pr = calculate_auc_pr_multiclass(y_test, model.predict_proba(X_test))
    aucpr_predict.append(auc_pr)
    print(classification_report(y_test,y_pred))
    print("Accuracy train",accuracie_train)
    print("Accuracy predict",accuracie_test)
    print("Loss",loss)
    print("MCC",mcc)
    print("AUC",auc_pr)
    print("==================================")
# Out:
# KNN
# problemall
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96       208
#            1       0.94      0.97      0.96       210
#            2       0.95      0.93      0.94       281
#            3       1.00      1.00      1.00        31
#            4       0.96      0.80      0.87        30
#            5       1.00      0.88      0.94        33
#            6       0.93      1.00      0.96        26
#
#     accuracy                           0.95       819
#    macro avg       0.96      0.94      0.95       819
# weighted avg       0.95      0.95      0.95       819
#
# Accuracy train 0.9987786259541984
# Accuracy predict 0.9511599511599511
# Loss 0.3543833522689094
# MCC 0.9346379148033198
# AUC 0.9778400963749388
# ==================================
# problem_gries
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97       208
#            1       0.94      0.97      0.96       210
#            2       0.96      0.94      0.95       281
#            3       1.00      1.00      1.00        31
#            4       0.96      0.80      0.87        30
#            5       1.00      0.94      0.97        33
#            6       0.93      1.00      0.96        26
#
#     accuracy                           0.96       819
#    macro avg       0.97      0.95      0.96       819
# weighted avg       0.96      0.96      0.96       819
#
# Accuracy train 0.9987786259541984
# Accuracy predict 0.9584859584859585
# Loss 0.3539772232482403
# MCC 0.9444213439508166
# AUC 0.9764819357105764
# ==================================
# code_gries
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96       208
#            1       0.95      0.98      0.97       210
#            2       0.96      0.93      0.94       281
#            3       1.00      1.00      1.00        31
#            4       0.96      0.80      0.87        30
#            5       1.00      0.82      0.90        33
#            6       0.93      1.00      0.96        26
#
#     accuracy                           0.95       819
#    macro avg       0.96      0.93      0.94       819
# weighted avg       0.95      0.95      0.95       819
#
# Accuracy train 0.9987786259541984
# Accuracy predict 0.9511599511599511
# Loss 0.26573379908983596
# MCC 0.9347244654155674
# AUC 0.979900641780542
# ==================================
# gries
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       208
#            1       0.95      0.98      0.97       210
#            2       0.96      0.94      0.95       281
#            3       1.00      1.00      1.00        31
#            4       0.96      0.80      0.87        30
#            5       1.00      0.88      0.94        33
#            6       0.93      1.00      0.96        26
#
#     accuracy                           0.96       819
#    macro avg       0.96      0.94      0.95       819
# weighted avg       0.96      0.96      0.96       819
#
# Accuracy train 0.9981679389312977
# Accuracy predict 0.9560439560439561
# Loss 0.26112055019655506
# MCC 0.9411327157536512
# AUC 0.9801675098362995
# ==================================
# problem_code
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91       208
#            1       0.94      0.95      0.95       210
#            2       0.93      0.91      0.92       281
#            3       1.00      1.00      1.00        31
#            4       0.96      0.80      0.87        30
#            5       1.00      0.82      0.90        33
#            6       0.81      1.00      0.90        26
#
#     accuracy                           0.93       819
#    macro avg       0.93      0.92      0.92       819
# weighted avg       0.93      0.93      0.93       819
#
# Accuracy train 0.9987786259541984
# Accuracy predict 0.9267399267399268
# Loss 0.34819969287027314
# MCC 0.9019947481750511
# AUC 0.9729511448166697
# ==================================
# code
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93       208
#            1       0.95      0.97      0.96       210
#            2       0.95      0.92      0.94       281
#            3       1.00      1.00      1.00        31
#            4       0.96      0.80      0.87        30
#            5       1.00      0.82      0.90        33
#            6       0.81      1.00      0.90        26
#
#     accuracy                           0.94       819
#    macro avg       0.94      0.92      0.93       819
# weighted avg       0.94      0.94      0.94       819
#
# Accuracy train 0.9987786259541984
# Accuracy predict 0.938949938949939
# Loss 0.32509674536336225
# MCC 0.9184250234567711
# AUC 0.9742955393521335
# ==================================
# SVM
# problemall
#               precision    recall  f1-score   support
#
#            0       0.92      0.95      0.93       208
#            1       0.91      0.96      0.94       210
#            2       0.94      0.91      0.92       281
#            3       1.00      1.00      1.00        31
#            4       0.90      0.63      0.75        30
#            5       0.83      0.76      0.79        33
#            6       0.88      0.88      0.88        26
#
#     accuracy                           0.92       819
#    macro avg       0.91      0.87      0.89       819
# weighted avg       0.92      0.92      0.92       819
#
# Accuracy train 0.9871755725190839
# Accuracy predict 0.9206349206349206
# Loss 0.2756941263179973
# MCC 0.8936980492178783
# AUC 0.9469091021276823
# ==================================
# problem_gries
#               precision    recall  f1-score   support
#
#            0       0.90      0.95      0.92       208
#            1       0.88      0.96      0.92       210
#            2       0.92      0.88      0.90       281
#            3       0.97      1.00      0.98        31
#            4       0.89      0.53      0.67        30
#            5       0.85      0.70      0.77        33
#            6       0.88      0.88      0.88        26
#
#     accuracy                           0.90       819
#    macro avg       0.90      0.84      0.86       819
# weighted avg       0.90      0.90      0.90       819
#
# Accuracy train 0.9737404580152672
# Accuracy predict 0.8998778998778999
# Loss 0.32364704987026766
# MCC 0.8660705534238327
# AUC 0.9337250063432986
# ==================================
# code_gries
#               precision    recall  f1-score   support
#
#            0       0.92      0.95      0.93       208
#            1       0.91      0.96      0.93       210
#            2       0.93      0.91      0.92       281
#            3       1.00      1.00      1.00        31
#            4       0.90      0.60      0.72        30
#            5       0.81      0.67      0.73        33
#            6       0.88      0.88      0.88        26
#
#     accuracy                           0.92       819
#    macro avg       0.91      0.85      0.87       819
# weighted avg       0.92      0.92      0.91       819
#
# Accuracy train 0.9847328244274809
# Accuracy predict 0.9157509157509157
# Loss 0.27708577006776797
# MCC 0.8869144258212591
# AUC 0.9455095085120367
# ==================================
# gries
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93       208
#            1       0.89      0.93      0.91       210
#            2       0.90      0.91      0.91       281
#            3       0.94      1.00      0.97        31
#            4       0.89      0.53      0.67        30
#            5       0.88      0.64      0.74        33
#            6       0.88      0.88      0.88        26
#
#     accuracy                           0.90       819
#    macro avg       0.90      0.84      0.86       819
# weighted avg       0.90      0.90      0.90       819
#
# Accuracy train 0.9694656488549618
# Accuracy predict 0.9035409035409036
# Loss 0.32074951062065965
# MCC 0.8702480279546219
# AUC 0.9313325205205052
# ==================================
# problem_code
#               precision    recall  f1-score   support
#
#            0       0.66      0.79      0.72       208
#            1       0.69      0.74      0.71       210
#            2       0.81      0.78      0.79       281
#            3       1.00      0.58      0.73        31
#            4       0.86      0.20      0.32        30
#            5       0.94      0.52      0.67        33
#            6       0.82      0.88      0.85        26
#
#     accuracy                           0.74       819
#    macro avg       0.82      0.64      0.69       819
# weighted avg       0.75      0.74      0.73       819
#
# Accuracy train 0.8180152671755725
# Accuracy predict 0.7362637362637363
# Loss 0.760508180171398
# MCC 0.6429863862339497
# AUC 0.76410629826572
# ==================================
# code
#               precision    recall  f1-score   support
#
#            0       0.61      0.79      0.69       208
#            1       0.68      0.67      0.67       210
#            2       0.79      0.79      0.79       281
#            3       1.00      0.52      0.68        31
#            4       0.50      0.10      0.17        30
#            5       0.89      0.48      0.63        33
#            6       0.83      0.77      0.80        26
#
#     accuracy                           0.71       819
#    macro avg       0.76      0.59      0.63       819
# weighted avg       0.72      0.71      0.70       819
#
# Accuracy train 0.7829007633587787
# Accuracy predict 0.7081807081807082
# Loss 0.8123807614098294
# MCC 0.60458172541259
# AUC 0.7263363990633833
# ==================================
# MLP
# problemall
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97       208
#            1       0.92      0.96      0.94       210
#            2       0.93      0.94      0.93       281
#            3       1.00      1.00      1.00        31
#            4       0.96      0.87      0.91        30
#            5       1.00      0.85      0.92        33
#            6       0.93      0.96      0.94        26
#
#     accuracy                           0.95       819
#    macro avg       0.96      0.93      0.95       819
# weighted avg       0.95      0.95      0.95       819
#
# Accuracy train 0.9908396946564886
# Accuracy predict 0.9462759462759462
# Loss 0.3943572
# MCC 0.928005083963785
# AUC 0.9558563616442065
# ==================================
# problem_gries
#               precision    recall  f1-score   support
#
#            0       0.99      0.94      0.97       208
#            1       0.92      0.98      0.95       210
#            2       0.93      0.94      0.94       281
#            3       1.00      1.00      1.00        31
#            4       1.00      0.80      0.89        30
#            5       1.00      0.88      0.94        33
#            6       0.93      1.00      0.96        26
#
#     accuracy                           0.95       819
#    macro avg       0.97      0.94      0.95       819
# weighted avg       0.95      0.95      0.95       819
#
# Accuracy train 0.9960305343511451
# Accuracy predict 0.9487179487179487
# Loss 0.3985149
# MCC 0.9314748093797579
# AUC 0.9572432299673108
# ==================================
# code_gries
#               precision    recall  f1-score   support
#
#            0       0.94      0.91      0.92       208
#            1       0.85      0.95      0.90       210
#            2       0.90      0.89      0.89       281
#            3       1.00      0.90      0.95        31
#            4       0.90      0.63      0.75        30
#            5       0.78      0.64      0.70        33
#            6       0.80      0.92      0.86        26
#
#     accuracy                           0.89       819
#    macro avg       0.88      0.83      0.85       819
# weighted avg       0.89      0.89      0.89       819
#
# Accuracy train 0.9654961832061069
# Accuracy predict 0.8913308913308914
# Loss 0.5626686
# MCC 0.8546044622428627
# AUC 0.9020110095067313
# ==================================
# gries
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95       208
#            1       0.94      0.93      0.94       210
#            2       0.89      0.94      0.91       281
#            3       1.00      1.00      1.00        31
#            4       0.92      0.80      0.86        30
#            5       0.87      0.82      0.84        33
#            6       1.00      0.96      0.98        26
#
#     accuracy                           0.93       819
#    macro avg       0.94      0.91      0.93       819
# weighted avg       0.93      0.93      0.93       819
#
# Accuracy train 0.9874809160305343
# Accuracy predict 0.9304029304029304
# Loss 0.4159455
# MCC 0.9067124583942148
# AUC 0.9488051989953388
# ==================================
# problem_code
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93       208
#            1       0.83      0.95      0.89       210
#            2       0.89      0.85      0.87       281
#            3       1.00      0.94      0.97        31
#            4       0.89      0.80      0.84        30
#            5       0.85      0.70      0.77        33
#            6       0.90      1.00      0.95        26
#
#     accuracy                           0.89       819
#    macro avg       0.90      0.88      0.89       819
# weighted avg       0.89      0.89      0.89       819
#
# Accuracy train 0.9770992366412213
# Accuracy predict 0.8901098901098901
# Loss 0.6061779
# MCC 0.8537031932824157
# AUC 0.9297075802529546
# ==================================
# code
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95       208
#            1       0.92      0.97      0.94       210
#            2       0.95      0.92      0.93       281
#            3       0.89      1.00      0.94        31
#            4       0.92      0.80      0.86        30
#            5       0.97      0.88      0.92        33
#            6       0.93      1.00      0.96        26
#
#     accuracy                           0.94       819
#    macro avg       0.93      0.93      0.93       819
# weighted avg       0.94      0.94      0.94       819
#
# Accuracy train 0.9880916030534351
# Accuracy predict 0.9377289377289377
# Loss 0.40160668
# MCC 0.9168560285239442
# AUC 0.9502328386525033
# ==================================
# Random Forest
# problemall
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       208
#            1       0.92      0.98      0.95       210
#            2       0.95      0.93      0.94       281
#            3       0.94      1.00      0.97        31
#            4       0.96      0.80      0.87        30
#            5       1.00      0.82      0.90        33
#            6       0.93      1.00      0.96        26
#
#     accuracy                           0.95       819
#    macro avg       0.95      0.93      0.94       819
# weighted avg       0.95      0.95      0.95       819
#
# Accuracy train 0.9987786259541984
# Accuracy predict 0.9474969474969475
# Loss 0.2609404727995213
# MCC 0.9298454816841125
# AUC 0.9683671612632663
# ==================================
# problem_gries
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97       208
#            1       0.92      0.99      0.95       210
#            2       0.95      0.93      0.94       281
#            3       1.00      1.00      1.00        31
#            4       0.96      0.80      0.87        30
#            5       1.00      0.82      0.90        33
#            6       0.93      1.00      0.96        26
#
#     accuracy                           0.95       819
#    macro avg       0.96      0.93      0.94       819
# weighted avg       0.95      0.95      0.95       819
#
# Accuracy train 0.9987786259541984
# Accuracy predict 0.9499389499389499
# Loss 0.2583588858931448
# MCC 0.9331497718744809
# AUC 0.9653840772709061
# ==================================
# code_gries
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.96       208
#            1       0.92      0.98      0.95       210
#            2       0.94      0.93      0.93       281
#            3       1.00      1.00      1.00        31
#            4       0.96      0.80      0.87        30
#            5       1.00      0.82      0.90        33
#            6       0.93      1.00      0.96        26
#
#     accuracy                           0.95       819
#    macro avg       0.96      0.93      0.94       819
# weighted avg       0.95      0.95      0.94       819
#
# Accuracy train 0.9987786259541984
# Accuracy predict 0.945054945054945
# Loss 0.2541831785321045
# MCC 0.9264817687582736
# AUC 0.9684110019011373
# ==================================
# gries
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97       208
#            1       0.92      0.99      0.95       210
#            2       0.95      0.93      0.94       281
#            3       1.00      1.00      1.00        31
#            4       0.96      0.80      0.87        30
#            5       1.00      0.82      0.90        33
#            6       0.93      1.00      0.96        26
#
#     accuracy                           0.95       819
#    macro avg       0.96      0.93      0.94       819
# weighted avg       0.95      0.95      0.95       819
#
# Accuracy train 0.9981679389312977
# Accuracy predict 0.9499389499389499
# Loss 0.23921340152245438
# MCC 0.9331497718744809
# AUC 0.9668661448923747
# ==================================
# problem_code
#               precision    recall  f1-score   support
#
#            0       0.92      0.95      0.94       208
#            1       0.96      0.96      0.96       210
#            2       0.92      0.94      0.93       281
#            3       1.00      1.00      1.00        31
#            4       0.96      0.77      0.85        30
#            5       1.00      0.76      0.86        33
#            6       0.93      1.00      0.96        26
#
#     accuracy                           0.94       819
#    macro avg       0.96      0.91      0.93       819
# weighted avg       0.94      0.94      0.94       819
#
# Accuracy train 0.9984732824427481
# Accuracy predict 0.9377289377289377
# Loss 0.39824936183622006
# MCC 0.9163596275580739
# AUC 0.9585339007313731
# ==================================
# code
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93       208
#            1       0.94      0.97      0.96       210
#            2       0.92      0.93      0.92       281
#            3       1.00      1.00      1.00        31
#            4       0.96      0.80      0.87        30
#            5       1.00      0.82      0.90        33
#            6       1.00      1.00      1.00        26
#
#     accuracy                           0.94       819
#    macro avg       0.96      0.92      0.94       819
# weighted avg       0.94      0.94      0.94       819
#
# Accuracy train 0.9987786259541984
# Accuracy predict 0.9365079365079365
# Loss 0.33469216802484253
# MCC 0.9146933304051158
# AUC 0.9538324740872087
# ==================================
# Voting
# problemall
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.96       208
#            1       0.92      0.97      0.95       210
#            2       0.93      0.93      0.93       281
#            3       1.00      1.00      1.00        31
#            4       0.96      0.80      0.87        30
#            5       1.00      0.88      0.94        33
#            6       0.93      1.00      0.96        26
#
#     accuracy                           0.95       819
#    macro avg       0.96      0.93      0.94       819
# weighted avg       0.95      0.95      0.94       819
#
# Accuracy train 0.9987786259541984
# Accuracy predict 0.945054945054945
# Loss 0.22154341013481108
# MCC 0.926396369924562
# AUC 0.9695504580525963
# ==================================
# problem_gries
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94       208
#            1       0.92      0.96      0.94       210
#            2       0.92      0.92      0.92       281
#            3       1.00      1.00      1.00        31
#            4       0.95      0.63      0.76        30
#            5       0.93      0.82      0.87        33
#            6       0.92      0.88      0.90        26
#
#     accuracy                           0.93       819
#    macro avg       0.94      0.88      0.90       819
# weighted avg       0.93      0.93      0.92       819
#
# Accuracy train 0.99206106870229
# Accuracy predict 0.9255189255189256
# Loss 0.23504296730983362
# MCC 0.8999576843000512
# AUC 0.9660518165861754
# ==================================
# code_gries
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97       208
#            1       0.92      0.98      0.94       210
#            2       0.94      0.93      0.94       281
#            3       1.00      1.00      1.00        31
#            4       0.96      0.80      0.87        30
#            5       1.00      0.82      0.90        33
#            6       0.93      1.00      0.96        26
#
#     accuracy                           0.95       819
#    macro avg       0.96      0.93      0.94       819
# weighted avg       0.95      0.95      0.95       819
#
# Accuracy train 0.9978625954198473
# Accuracy predict 0.9462759462759462
# Loss 0.20380295429147766
# MCC 0.9280938369494208
# AUC 0.970096193395275
# ==================================
# gries
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97       208
#            1       0.94      0.98      0.96       210
#            2       0.95      0.95      0.95       281
#            3       1.00      1.00      1.00        31
#            4       0.96      0.80      0.87        30
#            5       0.94      0.88      0.91        33
#            6       0.93      1.00      0.96        26
#
#     accuracy                           0.96       819
#    macro avg       0.96      0.94      0.95       819
# weighted avg       0.96      0.96      0.96       819
#
# Accuracy train 0.9981679389312977
# Accuracy predict 0.9560439560439561
# Loss 0.19419080207852213
# MCC 0.9411723768807532
# AUC 0.9708909119656873
# ==================================
# problem_code
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.94       208
#            1       0.94      0.96      0.95       210
#            2       0.95      0.93      0.94       281
#            3       0.94      1.00      0.97        31
#            4       0.96      0.80      0.87        30
#            5       1.00      0.76      0.86        33
#            6       0.93      1.00      0.96        26
#
#     accuracy                           0.94       819
#    macro avg       0.95      0.92      0.93       819
# weighted avg       0.94      0.94      0.94       819
#
# Accuracy train 0.9914503816793893
# Accuracy predict 0.938949938949939
# Loss 0.2921793112432943
# MCC 0.9182402217686699
# AUC 0.9579862654881343
# ==================================
# code
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91       208
#            1       0.90      0.87      0.88       210
#            2       0.88      0.90      0.89       281
#            3       0.97      0.90      0.93        31
#            4       0.92      0.77      0.84        30
#            5       0.86      0.58      0.69        33
#            6       0.93      1.00      0.96        26
#
#     accuracy                           0.89       819
#    macro avg       0.90      0.85      0.87       819
# weighted avg       0.89      0.89      0.89       819
#
# Accuracy train 0.9541984732824428
# Accuracy predict 0.8876678876678876
# Loss 0.35320340325348376
# MCC 0.8489325923748202
# AUC 0.951880721627124
# ==================================
# Stacking
# problemall
#               precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97       208
#            1       0.92      0.98      0.95       210
#            2       0.94      0.94      0.94       281
#            3       1.00      1.00      1.00        31
#            4       0.96      0.80      0.87        30
#            5       1.00      0.88      0.94        33
#            6       0.93      1.00      0.96        26
#
#     accuracy                           0.95       819
#    macro avg       0.96      0.94      0.95       819
# weighted avg       0.95      0.95      0.95       819
#
# Accuracy train 0.9987786259541984
# Accuracy predict 0.9499389499389499
# Loss 0.18629389848753136
# MCC 0.9330232986246245
# AUC 0.9716392991924223
# ==================================
# problem_gries
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.96       208
#            1       0.92      0.98      0.95       210
#            2       0.93      0.94      0.94       281
#            3       1.00      1.00      1.00        31
#            4       0.96      0.73      0.83        30
#            5       1.00      0.82      0.90        33
#            6       0.96      1.00      0.98        26
#
#     accuracy                           0.95       819
#    macro avg       0.96      0.92      0.94       819
# weighted avg       0.95      0.95      0.95       819
#
# Accuracy train 0.9981679389312977
# Accuracy predict 0.9462759462759462
# Loss 0.18203968497262885
# MCC 0.9279814523445296
# AUC 0.9728278300822845
# ==================================
# code_gries
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96       208
#            1       0.93      0.98      0.95       210
#            2       0.94      0.94      0.94       281
#            3       1.00      1.00      1.00        31
#            4       0.96      0.80      0.87        30
#            5       1.00      0.82      0.90        33
#            6       0.93      1.00      0.96        26
#
#     accuracy                           0.95       819
#    macro avg       0.96      0.93      0.94       819
# weighted avg       0.95      0.95      0.95       819
#
# Accuracy train 0.9987786259541984
# Accuracy predict 0.9487179487179487
# Loss 0.1724360858907454
# MCC 0.9313193872892643
# AUC 0.9733539450971858
# ==================================
# gries
#               precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97       208
#            1       0.93      0.98      0.95       210
#            2       0.94      0.95      0.94       281
#            3       1.00      1.00      1.00        31
#            4       0.96      0.80      0.87        30
#            5       1.00      0.82      0.90        33
#            6       0.93      1.00      0.96        26
#
#     accuracy                           0.95       819
#    macro avg       0.96      0.93      0.94       819
# weighted avg       0.95      0.95      0.95       819
#
# Accuracy train 0.9981679389312977
# Accuracy predict 0.9511599511599511
# Loss 0.17095579829041233
# MCC 0.9346022744016205
# AUC 0.9718040865277339
# ==================================
# problem_code
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.94       208
#            1       0.94      0.97      0.96       210
#            2       0.91      0.94      0.92       281
#            3       1.00      1.00      1.00        31
#            4       0.96      0.80      0.87        30
#            5       1.00      0.88      0.94        33
#            6       1.00      1.00      1.00        26
#
#     accuracy                           0.94       819
#    macro avg       0.97      0.93      0.95       819
# weighted avg       0.94      0.94      0.94       819
#
# Accuracy train 0.9987786259541984
# Accuracy predict 0.9413919413919414
# Loss 0.205965343092581
# MCC 0.9213219318049809
# AUC 0.9644454337371695
# ==================================
# code
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.93       208
#            1       0.95      0.97      0.96       210
#            2       0.91      0.93      0.92       281
#            3       1.00      1.00      1.00        31
#            4       0.96      0.80      0.87        30
#            5       1.00      0.82      0.90        33
#            6       0.93      1.00      0.96        26
#
#     accuracy                           0.93       819
#    macro avg       0.95      0.92      0.93       819
# weighted avg       0.93      0.93      0.93       819
#
# Accuracy train 0.9987786259541984
# Accuracy predict 0.9340659340659341
# Loss 0.21162452237885632
# MCC 0.9114488172153314
# AUC 0.9633907883833225
# ==================================

# %%
import pandas as pd
df=pd.DataFrame({
    "Model":ml_names,
    "Ablation":abl_names,
    "Accuracy_train":accuracies_train,
    "Accuracy_predict":accuracies_predict,
    "Loss":loss_predict,
    "Time_train":times_train,
    "Time_predict":times_predict,
    "MCC":mccs_predict,
    "AUC":aucpr_predict
})

# %%
df
# Out:
#             Model       Ablation  Accuracy_train  Accuracy_predict      Loss  \
# 0             KNN     problemall        0.998779          0.951160  0.354383
# 1             KNN  problem_gries        0.998779          0.958486  0.353977
# 2             KNN     code_gries        0.998779          0.951160  0.265734
# 3             KNN          gries        0.998168          0.956044  0.261121
# 4             KNN   problem_code        0.998779          0.926740  0.348200
# 5             KNN           code        0.998779          0.938950  0.325097
# 6             SVM     problemall        0.987176          0.920635  0.275694
# 7             SVM  problem_gries        0.973740          0.899878  0.323647
# 8             SVM     code_gries        0.984733          0.915751  0.277086
# 9             SVM          gries        0.969466          0.903541  0.320750
# 10            SVM   problem_code        0.818015          0.736264  0.760508
# 11            SVM           code        0.782901          0.708181  0.812381
# 12            MLP     problemall        0.990840          0.946276  0.394357
# 13            MLP  problem_gries        0.996031          0.948718  0.398515
# 14            MLP     code_gries        0.965496          0.891331  0.562669
# 15            MLP          gries        0.987481          0.930403  0.415946
# 16            MLP   problem_code        0.977099          0.890110  0.606178
# 17            MLP           code        0.988092          0.937729  0.401607
# 18  Random Forest     problemall        0.998779          0.947497  0.260940
# 19  Random Forest  problem_gries        0.998779          0.949939  0.258359
# 20  Random Forest     code_gries        0.998779          0.945055  0.254183
# 21  Random Forest          gries        0.998168          0.949939  0.239213
# 22  Random Forest   problem_code        0.998473          0.937729  0.398249
# 23  Random Forest           code        0.998779          0.936508  0.334692
# 24         Voting     problemall        0.998779          0.945055  0.221543
# 25         Voting  problem_gries        0.992061          0.925519  0.235043
# 26         Voting     code_gries        0.997863          0.946276  0.203803
# 27         Voting          gries        0.998168          0.956044  0.194191
# 28         Voting   problem_code        0.991450          0.938950  0.292179
# 29         Voting           code        0.954198          0.887668  0.353203
# 30       Stacking     problemall        0.998779          0.949939  0.186294
# 31       Stacking  problem_gries        0.998168          0.946276  0.182040
# 32       Stacking     code_gries        0.998779          0.948718  0.172436
# 33       Stacking          gries        0.998168          0.951160  0.170956
# 34       Stacking   problem_code        0.998779          0.941392  0.205965
# 35       Stacking           code        0.998779          0.934066  0.211625
#
#     Time_train  Time_predict       MCC       AUC
# 0     0.007611      4.243392  0.934638  0.977840
# 1     0.004718      3.415568  0.944421  0.976482
# 2     0.004729      3.360051  0.934724  0.979901
# 3     0.004113      2.550323  0.941133  0.980168
# 4     0.003020      1.715258  0.901995  0.972951
# 5     0.001793      0.850615  0.918425  0.974296
# 6    69.615979      5.632686  0.893698  0.946909
# 7    55.506962      4.014907  0.866071  0.933725
# 8    52.269890      3.786304  0.886914  0.945510
# 9    38.975035      2.992687  0.870248  0.931333
# 10   30.255676      2.698730  0.642986  0.764106
# 11   17.326181      1.218072  0.604582  0.726336
# 12    7.248439      0.024534  0.928005  0.955856
# 13    8.482946      0.020106  0.931475  0.957243
# 14    7.363178      0.020191  0.854604  0.902011
# 15    8.871775      0.014825  0.906712  0.948805
# 16    3.883614      0.011039  0.853703  0.929708
# 17    5.930331      0.006296  0.916856  0.950233
# 18    8.753294      0.024454  0.929845  0.968367
# 19    6.978887      0.021360  0.933150  0.965384
# 20    8.138878      0.021661  0.926482  0.968411
# 21    6.173612      0.020960  0.933150  0.966866
# 22    6.117651      0.019873  0.916360  0.958534
# 23    5.439398      0.019494  0.914693  0.953832
# 24   19.275515      0.047252  0.926396  0.969550
# 25   14.022127      0.046806  0.899958  0.966052
# 26   13.031938      0.045835  0.928094  0.970096
# 27   11.134078      0.040363  0.941172  0.970891
# 28    9.726499      0.033703  0.918240  0.957986
# 29   10.837817      0.029991  0.848933  0.951881
# 30   96.247712      0.051501  0.933023  0.971639
# 31   79.733747      0.045719  0.927981  0.972828
# 32   88.587953      0.045077  0.931319  0.973354
# 33   65.303491      0.039995  0.934602  0.971804
# 34   66.797972      0.033457  0.921322  0.964445
# 35   47.138277      0.029845  0.911449  0.963391

# %%
path="/content/drive/MyDrive/UDENAR/ProyectosGrado/Errol/Ginna/1. Tradicional Machine Learning/BestResult6/"

# %%
df.to_csv(path+"tradicionalML_ablationsResults.csv",index=False)

# %%
df=pd.read_csv(path+"tradicionalML_ablationsResults.csv")
df
# Out:
#             Model       Ablation  Accuracy_train  Accuracy_predict      Loss  \
# 0             KNN     problemall        0.998779          0.951160  0.354383
# 1             KNN  problem_gries        0.998779          0.958486  0.353977
# 2             KNN     code_gries        0.998779          0.951160  0.265734
# 3             KNN          gries        0.998168          0.956044  0.261121
# 4             KNN   problem_code        0.998779          0.926740  0.348200
# 5             KNN           code        0.998779          0.938950  0.325097
# 6             SVM     problemall        0.987176          0.920635  0.275694
# 7             SVM  problem_gries        0.973740          0.899878  0.323647
# 8             SVM     code_gries        0.984733          0.915751  0.277086
# 9             SVM          gries        0.969466          0.903541  0.320750
# 10            SVM   problem_code        0.818015          0.736264  0.760508
# 11            SVM           code        0.782901          0.708181  0.812381
# 12            MLP     problemall        0.990840          0.946276  0.394357
# 13            MLP  problem_gries        0.996031          0.948718  0.398515
# 14            MLP     code_gries        0.965496          0.891331  0.562669
# 15            MLP          gries        0.987481          0.930403  0.415946
# 16            MLP   problem_code        0.977099          0.890110  0.606178
# 17            MLP           code        0.988092          0.937729  0.401607
# 18  Random Forest     problemall        0.998779          0.947497  0.260940
# 19  Random Forest  problem_gries        0.998779          0.949939  0.258359
# 20  Random Forest     code_gries        0.998779          0.945055  0.254183
# 21  Random Forest          gries        0.998168          0.949939  0.239213
# 22  Random Forest   problem_code        0.998473          0.937729  0.398249
# 23  Random Forest           code        0.998779          0.936508  0.334692
# 24         Voting     problemall        0.998779          0.945055  0.221543
# 25         Voting  problem_gries        0.992061          0.925519  0.235043
# 26         Voting     code_gries        0.997863          0.946276  0.203803
# 27         Voting          gries        0.998168          0.956044  0.194191
# 28         Voting   problem_code        0.991450          0.938950  0.292179
# 29         Voting           code        0.954198          0.887668  0.353203
# 30       Stacking     problemall        0.998779          0.949939  0.186294
# 31       Stacking  problem_gries        0.998168          0.946276  0.182040
# 32       Stacking     code_gries        0.998779          0.948718  0.172436
# 33       Stacking          gries        0.998168          0.951160  0.170956
# 34       Stacking   problem_code        0.998779          0.941392  0.205965
# 35       Stacking           code        0.998779          0.934066  0.211625
#
#     Time_train  Time_predict       MCC       AUC
# 0     0.007611      4.243392  0.934638  0.977840
# 1     0.004718      3.415568  0.944421  0.976482
# 2     0.004729      3.360051  0.934724  0.979901
# 3     0.004113      2.550323  0.941133  0.980168
# 4     0.003020      1.715258  0.901995  0.972951
# 5     0.001793      0.850615  0.918425  0.974296
# 6    69.615979      5.632686  0.893698  0.946909
# 7    55.506962      4.014907  0.866071  0.933725
# 8    52.269890      3.786304  0.886914  0.945510
# 9    38.975035      2.992687  0.870248  0.931333
# 10   30.255676      2.698730  0.642986  0.764106
# 11   17.326181      1.218072  0.604582  0.726336
# 12    7.248439      0.024534  0.928005  0.955856
# 13    8.482946      0.020106  0.931475  0.957243
# 14    7.363178      0.020191  0.854604  0.902011
# 15    8.871775      0.014825  0.906712  0.948805
# 16    3.883614      0.011039  0.853703  0.929708
# 17    5.930331      0.006296  0.916856  0.950233
# 18    8.753294      0.024454  0.929845  0.968367
# 19    6.978887      0.021360  0.933150  0.965384
# 20    8.138878      0.021661  0.926482  0.968411
# 21    6.173612      0.020960  0.933150  0.966866
# 22    6.117651      0.019873  0.916360  0.958534
# 23    5.439398      0.019494  0.914693  0.953832
# 24   19.275515      0.047252  0.926396  0.969550
# 25   14.022127      0.046806  0.899958  0.966052
# 26   13.031938      0.045835  0.928094  0.970096
# 27   11.134078      0.040363  0.941172  0.970891
# 28    9.726499      0.033703  0.918240  0.957986
# 29   10.837817      0.029991  0.848933  0.951881
# 30   96.247712      0.051501  0.933023  0.971639
# 31   79.733747      0.045719  0.927981  0.972828
# 32   88.587953      0.045077  0.931319  0.973354
# 33   65.303491      0.039995  0.934602  0.971804
# 34   66.797972      0.033457  0.921322  0.964445
# 35   47.138277      0.029845  0.911449  0.963391

# %% [markdown]
# # Externd Data

# %%
extern_file = '/content/drive/MyDrive/UDENAR/ProyectosGrado/Errol/Ginna/Tuning/BestModels/Copia de ExternData.csv'
train_full = pd.read_csv(extern_file)
train_full
# Out:
#                                   Problem Description  \
# 0             Count how many even numbers are up to n
# 1                             Sum numbers from 1 to n
# 2          Prompt user for numbers until 0 is entered
# 3             Find first multiple of 7 greater than n
# 4                            Calculate factorial of n
# 5                Count digits in a positive integer n
# 6                        Sum all even numbers up to n
# 7                     Find a prime number using break
# 8                  Print cubes of numbers from 1 to n
# 9                   Prompt for password until correct
# 10  Print numbers from 1 to n, but condition exclu...
# 11  Divide a number by 2 repeatedly until it's les...
# 12                                Sum all digits of n
# 13    Count how many times 5 can be subtracted from n
# 14                   Calculate power using while loop
# 15                         Check if number is perfect
# 16                          Convert decimal to binary
# 17        Print items in list until negative is found
# 18                       Count multiples of 3 up to n
# 19                          Print odd numbers up to n
# 20                    Sum the first n natural numbers
# 21                            Sum odd numbers up to n
# 22                               Count primes up to n
# 23   Read and sum numbers until a negative is entered
# 24                            Find LCM of two numbers
# 25             Print Fibonacci sequence up to n terms
# 26                       Count multiples of 5 up to n
# 27     Find GCD of two numbers using Euclid algorithm
# 28  Prompt user for positive numbers until 5 are e...
# 29                 Sum multiples of 4 between 1 and n
# 30  Print the factorial of n, but n is not initial...
# 31  Reverse a list but forget to initialize the in...
# 32  Print numbers from a to b, missing both variab...
# 33  Sum even numbers in a list, with an off-by-one...
# 34  Count numbers divisible by 3, fails to initial...
#
#                                           Python Code  \
# 0   def count_evens_buggy(n):\n    i = 0\n    coun...
# 1   def sum_to_n_buggy(n):\n    total = 0\n    i =...
# 2   def input_until_zero_buggy():\n    num = int(i...
# 3   def first_multiple_7_buggy(n):\n    i = n + 1\...
# 4   def factorial_buggy(n):\n    result = 1\n    w...
# 5   def count_digits_buggy(n):\n    count = 0\n   ...
# 6   def sum_evens_buggy(n):\n    total = 0\n    i ...
# 7   def find_prime_buggy():\n    num = 2\n    whil...
# 8   def print_cubes_buggy(n):\n    while i <= n:\n...
# 9   def prompt_password_buggy():\n    password = i...
# 10  def print_numbers_buggy(n):\n    i = 1\n    wh...
# 11  def divide_repeatedly_buggy(n):\n    while n >...
# 12  def sum_digits_buggy(n):\n    total = 0\n    w...
# 13  def count_subtract_5_buggy(n):\n    count = 0\...
# 14  def power_buggy(base, exp):\n    result = 1\n ...
# 15  def is_perfect_buggy(n):\n    sum_div = 0\n   ...
# 16  def decimal_to_binary_buggy(n):\n    res = ''\...
# 17  def print_until_negative_buggy(lst):\n    i = ...
# 18  def count_mult_3_buggy(n):\n    i = 1\n    cou...
# 19  def print_odds_buggy(n):\n    i = 1\n    while...
# 20  def sum_n_buggy(n):\n    i = 1\n    total = 0\...
# 21  def sum_odds_buggy(n):\n    total = 0\n    i =...
# 22  def count_primes_buggy(n):\n    count = 0\n   ...
# 23  def sum_until_negative_buggy():\n    total = 0...
# 24  def lcm_buggy(a, b):\n    num = max(a, b)\n   ...
# 25  def fibonacci_buggy(n):\n    a, b = 0, 1\n    ...
# 26  def count_mult_5_buggy(n):\n    i = 1\n    cou...
# 27  def gcd_buggy(a, b):\n    while a != b:\n     ...
# 28  def count_positives_buggy():\n    count = 0\n ...
# 29  def sum_mult_4_buggy(n):\n    i = 1\n    while...
# 30  def buggy_factorial():\n    while n > 0:\n    ...
# 31  def buggy_reverse(lst):\n    # missing i = len...
# 32  def buggy_print_range(b):\n    # missing a = 1...
# 33  def buggy_sum_evens(lst):\n    i = 0\n    sum_...
# 34  def buggy_count_mult_3(n):\n    while i < n:  ...
#
#                                                Source  \
# 0   Inspired by CodeChef Learn Python (While Loop)...
# 1   Based on typical mistakes in Codeforces common...
# 2   Common error from GeeksforGeeks Python while l...
# 3     Typical error in CodeNet beginner loop problems
# 4             Inspired by classic factorial exercises
# 5   Inspired by digit counting problems in Codefor...
# 6   CodeChef/Codeforces summing problems, conditio...
# 7   Inspired by break/continue loop errors from Py...
# 8   Common initialization error, based on CodeNet ...
# 9   Typical validation loop error from Python begi...
# 10  Common inclusive/exclusive error in loops (Cod...
# 11  Inspired by CodeNet loop problems involving di...
# 12  Classic digit-processing error, Python/Codeforces
# 13  Common mistake in decrement loops (CodeNet/Cod...
# 14  Power calculation errors in Codeforces/Python ...
# 15        Perfect number mistakes, classic math loops
# 16  Typical binary conversion loop, Codeforces/Cod...
# 17  Inspired by control-flow misplacement from Pyt...
# 18  Loops with missed accumulation, typical in beg...
# 19         Increment logic error, Codeforces/CodeChef
# 20  Classic off-by-one loop error, inspired by bas...
# 21   Odd number sum, increment bug, beginner mistakes
# 22  Classic loop and condition error in prime coun...
# 23  Missing input update bug, shown in tutorials (...
# 24  LCM calculation, common loop bug (CodeNet/Code...
# 25  Sequence and assignment bug, inspired by class...
# 26  Missing i update, common beginner error, CodeC...
# 27  Euclid's algorithm off-by-one/condition bug, C...
# 28  Input accumulation/counting error, basic progr...
# 29  Sum variable scope bug, inspired by sum/accumu...
# 30  Initialization errors are a classic mistake (C...
# 31  Initialization and condition errors, common in...
# 32  Initialization and update errors frequently se...
# 33  Condition and update errors, drawn from typica...
# 34  Simultaneous initialization, condition, and bo...
#
#                                     Description Error  Error Label
# 0            missing increment leads to infinite loop            2
# 1                        i is incorrectly incremented            2
# 2                 number is never updated in the loop            2
# 3                                   i not incremented            2
# 4                               decrement by 2, not 1            2
# 5                       n not updated inside the loop            2
# 6                            loop condition incorrect            1
# 7                          break outside the if block            2
# 8                                   i not initialized            0
# 9                        password requested only once            2
# 10                               condition excludes n            1
# 11                integer division and missing update            2
# 12                                missing update of n            2
# 13                                   n is not updated            2
# 14                             missing increment of i            2
# 15              sum calculation and missing increment            2
# 16                      n not updated inside the loop            2
# 17                         break outside the if block            2
# 18                                count never updated            2
# 19                       i is incremented incorrectly            2
# 20                          loop condition excludes n            1
# 21                              i increment incorrect            2
# 22                          loop condition excludes n            1
# 23               does not read new number inside loop            2
# 24                     missing increment of candidate            2
# 25                           assignments out of order            2
# 26                                      i not updated            2
# 27                  condition may cause infinite loop            1
# 28                          counter never incremented            2
# 29              sum variable is reset inside the loop            2
# 30         n is not initialized before the while loop            0
# 31  missing initialization and undefined variable ...            3
# 32  missing initialization and wrong update in loo...            4
# 33   wrong condition and no accumulation in loop body            5
# 34  multiple errors in initialization, condition a...            6

# %%
train_full['Python Code']=train_full['Python Code'].apply(lambda x: x.replace("\\n","\n"))

# %%
train_full[["Estado incial","Transformación de estado","Estado final"]]=train_full['Python Code'].apply(DGries_states).apply(pd.Series)
# Out:
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body

# %%
train_full
# Out:
#                                   Problem Description  \
# 0             Count how many even numbers are up to n
# 1                             Sum numbers from 1 to n
# 2          Prompt user for numbers until 0 is entered
# 3             Find first multiple of 7 greater than n
# 4                            Calculate factorial of n
# 5                Count digits in a positive integer n
# 6                        Sum all even numbers up to n
# 7                     Find a prime number using break
# 8                  Print cubes of numbers from 1 to n
# 9                   Prompt for password until correct
# 10  Print numbers from 1 to n, but condition exclu...
# 11  Divide a number by 2 repeatedly until it's les...
# 12                                Sum all digits of n
# 13    Count how many times 5 can be subtracted from n
# 14                   Calculate power using while loop
# 15                         Check if number is perfect
# 16                          Convert decimal to binary
# 17        Print items in list until negative is found
# 18                       Count multiples of 3 up to n
# 19                          Print odd numbers up to n
# 20                    Sum the first n natural numbers
# 21                            Sum odd numbers up to n
# 22                               Count primes up to n
# 23   Read and sum numbers until a negative is entered
# 24                            Find LCM of two numbers
# 25             Print Fibonacci sequence up to n terms
# 26                       Count multiples of 5 up to n
# 27     Find GCD of two numbers using Euclid algorithm
# 28  Prompt user for positive numbers until 5 are e...
# 29                 Sum multiples of 4 between 1 and n
# 30  Print the factorial of n, but n is not initial...
# 31  Reverse a list but forget to initialize the in...
# 32  Print numbers from a to b, missing both variab...
# 33  Sum even numbers in a list, with an off-by-one...
# 34  Count numbers divisible by 3, fails to initial...
#
#                                           Python Code  \
# 0   def count_evens_buggy(n):\n    i = 0\n    coun...
# 1   def sum_to_n_buggy(n):\n    total = 0\n    i =...
# 2   def input_until_zero_buggy():\n    num = int(i...
# 3   def first_multiple_7_buggy(n):\n    i = n + 1\...
# 4   def factorial_buggy(n):\n    result = 1\n    w...
# 5   def count_digits_buggy(n):\n    count = 0\n   ...
# 6   def sum_evens_buggy(n):\n    total = 0\n    i ...
# 7   def find_prime_buggy():\n    num = 2\n    whil...
# 8   def print_cubes_buggy(n):\n    while i <= n:\n...
# 9   def prompt_password_buggy():\n    password = i...
# 10  def print_numbers_buggy(n):\n    i = 1\n    wh...
# 11  def divide_repeatedly_buggy(n):\n    while n >...
# 12  def sum_digits_buggy(n):\n    total = 0\n    w...
# 13  def count_subtract_5_buggy(n):\n    count = 0\...
# 14  def power_buggy(base, exp):\n    result = 1\n ...
# 15  def is_perfect_buggy(n):\n    sum_div = 0\n   ...
# 16  def decimal_to_binary_buggy(n):\n    res = ''\...
# 17  def print_until_negative_buggy(lst):\n    i = ...
# 18  def count_mult_3_buggy(n):\n    i = 1\n    cou...
# 19  def print_odds_buggy(n):\n    i = 1\n    while...
# 20  def sum_n_buggy(n):\n    i = 1\n    total = 0\...
# 21  def sum_odds_buggy(n):\n    total = 0\n    i =...
# 22  def count_primes_buggy(n):\n    count = 0\n   ...
# 23  def sum_until_negative_buggy():\n    total = 0...
# 24  def lcm_buggy(a, b):\n    num = max(a, b)\n   ...
# 25  def fibonacci_buggy(n):\n    a, b = 0, 1\n    ...
# 26  def count_mult_5_buggy(n):\n    i = 1\n    cou...
# 27  def gcd_buggy(a, b):\n    while a != b:\n     ...
# 28  def count_positives_buggy():\n    count = 0\n ...
# 29  def sum_mult_4_buggy(n):\n    i = 1\n    while...
# 30  def buggy_factorial():\n    while n > 0:\n    ...
# 31  def buggy_reverse(lst):\n    # missing i = len...
# 32  def buggy_print_range(b):\n    # missing a = 1...
# 33  def buggy_sum_evens(lst):\n    i = 0\n    sum_...
# 34  def buggy_count_mult_3(n):\n    while i < n:  ...
#
#                                                Source  \
# 0   Inspired by CodeChef Learn Python (While Loop)...
# 1   Based on typical mistakes in Codeforces common...
# 2   Common error from GeeksforGeeks Python while l...
# 3     Typical error in CodeNet beginner loop problems
# 4             Inspired by classic factorial exercises
# 5   Inspired by digit counting problems in Codefor...
# 6   CodeChef/Codeforces summing problems, conditio...
# 7   Inspired by break/continue loop errors from Py...
# 8   Common initialization error, based on CodeNet ...
# 9   Typical validation loop error from Python begi...
# 10  Common inclusive/exclusive error in loops (Cod...
# 11  Inspired by CodeNet loop problems involving di...
# 12  Classic digit-processing error, Python/Codeforces
# 13  Common mistake in decrement loops (CodeNet/Cod...
# 14  Power calculation errors in Codeforces/Python ...
# 15        Perfect number mistakes, classic math loops
# 16  Typical binary conversion loop, Codeforces/Cod...
# 17  Inspired by control-flow misplacement from Pyt...
# 18  Loops with missed accumulation, typical in beg...
# 19         Increment logic error, Codeforces/CodeChef
# 20  Classic off-by-one loop error, inspired by bas...
# 21   Odd number sum, increment bug, beginner mistakes
# 22  Classic loop and condition error in prime coun...
# 23  Missing input update bug, shown in tutorials (...
# 24  LCM calculation, common loop bug (CodeNet/Code...
# 25  Sequence and assignment bug, inspired by class...
# 26  Missing i update, common beginner error, CodeC...
# 27  Euclid's algorithm off-by-one/condition bug, C...
# 28  Input accumulation/counting error, basic progr...
# 29  Sum variable scope bug, inspired by sum/accumu...
# 30  Initialization errors are a classic mistake (C...
# 31  Initialization and condition errors, common in...
# 32  Initialization and update errors frequently se...
# 33  Condition and update errors, drawn from typica...
# 34  Simultaneous initialization, condition, and bo...
#
#                                     Description Error  Error Label  \
# 0            missing increment leads to infinite loop            2
# 1                        i is incorrectly incremented            2
# 2                 number is never updated in the loop            2
# 3                                   i not incremented            2
# 4                               decrement by 2, not 1            2
# 5                       n not updated inside the loop            2
# 6                            loop condition incorrect            1
# 7                          break outside the if block            2
# 8                                   i not initialized            0
# 9                        password requested only once            2
# 10                               condition excludes n            1
# 11                integer division and missing update            2
# 12                                missing update of n            2
# 13                                   n is not updated            2
# 14                             missing increment of i            2
# 15              sum calculation and missing increment            2
# 16                      n not updated inside the loop            2
# 17                         break outside the if block            2
# 18                                count never updated            2
# 19                       i is incremented incorrectly            2
# 20                          loop condition excludes n            1
# 21                              i increment incorrect            2
# 22                          loop condition excludes n            1
# 23               does not read new number inside loop            2
# 24                     missing increment of candidate            2
# 25                           assignments out of order            2
# 26                                      i not updated            2
# 27                  condition may cause infinite loop            1
# 28                          counter never incremented            2
# 29              sum variable is reset inside the loop            2
# 30         n is not initialized before the while loop            0
# 31  missing initialization and undefined variable ...            3
# 32  missing initialization and wrong update in loo...            4
# 33   wrong condition and no accumulation in loop body            5
# 34  multiple errors in initialization, condition a...            6
#
#                                         Estado incial  \
# 0                                i = 0\n    count = 0
# 1                                total = 0\n    i = 1
# 2      num = int(input('Enter number (0 to exit): '))
# 3                                           i = n + 1
# 4                                          result = 1
# 5                                           count = 0
# 6                                total = 0\n    i = 2
# 7                                             num = 2
# 8                               print(i ** 3)\ni += 1
# 9                password = input('Enter password: ')
# 10                                              i = 1
# 11                               print(n)\nn = n // 2
# 12                                          total = 0
# 13                                          count = 0
# 14                              result = 1\n    i = 0
# 15                       sum_div = 0\n    divisor = 1
# 16                                           res = ''
# 17                                              i = 0
# 18                               i = 1\n    count = 0
# 19                                              i = 1
# 20                               i = 1\n    total = 0
# 21                               total = 0\n    i = 1
# 22                               count = 0\n    i = 2
# 23  total = 0\n    num = int(input('Enter number (...
# 24                                    num = max(a, b)
# 25                             a, b = 0, 1\n    i = 0
# 26                               i = 1\n    count = 0
# 27           if a > b:\n    a -= b\nelse:\n    b -= a
# 28                                          count = 0
# 29                                              i = 1
# 30                                   print(n)\nn -= 1
# 31                              print(lst[j])\nj -= 1
# 32                            a = 1\nprint(a)\na += 1
# 33                           i = 0\n    sum_evens = 0
# 34        count = 0\nif i % 3 == 0:\n    pass\ni += 1
#
#                              Transformación de estado          Estado final
# 0                      if i % 2 == 0:\n    count += 1                i <= n
# 1                               total += i\ni = i + 0                i <= n
# 2                               print('Number:', num)              num != 0
# 3                                                pass            i % 7 != 0
# 4                                 result *= n\nn -= 2                 n > 1
# 5                                  n % 10\ncount += 1                 n > 0
# 6                                  total += i\ni += 2                 i < n
# 7   is_prime = True\ndivisor = 2\nwhile divisor < ...                  True
# 8                               print(i ** 3)\ni += 1                i <= n
# 9                                  print('Incorrect')  password != 'secret'
# 10                                   print(i)\ni += 1                 i < n
# 11                               print(n)\nn = n // 2                n >= 1
# 12                                    total += n % 10                 n > 0
# 13                                         count += 1                n >= 5
# 14                                     result *= base               i < exp
# 15        if n % divisor == 0:\n    sum_div = divisor           divisor < n
# 16                             res = str(n % 2) + res                 n > 0
# 17  print(lst[i])\nbreak\nif lst[i] < 0:\n    brea...          i < len(lst)
# 18                   if i % 3 == 0:\n    pass\ni += 1                i <= n
# 19                           print(i)\ni += 2\ni += 1                i <= n
# 20                                 total += i\ni += 1                 i < n
# 21      if i % 2 != 0:\n    total += i\ni = i + 1 - 1                i <= n
# 22            if is_prime(i):\n    count += 1\ni += 1                 i < n
# 23                                       total += num              num >= 0
# 24  if num % a == 0 and num % b == 0:\n    return num                  True
# 25                 print(a)\nb = a + b\na = b\ni += 1                 i < n
# 26                     if i % 5 == 0:\n    count += 1                i <= n
# 27           if a > b:\n    a -= b\nelse:\n    b -= a                a != b
# 28  num = int(input('Enter positive number: '))\ni...             count < 5
# 29      sum = 0\nif i % 4 == 0:\n    sum += i\ni += 1                i <= n
# 30                                   print(n)\nn -= 1                 n > 0
# 31                              print(lst[j])\nj -= 1                j >= 0
# 32                            a = 1\nprint(a)\na += 1                a <= b
# 33              if lst[i] % 2 == 0:\n    pass\ni += 1         i <= len(lst)
# 34        count = 0\nif i % 3 == 0:\n    pass\ni += 1                 i < n

# %%
train_full['Python Code']=train_full['Python Code'].apply(lambda x: x.replace("\\n","\n"))

# %%
train_full[["Estado incial","Transformación de estado","Estado final"]]=train_full['Python Code'].apply(DGries_states).apply(pd.Series)
# Out:
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body

# %%
# %%time
problem=train_full['Problem Description'].apply(encoder.tokenize_and_generate_embeddings_descriptions).to_numpy()
code=train_full['Python Code'].apply(encoder.tokenize_and_generate_embeddings_codes).to_numpy()
startstate = train_full['Estado incial'].apply(encoder.tokenize_and_generate_embeddings_codes).to_numpy()
finalstate = train_full['Estado final'].apply(encoder.tokenize_and_generate_embeddings_codes).to_numpy()
transstate = train_full['Transformación de estado'].apply(encoder.tokenize_and_generate_embeddings_codes).to_numpy()
# Out:
# CPU times: user 1.4 s, sys: 1e+03 µs, total: 1.4 s
# Wall time: 1.4 s

# %%
problem.shape,code.shape,startstate.shape,finalstate.shape,transstate.shape
# Out:
# ((35,), (35,), (35,), (35,), (35,))

# %%
print(startstate.shape)
print(startstate[0].shape)
# Out:
# (35,)
# (1, 8, 768)

# %%
Xp=np.array([sentence[0].mean(axis=0) for sentence in problem])
Xcode=np.array([sentence[0].mean(axis=0) for sentence in code])
Xs=np.array([sentence[0].mean(axis=0) for sentence in startstate])
Xf=np.array([sentence[0].mean(axis=0) for sentence in finalstate])
Xt=np.array([sentence[0].mean(axis=0) for sentence in transstate])
Xp.shape,Xs.shape,Xf.shape,Xt.shape
# Out:
# ((35, 768), (35, 768), (35, 768), (35, 768))

# %%
y=train_full['Error Label']
y=y.to_numpy()
np.unique(y)
# Out:
# array([0, 1, 2, 3, 4, 5, 6])

# %%
accuracies_predict=[]
loss_predict=[]
times_predict=[]
mccs_predict=[]
aucpr_predict=[]
ml_names=[]
abl_names=[]

ml_names=[]
abl_names=[]

# %%
from time import time


models_names=["KNN","SVM","MLP","Random Forest","Voting","Stacking"]
ablations_names=["problemall","problem_gries","code_gries","gries","problem_code","code"]

for name in models_names:
  print(name)
  for ablations_name in ablations_names:
    ml_names.append(name)
    abl_names.append(ablations_name)
    print(ablations_name)
    model=joblib.load(path+"bert_"+name+"_"+ablations_name+".joblib")
    print(model)
    if ablations_name=="problemall":
      Xe= np.concatenate((Xp,Xcode,Xs,Xt,Xf),axis=1)
    elif ablations_name=="problem_gries":
      Xe=np.concatenate((Xp,Xs,Xt,Xf),axis=1)
    elif ablations_name=="code_gries":
      Xe=np.concatenate((Xcode,Xs,Xt,Xf),axis=1)
    elif ablations_name=="gries":
      Xe=np.concatenate((Xs,Xt,Xf),axis=1)
    elif ablations_name=="problem_code":
      Xe=np.concatenate((Xp,Xcode),axis=1)
    elif ablations_name=="code":
      Xe=Xcode

    time1=time()
    y_pred=model.predict(Xe)
    time2=time()
    times_predict.append(time2-time1)

    accuracie_test=model.score(Xe,y)
    accuracies_predict.append(accuracie_test)
    #sparse_categorical_crossentropy
    y_pred_proba = model.predict_proba(Xe)
    loss=np.mean(sparse_categorical_crossentropy(y,y_pred_proba))
    loss_predict.append(loss)
    mcc = matthews_corrcoef(y, y_pred)
    mccs_predict.append(mcc)
    auc_pr = calculate_auc_pr_multiclass(y, y_pred_proba)
    aucpr_predict.append(auc_pr)
    print(classification_report(y,y_pred))
    print("Accuracy predict",accuracie_test)
    print("Loss",loss)
    print("MCC",mcc)
    print("AUC",auc_pr)
    print("==================================")
# Out:
# KNN
# problemall
# KNeighborsClassifier(n_neighbors=15, p=1, weights='distance')
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50         2
#            1       0.75      0.60      0.67         5
#            2       0.88      0.96      0.92        24
#            3       1.00      1.00      1.00         1
#            4       1.00      1.00      1.00         1
#            5       1.00      1.00      1.00         1
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.86        35
#    macro avg       0.73      0.72      0.73        35
# weighted avg       0.83      0.86      0.84        35
#
# Accuracy predict 0.8571428571428571
# Loss 0.3607021271782404
# MCC 0.7009542407055422
# AUC 0.8545179847840887
# ==================================
# problem_gries
# KNeighborsClassifier(n_neighbors=15, p=1, weights='distance')
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50         2
#            1       0.75      0.60      0.67         5
#            2       0.88      0.96      0.92        24
#            3       1.00      1.00      1.00         1
#            4       1.00      1.00      1.00         1
#            5       1.00      1.00      1.00         1
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.86        35
#    macro avg       0.73      0.72      0.73        35
# weighted avg       0.83      0.86      0.84        35
#
# Accuracy predict 0.8571428571428571
# Loss 0.7975487281472008
# MCC 0.7009542407055422
# AUC 0.7780770858312221
# ==================================
# code_gries
# KNeighborsClassifier(n_neighbors=15, p=1, weights='distance')
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50         2
#            1       0.67      0.40      0.50         5
#            2       0.85      0.92      0.88        24
#            3       1.00      1.00      1.00         1
#            4       1.00      1.00      1.00         1
#            5       1.00      1.00      1.00         1
#            6       1.00      1.00      1.00         1
#
#     accuracy                           0.83        35
#    macro avg       0.86      0.83      0.84        35
# weighted avg       0.82      0.83      0.82        35
#
# Accuracy predict 0.8285714285714286
# Loss 0.8761633264618852
# MCC 0.642838155715653
# AUC 0.8873819884541831
# ==================================
# gries
# KNeighborsClassifier(n_neighbors=15, p=1, weights='distance')
#               precision    recall  f1-score   support
#
#            0       0.20      0.50      0.29         2
#            1       0.67      0.40      0.50         5
#            2       0.87      0.83      0.85        24
#            3       1.00      1.00      1.00         1
#            4       1.00      1.00      1.00         1
#            5       1.00      1.00      1.00         1
#            6       1.00      1.00      1.00         1
#
#     accuracy                           0.77        35
#    macro avg       0.82      0.82      0.81        35
# weighted avg       0.82      0.77      0.79        35
#
# Accuracy predict 0.7714285714285715
# Loss 1.7136042312172752
# MCC 0.5717393462736051
# AUC 0.8734485560438434
# ==================================
# problem_code
# KNeighborsClassifier(n_neighbors=15, p=1, weights='distance')
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0       0.40      1.00      0.57         2
#            1       0.67      0.40      0.50         5
#            2       0.88      0.92      0.90        24
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         1
#            5       0.50      1.00      0.67         1
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.77        35
#    macro avg       0.35      0.47      0.38        35
# weighted avg       0.74      0.77      0.74        35
#
# Accuracy predict 0.7714285714285715
# Loss 1.2477363009395304
# MCC 0.5404662835641462
# AUC 0.79690674100337
# ==================================
# code
# KNeighborsClassifier(n_neighbors=15, p=1, weights='distance')
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         2
#            1       0.75      0.60      0.67         5
#            2       0.87      0.83      0.85        24
#            3       1.00      1.00      1.00         1
#            4       1.00      1.00      1.00         1
#            5       1.00      1.00      1.00         1
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.80        35
#    macro avg       0.73      0.78      0.74        35
# weighted avg       0.82      0.80      0.80        35
#
# Accuracy predict 0.8
# Loss 0.7717603979715262
# MCC 0.6210590034081188
# AUC 0.8174241244512571
# ==================================
# SVM
# problemall
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('classifier',
#                  SVC(C=69.51927961775606, gamma=3.359818286283781e-05,
#                      probability=True))])
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         2
#            1       1.00      0.60      0.75         5
#            2       0.88      0.96      0.92        24
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         1
#            5       0.50      1.00      0.67         1
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.83        35
#    macro avg       0.41      0.51      0.43        35
# weighted avg       0.79      0.83      0.80        35
#
# Accuracy predict 0.8285714285714286
# Loss 0.6445605710161619
# MCC 0.6466794458573009
# AUC 0.7014190454688064
# ==================================
# problem_gries
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('classifier',
#                  SVC(C=69.51927961775606, gamma=3.359818286283781e-05,
#                      probability=True))])
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         2
#            1       1.00      0.60      0.75         5
#            2       0.85      0.96      0.90        24
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         1
#            5       1.00      1.00      1.00         1
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.83        35
#    macro avg       0.48      0.51      0.47        35
# weighted avg       0.78      0.83      0.79        35
#
# Accuracy predict 0.8285714285714286
# Loss 0.6138966087724991
# MCC 0.6374627838342364
# AUC 0.6223860977747969
# ==================================
# code_gries
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('classifier',
#                  SVC(C=69.51927961775606, gamma=3.359818286283781e-05,
#                      probability=True))])
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0       0.40      1.00      0.57         2
#            1       1.00      0.60      0.75         5
#            2       0.88      0.92      0.90        24
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         1
#            5       0.50      1.00      0.67         1
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.80        35
#    macro avg       0.40      0.50      0.41        35
# weighted avg       0.78      0.80      0.77        35
#
# Accuracy predict 0.8
# Loss 0.5923925624707699
# MCC 0.5999515663463635
# AUC 0.8077110653749067
# ==================================
# gries
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('classifier',
#                  SVC(C=69.51927961775606, gamma=3.359818286283781e-05,
#                      probability=True))])
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0       0.33      1.00      0.50         2
#            1       0.75      0.60      0.67         5
#            2       0.92      0.92      0.92        24
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         1
#            5       1.00      1.00      1.00         1
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.80        35
#    macro avg       0.43      0.50      0.44        35
# weighted avg       0.78      0.80      0.78        35
#
# Accuracy predict 0.8
# Loss 0.5443781110277777
# MCC 0.6122945920716357
# AUC 0.827334671935077
# ==================================
# problem_code
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('classifier',
#                  SVC(C=69.51927961775606, gamma=3.359818286283781e-05,
#                      probability=True))])
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0       0.33      0.50      0.40         2
#            1       1.00      0.40      0.57         5
#            2       0.83      1.00      0.91        24
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         1
#            5       0.00      0.00      0.00         1
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.77        35
#    macro avg       0.31      0.27      0.27        35
# weighted avg       0.73      0.77      0.73        35
#
# Accuracy predict 0.7714285714285715
# Loss 0.8243141991981264
# MCC 0.48595579650111814
# AUC 0.524074856093367
# ==================================
# code
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('classifier',
#                  SVC(C=69.51927961775606, gamma=3.359818286283781e-05,
#                      probability=True))])
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         2
#            1       0.75      0.60      0.67         5
#            2       0.92      0.92      0.92        24
#            3       1.00      1.00      1.00         1
#            4       0.00      0.00      0.00         1
#            5       0.50      1.00      0.67         1
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.83        35
#    macro avg       0.52      0.65      0.56        35
# weighted avg       0.81      0.83      0.81        35
#
# Accuracy predict 0.8285714285714286
# Loss 0.5992327419362105
# MCC 0.6644986392449886
# AUC 0.8403911295259253
# ==================================
# MLP
# problemall
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('classifier',
#                  MLPClassifier(hidden_layer_sizes=(100, 100, 100),
#                                learning_rate='adaptive'))])
#               precision    recall  f1-score   support
#
#            0       0.33      0.50      0.40         2
#            1       1.00      0.80      0.89         5
#            2       0.89      1.00      0.94        24
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         1
#            5       1.00      1.00      1.00         1
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.86        35
#    macro avg       0.46      0.47      0.46        35
# weighted avg       0.80      0.86      0.82        35
#
# Accuracy predict 0.8571428571428571
# Loss 0.9868393
# MCC 0.6969345304310164
# AUC 0.6896080804116519
# ==================================
# problem_gries
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('classifier',
#                  MLPClassifier(hidden_layer_sizes=(100, 100, 100),
#                                learning_rate='adaptive'))])
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50         2
#            1       1.00      0.60      0.75         5
#            2       0.83      1.00      0.91        24
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         1
#            5       1.00      1.00      1.00         1
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.83        35
#    macro avg       0.48      0.44      0.45        35
# weighted avg       0.77      0.83      0.79        35
#
# Accuracy predict 0.8285714285714286
# Loss 1.4727205
# MCC 0.6262964791113548
# AUC 0.5741565032693574
# ==================================
# code_gries
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('classifier',
#                  MLPClassifier(hidden_layer_sizes=(100, 100, 100),
#                                learning_rate='adaptive'))])
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         2
#            1       0.75      0.60      0.67         5
#            2       0.92      0.96      0.94        24
#            3       1.00      1.00      1.00         1
#            4       0.00      0.00      0.00         1
#            5       1.00      1.00      1.00         1
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.86        35
#    macro avg       0.60      0.65      0.61        35
# weighted avg       0.82      0.86      0.83        35
#
# Accuracy predict 0.8571428571428571
# Loss 0.73957664
# MCC 0.711296576984912
# AUC 0.9678685330278507
# ==================================
# gries
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('classifier',
#                  MLPClassifier(hidden_layer_sizes=(100, 100, 100),
#                                learning_rate='adaptive'))])
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         2
#            1       0.67      0.40      0.50         5
#            2       0.89      1.00      0.94        24
#            3       1.00      1.00      1.00         1
#            4       0.00      0.00      0.00         1
#            5       1.00      1.00      1.00         1
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.86        35
#    macro avg       0.60      0.63      0.61        35
# weighted avg       0.80      0.86      0.82        35
#
# Accuracy predict 0.8571428571428571
# Loss 1.5223618
# MCC 0.699915123243258
# AUC 0.7617557029072531
# ==================================
# problem_code
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('classifier',
#                  MLPClassifier(hidden_layer_sizes=(100, 100, 100),
#                                learning_rate='adaptive'))])
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         2
#            1       0.67      0.40      0.50         5
#            2       0.85      0.96      0.90        24
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         1
#            5       0.00      0.00      0.00         1
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.77        35
#    macro avg       0.31      0.34      0.31        35
# weighted avg       0.72      0.77      0.74        35
#
# Accuracy predict 0.7714285714285715
# Loss 1.2132024
# MCC 0.5070736416042092
# AUC 0.6933318228575734
# ==================================
# code
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('classifier',
#                  MLPClassifier(hidden_layer_sizes=(100, 100, 100),
#                                learning_rate='adaptive'))])
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         2
#            1       0.67      0.40      0.50         5
#            2       0.85      0.96      0.90        24
#            3       1.00      1.00      1.00         1
#            4       0.00      0.00      0.00         1
#            5       1.00      1.00      1.00         1
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.83        35
#    macro avg       0.60      0.62      0.60        35
# weighted avg       0.77      0.83      0.79        35
#
# Accuracy predict 0.8285714285714286
# Loss 1.3066235
# MCC 0.6352791619938807
# AUC 0.8054490999337551
# ==================================
# Random Forest
# problemall
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# RandomForestClassifier(max_depth=15, n_estimators=80)
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67         2
#            1       1.00      0.60      0.75         5
#            2       0.80      1.00      0.89        24
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         1
#            5       1.00      1.00      1.00         1
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.83        35
#    macro avg       0.54      0.44      0.47        35
# weighted avg       0.78      0.83      0.78        35
#
# Accuracy predict 0.8285714285714286
# Loss 0.5268201365752834
# MCC 0.6298318068252363
# AUC 0.9938958175862938
# ==================================
# problem_gries
# RandomForestClassifier(max_depth=15, n_estimators=80)
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       0.75      0.60      0.67         5
#            2       0.86      1.00      0.92        24
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         1
#            5       1.00      1.00      1.00         1
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.86        35
#    macro avg       0.52      0.51      0.51        35
# weighted avg       0.78      0.86      0.81        35
#
# Accuracy predict 0.8571428571428571
# Loss 0.5280557056069746
# MCC 0.6940003733742952
# AUC 0.9802132391418105
# ==================================
# code_gries
# RandomForestClassifier(max_depth=15, n_estimators=80)
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       0.67      0.80      0.73         5
#            2       0.88      0.92      0.90        24
#            3       1.00      1.00      1.00         1
#            4       0.00      0.00      0.00         1
#            5       1.00      1.00      1.00         1
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.86        35
#    macro avg       0.65      0.67      0.66        35
# weighted avg       0.81      0.86      0.83        35
#
# Accuracy predict 0.8571428571428571
# Loss 0.6832129998484803
# MCC 0.7061433695191633
# AUC 0.7131924656596473
# ==================================
# gries
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# RandomForestClassifier(max_depth=15, n_estimators=80)
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       0.43      0.60      0.50         5
#            2       0.88      0.92      0.90        24
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         1
#            5       1.00      1.00      1.00         1
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.80        35
#    macro avg       0.47      0.50      0.49        35
# weighted avg       0.75      0.80      0.77        35
#
# Accuracy predict 0.8
# Loss 0.6636066786494066
# MCC 0.5862626673535392
# AUC 0.9495265508233846
# ==================================
# problem_code
# RandomForestClassifier(max_depth=15, n_estimators=80)
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       1.00      0.20      0.33         5
#            2       0.71      1.00      0.83        24
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         1
#            5       0.00      0.00      0.00         1
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.71        35
#    macro avg       0.24      0.17      0.17        35
# weighted avg       0.63      0.71      0.62        35
#
# Accuracy predict 0.7142857142857143
# Loss 0.7451755101681667
# MCC 0.26384504793551017
# AUC 0.5889129428868041
# ==================================
# code
# RandomForestClassifier(max_depth=15, n_estimators=80)
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67         2
#            1       1.00      0.40      0.57         5
#            2       0.75      1.00      0.86        24
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         1
#            5       0.00      0.00      0.00         1
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.77        35
#    macro avg       0.39      0.27      0.30        35
# weighted avg       0.71      0.77      0.71        35
#
# Accuracy predict 0.7714285714285715
# Loss 0.798441623500655
# MCC 0.4748599609435277
# AUC 0.8371292355119619
# ==================================
# Voting
# problemall
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# VotingClassifier(estimators=[('mlp',
#                               Pipeline(steps=[('scaler', StandardScaler()),
#                                               ('classifier',
#                                                MLPClassifier(hidden_layer_sizes=(100,
#                                                                                  100,
#                                                                                  100),
#                                                              learning_rate='adaptive'))])),
#                              ('rf',
#                               RandomForestClassifier(max_depth=15,
#                                                      n_estimators=80))],
#                  voting='soft')
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67         2
#            1       1.00      0.80      0.89         5
#            2       0.86      1.00      0.92        24
#            3       1.00      1.00      1.00         1
#            4       0.00      0.00      0.00         1
#            5       1.00      1.00      1.00         1
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.89        35
#    macro avg       0.69      0.61      0.64        35
# weighted avg       0.84      0.89      0.86        35
#
# Accuracy predict 0.8857142857142857
# Loss 0.388097914895422
# MCC 0.7629621962179767
# AUC 0.9993259055759055
# ==================================
# problem_gries
# VotingClassifier(estimators=[('mlp',
#                               Pipeline(steps=[('scaler', StandardScaler()),
#                                               ('classifier',
#                                                MLPClassifier(hidden_layer_sizes=(100,
#                                                                                  100,
#                                                                                  100),
#                                                              learning_rate='adaptive'))])),
#                              ('rf',
#                               RandomForestClassifier(max_depth=15,
#                                                      n_estimators=80))],
#                  voting='soft')
#               precision    recall  f1-score   support
#
#            0       0.40      1.00      0.57         2
#            1       1.00      0.40      0.57         5
#            2       0.85      0.96      0.90        24
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         1
#            5       1.00      1.00      1.00         1
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.80        35
#    macro avg       0.46      0.48      0.43        35
# weighted avg       0.78      0.80      0.76        35
#
# Accuracy predict 0.8
# Loss 0.5341038269535563
# MCC 0.5804663849113396
# AUC 0.8672758849899297
# ==================================
# code_gries
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# VotingClassifier(estimators=[('mlp',
#                               Pipeline(steps=[('scaler', StandardScaler()),
#                                               ('classifier',
#                                                MLPClassifier(hidden_layer_sizes=(100,
#                                                                                  100,
#                                                                                  100),
#                                                              learning_rate='adaptive'))])),
#                              ('rf',
#                               RandomForestClassifier(max_depth=15,
#                                                      n_estimators=80))],
#                  voting='soft')
#               precision    recall  f1-score   support
#
#            0       0.33      0.50      0.40         2
#            1       0.75      0.60      0.67         5
#            2       0.88      0.96      0.92        24
#            3       1.00      1.00      1.00         1
#            4       0.00      0.00      0.00         1
#            5       1.00      1.00      1.00         1
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.83        35
#    macro avg       0.57      0.58      0.57        35
# weighted avg       0.79      0.83      0.81        35
#
# Accuracy predict 0.8285714285714286
# Loss 0.5097330974509483
# MCC 0.6401489204818585
# AUC 0.8157133572250188
# ==================================
# gries
# VotingClassifier(estimators=[('mlp',
#                               Pipeline(steps=[('scaler', StandardScaler()),
#                                               ('classifier',
#                                                MLPClassifier(hidden_layer_sizes=(100,
#                                                                                  100,
#                                                                                  100),
#                                                              learning_rate='adaptive'))])),
#                              ('rf',
#                               RandomForestClassifier(max_depth=15,
#                                                      n_estimators=80))],
#                  voting='soft')
# ...
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# StackingClassifier(estimators=[('mlp',
#                                 Pipeline(steps=[('scaler', StandardScaler()),
#                                                 ('classifier',
#                                                  MLPClassifier(hidden_layer_sizes=(100,
#                                                                                    100,
#                                                                                    100),
#                                                                learning_rate='adaptive'))])),
#                                ('rf',
#                                 RandomForestClassifier(max_depth=15,
#                                                        n_estimators=80))],
#                    final_estimator=LogisticRegression())
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67         2
#            1       1.00      0.40      0.57         5
#            2       0.80      1.00      0.89        24
#            3       1.00      1.00      1.00         1
#            4       0.00      0.00      0.00         1
#            5       1.00      1.00      1.00         1
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.83        35
#    macro avg       0.69      0.56      0.59        35
# weighted avg       0.81      0.83      0.79        35
#
# Accuracy predict 0.8285714285714286
# Loss 0.5805671602532746
# MCC 0.6348957264914545
# AUC 0.7136577223481986
# ==================================
# problem_gries
# StackingClassifier(estimators=[('mlp',
#                                 Pipeline(steps=[('scaler', StandardScaler()),
#                                                 ('classifier',
#                                                  MLPClassifier(hidden_layer_sizes=(100,
#                                                                                    100,
#                                                                                    100),
#                                                                learning_rate='adaptive'))])),
#                                ('rf',
#                                 RandomForestClassifier(max_depth=15,
#                                                        n_estimators=80))],
#                    final_estimator=LogisticRegression())
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         2
#            1       1.00      0.40      0.57         5
#            2       0.83      1.00      0.91        24
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         1
#            5       1.00      1.00      1.00         1
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.83        35
#    macro avg       0.50      0.49      0.47        35
# weighted avg       0.78      0.83      0.78        35
#
# Accuracy predict 0.8285714285714286
# Loss 0.6005634735936235
# MCC 0.6325803902730072
# AUC 0.8480823852529518
# ==================================
# code_gries
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# StackingClassifier(estimators=[('mlp',
#                                 Pipeline(steps=[('scaler', StandardScaler()),
#                                                 ('classifier',
#                                                  MLPClassifier(hidden_layer_sizes=(100,
#                                                                                    100,
#                                                                                    100),
#                                                                learning_rate='adaptive'))])),
#                                ('rf',
#                                 RandomForestClassifier(max_depth=15,
#                                                        n_estimators=80))],
#                    final_estimator=LogisticRegression())
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      0.60      0.75         5
#            2       0.86      1.00      0.92        24
#            3       1.00      1.00      1.00         1
#            4       0.00      0.00      0.00         1
#            5       1.00      1.00      1.00         1
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.89        35
#    macro avg       0.69      0.66      0.67        35
# weighted avg       0.84      0.89      0.85        35
#
# Accuracy predict 0.8857142857142857
# Loss 0.45127298388671405
# MCC 0.7652281034846948
# AUC 0.8555406929556018
# ==================================
# gries
# StackingClassifier(estimators=[('mlp',
#                                 Pipeline(steps=[('scaler', StandardScaler()),
#                                                 ('classifier',
#                                                  MLPClassifier(hidden_layer_sizes=(100,
#                                                                                    100,
#                                                                                    100),
#                                                                learning_rate='adaptive'))])),
#                                ('rf',
#                                 RandomForestClassifier(max_depth=15,
#                                                        n_estimators=80))],
#                    final_estimator=LogisticRegression())
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50         2
#            1       0.50      0.60      0.55         5
#            2       0.88      0.92      0.90        24
#            3       1.00      1.00      1.00         1
#            4       0.00      0.00      0.00         1
#            5       1.00      1.00      1.00         1
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.80        35
#    macro avg       0.55      0.57      0.56        35
# weighted avg       0.76      0.80      0.78        35
#
# Accuracy predict 0.8
# Loss 0.5603796532512594
# MCC 0.586747147619788
# AUC 0.7109747966907253
# ==================================
# problem_code
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# StackingClassifier(estimators=[('mlp',
#                                 Pipeline(steps=[('scaler', StandardScaler()),
#                                                 ('classifier',
#                                                  MLPClassifier(hidden_layer_sizes=(100,
#                                                                                    100,
#                                                                                    100),
#                                                                learning_rate='adaptive'))])),
#                                ('rf',
#                                 RandomForestClassifier(max_depth=15,
#                                                        n_estimators=80))],
#                    final_estimator=LogisticRegression())
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67         2
#            1       1.00      0.40      0.57         5
#            2       0.75      1.00      0.86        24
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         1
#            5       0.00      0.00      0.00         1
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.77        35
#    macro avg       0.39      0.27      0.30        35
# weighted avg       0.71      0.77      0.71        35
#
# Accuracy predict 0.7714285714285715
# Loss 0.7922780025162146
# MCC 0.4748599609435277
# AUC 0.6754136023856521
# ==================================
# code
# StackingClassifier(estimators=[('mlp',
#                                 Pipeline(steps=[('scaler', StandardScaler()),
#                                                 ('classifier',
#                                                  MLPClassifier(hidden_layer_sizes=(100,
#                                                                                    100,
#                                                                                    100),
#                                                                learning_rate='adaptive'))])),
#                                ('rf',
#                                 RandomForestClassifier(max_depth=15,
#                                                        n_estimators=80))],
#                    final_estimator=LogisticRegression())
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       0.50      0.20      0.29         5
#            2       0.79      0.96      0.87        24
#            3       1.00      1.00      1.00         1
#            4       0.00      0.00      0.00         1
#            5       1.00      1.00      1.00         1
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.80        35
#    macro avg       0.61      0.59      0.59        35
# weighted avg       0.73      0.80      0.75        35
#
# Accuracy predict 0.8
# Loss 0.5849380640652504
# MCC 0.5583527209171832
# AUC 0.8122833140863747
# ==================================
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import pandas as pd
dfe=pd.DataFrame({
    "Model":ml_names,
    "Ablation":abl_names,
    "Accuracy_predict":accuracies_predict,
    "Loss":loss_predict,
    "Time_predict":times_predict,
    "MCC":mccs_predict,
    "AUC":aucpr_predict
})

# %%
dfe
# Out:
#             Model       Ablation  Accuracy_predict      Loss  Time_predict  \
# 0             KNN     problemall          0.857143  0.360702      0.204653
# 1             KNN  problem_gries          0.857143  0.797549      0.145043
# 2             KNN     code_gries          0.828571  0.876163      0.148208
# 3             KNN          gries          0.771429  1.713604      0.121563
# 4             KNN   problem_code          0.771429  1.247736      0.075882
# 5             KNN           code          0.800000  0.771760      0.038732
# 6             SVM     problemall          0.828571  0.644561      0.235719
# 7             SVM  problem_gries          0.828571  0.613897      0.193871
# 8             SVM     code_gries          0.800000  0.592393      0.169754
# 9             SVM          gries          0.800000  0.544378      0.127387
# 10            SVM   problem_code          0.771429  0.824314      0.116718
# 11            SVM           code          0.828571  0.599233      0.052726
# 12            MLP     problemall          0.857143  0.986839      0.002272
# 13            MLP  problem_gries          0.828571  1.472721      0.001816
# 14            MLP     code_gries          0.857143  0.739577      0.001794
# 15            MLP          gries          0.857143  1.522362      0.001765
# 16            MLP   problem_code          0.771429  1.213202      0.001499
# 17            MLP           code          0.828571  1.306623      0.001232
# 18  Random Forest     problemall          0.828571  0.526820      0.006572
# 19  Random Forest  problem_gries          0.857143  0.528056      0.006328
# 20  Random Forest     code_gries          0.857143  0.683213      0.006632
# 21  Random Forest          gries          0.800000  0.663607      0.006456
# 22  Random Forest   problem_code          0.714286  0.745176      0.005872
# 23  Random Forest           code          0.771429  0.798442      0.007363
# 24         Voting     problemall          0.885714  0.388098      0.010726
# 25         Voting  problem_gries          0.800000  0.534104      0.008678
# 26         Voting     code_gries          0.828571  0.509733      0.009748
# 27         Voting          gries          0.828571  0.552149      0.008145
# 28         Voting   problem_code          0.828571  0.641194      0.009383
# 29         Voting           code          0.828571  0.772520      0.007985
# 30       Stacking     problemall          0.828571  0.580567      0.009035
# 31       Stacking  problem_gries          0.828571  0.600563      0.008472
# 32       Stacking     code_gries          0.885714  0.451273      0.011781
# 33       Stacking          gries          0.800000  0.560380      0.008615
# 34       Stacking   problem_code          0.771429  0.792278      0.011419
# 35       Stacking           code          0.800000  0.584938      0.008023
#
#          MCC       AUC
# 0   0.700954  0.854518
# 1   0.700954  0.778077
# 2   0.642838  0.887382
# 3   0.571739  0.873449
# 4   0.540466  0.796907
# 5   0.621059  0.817424
# 6   0.646679  0.701419
# 7   0.637463  0.622386
# 8   0.599952  0.807711
# 9   0.612295  0.827335
# 10  0.485956  0.524075
# 11  0.664499  0.840391
# 12  0.696935  0.689608
# 13  0.626296  0.574157
# 14  0.711297  0.967869
# 15  0.699915  0.761756
# 16  0.507074  0.693332
# 17  0.635279  0.805449
# 18  0.629832  0.993896
# 19  0.694000  0.980213
# 20  0.706143  0.713192
# 21  0.586263  0.949527
# 22  0.263845  0.588913
# 23  0.474860  0.837129
# 24  0.762962  0.999326
# 25  0.580466  0.867276
# 26  0.640149  0.815713
# 27  0.658500  0.841229
# 28  0.631066  0.499814
# 29  0.636986  0.811500
# 30  0.634896  0.713658
# 31  0.632580  0.848082
# 32  0.765228  0.855541
# 33  0.586747  0.710975
# 34  0.474860  0.675414
# 35  0.558353  0.812283

# %%
dfe.to_csv(path+"bert_externData_ablationsResults.csv",index=False)

# %%
dfe=pd.read_csv(path+"bert_externData_ablationsResults.csv")
dfe
# Out:
#             Model       Ablation  Accuracy_predict      Loss  Time_predict  \
# 0             KNN     problemall          0.857143  0.360702      0.204653
# 1             KNN  problem_gries          0.857143  0.797549      0.145043
# 2             KNN     code_gries          0.828571  0.876163      0.148208
# 3             KNN          gries          0.771429  1.713604      0.121563
# 4             KNN   problem_code          0.771429  1.247736      0.075882
# 5             KNN           code          0.800000  0.771760      0.038732
# 6             SVM     problemall          0.828571  0.644561      0.235719
# 7             SVM  problem_gries          0.828571  0.613897      0.193871
# 8             SVM     code_gries          0.800000  0.592393      0.169754
# 9             SVM          gries          0.800000  0.544378      0.127387
# 10            SVM   problem_code          0.771429  0.824314      0.116718
# 11            SVM           code          0.828571  0.599233      0.052726
# 12            MLP     problemall          0.857143  0.986839      0.002272
# 13            MLP  problem_gries          0.828571  1.472721      0.001816
# 14            MLP     code_gries          0.857143  0.739577      0.001794
# 15            MLP          gries          0.857143  1.522362      0.001765
# 16            MLP   problem_code          0.771429  1.213202      0.001499
# 17            MLP           code          0.828571  1.306623      0.001232
# 18  Random Forest     problemall          0.828571  0.526820      0.006572
# 19  Random Forest  problem_gries          0.857143  0.528056      0.006328
# 20  Random Forest     code_gries          0.857143  0.683213      0.006632
# 21  Random Forest          gries          0.800000  0.663607      0.006456
# 22  Random Forest   problem_code          0.714286  0.745176      0.005872
# 23  Random Forest           code          0.771429  0.798442      0.007363
# 24         Voting     problemall          0.885714  0.388098      0.010726
# 25         Voting  problem_gries          0.800000  0.534104      0.008678
# 26         Voting     code_gries          0.828571  0.509733      0.009748
# 27         Voting          gries          0.828571  0.552149      0.008145
# 28         Voting   problem_code          0.828571  0.641194      0.009383
# 29         Voting           code          0.828571  0.772520      0.007985
# 30       Stacking     problemall          0.828571  0.580567      0.009035
# 31       Stacking  problem_gries          0.828571  0.600563      0.008472
# 32       Stacking     code_gries          0.885714  0.451273      0.011781
# 33       Stacking          gries          0.800000  0.560380      0.008615
# 34       Stacking   problem_code          0.771429  0.792278      0.011419
# 35       Stacking           code          0.800000  0.584938      0.008023
#
#          MCC       AUC
# 0   0.700954  0.854518
# 1   0.700954  0.778077
# 2   0.642838  0.887382
# 3   0.571739  0.873449
# 4   0.540466  0.796907
# 5   0.621059  0.817424
# 6   0.646679  0.701419
# 7   0.637463  0.622386
# 8   0.599952  0.807711
# 9   0.612295  0.827335
# 10  0.485956  0.524075
# 11  0.664499  0.840391
# 12  0.696935  0.689608
# 13  0.626296  0.574157
# 14  0.711297  0.967869
# 15  0.699915  0.761756
# 16  0.507074  0.693332
# 17  0.635279  0.805449
# 18  0.629832  0.993896
# 19  0.694000  0.980213
# 20  0.706143  0.713192
# 21  0.586263  0.949527
# 22  0.263845  0.588913
# 23  0.474860  0.837129
# 24  0.762962  0.999326
# 25  0.580466  0.867276
# 26  0.640149  0.815713
# 27  0.658500  0.841229
# 28  0.631066  0.499814
# 29  0.636986  0.811500
# 30  0.634896  0.713658
# 31  0.632580  0.848082
# 32  0.765228  0.855541
# 33  0.586747  0.710975
# 34  0.474860  0.675414
# 35  0.558353  0.812283

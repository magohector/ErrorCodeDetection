# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.56.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.35.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.8.3)

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import re
import shutil
import string
from sklearn.metrics import classification_report
import tensorflow as tf
from keras.models import Model
from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras.optimizers import Adam
from keras.callbacks import EarlyStopping,ModelCheckpoint
from tensorflow.keras.layers import Dense, Input, Dropout, Bidirectional, LSTM, Embedding, BatchNormalization,  Reshape, Conv2D, MaxPool2D, concatenate, Flatten, Activation
import torch
import numpy as np
from transformers import BertTokenizer, BertModel,RobertaTokenizer, RobertaModel,AutoTokenizer, AutoModel
import ast

# %%
# Verificar si la GPU está disponible
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
archivo_3 = '/content/drive/MyDrive/UDENAR/ProyectosGrado/Errol/Ginna/ResultsGraph//DataProgramsandDescriptions-CatRetroalimentacion5000.xlsx'
train_full = pd.read_excel(archivo_3)

# %% [markdown]
# # AST spliter D. Gries form

# %%
class WhileLoopFinder(ast.NodeVisitor):
    def __init__(self, source_code):
        self.source_code = source_code.splitlines()
        self.functions_with_while = []
        self.current_function = None

    def visit_FunctionDef(self, node):
        original_current_function = self.current_function
        self.current_function = {
            "function_name": node.name,
            "has_while_loop": False,
            "pre_while_code_lines": [],
            "while_loops": []
        }

        function_start_line = node.lineno - 1
        function_end_line = (node.end_lineno if hasattr(node, 'end_lineno') else len(self.source_code))
        function_lines = self.source_code[function_start_line:function_end_line]

        found_while = False
        for stmt in node.body:
            if isinstance(stmt, ast.While):
                self.current_function["has_while_loop"] = True
                found_while = True
                try:
                    while_condition = ast.unparse(stmt.test).strip()
                    print("OK condition")
                except AttributeError:
                    print("Error al obtener la condición del while")
                try:
                    while_body_code = ast.unparse(ast.Module(body=stmt.body, type_ignores=[])).strip()
                    print("Ok body")
                except AttributeError:
                    print("Error al obtener el código del cuerpo del while")

                self.current_function["while_loops"].append({
                    "condition": while_condition,
                    "body_code": while_body_code
                })
            elif not found_while:
                start_line = stmt.lineno - 1
                end_line = (stmt.end_lineno if hasattr(stmt, 'end_lineno') else stmt.lineno)
                self.current_function["pre_while_code_lines"].extend(self.source_code[start_line:end_line])
            self.generic_visit(stmt)

        if self.current_function["has_while_loop"]:
            last_while_end_line = None
            if self.current_function["while_loops"]:
                last_while_node = next((node for node in reversed(node.body) if isinstance(node, ast.While)), None)
                if last_while_node and hasattr(last_while_node, 'end_lineno'):
                    last_while_end_line = last_while_node.end_lineno
            post_while_code_lines = []
            if last_while_end_line:
                function_indent = len(self.source_code[node.lineno - 1]) - len(self.source_code[node.lineno - 1].lstrip())
                for line in self.source_code[last_while_end_line:function_end_line]:
                    if line.startswith(self.source_code[node.lineno - 1][:function_indent] + "    "):
                        post_while_code_lines.append(line[function_indent + 4:])
                    else:
                        post_while_code_lines.append(line[function_indent:])
            self.current_function["post_while_code_lines"] = "\n".join(post_while_code_lines).strip()
            self.current_function["pre_while_code_lines"] = "\n".join(self.current_function["pre_while_code_lines"]).strip()
            self.functions_with_while.append(self.current_function)

        self.current_function = original_current_function

# %%
def DGries_states(solution):
  try:
    # Crear el AST
    tree = ast.parse(solution)
    # Recorrer el AST con nuestro visitante
    finder = WhileLoopFinder(solution)
    finder.visit(tree)
    for func_info in finder.functions_with_while:
      initial_state=func_info["pre_while_code_lines"] if func_info["pre_while_code_lines"] else False
      end_state=""
      transformation_state=""
      for j, wl in enumerate(func_info["while_loops"]):
          end_state=wl["condition"]
          transformation_state=wl["body_code"]

      if not initial_state:
        initial_state=transformation_state
      return initial_state,transformation_state,end_state
  except Exception as error:
    return "Exception:"+str(error),"Exception:"+str(error),"Exception:"+str(error)

# %% [markdown]
# # Encoder Description and Code

# %%
class Encoder:
  def __init__(self):
    self.is_loadtokenizers=False



  def tokenize_and_generate_embeddings_descriptions(self,description):
    if not self.is_loadtokenizers:
      raise ValueError("tokenizers dont load")
    # Tokenize input description and move tokens to GPU
    tokens = self.beart_tokenizer.encode_plus(description, return_tensors="pt", truncation=True)
    tokens = {key: value.to(device) for key, value in tokens.items()}
    # Generate embeddings
    with torch.no_grad():
        outputs = self.beart_model(**tokens)
    # Extract embeddings for all tokens
    desc_embeddings = outputs.last_hidden_state.cpu().numpy()
    return desc_embeddings

  def tokenize_and_generate_embeddings_codes(self,code):
    if not self.is_loadtokenizers:
      raise ValueError("tokenizers dont load")
    # Tokenize input code and move tokens to GPU
    tokens = self.codebeart_tokenizer.encode_plus(code, return_tensors="pt", truncation=True)
    tokens = {key: value.to(device) for key, value in tokens.items()}
    # Generate embeddings
    with torch.no_grad():
        outputs = self.codebeart_model(**tokens)
    # Extract embeddings for all tokens
    code_embeddings = outputs.last_hidden_state.cpu().numpy()

    return code_embeddings


  def tokenize_and_generate_embeddings_graphcodes(self,code):
    if not self.is_loadtokenizers:
      raise ValueError("tokenizers dont load")
    # Tokenize input code and move tokens to GPU
    tokens = self.graphcodebert_tokenizer.encode_plus(code, return_tensors="pt", truncation=True)
    tokens = {key: value.to(device) for key, value in tokens.items()}
    # Generate embeddings
    with torch.no_grad():
        outputs = self.graphcodebert_model(**tokens)
    # Extract embeddings for all tokens
    code_embeddings = outputs.last_hidden_state.cpu().numpy()
    return code_embeddings

  def load_beart_tokenizer(self):
    # Verificar si la GPU está disponible
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Cargar el tokenizer y el modelo en la GPU si está disponible
    model_name = "bert-base-uncased"
    self.beart_model = BertModel.from_pretrained(model_name)
    self.beart_tokenizer = BertTokenizer.from_pretrained(model_name)
    self.beart_model.to(device)

  def load_graphcodebert_tokenizer(self):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    self.graphcodebert_tokenizer = AutoTokenizer.from_pretrained("microsoft/graphcodebert-base")
    self.graphcodebert_model = AutoModel.from_pretrained("microsoft/graphcodebert-base")
    self.graphcodebert_model.to(device)


  def load_codebert_tokenizer(self):
    # Verificar si la GPU está disponible
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Cargar el tokenizer y el modelo en la GPU si está disponible
    self.codebeart_tokenizer = RobertaTokenizer.from_pretrained("microsoft/codebert-base")
    self.codebeart_model = RobertaModel.from_pretrained("microsoft/codebert-base")
    self.codebeart_model.to(device)

  def start_tokenizer(self):
    self.load_beart_tokenizer()
    #self.load_codebert_tokenizer()
    self.load_graphcodebert_tokenizer()
    self.is_loadtokenizers=True

# %% [markdown]
# # All characteristics

# %%
def categoricallabelAll(w):

  if w=="['Initial state']":
    return 0
  if w=="['Final state']":
    return 1
  if w=="['State transformation']":
    return 2
  if w=="['Initial state', 'Final state']":
    return 3
  if w=="['Initial state', 'State transformation']":
    return 4
  if w=="['Final state', 'State transformation']":
    return 5
  if w=="['Initial state', 'Final state', 'State transformation']":
    return 6
  return 7

category=np.array([
    'Initial state',
    'Final state',
    'State transformation',
    'Initial state, Final state',
    'Initial state, State transformation',
    'Final state, State transformation',
    'Initial state, Final state, State transformation'

])

# %% [markdown]
# # Load Dataset

# %%
train_full.head()
# Out:
#    No.                                           Problema  \
# 0    1  Write a Python function that returns the facto...
# 1    2  Write a Python function that returns the sum o...
# 2    3  Write a Python function that prints the number...
# 3    4  Write a Python function to print the numbers f...
# 4    5  Write a Python function to check if a number i...
#
#                                             Solución  \
# 0  def factorial(n):\n    result = 1\n    i = 1\n...
# 1  def sum_1_to_100():\n    total = 0\n    i = 1\...
# 2  def print_and_store():\n    numbers = []\n    ...
# 3  def print_and_store_reverse():\n    numbers = ...
# 4  def is_prime(num):\n    if num <= 1:\n        ...
#
#                  Estado incial Estado final  \
# 0            result = 1, i = 1       i <= n
# 1    total = 0, i = 1, n = 100       i <= n
# 2  numbers = [], i = 0, n = 10       i <= n
# 3  numbers = [], i = 10, n = 1       i >= n
# 4              i = 2, i = = 0:  i <= num//2
#
#                      Transformación de estado Etiqueta 1   Etiqueta 2  \
# 0                         result *= i, i += 1    Correct  ['Correct']
# 1                          total += i, i += 1    Correct  ['Correct']
# 2         print(i), numbers.append(i), i += 1    Correct  ['Correct']
# 3         print(i), numbers.append(i), i -= 1    Correct  ['Correct']
# 4  if num % i == 0:,     return False, i += 1    Correct  ['Correct']
#
#   Realimentación
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
train_full.drop(["No.","Realimentación","Estado incial","Estado final","Transformación de estado"],axis=1,inplace=True)
train_full
# Out:
#                                                Problema  \
# 0     Write a Python function that returns the facto...
# 1     Write a Python function that returns the sum o...
# 2     Write a Python function that prints the number...
# 3     Write a Python function to print the numbers f...
# 4     Write a Python function to check if a number i...
# ...                                                 ...
# 4995  Write a Python function that returns the sum o...
# 4996  Write a Python function that returns the facto...
# 4997  Write a Python function that prints the number...
# 4998  Write a Python function to print the numbers f...
# 4999  Write a Python function that finds the smalles...
#
#                                                Solución Etiqueta 1  \
# 0     def factorial(n):\n    result = 1\n    i = 1\n...    Correct
# 1     def sum_1_to_100():\n    total = 0\n    i = 1\...    Correct
# 2     def print_and_store():\n    numbers = []\n    ...    Correct
# 3     def print_and_store_reverse():\n    numbers = ...    Correct
# 4     def is_prime(num):\n    if num <= 1:\n        ...    Correct
# ...                                                 ...        ...
# 4995  def sum_of_first_five_numbers():\n    number =...  Incorrect
# 4996  def factorial(n):\n    result = 0\n    i = 0\n...  Incorrect
# 4997  def print_and_store_numbers():\n    numbers = ...  Incorrect
# 4998  def print_and_store_numbers():\n    numbers = ...  Incorrect
# 4999  def find_smallest(numbers):\n    smallest = nu...  Incorrect
#
#                             Etiqueta 2
# 0                          ['Correct']
# 1                          ['Correct']
# 2                          ['Correct']
# 3                          ['Correct']
# 4                          ['Correct']
# ...                                ...
# 4995  ['Initial state', 'Final state']
# 4996  ['Initial state', 'Final state']
# 4997  ['Initial state', 'Final state']
# 4998  ['Initial state', 'Final state']
# 4999  ['Initial state', 'Final state']
#
# [5000 rows x 4 columns]

# %%
train_full[["Estado incial","Transformación de estado","Estado final"]]=train_full['Solución'].apply(DGries_states).apply(pd.Series)
# Out:
# Streaming output truncated to the last 5000 lines.
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body
# OK condition
# Ok body

# %%
train_full = train_full[train_full['Etiqueta 1']!='Correct'].copy()

# %%
y=train_full['Etiqueta 2'].apply(categoricallabelAll)
np.unique(y)
# Out:
# array([0, 1, 2, 3, 4, 5, 6])

# %%
train_full.dropna(inplace=True)

# %%
np.unique(train_full['Etiqueta 2'])
# Out:
# array(["['Final state', 'State transformation']", "['Final state']",
#        "['Initial state', 'Final state', 'State transformation']",
#        "['Initial state', 'Final state']",
#        "['Initial state', 'State transformation']", "['Initial state']",
#        "['State transformation']"], dtype=object)

# %%
encoder=Encoder()
encoder.start_tokenizer()
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at microsoft/graphcodebert-base and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# %%time
problem=train_full['Problema'].apply(encoder.tokenize_and_generate_embeddings_descriptions).to_numpy()
code=train_full['Solución'].apply(encoder.tokenize_and_generate_embeddings_graphcodes).to_numpy()
startstate = train_full['Estado incial'].apply(encoder.tokenize_and_generate_embeddings_graphcodes).to_numpy()
finalstate = train_full['Estado final'].apply(encoder.tokenize_and_generate_embeddings_graphcodes).to_numpy()
transstate = train_full['Transformación de estado'].apply(encoder.tokenize_and_generate_embeddings_graphcodes).to_numpy()
# Out:
# CPU times: user 2min 46s, sys: 744 ms, total: 2min 47s
# Wall time: 3min 44s

# %%
problem.shape,code.shape,startstate.shape,finalstate.shape,transstate.shape
# Out:
# ((3459,), (3459,), (3459,), (3459,), (3459,))

# %%
print(startstate.shape)
print(startstate[1262].shape)
# Out:
# (3459,)
# (1, 13, 768)

# %%
Xp=np.array([sentence[0].mean(axis=0) for sentence in problem])
Xcode=np.array([sentence[0].mean(axis=0) for sentence in code])
Xs=np.array([sentence[0].mean(axis=0) for sentence in startstate])
Xf=np.array([sentence[0].mean(axis=0) for sentence in finalstate])
Xt=np.array([sentence[0].mean(axis=0) for sentence in transstate])
Xp.shape,Xs.shape,Xf.shape,Xt.shape
# Out:
# ((3459, 768), (3459, 768), (3459, 768), (3459, 768))

# %%
y=train_full['Etiqueta 2'].apply(categoricallabelAll)
y=y.to_numpy()
np.unique(y)
# Out:
# array([0, 1, 2, 3, 4, 5, 6])

# %%
from sklearn.model_selection import train_test_split

Xp_train,Xp_test,Xcode_train,Xcode_test,Xs_train,Xs_test,Xt_train,Xt_test,Xf_train,Xf_test,y_train,y_test=train_test_split(Xp,Xcode,Xs,Xt,Xf,y,test_size=0.2,random_state=2023, stratify=y)

# %%
Xp_train.shape,Xp_test.shape,Xcode_train.shape, Xcode_test.shape, Xs_train.shape,Xs_test.shape,Xt_train.shape,Xt_test.shape,Xf_train.shape,Xf_test.shape,y_train.shape,y_test.shape
# Out:
# ((2767, 768),
#  (692, 768),
#  (2767, 768),
#  (692, 768),
#  (2767, 768),
#  (692, 768),
#  (2767, 768),
#  (692, 768),
#  (2767, 768),
#  (692, 768),
#  (2767,),
#  (692,))

# %% [markdown]
# # Keras model

# %%
from tensorflow.keras import backend as K
import gc
def ANNTC(input,base,pow_initial,num_max_blocks):

  drop_out=0.5
  print("base",base,"pow",pow_initial,"num_max_blocks",num_max_blocks)
  n=num_max_blocks//2
  neurons=int(base**(pow_initial+n+1))
  # Encoder
  x=None
  print("Encoder",n)
  try:
    for i in range(n):
      x=Dense(neurons)(input)
      x=BatchNormalization()(x)
      x=Activation('relu')(x)
      x=Dropout(drop_out)(x)
      input=x
      drop_out=0.2
      print("Block ",i,neurons)
      neurons=int(neurons/base)



    #BottleNeck
    x=Dense(neurons)(x)
    x=BatchNormalization()(x)
    x=Activation('relu')(x)
    x=Dropout(0.2)(x)
    print("BottleNeck",neurons)

    # Decoder
    print("Decoder",n)
    for i in range(n):
      neurons=int(neurons*base)
      print("Block ",i,neurons)
      x=Dense(neurons)(x)
      x=BatchNormalization()(x)
      x=Activation('relu')(x)
      x=Dropout(drop_out)(x)
      if i==n-1:
        drop_out=0.5
      drop_out=0.2
  except Exception as err:

    K.clear_session()
    gc.collect()
    del x
    print(f"Unexpected {err=}, {type(err)=}")
    raise

  return x

def neural_network_all(problem,code,start_input,trass_input,final_input,base=10,pow_initial=4,num_max_blocks=3):
  mlp_p=ANNTC(problem,base,pow_initial,num_max_blocks)
  mlp_code=ANNTC(code,base,pow_initial,num_max_blocks)
  mlp_s=ANNTC(start_input,base,pow_initial,num_max_blocks)
  mlp_t=ANNTC(trass_input,base,pow_initial,num_max_blocks)
  mlp_f=ANNTC(final_input,base,pow_initial,num_max_blocks)
  ## Concatenate All models
  combined = concatenate([mlp_p,mlp_code ,mlp_s, mlp_t,mlp_f])
  ## output layer
  output=Dense(8)(combined)
  output=BatchNormalization()(output)
  output=Activation('softmax')(output)
  ## Model
  model = Model(inputs=[problem_input,code,start_input, trass_input,final_input], outputs=output)
  return model


def neural_network_code_gries(code_input,start_input,trass_input,final_input,base=10,pow_initial=4,num_max_blocks=3):
  mlp_code=ANNTC(code_input,base,pow_initial,num_max_blocks)
  mlp_s=ANNTC(start_input,base,pow_initial,num_max_blocks)
  mlp_t=ANNTC(trass_input,base,pow_initial,num_max_blocks)
  mlp_f=ANNTC(final_input,base,pow_initial,num_max_blocks)
  ## Concatenate All models
  combined = concatenate([mlp_code, mlp_s, mlp_t,mlp_f])
  ## output layer
  output=Dense(8)(combined)
  output=BatchNormalization()(output)
  output=Activation('softmax')(output)
  ## Model
  model = Model(inputs=[code_input, start_input, trass_input,final_input], outputs=output)
  return model

def neural_network(problem,start_input,trass_input,final_input,base=10,pow_initial=4,num_max_blocks=3):
  mlp_p=ANNTC(problem,base,pow_initial,num_max_blocks)
  mlp_s=ANNTC(start_input,base,pow_initial,num_max_blocks)
  mlp_t=ANNTC(trass_input,base,pow_initial,num_max_blocks)
  mlp_f=ANNTC(final_input,base,pow_initial,num_max_blocks)
  ## Concatenate All models
  combined = concatenate([mlp_p, mlp_s, mlp_t,mlp_f])
  ## output layer
  output=Dense(8)(combined)
  output=BatchNormalization()(output)
  output=Activation('softmax')(output)
  ## Model
  model = Model(inputs=[problem_input, start_input, trass_input,final_input], outputs=output)
  return model


def neural_network_wproblem(start_input,trass_input,final_input,base=10,pow_initial=4,num_max_blocks=3):
  mlp_s=ANNTC(start_input,base,pow_initial,num_max_blocks)
  mlp_t=ANNTC(trass_input,base,pow_initial,num_max_blocks)
  mlp_f=ANNTC(final_input,base,pow_initial,num_max_blocks)
  ## Concatenate All models
  combined = concatenate([mlp_s, mlp_t,mlp_f])
  ## output layer
  output=Dense(8)(combined)
  output=BatchNormalization()(output)
  output=Activation('softmax')(output)
  ## Model
  model = Model(inputs=[start_input, trass_input,final_input], outputs=output)
  return model

def neural_network_problem_code(problem,code_input,base=10,pow_initial=4,num_max_blocks=3):
  mlp_p=ANNTC(problem,base,pow_initial,num_max_blocks)
  mlp_code=ANNTC(code_input,base,pow_initial,num_max_blocks)
  ## Concatenate All models
  combined = concatenate([mlp_p, mlp_code])
  ## output layer
  output=Dense(8)(combined)
  output=BatchNormalization()(output)
  output=Activation('softmax')(output)
  ## Model
  model = Model(inputs=[problem, code_input], outputs=output)
  return model

def neural_network_code(code_input,base=10,pow_initial=4,num_max_blocks=3):

  mlp_code=ANNTC(code_input,base,pow_initial,num_max_blocks)
  ## output layer
  output=Dense(8)(mlp_code)
  output=BatchNormalization()(output)
  output=Activation('softmax')(output)
  ## Model
  model = Model(inputs=[code_input], outputs=output)
  return model

# %%
import numpy as np
np.linspace(5,70,14)
# Out:
# array([ 5., 10., 15., 20., 25., 30., 35., 40., 45., 50., 55., 60., 65.,
#        70.])

# %%
models=[]
models_names=["problemall","problem_gries","code_gries","gries","problem_code","code"]

problem_input=Input((768,))
code_input=Input((768,))
start_input=Input((768,))
trass_input=Input((768,))
final_input=Input((768,))

print("problem all")
models.append(neural_network_all(problem_input,code_input,start_input,trass_input,final_input,base=8,pow_initial=1, num_max_blocks=3))
print("\nproblem gries")
models.append(neural_network(problem_input,start_input,trass_input,final_input,base=8,pow_initial=1, num_max_blocks=3))
print("\ncode gries")
models.append(neural_network_code_gries(code_input,start_input,trass_input,final_input,base=8,pow_initial=1, num_max_blocks=3))
print("\ngries")
models.append(neural_network_wproblem(start_input,trass_input,final_input,base=8,pow_initial=1, num_max_blocks=3))
print("\nproblem code")
models.append(neural_network_problem_code(problem_input,code_input,base=8,pow_initial=1, num_max_blocks=3))
print("\ncode")
models.append(neural_network_code(code_input,base=8,pow_initial=1, num_max_blocks=3))
# Out:
# problem all
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
#
# problem gries
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
#
# code gries
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
#
# gries
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
#
# problem code
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512
#
# code
# base 8 pow 1 num_max_blocks 3
# Encoder 1
# Block  0 512
# BottleNeck 64
# Decoder 1
# Block  0 512

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
from time import time
#tensorflow random state
tf.random.set_seed(2023)

times=[]
max_accuracies=[]
max_val_accuracies=[]
max_val_losses=[]
max_losses=[]
learning_rates=[]
Model_Xtrain=[Xp_train,Xcode_train,Xs_train,Xt_train,Xf_train]

for i,my_model in enumerate(models):
  print(models_names[i])

  problem_input=Input((768,))
  start_input=Input((768,))
  trass_input=Input((768,))
  final_input=Input((768,))

  patience=35

  my_model.compile(loss='sparse_categorical_crossentropy',
                optimizer=Adam(),
                metrics=['accuracy'])

  es = EarlyStopping(monitor='val_loss', mode='min', patience=patience)

  mc = ModelCheckpoint('/content/drive/MyDrive/UDENAR/ProyectosGrado/Errol/Ginna/ResultsGraph/ablations_finall_{0}.keras'.format(models_names[i]), monitor='val_loss', mode='min', save_best_only=True)
  reduce_lr = ReduceLROnPlateau(
      monitor='val_loss',
      factor=0.1,
      patience=patience//2,
      min_lr=1e-9,
      verbose=1
  )
  if(i==1):
    Model_Xtrain=[Xp_train,Xs_train,Xt_train,Xf_train]
  if(i==2):
    Model_Xtrain=[Xcode_train,Xs_train,Xt_train,Xf_train]
  if(i==3):
    Model_Xtrain=[Xs_train,Xt_train,Xf_train]
  if(i==4):
    Model_Xtrain=[Xp_train,Xcode_train]
  if(i==5):
    Model_Xtrain=[Xcode_train]


  time1=time()
  history=my_model.fit(Model_Xtrain,y_train,batch_size=100,epochs=1000,
            validation_split=0.2,callbacks=[es, mc,reduce_lr])
  time2=time()

  df_histories=pd.DataFrame(history.history)
  df_histories.to_csv('/content/drive/MyDrive/UDENAR/ProyectosGrado/Errol/Ginna/ResultsGraph/ablations_best_finall_{0}.csv'.format(models_names[i]))

  times.append(time2-time1)

  max_accuracies.append(max(history.history['accuracy']))
  max_val_accuracies.append(max(history.history['val_accuracy']))
  max_val_losses.append(max(history.history['val_loss']))
  max_losses.append(max(history.history['loss']))
  learning_rates.append(min(history.history['learning_rate']))

  print(f"{patience}")
  print("times=",time2-time1)
  print("max_val_accuracy",max(history.history['val_accuracy']))
  print("max_accuracy",max(history.history['accuracy']))


  print("max_val_loss",max(history.history['val_loss']))
  print("max_loss",max(history.history['loss']))
  print("learning_rate",min(history.history['learning_rate']))
# Out:
# problemall
# Epoch 1/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 35s 644ms/step - accuracy: 0.2278 - loss: 2.1968 - val_accuracy: 0.3321 - val_loss: 1.9579 - learning_rate: 0.0010
# Epoch 2/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.5050 - loss: 1.5729 - val_accuracy: 0.4693 - val_loss: 1.9097 - learning_rate: 0.0010
# Epoch 3/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5967 - loss: 1.4028 - val_accuracy: 0.4982 - val_loss: 1.8635 - learning_rate: 0.0010
# Epoch 4/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.6659 - loss: 1.2574 - val_accuracy: 0.5578 - val_loss: 1.7842 - learning_rate: 0.0010
# Epoch 5/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.7063 - loss: 1.1550 - val_accuracy: 0.5866 - val_loss: 1.6879 - learning_rate: 0.0010
# Epoch 6/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.7521 - loss: 1.0766 - val_accuracy: 0.7004 - val_loss: 1.5649 - learning_rate: 0.0010
# Epoch 7/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.7625 - loss: 1.0010 - val_accuracy: 0.6823 - val_loss: 1.4984 - learning_rate: 0.0010
# Epoch 8/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.8035 - loss: 0.9506 - val_accuracy: 0.7437 - val_loss: 1.3730 - learning_rate: 0.0010
# Epoch 9/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.8351 - loss: 0.8821 - val_accuracy: 0.7942 - val_loss: 1.2557 - learning_rate: 0.0010
# Epoch 10/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.8265 - loss: 0.8480 - val_accuracy: 0.7852 - val_loss: 1.1868 - learning_rate: 0.0010
# Epoch 11/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.8471 - loss: 0.8097 - val_accuracy: 0.8051 - val_loss: 1.0743 - learning_rate: 0.0010
# Epoch 12/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.8641 - loss: 0.7581 - val_accuracy: 0.7960 - val_loss: 1.0353 - learning_rate: 0.0010
# Epoch 13/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.8590 - loss: 0.7521 - val_accuracy: 0.8213 - val_loss: 0.9362 - learning_rate: 0.0010
# Epoch 14/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8759 - loss: 0.7015 - val_accuracy: 0.8303 - val_loss: 0.8696 - learning_rate: 0.0010
# Epoch 15/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.8831 - loss: 0.6776 - val_accuracy: 0.8412 - val_loss: 0.8264 - learning_rate: 0.0010
# Epoch 16/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.8854 - loss: 0.6635 - val_accuracy: 0.8394 - val_loss: 0.7906 - learning_rate: 0.0010
# Epoch 17/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8974 - loss: 0.6297 - val_accuracy: 0.8285 - val_loss: 0.8144 - learning_rate: 0.0010
# Epoch 18/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8967 - loss: 0.6143 - val_accuracy: 0.7942 - val_loss: 0.8139 - learning_rate: 0.0010
# Epoch 19/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9058 - loss: 0.5792 - val_accuracy: 0.8520 - val_loss: 0.6877 - learning_rate: 0.0010
# Epoch 20/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8959 - loss: 0.5630 - val_accuracy: 0.8159 - val_loss: 0.7676 - learning_rate: 0.0010
# Epoch 21/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9054 - loss: 0.5541 - val_accuracy: 0.8394 - val_loss: 0.6879 - learning_rate: 0.0010
# Epoch 22/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9210 - loss: 0.5196 - val_accuracy: 0.8412 - val_loss: 0.6924 - learning_rate: 0.0010
# Epoch 23/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9180 - loss: 0.5093 - val_accuracy: 0.8610 - val_loss: 0.6566 - learning_rate: 0.0010
# Epoch 24/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9255 - loss: 0.4805 - val_accuracy: 0.8773 - val_loss: 0.5893 - learning_rate: 0.0010
# Epoch 25/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9314 - loss: 0.4592 - val_accuracy: 0.8556 - val_loss: 0.6364 - learning_rate: 0.0010
# Epoch 26/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9292 - loss: 0.4571 - val_accuracy: 0.8285 - val_loss: 0.7024 - learning_rate: 0.0010
# Epoch 27/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9373 - loss: 0.4388 - val_accuracy: 0.8736 - val_loss: 0.5554 - learning_rate: 0.0010
# Epoch 28/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9374 - loss: 0.4199 - val_accuracy: 0.8755 - val_loss: 0.5358 - learning_rate: 0.0010
# Epoch 29/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9345 - loss: 0.4087 - val_accuracy: 0.8718 - val_loss: 0.5651 - learning_rate: 0.0010
# Epoch 30/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9451 - loss: 0.3917 - val_accuracy: 0.8899 - val_loss: 0.5107 - learning_rate: 0.0010
# Epoch 31/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9481 - loss: 0.3737 - val_accuracy: 0.8845 - val_loss: 0.5065 - learning_rate: 0.0010
# Epoch 32/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9477 - loss: 0.3677 - val_accuracy: 0.8755 - val_loss: 0.5030 - learning_rate: 0.0010
# Epoch 33/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - accuracy: 0.9536 - loss: 0.3539 - val_accuracy: 0.8827 - val_loss: 0.4848 - learning_rate: 0.0010
# Epoch 34/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9490 - loss: 0.3418 - val_accuracy: 0.8863 - val_loss: 0.4630 - learning_rate: 0.0010
# Epoch 35/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9528 - loss: 0.3390 - val_accuracy: 0.8917 - val_loss: 0.4570 - learning_rate: 0.0010
# Epoch 36/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9527 - loss: 0.3367 - val_accuracy: 0.8971 - val_loss: 0.4307 - learning_rate: 0.0010
# Epoch 37/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9465 - loss: 0.3310 - val_accuracy: 0.8953 - val_loss: 0.4632 - learning_rate: 0.0010
# Epoch 38/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9563 - loss: 0.3185 - val_accuracy: 0.8736 - val_loss: 0.5018 - learning_rate: 0.0010
# Epoch 39/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9646 - loss: 0.2963 - val_accuracy: 0.8736 - val_loss: 0.5394 - learning_rate: 0.0010
# Epoch 40/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9579 - loss: 0.2927 - val_accuracy: 0.9007 - val_loss: 0.4021 - learning_rate: 0.0010
# Epoch 41/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9470 - loss: 0.2946 - val_accuracy: 0.9061 - val_loss: 0.3900 - learning_rate: 0.0010
# Epoch 42/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9643 - loss: 0.2745 - val_accuracy: 0.9116 - val_loss: 0.3927 - learning_rate: 0.0010
# Epoch 43/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9709 - loss: 0.2607 - val_accuracy: 0.9097 - val_loss: 0.3964 - learning_rate: 0.0010
# Epoch 44/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9686 - loss: 0.2500 - val_accuracy: 0.9152 - val_loss: 0.3840 - learning_rate: 0.0010
# Epoch 45/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9644 - loss: 0.2610 - val_accuracy: 0.9134 - val_loss: 0.3735 - learning_rate: 0.0010
# Epoch 46/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9661 - loss: 0.2412 - val_accuracy: 0.9007 - val_loss: 0.3874 - learning_rate: 0.0010
# Epoch 47/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9689 - loss: 0.2362 - val_accuracy: 0.9079 - val_loss: 0.3733 - learning_rate: 0.0010
# Epoch 48/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9691 - loss: 0.2415 - val_accuracy: 0.9134 - val_loss: 0.3547 - learning_rate: 0.0010
# Epoch 49/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9702 - loss: 0.2368 - val_accuracy: 0.9152 - val_loss: 0.3505 - learning_rate: 0.0010
# Epoch 50/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9652 - loss: 0.2286 - val_accuracy: 0.9061 - val_loss: 0.3573 - learning_rate: 0.0010
# Epoch 51/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9712 - loss: 0.2249 - val_accuracy: 0.9116 - val_loss: 0.3731 - learning_rate: 0.0010
# Epoch 52/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9699 - loss: 0.2216 - val_accuracy: 0.9061 - val_loss: 0.3763 - learning_rate: 0.0010
# Epoch 53/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9653 - loss: 0.2144 - val_accuracy: 0.9061 - val_loss: 0.3489 - learning_rate: 0.0010
# Epoch 54/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9717 - loss: 0.2073 - val_accuracy: 0.9134 - val_loss: 0.3546 - learning_rate: 0.0010
# Epoch 55/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9728 - loss: 0.1997 - val_accuracy: 0.8971 - val_loss: 0.3603 - learning_rate: 0.0010
# Epoch 56/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9741 - loss: 0.2031 - val_accuracy: 0.9079 - val_loss: 0.3499 - learning_rate: 0.0010
# Epoch 57/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9813 - loss: 0.1858 - val_accuracy: 0.9116 - val_loss: 0.3441 - learning_rate: 0.0010
# Epoch 58/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9740 - loss: 0.1909 - val_accuracy: 0.9134 - val_loss: 0.3496 - learning_rate: 0.0010
# Epoch 59/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9742 - loss: 0.1824 - val_accuracy: 0.9170 - val_loss: 0.3275 - learning_rate: 0.0010
# Epoch 60/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9708 - loss: 0.1855 - val_accuracy: 0.9260 - val_loss: 0.3316 - learning_rate: 0.0010
# Epoch 61/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9780 - loss: 0.1748 - val_accuracy: 0.9134 - val_loss: 0.3197 - learning_rate: 0.0010
# Epoch 62/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9803 - loss: 0.1714 - val_accuracy: 0.9061 - val_loss: 0.3355 - learning_rate: 0.0010
# Epoch 63/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9807 - loss: 0.1693 - val_accuracy: 0.9170 - val_loss: 0.3308 - learning_rate: 0.0010
# Epoch 64/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9808 - loss: 0.1582 - val_accuracy: 0.9170 - val_loss: 0.3279 - learning_rate: 0.0010
# Epoch 65/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9834 - loss: 0.1628 - val_accuracy: 0.9152 - val_loss: 0.3262 - learning_rate: 0.0010
# Epoch 66/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9855 - loss: 0.1525 - val_accuracy: 0.9097 - val_loss: 0.3154 - learning_rate: 0.0010
# Epoch 67/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9804 - loss: 0.1508 - val_accuracy: 0.9152 - val_loss: 0.3278 - learning_rate: 0.0010
# Epoch 68/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9846 - loss: 0.1442 - val_accuracy: 0.9242 - val_loss: 0.3188 - learning_rate: 0.0010
# Epoch 69/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9841 - loss: 0.1474 - val_accuracy: 0.9170 - val_loss: 0.3244 - learning_rate: 0.0010
# Epoch 70/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9816 - loss: 0.1461 - val_accuracy: 0.9025 - val_loss: 0.3366 - learning_rate: 0.0010
# Epoch 71/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9803 - loss: 0.1450 - val_accuracy: 0.9152 - val_loss: 0.3225 - learning_rate: 0.0010
# Epoch 72/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9825 - loss: 0.1423 - val_accuracy: 0.9242 - val_loss: 0.3026 - learning_rate: 0.0010
# Epoch 73/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9867 - loss: 0.1375 - val_accuracy: 0.9134 - val_loss: 0.2978 - learning_rate: 0.0010
# Epoch 74/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9860 - loss: 0.1299 - val_accuracy: 0.9296 - val_loss: 0.3153 - learning_rate: 0.0010
# Epoch 75/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9812 - loss: 0.1370 - val_accuracy: 0.9260 - val_loss: 0.3030 - learning_rate: 0.0010
# Epoch 76/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9799 - loss: 0.1368 - val_accuracy: 0.9260 - val_loss: 0.2951 - learning_rate: 0.0010
# Epoch 77/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9807 - loss: 0.1312 - val_accuracy: 0.9224 - val_loss: 0.3103 - learning_rate: 0.0010
# Epoch 78/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9785 - loss: 0.1339 - val_accuracy: 0.9206 - val_loss: 0.3075 - learning_rate: 0.0010
# Epoch 79/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9827 - loss: 0.1251 - val_accuracy: 0.9152 - val_loss: 0.3294 - learning_rate: 0.0010
# Epoch 80/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9871 - loss: 0.1170 - val_accuracy: 0.9152 - val_loss: 0.3141 - learning_rate: 0.0010
# Epoch 81/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9856 - loss: 0.1224 - val_accuracy: 0.9170 - val_loss: 0.3161 - learning_rate: 0.0010
# Epoch 82/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9843 - loss: 0.1197 - val_accuracy: 0.9224 - val_loss: 0.2854 - learning_rate: 0.0010
# Epoch 83/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9848 - loss: 0.1188 - val_accuracy: 0.9242 - val_loss: 0.2953 - learning_rate: 0.0010
# Epoch 84/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9831 - loss: 0.1158 - val_accuracy: 0.9224 - val_loss: 0.3220 - learning_rate: 0.0010
# Epoch 85/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9866 - loss: 0.1162 - val_accuracy: 0.9134 - val_loss: 0.3084 - learning_rate: 0.0010
# Epoch 86/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9831 - loss: 0.1144 - val_accuracy: 0.9278 - val_loss: 0.2699 - learning_rate: 0.0010
# Epoch 87/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9856 - loss: 0.1157 - val_accuracy: 0.9224 - val_loss: 0.2710 - learning_rate: 0.0010
# Epoch 88/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9918 - loss: 0.1050 - val_accuracy: 0.9296 - val_loss: 0.2883 - learning_rate: 0.0010
# Epoch 89/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9836 - loss: 0.1118 - val_accuracy: 0.9260 - val_loss: 0.3115 - learning_rate: 0.0010
# Epoch 90/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9867 - loss: 0.1038 - val_accuracy: 0.9332 - val_loss: 0.2882 - learning_rate: 0.0010
# Epoch 91/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9885 - loss: 0.1017 - val_accuracy: 0.9260 - val_loss: 0.3033 - learning_rate: 0.0010
# Epoch 92/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9870 - loss: 0.1033 - val_accuracy: 0.9278 - val_loss: 0.2936 - learning_rate: 0.0010
# Epoch 93/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9810 - loss: 0.1039 - val_accuracy: 0.9206 - val_loss: 0.3033 - learning_rate: 0.0010
# Epoch 94/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9867 - loss: 0.1032 - val_accuracy: 0.9116 - val_loss: 0.3127 - learning_rate: 0.0010
# Epoch 95/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9909 - loss: 0.0969 - val_accuracy: 0.9278 - val_loss: 0.3138 - learning_rate: 0.0010
# Epoch 96/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9900 - loss: 0.0906 - val_accuracy: 0.9260 - val_loss: 0.2901 - learning_rate: 0.0010
# Epoch 97/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9893 - loss: 0.0964 - val_accuracy: 0.9260 - val_loss: 0.2882 - learning_rate: 0.0010
# Epoch 98/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9906 - loss: 0.0866 - val_accuracy: 0.9296 - val_loss: 0.2927 - learning_rate: 0.0010
# Epoch 99/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9860 - loss: 0.0934 - val_accuracy: 0.9242 - val_loss: 0.2670 - learning_rate: 0.0010
# Epoch 100/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9867 - loss: 0.0924 - val_accuracy: 0.9368 - val_loss: 0.2689 - learning_rate: 0.0010
# Epoch 101/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9924 - loss: 0.0775 - val_accuracy: 0.9368 - val_loss: 0.2716 - learning_rate: 0.0010
# Epoch 102/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9913 - loss: 0.0873 - val_accuracy: 0.9314 - val_loss: 0.2760 - learning_rate: 0.0010
# Epoch 103/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9899 - loss: 0.0849 - val_accuracy: 0.9242 - val_loss: 0.2679 - learning_rate: 0.0010
# Epoch 104/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9901 - loss: 0.0823 - val_accuracy: 0.9350 - val_loss: 0.2645 - learning_rate: 0.0010
# Epoch 105/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9889 - loss: 0.0819 - val_accuracy: 0.9296 - val_loss: 0.3005 - learning_rate: 0.0010
# Epoch 106/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9877 - loss: 0.0884 - val_accuracy: 0.9260 - val_loss: 0.2853 - learning_rate: 0.0010
# Epoch 107/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9942 - loss: 0.0818 - val_accuracy: 0.9260 - val_loss: 0.2778 - learning_rate: 0.0010
# Epoch 108/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9924 - loss: 0.0781 - val_accuracy: 0.9386 - val_loss: 0.2735 - learning_rate: 0.0010
# Epoch 109/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9931 - loss: 0.0741 - val_accuracy: 0.9404 - val_loss: 0.2862 - learning_rate: 0.0010
# Epoch 110/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9920 - loss: 0.0729 - val_accuracy: 0.9314 - val_loss: 0.2686 - learning_rate: 0.0010
# Epoch 111/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9927 - loss: 0.0700 - val_accuracy: 0.9368 - val_loss: 0.2781 - learning_rate: 0.0010
# Epoch 112/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9940 - loss: 0.0711 - val_accuracy: 0.9188 - val_loss: 0.2901 - learning_rate: 0.0010
# Epoch 113/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9960 - loss: 0.0618 - val_accuracy: 0.9386 - val_loss: 0.2673 - learning_rate: 0.0010
# Epoch 114/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9915 - loss: 0.0665 - val_accuracy: 0.9314 - val_loss: 0.2967 - learning_rate: 0.0010
# Epoch 115/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9905 - loss: 0.0710 - val_accuracy: 0.9350 - val_loss: 0.2805 - learning_rate: 0.0010
# Epoch 116/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9882 - loss: 0.0719 - val_accuracy: 0.9314 - val_loss: 0.2813 - learning_rate: 0.0010
# Epoch 117/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9903 - loss: 0.0733 - val_accuracy: 0.9188 - val_loss: 0.2940 - learning_rate: 0.0010
# Epoch 118/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9927 - loss: 0.0670 - val_accuracy: 0.9278 - val_loss: 0.2848 - learning_rate: 0.0010
# Epoch 119/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9937 - loss: 0.0683 - val_accuracy: 0.9260 - val_loss: 0.2834 - learning_rate: 0.0010
# Epoch 120/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9896 - loss: 0.0723 - val_accuracy: 0.9350 - val_loss: 0.2872 - learning_rate: 0.0010
# Epoch 121/1000
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9904 - loss: 0.0724
# Epoch 121: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9905 - loss: 0.0721 - val_accuracy: 0.9206 - val_loss: 0.3222 - learning_rate: 0.0010
# Epoch 122/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9952 - loss: 0.0660 - val_accuracy: 0.9242 - val_loss: 0.2986 - learning_rate: 1.0000e-04
# Epoch 123/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9934 - loss: 0.0606 - val_accuracy: 0.9296 - val_loss: 0.2789 - learning_rate: 1.0000e-04
# Epoch 124/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9943 - loss: 0.0573 - val_accuracy: 0.9350 - val_loss: 0.2657 - learning_rate: 1.0000e-04
# Epoch 125/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9957 - loss: 0.0559 - val_accuracy: 0.9350 - val_loss: 0.2600 - learning_rate: 1.0000e-04
# Epoch 126/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9956 - loss: 0.0524 - val_accuracy: 0.9350 - val_loss: 0.2544 - learning_rate: 1.0000e-04
# Epoch 127/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9963 - loss: 0.0547 - val_accuracy: 0.9386 - val_loss: 0.2500 - learning_rate: 1.0000e-04
# Epoch 128/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9981 - loss: 0.0520 - val_accuracy: 0.9404 - val_loss: 0.2516 - learning_rate: 1.0000e-04
# Epoch 129/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9975 - loss: 0.0536 - val_accuracy: 0.9422 - val_loss: 0.2510 - learning_rate: 1.0000e-04
# Epoch 130/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9954 - loss: 0.0556 - val_accuracy: 0.9458 - val_loss: 0.2499 - learning_rate: 1.0000e-04
# Epoch 131/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9968 - loss: 0.0528 - val_accuracy: 0.9458 - val_loss: 0.2496 - learning_rate: 1.0000e-04
# Epoch 132/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9910 - loss: 0.0531 - val_accuracy: 0.9440 - val_loss: 0.2497 - learning_rate: 1.0000e-04
# Epoch 133/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9985 - loss: 0.0482 - val_accuracy: 0.9422 - val_loss: 0.2484 - learning_rate: 1.0000e-04
# Epoch 134/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9979 - loss: 0.0466 - val_accuracy: 0.9440 - val_loss: 0.2481 - learning_rate: 1.0000e-04
# Epoch 135/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9973 - loss: 0.0530 - val_accuracy: 0.9440 - val_loss: 0.2483 - learning_rate: 1.0000e-04
# Epoch 136/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9970 - loss: 0.0482 - val_accuracy: 0.9386 - val_loss: 0.2494 - learning_rate: 1.0000e-04
# Epoch 137/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9957 - loss: 0.0493 - val_accuracy: 0.9386 - val_loss: 0.2514 - learning_rate: 1.0000e-04
# Epoch 138/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9969 - loss: 0.0434 - val_accuracy: 0.9368 - val_loss: 0.2523 - learning_rate: 1.0000e-04
# Epoch 139/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9972 - loss: 0.0465 - val_accuracy: 0.9404 - val_loss: 0.2515 - learning_rate: 1.0000e-04
# Epoch 140/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9993 - loss: 0.0451 - val_accuracy: 0.9440 - val_loss: 0.2509 - learning_rate: 1.0000e-04
# Epoch 141/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9980 - loss: 0.0458 - val_accuracy: 0.9422 - val_loss: 0.2494 - learning_rate: 1.0000e-04
# Epoch 142/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9984 - loss: 0.0450 - val_accuracy: 0.9422 - val_loss: 0.2487 - learning_rate: 1.0000e-04
# Epoch 143/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9964 - loss: 0.0477 - val_accuracy: 0.9422 - val_loss: 0.2475 - learning_rate: 1.0000e-04
# Epoch 144/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9989 - loss: 0.0440 - val_accuracy: 0.9422 - val_loss: 0.2461 - learning_rate: 1.0000e-04
# Epoch 145/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9991 - loss: 0.0431 - val_accuracy: 0.9440 - val_loss: 0.2474 - learning_rate: 1.0000e-04
# Epoch 146/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9973 - loss: 0.0446 - val_accuracy: 0.9440 - val_loss: 0.2474 - learning_rate: 1.0000e-04
# Epoch 147/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9951 - loss: 0.0493 - val_accuracy: 0.9440 - val_loss: 0.2453 - learning_rate: 1.0000e-04
# Epoch 148/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9979 - loss: 0.0448 - val_accuracy: 0.9404 - val_loss: 0.2468 - learning_rate: 1.0000e-04
# Epoch 149/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9981 - loss: 0.0435 - val_accuracy: 0.9386 - val_loss: 0.2458 - learning_rate: 1.0000e-04
# Epoch 150/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9991 - loss: 0.0427 - val_accuracy: 0.9422 - val_loss: 0.2458 - learning_rate: 1.0000e-04
# Epoch 151/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9981 - loss: 0.0422 - val_accuracy: 0.9422 - val_loss: 0.2476 - learning_rate: 1.0000e-04
# Epoch 152/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9965 - loss: 0.0456 - val_accuracy: 0.9422 - val_loss: 0.2475 - learning_rate: 1.0000e-04
# Epoch 153/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9980 - loss: 0.0434 - val_accuracy: 0.9422 - val_loss: 0.2491 - learning_rate: 1.0000e-04
# Epoch 154/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9987 - loss: 0.0419 - val_accuracy: 0.9422 - val_loss: 0.2497 - learning_rate: 1.0000e-04
# Epoch 155/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9978 - loss: 0.0425 - val_accuracy: 0.9404 - val_loss: 0.2503 - learning_rate: 1.0000e-04
# Epoch 156/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9967 - loss: 0.0442 - val_accuracy: 0.9422 - val_loss: 0.2506 - learning_rate: 1.0000e-04
# Epoch 157/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9976 - loss: 0.0411 - val_accuracy: 0.9422 - val_loss: 0.2496 - learning_rate: 1.0000e-04
# Epoch 158/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9989 - loss: 0.0396 - val_accuracy: 0.9422 - val_loss: 0.2499 - learning_rate: 1.0000e-04
# Epoch 159/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9979 - loss: 0.0428 - val_accuracy: 0.9422 - val_loss: 0.2467 - learning_rate: 1.0000e-04
# Epoch 160/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9984 - loss: 0.0440 - val_accuracy: 0.9404 - val_loss: 0.2451 - learning_rate: 1.0000e-04
# Epoch 161/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9983 - loss: 0.0398 - val_accuracy: 0.9368 - val_loss: 0.2489 - learning_rate: 1.0000e-04
# Epoch 162/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9963 - loss: 0.0422 - val_accuracy: 0.9386 - val_loss: 0.2477 - learning_rate: 1.0000e-04
# Epoch 163/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9987 - loss: 0.0392 - val_accuracy: 0.9440 - val_loss: 0.2469 - learning_rate: 1.0000e-04
# Epoch 164/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9985 - loss: 0.0413 - val_accuracy: 0.9440 - val_loss: 0.2465 - learning_rate: 1.0000e-04
# Epoch 165/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9962 - loss: 0.0416 - val_accuracy: 0.9440 - val_loss: 0.2481 - learning_rate: 1.0000e-04
# Epoch 166/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9995 - loss: 0.0384 - val_accuracy: 0.9440 - val_loss: 0.2479 - learning_rate: 1.0000e-04
# Epoch 167/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9976 - loss: 0.0422 - val_accuracy: 0.9440 - val_loss: 0.2466 - learning_rate: 1.0000e-04
# Epoch 168/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9981 - loss: 0.0393 - val_accuracy: 0.9440 - val_loss: 0.2449 - learning_rate: 1.0000e-04
# Epoch 169/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9987 - loss: 0.0389 - val_accuracy: 0.9458 - val_loss: 0.2440 - learning_rate: 1.0000e-04
# Epoch 170/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9976 - loss: 0.0402 - val_accuracy: 0.9440 - val_loss: 0.2461 - learning_rate: 1.0000e-04
# Epoch 171/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9970 - loss: 0.0429 - val_accuracy: 0.9458 - val_loss: 0.2463 - learning_rate: 1.0000e-04
# Epoch 172/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9995 - loss: 0.0392 - val_accuracy: 0.9440 - val_loss: 0.2447 - learning_rate: 1.0000e-04
# Epoch 173/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9990 - loss: 0.0381 - val_accuracy: 0.9440 - val_loss: 0.2446 - learning_rate: 1.0000e-04
# Epoch 174/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9988 - loss: 0.0371 - val_accuracy: 0.9440 - val_loss: 0.2478 - learning_rate: 1.0000e-04
# Epoch 175/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9981 - loss: 0.0395 - val_accuracy: 0.9422 - val_loss: 0.2470 - learning_rate: 1.0000e-04
# Epoch 176/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9993 - loss: 0.0367 - val_accuracy: 0.9440 - val_loss: 0.2467 - learning_rate: 1.0000e-04
# Epoch 177/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9979 - loss: 0.0373 - val_accuracy: 0.9458 - val_loss: 0.2433 - learning_rate: 1.0000e-04
# Epoch 178/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9986 - loss: 0.0404 - val_accuracy: 0.9458 - val_loss: 0.2442 - learning_rate: 1.0000e-04
# Epoch 179/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9973 - loss: 0.0406 - val_accuracy: 0.9458 - val_loss: 0.2472 - learning_rate: 1.0000e-04
# Epoch 180/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9990 - loss: 0.0392 - val_accuracy: 0.9440 - val_loss: 0.2503 - learning_rate: 1.0000e-04
# Epoch 181/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9981 - loss: 0.0383 - val_accuracy: 0.9458 - val_loss: 0.2468 - learning_rate: 1.0000e-04
# Epoch 182/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9982 - loss: 0.0363 - val_accuracy: 0.9458 - val_loss: 0.2457 - learning_rate: 1.0000e-04
# Epoch 183/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9982 - loss: 0.0387 - val_accuracy: 0.9458 - val_loss: 0.2471 - learning_rate: 1.0000e-04
# Epoch 184/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9976 - loss: 0.0377 - val_accuracy: 0.9458 - val_loss: 0.2478 - learning_rate: 1.0000e-04
# Epoch 185/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9981 - loss: 0.0379 - val_accuracy: 0.9440 - val_loss: 0.2487 - learning_rate: 1.0000e-04
# Epoch 186/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9987 - loss: 0.0376 - val_accuracy: 0.9440 - val_loss: 0.2488 - learning_rate: 1.0000e-04
# Epoch 187/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9994 - loss: 0.0352 - val_accuracy: 0.9422 - val_loss: 0.2509 - learning_rate: 1.0000e-04
# Epoch 188/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9971 - loss: 0.0370 - val_accuracy: 0.9440 - val_loss: 0.2521 - learning_rate: 1.0000e-04
# Epoch 189/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9979 - loss: 0.0358 - val_accuracy: 0.9458 - val_loss: 0.2493 - learning_rate: 1.0000e-04
# Epoch 190/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9972 - loss: 0.0391 - val_accuracy: 0.9477 - val_loss: 0.2464 - learning_rate: 1.0000e-04
# Epoch 191/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9994 - loss: 0.0363 - val_accuracy: 0.9440 - val_loss: 0.2468 - learning_rate: 1.0000e-04
# Epoch 192/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9979 - loss: 0.0371 - val_accuracy: 0.9440 - val_loss: 0.2468 - learning_rate: 1.0000e-04
# Epoch 193/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9977 - loss: 0.0351 - val_accuracy: 0.9440 - val_loss: 0.2460 - learning_rate: 1.0000e-04
# Epoch 194/1000
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9977 - loss: 0.0352
# Epoch 194: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9976 - loss: 0.0352 - val_accuracy: 0.9458 - val_loss: 0.2435 - learning_rate: 1.0000e-04
# Epoch 195/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9985 - loss: 0.0356 - val_accuracy: 0.9458 - val_loss: 0.2433 - learning_rate: 1.0000e-05
# Epoch 196/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9997 - loss: 0.0344 - val_accuracy: 0.9477 - val_loss: 0.2433 - learning_rate: 1.0000e-05
# Epoch 197/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9960 - loss: 0.0381 - val_accuracy: 0.9477 - val_loss: 0.2433 - learning_rate: 1.0000e-05
# Epoch 198/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9996 - loss: 0.0349 - val_accuracy: 0.9477 - val_loss: 0.2434 - learning_rate: 1.0000e-05
# Epoch 199/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9985 - loss: 0.0367 - val_accuracy: 0.9477 - val_loss: 0.2440 - learning_rate: 1.0000e-05
# Epoch 200/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9984 - loss: 0.0352 - val_accuracy: 0.9477 - val_loss: 0.2447 - learning_rate: 1.0000e-05
# Epoch 201/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9980 - loss: 0.0369 - val_accuracy: 0.9477 - val_loss: 0.2450 - learning_rate: 1.0000e-05
# Epoch 202/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9989 - loss: 0.0351 - val_accuracy: 0.9458 - val_loss: 0.2454 - learning_rate: 1.0000e-05
# Epoch 203/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9990 - loss: 0.0341 - val_accuracy: 0.9458 - val_loss: 0.2454 - learning_rate: 1.0000e-05
# Epoch 204/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9986 - loss: 0.0373 - val_accuracy: 0.9477 - val_loss: 0.2456 - learning_rate: 1.0000e-05
# Epoch 205/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9977 - loss: 0.0387 - val_accuracy: 0.9477 - val_loss: 0.2455 - learning_rate: 1.0000e-05
# Epoch 206/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9987 - loss: 0.0345 - val_accuracy: 0.9477 - val_loss: 0.2456 - learning_rate: 1.0000e-05
# Epoch 207/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9998 - loss: 0.0350 - val_accuracy: 0.9477 - val_loss: 0.2455 - learning_rate: 1.0000e-05
# Epoch 208/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9995 - loss: 0.0355 - val_accuracy: 0.9477 - val_loss: 0.2456 - learning_rate: 1.0000e-05
# Epoch 209/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9986 - loss: 0.0363 - val_accuracy: 0.9477 - val_loss: 0.2454 - learning_rate: 1.0000e-05
# Epoch 210/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9994 - loss: 0.0336 - val_accuracy: 0.9477 - val_loss: 0.2454 - learning_rate: 1.0000e-05
# Epoch 211/1000
# 21/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9959 - loss: 0.0391
# Epoch 211: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9961 - loss: 0.0388 - val_accuracy: 0.9477 - val_loss: 0.2451 - learning_rate: 1.0000e-05
# Epoch 212/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9996 - loss: 0.0324 - val_accuracy: 0.9477 - val_loss: 0.2452 - learning_rate: 1.0000e-06
# Epoch 213/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9997 - loss: 0.0348 - val_accuracy: 0.9477 - val_loss: 0.2451 - learning_rate: 1.0000e-06
# Epoch 214/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9991 - loss: 0.0354 - val_accuracy: 0.9477 - val_loss: 0.2448 - learning_rate: 1.0000e-06
# Epoch 215/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9990 - loss: 0.0362 - val_accuracy: 0.9477 - val_loss: 0.2446 - learning_rate: 1.0000e-06
# Epoch 216/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9999 - loss: 0.0339 - val_accuracy: 0.9477 - val_loss: 0.2443 - learning_rate: 1.0000e-06
# Epoch 217/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9990 - loss: 0.0339 - val_accuracy: 0.9477 - val_loss: 0.2442 - learning_rate: 1.0000e-06
# Epoch 218/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9992 - loss: 0.0366 - val_accuracy: 0.9477 - val_loss: 0.2438 - learning_rate: 1.0000e-06
# Epoch 219/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9987 - loss: 0.0353 - val_accuracy: 0.9477 - val_loss: 0.2435 - learning_rate: 1.0000e-06
# Epoch 220/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9991 - loss: 0.0349 - val_accuracy: 0.9477 - val_loss: 0.2439 - learning_rate: 1.0000e-06
# Epoch 221/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9976 - loss: 0.0354 - val_accuracy: 0.9477 - val_loss: 0.2439 - learning_rate: 1.0000e-06
# Epoch 222/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9995 - loss: 0.0343 - val_accuracy: 0.9477 - val_loss: 0.2438 - learning_rate: 1.0000e-06
# Epoch 223/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9993 - loss: 0.0354 - val_accuracy: 0.9477 - val_loss: 0.2437 - learning_rate: 1.0000e-06
# Epoch 224/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9993 - loss: 0.0333 - val_accuracy: 0.9477 - val_loss: 0.2436 - learning_rate: 1.0000e-06
# Epoch 225/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9990 - loss: 0.0370 - val_accuracy: 0.9477 - val_loss: 0.2436 - learning_rate: 1.0000e-06
# Epoch 226/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9990 - loss: 0.0359 - val_accuracy: 0.9477 - val_loss: 0.2439 - learning_rate: 1.0000e-06
# Epoch 227/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9976 - loss: 0.0362 - val_accuracy: 0.9477 - val_loss: 0.2440 - learning_rate: 1.0000e-06
# Epoch 228/1000
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9979 - loss: 0.0373
# Epoch 228: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9978 - loss: 0.0373 - val_accuracy: 0.9477 - val_loss: 0.2440 - learning_rate: 1.0000e-06
# Epoch 229/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9991 - loss: 0.0344 - val_accuracy: 0.9477 - val_loss: 0.2444 - learning_rate: 1.0000e-07
# Epoch 230/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9989 - loss: 0.0347 - val_accuracy: 0.9477 - val_loss: 0.2445 - learning_rate: 1.0000e-07
# Epoch 231/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0345 - val_accuracy: 0.9477 - val_loss: 0.2443 - learning_rate: 1.0000e-07
# Epoch 232/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9977 - loss: 0.0361 - val_accuracy: 0.9477 - val_loss: 0.2444 - learning_rate: 1.0000e-07
# 35
# times= 144.71732449531555
# max_val_accuracy 0.9476534128189087
# max_accuracy 1.0
# max_val_loss 1.9579122066497803
# max_loss 2.019821882247925
# learning_rate 1.000000082740371e-07
# problem_gries
# Epoch 1/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 30s 619ms/step - accuracy: 0.2324 - loss: 2.1355 - val_accuracy: 0.5325 - val_loss: 1.8967 - learning_rate: 0.0010
# Epoch 2/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.5106 - loss: 1.5681 - val_accuracy: 0.5668 - val_loss: 1.8095 - learning_rate: 0.0010
# Epoch 3/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.5920 - loss: 1.3815 - val_accuracy: 0.6444 - val_loss: 1.7209 - learning_rate: 0.0010
# Epoch 4/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.6720 - loss: 1.2550 - val_accuracy: 0.6606 - val_loss: 1.6410 - learning_rate: 0.0010
# Epoch 5/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.7084 - loss: 1.1645 - val_accuracy: 0.6570 - val_loss: 1.5542 - learning_rate: 0.0010
# Epoch 6/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.7416 - loss: 1.0825 - val_accuracy: 0.6877 - val_loss: 1.4812 - learning_rate: 0.0010
# Epoch 7/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.7679 - loss: 1.0283 - val_accuracy: 0.7437 - val_loss: 1.3604 - learning_rate: 0.0010
# Epoch 8/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.7857 - loss: 0.9680 - val_accuracy: 0.7581 - val_loss: 1.2614 - learning_rate: 0.0010
# Epoch 9/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8023 - loss: 0.9334 - val_accuracy: 0.7744 - val_loss: 1.1626 - learning_rate: 0.0010
# Epoch 10/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8236 - loss: 0.8724 - val_accuracy: 0.7978 - val_loss: 1.0862 - learning_rate: 0.0010
# Epoch 11/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8275 - loss: 0.8500 - val_accuracy: 0.8014 - val_loss: 0.9962 - learning_rate: 0.0010
# Epoch 12/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8475 - loss: 0.8025 - val_accuracy: 0.8032 - val_loss: 0.9311 - learning_rate: 0.0010
# Epoch 13/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8695 - loss: 0.7544 - val_accuracy: 0.8105 - val_loss: 0.8907 - learning_rate: 0.0010
# Epoch 14/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.8674 - loss: 0.7299 - val_accuracy: 0.8303 - val_loss: 0.8276 - learning_rate: 0.0010
# Epoch 15/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.8766 - loss: 0.7089 - val_accuracy: 0.8466 - val_loss: 0.7686 - learning_rate: 0.0010
# Epoch 16/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8807 - loss: 0.6601 - val_accuracy: 0.8357 - val_loss: 0.7254 - learning_rate: 0.0010
# Epoch 17/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8875 - loss: 0.6472 - val_accuracy: 0.8502 - val_loss: 0.7136 - learning_rate: 0.0010
# Epoch 18/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8851 - loss: 0.6319 - val_accuracy: 0.8339 - val_loss: 0.6758 - learning_rate: 0.0010
# Epoch 19/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8926 - loss: 0.6135 - val_accuracy: 0.8520 - val_loss: 0.6577 - learning_rate: 0.0010
# Epoch 20/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9011 - loss: 0.5827 - val_accuracy: 0.8574 - val_loss: 0.6207 - learning_rate: 0.0010
# Epoch 21/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9084 - loss: 0.5460 - val_accuracy: 0.8574 - val_loss: 0.6031 - learning_rate: 0.0010
# Epoch 22/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9088 - loss: 0.5485 - val_accuracy: 0.8610 - val_loss: 0.5878 - learning_rate: 0.0010
# Epoch 23/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9207 - loss: 0.5174 - val_accuracy: 0.8791 - val_loss: 0.5653 - learning_rate: 0.0010
# Epoch 24/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9018 - loss: 0.5187 - val_accuracy: 0.8700 - val_loss: 0.5535 - learning_rate: 0.0010
# Epoch 25/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9108 - loss: 0.4982 - val_accuracy: 0.8664 - val_loss: 0.5502 - learning_rate: 0.0010
# Epoch 26/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9131 - loss: 0.4870 - val_accuracy: 0.8700 - val_loss: 0.5426 - learning_rate: 0.0010
# Epoch 27/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9202 - loss: 0.4701 - val_accuracy: 0.8755 - val_loss: 0.5076 - learning_rate: 0.0010
# Epoch 28/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9272 - loss: 0.4386 - val_accuracy: 0.8736 - val_loss: 0.5041 - learning_rate: 0.0010
# Epoch 29/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9247 - loss: 0.4398 - val_accuracy: 0.8755 - val_loss: 0.5046 - learning_rate: 0.0010
# Epoch 30/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9311 - loss: 0.4242 - val_accuracy: 0.8827 - val_loss: 0.4891 - learning_rate: 0.0010
# Epoch 31/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9312 - loss: 0.4118 - val_accuracy: 0.8736 - val_loss: 0.4962 - learning_rate: 0.0010
# Epoch 32/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9333 - loss: 0.3951 - val_accuracy: 0.8989 - val_loss: 0.4676 - learning_rate: 0.0010
# Epoch 33/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9456 - loss: 0.3762 - val_accuracy: 0.8953 - val_loss: 0.4545 - learning_rate: 0.0010
# Epoch 34/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9349 - loss: 0.3815 - val_accuracy: 0.8881 - val_loss: 0.4555 - learning_rate: 0.0010
# Epoch 35/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9390 - loss: 0.3728 - val_accuracy: 0.8989 - val_loss: 0.4335 - learning_rate: 0.0010
# Epoch 36/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9416 - loss: 0.3578 - val_accuracy: 0.8917 - val_loss: 0.4275 - learning_rate: 0.0010
# Epoch 37/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9444 - loss: 0.3373 - val_accuracy: 0.9007 - val_loss: 0.4232 - learning_rate: 0.0010
# Epoch 38/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9502 - loss: 0.3477 - val_accuracy: 0.8881 - val_loss: 0.4243 - learning_rate: 0.0010
# Epoch 39/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9504 - loss: 0.3232 - val_accuracy: 0.8845 - val_loss: 0.4360 - learning_rate: 0.0010
# Epoch 40/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9538 - loss: 0.3140 - val_accuracy: 0.9007 - val_loss: 0.4242 - learning_rate: 0.0010
# Epoch 41/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9495 - loss: 0.3159 - val_accuracy: 0.8989 - val_loss: 0.4121 - learning_rate: 0.0010
# Epoch 42/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9496 - loss: 0.3135 - val_accuracy: 0.8953 - val_loss: 0.4021 - learning_rate: 0.0010
# Epoch 43/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9514 - loss: 0.3000 - val_accuracy: 0.8953 - val_loss: 0.4062 - learning_rate: 0.0010
# Epoch 44/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9564 - loss: 0.2821 - val_accuracy: 0.8899 - val_loss: 0.3926 - learning_rate: 0.0010
# Epoch 45/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9502 - loss: 0.2887 - val_accuracy: 0.9007 - val_loss: 0.3923 - learning_rate: 0.0010
# Epoch 46/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9544 - loss: 0.2880 - val_accuracy: 0.9025 - val_loss: 0.3790 - learning_rate: 0.0010
# Epoch 47/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9657 - loss: 0.2686 - val_accuracy: 0.8989 - val_loss: 0.3837 - learning_rate: 0.0010
# Epoch 48/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9567 - loss: 0.2719 - val_accuracy: 0.9007 - val_loss: 0.3820 - learning_rate: 0.0010
# Epoch 49/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9549 - loss: 0.2699 - val_accuracy: 0.9188 - val_loss: 0.3530 - learning_rate: 0.0010
# Epoch 50/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9603 - loss: 0.2576 - val_accuracy: 0.9116 - val_loss: 0.3545 - learning_rate: 0.0010
# Epoch 51/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9660 - loss: 0.2536 - val_accuracy: 0.9206 - val_loss: 0.3446 - learning_rate: 0.0010
# Epoch 52/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9692 - loss: 0.2396 - val_accuracy: 0.9134 - val_loss: 0.3542 - learning_rate: 0.0010
# Epoch 53/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9602 - loss: 0.2345 - val_accuracy: 0.9061 - val_loss: 0.3620 - learning_rate: 0.0010
# Epoch 54/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9636 - loss: 0.2292 - val_accuracy: 0.9170 - val_loss: 0.3433 - learning_rate: 0.0010
# Epoch 55/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9636 - loss: 0.2314 - val_accuracy: 0.9170 - val_loss: 0.3514 - learning_rate: 0.0010
# Epoch 56/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9605 - loss: 0.2309 - val_accuracy: 0.9061 - val_loss: 0.3470 - learning_rate: 0.0010
# Epoch 57/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9688 - loss: 0.2174 - val_accuracy: 0.9097 - val_loss: 0.3470 - learning_rate: 0.0010
# Epoch 58/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9687 - loss: 0.2185 - val_accuracy: 0.9152 - val_loss: 0.3457 - learning_rate: 0.0010
# Epoch 59/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9667 - loss: 0.2102 - val_accuracy: 0.9188 - val_loss: 0.3391 - learning_rate: 0.0010
# Epoch 60/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9702 - loss: 0.2053 - val_accuracy: 0.9097 - val_loss: 0.3379 - learning_rate: 0.0010
# Epoch 61/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9652 - loss: 0.2067 - val_accuracy: 0.9134 - val_loss: 0.3421 - learning_rate: 0.0010
# Epoch 62/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9769 - loss: 0.1851 - val_accuracy: 0.9097 - val_loss: 0.3427 - learning_rate: 0.0010
# Epoch 63/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9654 - loss: 0.2042 - val_accuracy: 0.9152 - val_loss: 0.3229 - learning_rate: 0.0010
# Epoch 64/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9719 - loss: 0.1887 - val_accuracy: 0.9116 - val_loss: 0.3324 - learning_rate: 0.0010
# Epoch 65/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9661 - loss: 0.1933 - val_accuracy: 0.9188 - val_loss: 0.3295 - learning_rate: 0.0010
# Epoch 66/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9647 - loss: 0.2001 - val_accuracy: 0.9206 - val_loss: 0.3378 - learning_rate: 0.0010
# Epoch 67/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9766 - loss: 0.1832 - val_accuracy: 0.9278 - val_loss: 0.3260 - learning_rate: 0.0010
# Epoch 68/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9763 - loss: 0.1751 - val_accuracy: 0.9206 - val_loss: 0.3233 - learning_rate: 0.0010
# Epoch 69/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9810 - loss: 0.1650 - val_accuracy: 0.9152 - val_loss: 0.3254 - learning_rate: 0.0010
# Epoch 70/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9765 - loss: 0.1680 - val_accuracy: 0.9134 - val_loss: 0.3244 - learning_rate: 0.0010
# Epoch 71/1000
# ...
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9820 - loss: 0.0761 - val_accuracy: 0.9116 - val_loss: 0.3171 - learning_rate: 1.0000e-04
# Epoch 154/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9821 - loss: 0.0792 - val_accuracy: 0.9134 - val_loss: 0.3145 - learning_rate: 1.0000e-04
# Epoch 155/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9817 - loss: 0.0742 - val_accuracy: 0.9134 - val_loss: 0.3169 - learning_rate: 1.0000e-04
# Epoch 156/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9814 - loss: 0.0873 - val_accuracy: 0.9116 - val_loss: 0.3129 - learning_rate: 1.0000e-04
# Epoch 157/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9844 - loss: 0.0838 - val_accuracy: 0.9170 - val_loss: 0.3125 - learning_rate: 1.0000e-04
# Epoch 158/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9798 - loss: 0.0774 - val_accuracy: 0.9170 - val_loss: 0.3148 - learning_rate: 1.0000e-04
# Epoch 159/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9832 - loss: 0.0780 - val_accuracy: 0.9134 - val_loss: 0.3163 - learning_rate: 1.0000e-04
# Epoch 160/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9895 - loss: 0.0657 - val_accuracy: 0.9152 - val_loss: 0.3138 - learning_rate: 1.0000e-04
# Epoch 161/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9794 - loss: 0.0785 - val_accuracy: 0.9134 - val_loss: 0.3124 - learning_rate: 1.0000e-04
# Epoch 162/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9872 - loss: 0.0740 - val_accuracy: 0.9134 - val_loss: 0.3050 - learning_rate: 1.0000e-04
# Epoch 163/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9835 - loss: 0.0723 - val_accuracy: 0.9116 - val_loss: 0.3051 - learning_rate: 1.0000e-04
# Epoch 164/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9826 - loss: 0.0757 - val_accuracy: 0.9116 - val_loss: 0.3119 - learning_rate: 1.0000e-04
# Epoch 165/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9826 - loss: 0.0744 - val_accuracy: 0.9170 - val_loss: 0.3097 - learning_rate: 1.0000e-04
# Epoch 166/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9802 - loss: 0.0745 - val_accuracy: 0.9152 - val_loss: 0.3077 - learning_rate: 1.0000e-04
# Epoch 167/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9833 - loss: 0.0725 - val_accuracy: 0.9188 - val_loss: 0.2998 - learning_rate: 1.0000e-04
# Epoch 168/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9831 - loss: 0.0705 - val_accuracy: 0.9134 - val_loss: 0.3037 - learning_rate: 1.0000e-04
# Epoch 169/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9811 - loss: 0.0782 - val_accuracy: 0.9097 - val_loss: 0.3106 - learning_rate: 1.0000e-04
# Epoch 170/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9840 - loss: 0.0740 - val_accuracy: 0.9170 - val_loss: 0.3140 - learning_rate: 1.0000e-04
# Epoch 171/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9828 - loss: 0.0787 - val_accuracy: 0.9116 - val_loss: 0.3111 - learning_rate: 1.0000e-04
# Epoch 172/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9820 - loss: 0.0742 - val_accuracy: 0.9061 - val_loss: 0.3086 - learning_rate: 1.0000e-04
# Epoch 173/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9869 - loss: 0.0710 - val_accuracy: 0.9116 - val_loss: 0.3095 - learning_rate: 1.0000e-04
# Epoch 174/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9863 - loss: 0.0692 - val_accuracy: 0.9188 - val_loss: 0.3040 - learning_rate: 1.0000e-04
# Epoch 175/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9802 - loss: 0.0784 - val_accuracy: 0.9188 - val_loss: 0.3000 - learning_rate: 1.0000e-04
# Epoch 176/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9819 - loss: 0.0746 - val_accuracy: 0.9170 - val_loss: 0.2978 - learning_rate: 1.0000e-04
# Epoch 177/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9815 - loss: 0.0731 - val_accuracy: 0.9170 - val_loss: 0.3033 - learning_rate: 1.0000e-04
# Epoch 178/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9794 - loss: 0.0771 - val_accuracy: 0.9206 - val_loss: 0.3015 - learning_rate: 1.0000e-04
# Epoch 179/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9837 - loss: 0.0741 - val_accuracy: 0.9260 - val_loss: 0.2972 - learning_rate: 1.0000e-04
# Epoch 180/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9812 - loss: 0.0730 - val_accuracy: 0.9152 - val_loss: 0.3053 - learning_rate: 1.0000e-04
# Epoch 181/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9875 - loss: 0.0670 - val_accuracy: 0.9206 - val_loss: 0.3078 - learning_rate: 1.0000e-04
# Epoch 182/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9845 - loss: 0.0622 - val_accuracy: 0.9152 - val_loss: 0.3081 - learning_rate: 1.0000e-04
# Epoch 183/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9835 - loss: 0.0713 - val_accuracy: 0.9206 - val_loss: 0.3038 - learning_rate: 1.0000e-04
# Epoch 184/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9865 - loss: 0.0699 - val_accuracy: 0.9116 - val_loss: 0.3107 - learning_rate: 1.0000e-04
# Epoch 185/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9869 - loss: 0.0659 - val_accuracy: 0.9152 - val_loss: 0.3095 - learning_rate: 1.0000e-04
# Epoch 186/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9838 - loss: 0.0723 - val_accuracy: 0.9116 - val_loss: 0.3088 - learning_rate: 1.0000e-04
# Epoch 187/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9881 - loss: 0.0642 - val_accuracy: 0.9116 - val_loss: 0.3136 - learning_rate: 1.0000e-04
# Epoch 188/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9800 - loss: 0.0733 - val_accuracy: 0.9206 - val_loss: 0.3112 - learning_rate: 1.0000e-04
# Epoch 189/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9887 - loss: 0.0582 - val_accuracy: 0.9206 - val_loss: 0.3070 - learning_rate: 1.0000e-04
# Epoch 190/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9863 - loss: 0.0617 - val_accuracy: 0.9242 - val_loss: 0.2984 - learning_rate: 1.0000e-04
# Epoch 191/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9851 - loss: 0.0671 - val_accuracy: 0.9170 - val_loss: 0.2997 - learning_rate: 1.0000e-04
# Epoch 192/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9857 - loss: 0.0667 - val_accuracy: 0.9152 - val_loss: 0.3006 - learning_rate: 1.0000e-04
# Epoch 193/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9830 - loss: 0.0758 - val_accuracy: 0.9278 - val_loss: 0.2979 - learning_rate: 1.0000e-04
# Epoch 194/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9853 - loss: 0.0632 - val_accuracy: 0.9242 - val_loss: 0.2972 - learning_rate: 1.0000e-04
# Epoch 195/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9850 - loss: 0.0627 - val_accuracy: 0.9206 - val_loss: 0.2958 - learning_rate: 1.0000e-04
# Epoch 196/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9863 - loss: 0.0657 - val_accuracy: 0.9206 - val_loss: 0.2915 - learning_rate: 1.0000e-04
# Epoch 197/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9858 - loss: 0.0651 - val_accuracy: 0.9170 - val_loss: 0.2982 - learning_rate: 1.0000e-04
# Epoch 198/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9877 - loss: 0.0618 - val_accuracy: 0.9134 - val_loss: 0.2902 - learning_rate: 1.0000e-04
# Epoch 199/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9890 - loss: 0.0637 - val_accuracy: 0.9152 - val_loss: 0.2896 - learning_rate: 1.0000e-04
# Epoch 200/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9822 - loss: 0.0693 - val_accuracy: 0.9152 - val_loss: 0.2926 - learning_rate: 1.0000e-04
# Epoch 201/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9818 - loss: 0.0665 - val_accuracy: 0.9152 - val_loss: 0.2982 - learning_rate: 1.0000e-04
# Epoch 202/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9816 - loss: 0.0703 - val_accuracy: 0.9278 - val_loss: 0.2984 - learning_rate: 1.0000e-04
# Epoch 203/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9876 - loss: 0.0614 - val_accuracy: 0.9224 - val_loss: 0.3014 - learning_rate: 1.0000e-04
# Epoch 204/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9857 - loss: 0.0669 - val_accuracy: 0.9260 - val_loss: 0.2937 - learning_rate: 1.0000e-04
# Epoch 205/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9879 - loss: 0.0588 - val_accuracy: 0.9242 - val_loss: 0.2868 - learning_rate: 1.0000e-04
# Epoch 206/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9908 - loss: 0.0604 - val_accuracy: 0.9224 - val_loss: 0.2884 - learning_rate: 1.0000e-04
# Epoch 207/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9883 - loss: 0.0610 - val_accuracy: 0.9206 - val_loss: 0.2935 - learning_rate: 1.0000e-04
# Epoch 208/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9836 - loss: 0.0630 - val_accuracy: 0.9260 - val_loss: 0.2910 - learning_rate: 1.0000e-04
# Epoch 209/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9879 - loss: 0.0576 - val_accuracy: 0.9278 - val_loss: 0.2907 - learning_rate: 1.0000e-04
# Epoch 210/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9905 - loss: 0.0585 - val_accuracy: 0.9152 - val_loss: 0.3040 - learning_rate: 1.0000e-04
# Epoch 211/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9879 - loss: 0.0577 - val_accuracy: 0.9170 - val_loss: 0.3117 - learning_rate: 1.0000e-04
# Epoch 212/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9883 - loss: 0.0576 - val_accuracy: 0.9224 - val_loss: 0.3001 - learning_rate: 1.0000e-04
# Epoch 213/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9879 - loss: 0.0582 - val_accuracy: 0.9278 - val_loss: 0.2943 - learning_rate: 1.0000e-04
# Epoch 214/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9831 - loss: 0.0652 - val_accuracy: 0.9260 - val_loss: 0.2893 - learning_rate: 1.0000e-04
# Epoch 215/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9865 - loss: 0.0657 - val_accuracy: 0.9278 - val_loss: 0.2854 - learning_rate: 1.0000e-04
# Epoch 216/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9857 - loss: 0.0599 - val_accuracy: 0.9224 - val_loss: 0.2918 - learning_rate: 1.0000e-04
# Epoch 217/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9868 - loss: 0.0582 - val_accuracy: 0.9224 - val_loss: 0.2949 - learning_rate: 1.0000e-04
# Epoch 218/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9885 - loss: 0.0584 - val_accuracy: 0.9206 - val_loss: 0.3046 - learning_rate: 1.0000e-04
# Epoch 219/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9899 - loss: 0.0582 - val_accuracy: 0.9278 - val_loss: 0.2912 - learning_rate: 1.0000e-04
# Epoch 220/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9837 - loss: 0.0695 - val_accuracy: 0.9278 - val_loss: 0.2920 - learning_rate: 1.0000e-04
# Epoch 221/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9917 - loss: 0.0502 - val_accuracy: 0.9332 - val_loss: 0.2956 - learning_rate: 1.0000e-04
# Epoch 222/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9879 - loss: 0.0589 - val_accuracy: 0.9314 - val_loss: 0.3042 - learning_rate: 1.0000e-04
# Epoch 223/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9884 - loss: 0.0587 - val_accuracy: 0.9332 - val_loss: 0.2993 - learning_rate: 1.0000e-04
# Epoch 224/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9903 - loss: 0.0564 - val_accuracy: 0.9314 - val_loss: 0.2939 - learning_rate: 1.0000e-04
# Epoch 225/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9859 - loss: 0.0586 - val_accuracy: 0.9242 - val_loss: 0.2955 - learning_rate: 1.0000e-04
# Epoch 226/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9890 - loss: 0.0554 - val_accuracy: 0.9242 - val_loss: 0.3021 - learning_rate: 1.0000e-04
# Epoch 227/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9850 - loss: 0.0639 - val_accuracy: 0.9242 - val_loss: 0.2959 - learning_rate: 1.0000e-04
# Epoch 228/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9903 - loss: 0.0565 - val_accuracy: 0.9260 - val_loss: 0.2947 - learning_rate: 1.0000e-04
# Epoch 229/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9849 - loss: 0.0625 - val_accuracy: 0.9260 - val_loss: 0.2882 - learning_rate: 1.0000e-04
# Epoch 230/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9900 - loss: 0.0547 - val_accuracy: 0.9278 - val_loss: 0.2948 - learning_rate: 1.0000e-04
# Epoch 231/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9886 - loss: 0.0541 - val_accuracy: 0.9314 - val_loss: 0.2959 - learning_rate: 1.0000e-04
# Epoch 232/1000
# 14/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0642
# Epoch 232: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9877 - loss: 0.0618 - val_accuracy: 0.9350 - val_loss: 0.2916 - learning_rate: 1.0000e-04
# Epoch 233/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9865 - loss: 0.0533 - val_accuracy: 0.9350 - val_loss: 0.2929 - learning_rate: 1.0000e-05
# Epoch 234/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9889 - loss: 0.0505 - val_accuracy: 0.9350 - val_loss: 0.2928 - learning_rate: 1.0000e-05
# Epoch 235/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9885 - loss: 0.0545 - val_accuracy: 0.9350 - val_loss: 0.2933 - learning_rate: 1.0000e-05
# Epoch 236/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9900 - loss: 0.0544 - val_accuracy: 0.9368 - val_loss: 0.2933 - learning_rate: 1.0000e-05
# Epoch 237/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9895 - loss: 0.0545 - val_accuracy: 0.9350 - val_loss: 0.2944 - learning_rate: 1.0000e-05
# Epoch 238/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9868 - loss: 0.0576 - val_accuracy: 0.9332 - val_loss: 0.2948 - learning_rate: 1.0000e-05
# Epoch 239/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9916 - loss: 0.0534 - val_accuracy: 0.9332 - val_loss: 0.2959 - learning_rate: 1.0000e-05
# Epoch 240/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9869 - loss: 0.0566 - val_accuracy: 0.9332 - val_loss: 0.2956 - learning_rate: 1.0000e-05
# Epoch 241/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9910 - loss: 0.0509 - val_accuracy: 0.9314 - val_loss: 0.2954 - learning_rate: 1.0000e-05
# Epoch 242/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9947 - loss: 0.0465 - val_accuracy: 0.9332 - val_loss: 0.2957 - learning_rate: 1.0000e-05
# Epoch 243/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9883 - loss: 0.0539 - val_accuracy: 0.9332 - val_loss: 0.2947 - learning_rate: 1.0000e-05
# Epoch 244/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9877 - loss: 0.0569 - val_accuracy: 0.9332 - val_loss: 0.2937 - learning_rate: 1.0000e-05
# Epoch 245/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9873 - loss: 0.0579 - val_accuracy: 0.9332 - val_loss: 0.2932 - learning_rate: 1.0000e-05
# Epoch 246/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9940 - loss: 0.0462 - val_accuracy: 0.9314 - val_loss: 0.2930 - learning_rate: 1.0000e-05
# Epoch 247/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9871 - loss: 0.0587 - val_accuracy: 0.9350 - val_loss: 0.2917 - learning_rate: 1.0000e-05
# Epoch 248/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9914 - loss: 0.0516 - val_accuracy: 0.9350 - val_loss: 0.2910 - learning_rate: 1.0000e-05
# Epoch 249/1000
# 14/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9908 - loss: 0.0489
# Epoch 249: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9896 - loss: 0.0523 - val_accuracy: 0.9368 - val_loss: 0.2912 - learning_rate: 1.0000e-05
# Epoch 250/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9911 - loss: 0.0514 - val_accuracy: 0.9368 - val_loss: 0.2907 - learning_rate: 1.0000e-06
# 35
# times= 70.08385181427002
# max_val_accuracy 0.9368231296539307
# max_accuracy 0.9927700161933899
# max_val_loss 2.0486316680908203
# max_loss 2.196782350540161
# learning_rate 1.0000001111620804e-06

# %%
df_histories=pd.DataFrame({"times":times,"max_accuracies":max_accuracies,"max_val_accuracies":max_val_accuracies,"max_val_losses":max_val_losses,"max_losses":max_losses,"learning_rates":learning_rates})
df_histories.to_csv('/content/drive/MyDrive/UDENAR/ProyectosGrado/Errol/Ginna/ResultsGraph/ablations_finall.csv')

# %%
df_histories
# Out:
#         times  max_accuracies  max_val_accuracies  max_val_losses  max_losses  \
# 0  144.717324        1.000000            0.947653        1.957912    2.019822
# 1  106.195788        0.998644            0.940433        1.896729    1.993182
# 2  117.460625        1.000000            0.953069        1.942038    2.025564
# 3   98.425345        0.998644            0.940433        1.953331    1.988816
# 4   80.881043        0.985088            0.907942        2.009059    2.213736
# 5   70.083852        0.992770            0.936823        2.048632    2.196782
#
#    learning_rates
# 0    1.000000e-07
# 1    1.000000e-06
# 2    1.000000e-06
# 3    1.000000e-06
# 4    1.000000e-07
# 5    1.000000e-06

# %%
from sklearn.metrics import matthews_corrcoef, precision_recall_curve, auc
from sklearn.preprocessing import label_binarize
import numpy as np

def calculate_mcc_multiclass(y_true, y_pred_probs):
    y_pred_labels = np.argmax(y_pred_probs, axis=1)
    # Convertir etiquetas verdaderas one-hot a etiquetas enteras si es necesario
    #y_true_labels = np.argmax(y_true, axis=1) if y_true.ndim > 1 else y_true
    return matthews_corrcoef(y_true, y_pred_labels)

def calculate_auc_pr_multiclass(y_true, y_pred_probs, average='macro'):
    n_classes = y_pred_probs.shape[1]
    #y_true_labels = np.argmax(y_true, axis=1) if y_true.ndim > 1 else y_true
    y_true_bin = label_binarize(y_true, classes=range(n_classes))

    auc_pr_list = []
    for i in range(n_classes):
        precision, recall, _ = precision_recall_curve(y_true_bin[:, i], y_pred_probs[:, i])
        auc_pr_list.append(auc(recall, precision))

    if average == 'macro':
        return np.mean(auc_pr_list)
    elif average == 'weighted':
        class_counts = y_true_bin.sum(axis=0)
        return np.average(auc_pr_list, weights=class_counts)
    else:
        return auc_pr_list

# %%
from tensorflow import keras
accuracies_predict=[]
loss_predict=[]
times_predict=[]
mccs_predict=[]
aucpr_predict=[]

Model_Xtest=[Xp_test,Xcode_test,Xs_test,Xt_test,Xf_test]
for i,my_model in enumerate(models):
  model=keras.models.load_model('/content/drive/MyDrive/UDENAR/ProyectosGrado/Errol/Ginna/ResultsGraph/ablations_finall_{0}.keras'.format(models_names[i]))
  if(i==1):
    Model_Xtest=[Xp_test,Xs_test,Xt_test,Xf_test]
  if(i==2):
    Model_Xtest=[Xcode_test,Xs_test,Xt_test,Xf_test]
  if(i==3):
    Model_Xtest=[Xs_test,Xt_test,Xf_test]
  if(i==4):
    Model_Xtest=[Xp_test,Xcode_test]
  if(i==5):
    Model_Xtest=[Xcode_test]

  evaluate=model.evaluate(Model_Xtest,y_test)

  t1=time()
  y_pred=model.predict(Model_Xtest)
  t2=time()
  mcc=calculate_mcc_multiclass(y_test, y_pred)
  auc_pr=calculate_auc_pr_multiclass(y_test, y_pred)

  times_predict.append(t2-t1)
  accuracies_predict.append(evaluate[1])
  loss_predict.append(evaluate[0])
  mccs_predict.append(mcc)
  aucpr_predict.append(auc_pr)


  accuracy=evaluate[1]
  loss=evaluate[0]

  print("accuracy",accuracy)
  print("loss",loss)
  print("mcc",mcc)
  print("auc_pr",auc_pr)
  print("time predict",t2-t1)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.9437 - loss: 0.2053
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step
# accuracy 0.9349710941314697
# loss 0.2586961090564728
# mcc 0.9131520814930358
# auc_pr 0.8967345898717543
# time predict 2.0086426734924316
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.9411 - loss: 0.2442
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step
# accuracy 0.9306358098983765
# loss 0.2975481450557709
# mcc 0.9073842674211551
# auc_pr 0.888445391138643
# time predict 1.6127400398254395
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9455 - loss: 0.1947
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step
# accuracy 0.9320809245109558
# loss 0.25026023387908936
# mcc 0.9093666321956615
# auc_pr 0.9016988006274875
# time predict 1.5622568130493164
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9252 - loss: 0.2368
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step
# accuracy 0.9205202460289001
# loss 0.2785130441188812
# mcc 0.8938154828923313
# auc_pr 0.8922277423176179
# time predict 1.2819085121154785
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9080 - loss: 0.3172
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# accuracy 0.9031791687011719
# loss 0.36563894152641296
# mcc 0.8705034114738855
# auc_pr 0.886796724137777
# time predict 1.0421109199523926
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9168 - loss: 0.3406
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# accuracy 0.9075144529342651
# loss 0.3785313069820404
# mcc 0.8764406746068185
# auc_pr 0.8958740669676131
# time predict 0.7328145503997803
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:1033: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(

# %%
df_histories['accuracies_predict']=accuracies_predict
df_histories['loss_predict']=loss_predict
df_histories['times_predict']=times_predict
df_histories['mccs']=mccs_predict
df_histories['aucpr']=aucpr_predict
df_histories.to_csv('/content/drive/MyDrive/UDENAR/ProyectosGrado/Errol/Ginna/ResultsGraph/ablation_best_finall_predict.csv')

# %%
df_histories['model']=models_names

# %%
df_histories
# Out:
#         times  max_accuracies  max_val_accuracies  max_val_losses  max_losses  \
# 0  144.717324        1.000000            0.947653        1.957912    2.019822
# 1  106.195788        0.998644            0.940433        1.896729    1.993182
# 2  117.460625        1.000000            0.953069        1.942038    2.025564
# 3   98.425345        0.998644            0.940433        1.953331    1.988816
# 4   80.881043        0.985088            0.907942        2.009059    2.213736
# 5   70.083852        0.992770            0.936823        2.048632    2.196782
#
#    learning_rates  accuracies_predict  loss_predict  times_predict      mccs  \
# 0    1.000000e-07            0.934971      0.258696       2.008643  0.913152
# 1    1.000000e-06            0.930636      0.297548       1.612740  0.907384
# 2    1.000000e-06            0.932081      0.250260       1.562257  0.909367
# 3    1.000000e-06            0.920520      0.278513       1.281909  0.893815
# 4    1.000000e-07            0.903179      0.365639       1.042111  0.870503
# 5    1.000000e-06            0.907514      0.378531       0.732815  0.876441
#
#       aucpr          model
# 0  0.896735     problemall
# 1  0.888445  problem_gries
# 2  0.901699     code_gries
# 3  0.892228          gries
# 4  0.886797   problem_code
# 5  0.895874           code

# %%
df_histories[(df_histories['aucpr']>0.89)]
# Out:
#         times  max_accuracies  max_val_accuracies  max_val_losses  max_losses  \
# 0  144.717324        1.000000            0.947653        1.957912    2.019822
# 2  117.460625        1.000000            0.953069        1.942038    2.025564
# 3   98.425345        0.998644            0.940433        1.953331    1.988816
# 5   70.083852        0.992770            0.936823        2.048632    2.196782
#
#    learning_rates  accuracies_predict  loss_predict  times_predict      mccs  \
# 0    1.000000e-07            0.934971      0.258696       2.008643  0.913152
# 2    1.000000e-06            0.932081      0.250260       1.562257  0.909367
# 3    1.000000e-06            0.920520      0.278513       1.281909  0.893815
# 5    1.000000e-06            0.907514      0.378531       0.732815  0.876441
#
#       aucpr       model
# 0  0.896735  problemall
# 2  0.901699  code_gries
# 3  0.892228       gries
# 5  0.895874        code

# %%
df_histories[(df_histories['aucpr']>0.89)&(df_histories['max_accuracies']-df_histories['max_val_accuracies']<0.06)]
# Out:
#         times  max_accuracies  max_val_accuracies  max_val_losses  max_losses  \
# 0  144.717324        1.000000            0.947653        1.957912    2.019822
# 2  117.460625        1.000000            0.953069        1.942038    2.025564
# 3   98.425345        0.998644            0.940433        1.953331    1.988816
# 5   70.083852        0.992770            0.936823        2.048632    2.196782
#
#    learning_rates  accuracies_predict  loss_predict  times_predict      mccs  \
# 0    1.000000e-07            0.934971      0.258696       2.008643  0.913152
# 2    1.000000e-06            0.932081      0.250260       1.562257  0.909367
# 3    1.000000e-06            0.920520      0.278513       1.281909  0.893815
# 5    1.000000e-06            0.907514      0.378531       0.732815  0.876441
#
#       aucpr       model
# 0  0.896735  problemall
# 2  0.901699  code_gries
# 3  0.892228       gries
# 5  0.895874        code

# %% [markdown]
# Early stoping 40 the best
